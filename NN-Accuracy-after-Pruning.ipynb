# %%
# Imports

########################################################################
# Python Standard Libraries
import os
import multiprocessing
from timeit import default_timer as timer
import random
import math

########################################################################
# Numpy Library
import numpy as np # linear algebra

########################################################################
# Pandas Library
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

########################################################################
# MATPLOT Library
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
# %matplotlib inline

########################################################################
# SKLearn Library
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_recall_curve, classification_report, confusion_matrix, average_precision_score, roc_curve, auc, multilabel_confusion_matrix

########################################################################
# SCIPY Library
from scipy.stats import gaussian_kde
import scipy.stats as st


########################################################################
# Keras Library
from keras.models import Sequential
from keras.layers import Dense

########################################################################
# Init random seed
#seed = 13
#np.random.seed(seed)

# %%
# Utility functions
########################################################################
# Print system information
def print_system_info():
    mem_bytes = os.sysconf('SC_PAGE_SIZE') * os.sysconf('SC_PHYS_PAGES')  # e.g. 4015976448
    mem_gib = mem_bytes/(1024.**3)  # e.g. 3.74
    print("{:<23}{:f} GB".format('RAM:', mem_gib))
    print("{:<23}{:d}".format('CORES:', multiprocessing.cpu_count()))
    # !lscpu

########################################################################
# Walk through input files
def print_input_files():
    # Input data files are available in the "../input/" directory.
    for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            print(os.path.join(dirname, filename))

########################################################################
# Dump text files
def dump_text_file(fname):
    with open(fname, 'r') as f:
        print(f.read())

########################################################################
# Dump CSV files
def dump_csv_file(fname, count=5):
    # count: 0 - column names only, -1 - all rows, default = 5 rows max
    df = pd.read_csv(fname)
    if count < 0:
        count = df.shape[0]
    return df.head(count)

########################################################################
# Dataset related functions
ds_nbaiot = '/kaggle/input/nbaiot-dataset'
dn_nbaiot = ['Danmini_Doorbell', 'Ecobee_Thermostat', 'Ennio_Doorbell', 'Philips_B120N10_Baby_Monitor', 'Provision_PT_737E_Security_Camera', 'Provision_PT_838_Security_Camera', 'Samsung_SNH_1011_N_Webcam', 'SimpleHome_XCS7_1002_WHT_Security_Camera', 'SimpleHome_XCS7_1003_WHT_Security_Camera']

def fname(ds, f):
    if '.csv' not in f:
        f = f'{f}.csv'
    return os.path.join(ds, f)

def fname_nbaiot(f):
    return fname(ds_nbaiot, f)

def get_nbaiot_device_files():
    nbaiot_all_files = dump_csv_file(fname_nbaiot('data_summary'), -1)
    nbaiot_all_files = nbaiot_all_files.iloc[:,0:1].values
    device_id = 1
    indices = []
    for j in range(len(nbaiot_all_files)):
        if str(device_id) not in str(nbaiot_all_files[j]):
            indices.append(j)
            device_id += 1
    nbaiot_device_files = np.split(nbaiot_all_files, indices)
    return nbaiot_device_files

def get_nbaiot_device_data(device_id, count_norm=-1, count_anom=-1):
    if device_id < 1 or device_id > 9:
        assert False, "Please provide a valid device ID 1-9, both inclusive"
    if count_anom == -1:
        count_anom = count_norm
    device_index = device_id -1
    device_files = get_nbaiot_device_files()
    device_file = device_files[device_index]
    df = pd.DataFrame()
    y = []
    for i in range(len(device_file)):
        fname = str(device_file[i][0])
        df_c = pd.read_csv(fname_nbaiot(fname))
        count = count_anom
        if 'benign' in fname:
            count = count_norm
        count = min(count, df_c.shape[0]) if count >=0 else df_c.shape[0]
        rows = count
        print("processing", fname, "rows =", rows)
        y_np = np.ones(rows) if 'benign' in fname else np.zeros(rows)
        y.extend(y_np.tolist())
        df = pd.concat([df.iloc[:,:].reset_index(drop=True),
                      df_c.iloc[:rows,:].reset_index(drop=True)], axis=0)
    X = df.iloc[:,:].values
    y = np.array(y)
    Xdf = df
    return (X, y, Xdf)

def get_nbaiot_devices_data():
    devices_data = []
    for i in range(9):
        device_id = i + 1
        (X, y) = get_nbaiot_device_data(device_id)
        devices_data.append((X, y))
    return devices_data
#print_input_files()
print_system_info()
# Out:
# RAM:                   18.571461 GB
# CORES:                 4
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              4
# On-line CPU(s) list: 0-3
# Thread(s) per core:  2
# Core(s) per socket:  2
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           AuthenticAMD
# CPU family:          23
# Model:               49
# Model name:          AMD EPYC 7B12
# Stepping:            0
# CPU MHz:             2250.000
# BogoMIPS:            4500.00
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            512K
# L3 cache:            16384K
# NUMA node0 CPU(s):   0-3
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid

# %%
def remove_correlated_features(df, threshold):
    df = df.copy()
    # Create correlation matrix
    corr_matrix = df.corr().abs()

    # Select upper triangle of correlation matrix
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

    # Find features with correlation greater than a threshold
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

    # Drop features 
    df.drop(to_drop, axis=1, inplace=True)
    return df.iloc[:,:].values

def mark_important_features(vector, pc_keep): # pc_keep is the percentage (0-100) of labels to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    important_bool = (vector >= th)
    important_int = important_bool.astype(int)
    return important_int

def select_features(X, X_norm, X_anom, threshold):
    rows_n = X_norm.shape[0]
    rows_a = X_anom.shape[0]
    if rows_n == 0 or rows_a == 0:
        return X

    y_norm = np.ones(rows_n)
    y_anom = -1 * np.ones(rows_a)

    reg_n = LinearRegression(fit_intercept=False)
    reg_n.fit(X_norm, y_norm)
    coef_n = abs(reg_n.coef_)
    n = mark_important_features(coef_n, threshold)

    reg_a = LinearRegression(fit_intercept=False)
    reg_a.fit(X_anom, y_anom)
    coef_a = abs(reg_a.coef_)
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel

# %%
def create_binary_classifier(hidden_layers, input_dim):
    layers = []
    for hl in hidden_layers:
        if hl > 0:
            layers.append(hl)

    layer_count = len(layers)
    assert layer_count >= 1, 'at least 1 non-zero hidden layer is needed'
    model = Sequential()
    model.add(Dense(layers[0],input_dim=input_dim,activation='relu'))
    for i in range(1, layer_count):
        model.add(Dense(layers[i],activation='relu'))

    model.add(Dense(1,activation='sigmoid'))
    #model.summary()
    model.compile(loss = 'binary_crossentropy',
             optimizer ='adam',metrics=['accuracy'])
    return model

# %%
def compute_time_complexity_single_pass(neurons_input, structure, neurons_output):
    count_hidden_layers = len(structure)
    neurons = [neurons_input, *structure, neurons_output]
    complexity = 0
    for i in range(count_hidden_layers + 1):
        complexity += neurons[i] * neurons[i+1]
    return complexity

# %%
def keep_mask(vector, pc_keep): # pc_keep is the percentage (0-100) of items to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    mask_bool = (vector >= th)
    mask_int = mask_bool.astype(int)
    return (mask_bool, mask_int)

# %%
'''
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel
'''
# Out:
# '\n    a = mark_important_features(coef_a, threshold)\n   \n    mask = np.bitwise_or(n,a)\n    mask = mask == 1 # convert to Boolean\n    X_sel = X[:, mask]\n    return X_sel\n'

# %%
def analyze_ranks(model, threshold):
    w_d = 0
    b_d = 0
    layer_count = len(model.layers)
    layer_ranks = []
    new_structure = []
    for i in range(layer_count-1):
        (w_c, b_c) = model.layers[i+1].get_weights() # current weigths and biases
        rows = w_c.shape[0]
        cols = w_c.shape[1]
        w_c_abs = np.absolute(w_c)
        rank_neurons = np.sum(w_c_abs, axis=1) / cols
        rank_layer = np.sum(rank_neurons) / rows
        layer_ranks.append(rank_layer)
        (mask_bool, mask_int) = keep_mask(rank_neurons, threshold)
        new_neuron_count = np.sum(mask_int)
        new_structure.append(new_neuron_count)
        #print(f'{i+1}: {rank_neurons.shape} {rank_layer} {mask_int} {new_neuron_count}')
    layer_ranks = np.array(layer_ranks)
    new_structure = np.array(new_structure)
    (mask_bool, mask_int) = keep_mask(layer_ranks, threshold)
    new_structure = new_structure[mask_bool]
    #new_structure_masked = new_structure
    #print(f'layer mask: {mask_int} {new_structure}')
    return new_structure

# %%
model = None
def compute_report(title, model, X, y):
    y_pred = model.predict(X)
    y_pred = (y_pred > 0.25)
    #print(y_pred)
    #y_pred[y_pred <= 0] = -1 # convert negative values as 0 for anomaly
    #y_pred[y_pred > 0] = 1 # convert positive values as 1 for normal
    acc = accuracy_score(y, y_pred)
    tn, fp, fn, tp = confusion_matrix(y, y_pred, labels=[0,1]).ravel()
    cr = classification_report(y, y_pred)
    print("title,acc,tn,fp,fn,tp")
    print(f'{title}-cm,{acc:.2f},{tn},{fp},{fn},{tp}')
    #print(f'{cr}')
    results = model.evaluate(X, y, verbose=0)
    print(f'{title}-eval,{results}')
    return results[1] # accuracy

def rank_computation(title, X, y, structure, fc):
    global model
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    print (f"========{title}========")
    feature_count = X.shape[1]
    print(f'Features={feature_count}')
    print(f'NN Structure: layers={len(structure)}, neurons: {structure}')
    complexity = compute_time_complexity_single_pass(fc, structure, 1)
    print(f'complexity: {complexity}')
    model = create_binary_classifier(structure, feature_count)
    model.fit(X_train,y_train,epochs=150,batch_size=10,verbose=0)
    #analyze_ranks(model, 95)
    acc_t = compute_report('training', model, X_train, y_train)
    acc_v = compute_report('validation', model, X_test, y_test)
    return (complexity, acc_t, acc_v)

# %%
output_title = ''
output_cplx_all_devices = []  # time complexity
output_acc_t_all_devices = [] # training accuracy
output_acc_v_all_devices = [] # validation accuracy

# %%
debug_flag = True

# %%
if debug_flag:
    count_norm = 1000
    count_anom = 100
    #device_indices = [0]
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]
else:
    count_norm = -1
    count_anom = -1
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]

structures = {
    '0': [97, 48, 73, 58, 64, 53, 83],
    '1': [88, 52, 66, 58, 75],
    '2': [57, 31, 43, 38, 34, 49],
    '3': [101, 46, 67, 55, 60, 50, 75],
    '4': [87, 43, 58, 52, 47, 75],
    '5': [88, 44, 58, 52, 48, 75],
    '6': [59, 32, 44, 39, 35, 50],
    '7': [76, 48, 59, 53, 67],
    '8': [88, 48, 59, 53, 76]
}

fcs = [47, 47, 59, 51, 40, 42, 56, 56, 56]
for i in device_indices:
    global output_title
    device_index = i
    device_id = device_index + 1
    device_name = dn_nbaiot[device_index]
    (X, y, Xdf) = get_nbaiot_device_data(device_id, count_norm, count_anom)
    X = remove_correlated_features(Xdf, 0.98)
    X_std = StandardScaler().fit_transform(X)
    indices_norm = np.where(y >= 0.5)
    indices_anom = np.where(y <= 0.5)
    X_norm_all = X_std[indices_norm]
    X_anom_all = X_std[indices_anom]
    X_std = select_features(X_std, X_norm_all, X_anom_all,75)
    fc = fcs[i]
    print(f'############################[{i+1} - {device_name}]##########################')
    (complexity, acc_t, acc_v) = rank_computation(device_name, X_std, y, structures.get(f'{i}'), fc)
    thresholds = [100, 99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88, 87, 86, 85]
    output_title = 'device_name'
    output_cplx = f'{device_name}'
    output_acc_t = f'{device_name}'
    output_acc_v = f'{device_name}'
    main_model = [model]
    main_model = main_model[0]
    for th_i in range(30):
        threshold = 100 - th_i
        main_model = model
        output_title = f'{output_title},{threshold}'
        new_structure = analyze_ranks(main_model, threshold)
        new_complexity = compute_time_complexity_single_pass(fc, new_structure, 1)
        print("........................................")
        print(f'Th={threshold}, Revised NN Structure: layers={len(new_structure)}, neurons: {new_structure}, complexity: {new_complexity}')
        samples = 4
        (avg_complexity, avg_acc_t, avg_acc_v) = (0., 0., 0.)
        for k in range(samples):
            (complexity, acc_t, acc_v) = rank_computation(f'{device_name}-{threshold}', X_std, y, new_structure, fc)
            avg_complexity += complexity
            avg_acc_t += acc_t
            avg_acc_v += acc_v

        avg_complexity = avg_complexity / samples
        avg_acc_t = avg_acc_t / samples
        avg_acc_v = avg_acc_v / samples

        output_cplx = f'{output_cplx},{avg_complexity}'
        output_acc_t = f'{output_acc_t},{avg_acc_t}'
        output_acc_v = f'{output_acc_v},{avg_acc_v}'
    output_cplx_all_devices.append(output_cplx)
    output_acc_t_all_devices.append(output_acc_t)
    output_acc_v_all_devices.append(output_acc_v)
# Out:
# processing 1.benign.csv rows = 1000
# processing 1.gafgyt.combo.csv rows = 100
# processing 1.gafgyt.junk.csv rows = 100
# processing 1.gafgyt.scan.csv rows = 100
# processing 1.gafgyt.tcp.csv rows = 100
# processing 1.gafgyt.udp.csv rows = 100
# processing 1.mirai.ack.csv rows = 100
# processing 1.mirai.scan.csv rows = 100
# processing 1.mirai.syn.csv rows = 100
# processing 1.mirai.udp.csv rows = 100
# processing 1.mirai.udpplain.csv rows = 100
# ############################[1 - Danmini_Doorbell]##########################
# ========Danmini_Doorbell========
# Features=43
# NN Structure: layers=7, neurons: [97, 48, 73, 58, 64, 53, 83]
# complexity: 28539
# title,acc,tn,fp,fn,tp
# training-cm,1.00,665,4,1,670
# training-eval,[0.009366892278194427, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,2,2,327
# validation-eval,[0.0181092731654644, 0.9939393997192383]
# ........................................
# Th=100, Revised NN Structure: layers=7, neurons: [97 48 73 58 64 53 83], complexity: 28539
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 48 73 58 64 53 83]
# complexity: 28539
# title,acc,tn,fp,fn,tp
# training-cm,1.00,665,2,1,672
# training-eval,[0.008363429456949234, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,4,1,326
# validation-eval,[0.035469189286231995, 0.9924242496490479]
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 48 73 58 64 53 83]
# complexity: 28539
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,5,2,667
# training-eval,[0.015441491268575191, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,320,9,0,331
# validation-eval,[0.7152331471443176, 0.9909090995788574]
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 48 73 58 64 53 83]
# complexity: 28539
# title,acc,tn,fp,fn,tp
# training-cm,1.00,659,4,2,675
# training-eval,[0.019290154799818993, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,3,1,322
# validation-eval,[0.014993319287896156, 0.9939393997192383]
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 48 73 58 64 53 83]
# complexity: 28539
# title,acc,tn,fp,fn,tp
# training-cm,0.99,674,0,8,658
# training-eval,[0.017156073823571205, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,1,3,331
# validation-eval,[0.03343596309423447, 0.9939393997192383]
# ........................................
# Th=99, Revised NN Structure: layers=6, neurons: [96 47 72 57 63 52], complexity: 23431
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [96 47 72 57 63 52]
# complexity: 23431
# title,acc,tn,fp,fn,tp
# training-cm,1.00,672,3,2,663
# training-eval,[0.012647445313632488, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,319,6,0,335
# validation-eval,[0.5285513997077942, 0.9939393997192383]
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [96 47 72 57 63 52]
# complexity: 23431
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,0,10,672
# training-eval,[0.02084195241332054, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,341,1,1,317
# validation-eval,[0.02336173504590988, 0.9969696998596191]
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [96 47 72 57 63 52]
# complexity: 23431
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,5,2,666
# training-eval,[0.012631106190383434, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,325,3,0,332
# validation-eval,[0.011770842596888542, 0.9924242496490479]
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [96 47 72 57 63 52]
# complexity: 23431
# title,acc,tn,fp,fn,tp
# training-cm,1.00,674,5,1,660
# training-eval,[0.010811099782586098, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,320,1,1,338
# validation-eval,[0.013795970939099789, 0.9954545497894287]
# ........................................
# Th=98, Revised NN Structure: layers=5, neurons: [94 46 70 55 61], complexity: 19228
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [94 46 70 55 61]
# complexity: 19228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,4,1,667
# training-eval,[0.010189457796514034, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,324,4,1,331
# validation-eval,[0.10466762632131577, 0.9909090995788574]
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [94 46 70 55 61]
# complexity: 19228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,3,1,670
# training-eval,[0.00913145300000906, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,2,4,325
# validation-eval,[0.14847628772258759, 0.9909090995788574]
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [94 46 70 55 61]
# complexity: 19228
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,5,2,666
# training-eval,[0.014488659799098969, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,3,1,331
# validation-eval,[0.014922241680324078, 0.9939393997192383]
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [94 46 70 55 61]
# complexity: 19228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,642,2,3,693
# training-eval,[0.01205801498144865, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,349,7,2,302
# validation-eval,[0.08969313651323318, 0.9909090995788574]
# ........................................
# Th=97, Revised NN Structure: layers=4, neurons: [91 44 67 53], complexity: 14833
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [91 44 67 53]
# complexity: 14833
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,3,1,657
# training-eval,[0.008726682513952255, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,2,4,338
# validation-eval,[0.16395404934883118, 0.9939393997192383]
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [91 44 67 53]
# complexity: 14833
# title,acc,tn,fp,fn,tp
# training-cm,0.99,663,7,1,669
# training-eval,[0.010875786654651165, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,5,3,327
# validation-eval,[0.3066652715206146, 0.9909090995788574]
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [91 44 67 53]
# complexity: 14833
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,3,1,674
# training-eval,[0.009234773926436901, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,4,1,324
# validation-eval,[0.017786771059036255, 0.9939393997192383]
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [91 44 67 53]
# complexity: 14833
# title,acc,tn,fp,fn,tp
# training-cm,1.00,663,4,2,671
# training-eval,[0.013595730066299438, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,4,0,327
# validation-eval,[0.02577921561896801, 0.9924242496490479]
# ........................................
# Th=96, Revised NN Structure: layers=3, neurons: [87 42 50], complexity: 9893
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [87 42 50]
# complexity: 9893
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,3,2,671
# training-eval,[0.012389046140015125, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,2,2,325
# validation-eval,[0.1804216504096985, 0.9924242496490479]
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [87 42 50]
# complexity: 9893
# title,acc,tn,fp,fn,tp
# training-cm,1.00,681,4,1,654
# training-eval,[0.009311879985034466, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,2,2,343
# validation-eval,[0.04207569360733032, 0.9924242496490479]
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [87 42 50]
# complexity: 9893
# title,acc,tn,fp,fn,tp
# training-cm,1.00,661,5,1,673
# training-eval,[0.01288088783621788, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,334,0,3,323
# validation-eval,[0.20753751695156097, 0.9954545497894287]
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [87 42 50]
# complexity: 9893
# title,acc,tn,fp,fn,tp
# training-cm,1.00,646,4,2,688
# training-eval,[0.012240584939718246, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,348,2,0,310
# validation-eval,[0.019293436780571938, 0.9969696998596191]
# ........................................
# Th=95, Revised NN Structure: layers=2, neurons: [39 47], complexity: 3713
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [39 47]
# complexity: 3713
# title,acc,tn,fp,fn,tp
# training-cm,1.00,690,0,4,646
# training-eval,[0.009648511186242104, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,308,2,5,345
# validation-eval,[0.06914998590946198, 0.989393949508667]
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [39 47]
# complexity: 3713
# title,acc,tn,fp,fn,tp
# training-cm,1.00,653,4,0,683
# training-eval,[0.005811045877635479, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,341,2,2,315
# validation-eval,[0.03609154745936394, 0.9939393997192383]
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [39 47]
# complexity: 3713
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,3,0,658
# training-eval,[0.004683549515902996, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,314,4,4,338
# validation-eval,[0.10084695369005203, 0.9878787994384766]
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [39 47]
# complexity: 3713
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,3,1,669
# training-eval,[0.010765640996396542, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,4,2,328
# validation-eval,[0.02374468371272087, 0.9939393997192383]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [44], complexity: 2112
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [44]
# complexity: 2112
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,5,8,658
# training-eval,[0.020168090239167213, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,325,1,1,333
# validation-eval,[0.011207720264792442, 0.9969696998596191]
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [44]
# complexity: 2112
# title,acc,tn,fp,fn,tp
# training-cm,0.99,682,6,1,651
# training-eval,[0.01762315072119236, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,308,4,1,347
# validation-eval,[0.02056722342967987, 0.9939393997192383]
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [44]
# complexity: 2112
# title,acc,tn,fp,fn,tp
# training-cm,0.99,678,6,2,654
# training-eval,[0.01928616873919964, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,312,4,0,344
# validation-eval,[0.012264075689017773, 0.9954545497894287]
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [44]
# complexity: 2112
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,6,2,665
# training-eval,[0.017951691523194313, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,9,0,333
# validation-eval,[0.07698194682598114, 0.989393949508667]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [40], complexity: 1920
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,0.99,683,5,4,648
# training-eval,[0.013826806098222733, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,310,2,5,343
# validation-eval,[0.04290488362312317, 0.9909090995788574]
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,0.99,661,6,4,669
# training-eval,[0.013690339401364326, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,1,7,320
# validation-eval,[0.16806921362876892, 0.9863636493682861]
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,1.00,684,4,2,650
# training-eval,[0.014695695601403713, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,310,2,3,345
# validation-eval,[0.06747696548700333, 0.9878787994384766]
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,0.99,649,4,7,680
# training-eval,[0.02038026973605156, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,346,1,5,308
# validation-eval,[0.17435656487941742, 0.9924242496490479]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [36], complexity: 1728
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [36]
# complexity: 1728
# title,acc,tn,fp,fn,tp
# training-cm,0.99,661,4,7,668
# training-eval,[0.02110559120774269, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,2,2,323
# validation-eval,[0.013089971616864204, 0.9969696998596191]
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [36]
# complexity: 1728
# title,acc,tn,fp,fn,tp
# training-cm,0.99,672,6,8,654
# training-eval,[0.024102889001369476, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,1,1,337
# validation-eval,[0.010200336575508118, 0.9969696998596191]
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [36]
# complexity: 1728
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,0,4,669
# training-eval,[0.01138645876199007, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,1,8,319
# validation-eval,[0.0852987989783287, 0.9863636493682861]
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [36]
# complexity: 1728
# title,acc,tn,fp,fn,tp
# training-cm,0.99,663,6,7,664
# training-eval,[0.020217236131429672, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,1,3,326
# validation-eval,[0.022990409284830093, 0.9924242496490479]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [32], complexity: 1536
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [32]
# complexity: 1536
# title,acc,tn,fp,fn,tp
# training-cm,1.00,653,5,1,681
# training-eval,[0.012334553524851799, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,5,4,314
# validation-eval,[0.0493588000535965, 0.9909090995788574]
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [32]
# complexity: 1536
# title,acc,tn,fp,fn,tp
# training-cm,0.99,675,6,4,655
# training-eval,[0.014108364470303059, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,1,6,335
# validation-eval,[0.03635743632912636, 0.989393949508667]
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [32]
# complexity: 1536
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,0,3,669
# training-eval,[0.009566224180161953, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,330,2,8,320
# validation-eval,[0.06328915059566498, 0.9863636493682861]
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [32]
# complexity: 1536
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,6,2,672
# training-eval,[0.01868416927754879, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,6,0,326
# validation-eval,[0.037889644503593445, 0.9909090995788574]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [28], complexity: 1344
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,1.00,680,2,3,655
# training-eval,[0.010367988608777523, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,311,7,8,334
# validation-eval,[0.1765369474887848, 0.9818181991577148]
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,0.99,656,6,6,672
# training-eval,[0.020705902948975563, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,338,0,3,319
# validation-eval,[0.019631613045930862, 0.9939393997192383]
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,3,6,663
# training-eval,[0.019341755658388138, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,3,3,328
# validation-eval,[0.025348873808979988, 0.9909090995788574]
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,1.00,663,3,2,672
# training-eval,[0.01161298155784607, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,328,6,4,322
# validation-eval,[0.0895598977804184, 0.9833333492279053]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [25], complexity: 1200
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,4,7,667
# training-eval,[0.020713772624731064, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,3,2,324
# validation-eval,[0.024000292643904686, 0.9909090995788574]
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,647,5,7,681
# training-eval,[0.020259175449609756, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,346,2,2,310
# validation-eval,[0.028573917225003242, 0.9939393997192383]
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,0,5,665
# training-eval,[0.01660553738474846, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,0,6,324
# validation-eval,[0.03660416975617409, 0.9909090995788574]
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,5,2,663
# training-eval,[0.014635385014116764, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,316,9,5,330
# validation-eval,[0.10372468084096909, 0.9863636493682861]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [22], complexity: 1056
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,11,1,660
# training-eval,[0.01549583300948143, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,319,2,4,335
# validation-eval,[0.07930489629507065, 0.989393949508667]
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,1.00,698,1,5,636
# training-eval,[0.019329842180013657, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,301,0,4,355
# validation-eval,[0.02411099709570408, 0.9924242496490479]
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,0.99,654,3,6,677
# training-eval,[0.01931147649884224, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,340,3,4,313
# validation-eval,[0.031574975699186325, 0.989393949508667]
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,0.99,661,4,5,670
# training-eval,[0.016399256885051727, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,4,4,321
# validation-eval,[0.045346226543188095, 0.9878787994384766]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [19], complexity: 912
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,684,2,7,647
# training-eval,[0.020564228296279907, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,311,3,4,342
# validation-eval,[0.10170724987983704, 0.989393949508667]
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,3,7,666
# training-eval,[0.01836415007710457, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,331,2,8,319
# validation-eval,[0.11304346472024918, 0.9863636493682861]
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,636,3,9,692
# training-eval,[0.019827764481306076, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,358,3,3,296
# validation-eval,[0.02144368551671505, 0.9924242496490479]
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,1,3,663
# training-eval,[0.012980394065380096, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,1,6,328
# validation-eval,[0.05225331708788872, 0.989393949508667]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [16], complexity: 768
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,684,4,5,647
# training-eval,[0.018814103677868843, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,308,4,4,344
# validation-eval,[0.029207071289420128, 0.9833333492279053]
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,688,6,4,642
# training-eval,[0.013212134130299091, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,305,1,6,348
# validation-eval,[0.0428612157702446, 0.9878787994384766]
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,1.00,683,3,3,651
# training-eval,[0.009276245720684528, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,310,4,7,339
# validation-eval,[0.05623247101902962, 0.9878787994384766]
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,679,5,4,652
# training-eval,[0.021861854940652847, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,3,4,340
# validation-eval,[0.14150427281856537, 0.989393949508667]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [13], complexity: 624
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,0.99,674,5,8,653
# training-eval,[0.02508792094886303, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,320,1,1,338
# validation-eval,[0.013342720456421375, 0.9954545497894287]
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,0.99,678,4,7,651
# training-eval,[0.021333122625947, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,2,2,340
# validation-eval,[0.01420577336102724, 0.9924242496490479]
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,5,5,664
# training-eval,[0.01803114078938961, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,327,2,4,327
# validation-eval,[0.03292471542954445, 0.9878787994384766]
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,0.99,665,5,6,664
# training-eval,[0.018333101645112038, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,2,3,327
# validation-eval,[0.028654204681515694, 0.9924242496490479]
# ........................................
# Th=84, Revised NN Structure: layers=1, neurons: [11], complexity: 528
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,7,7,656
# training-eval,[0.022269824519753456, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,320,3,4,333
# validation-eval,[0.08164676278829575, 0.9878787994384766]
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,3,4,671
# training-eval,[0.012955665588378906, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,332,3,12,313
# validation-eval,[0.19078192114830017, 0.9757575988769531]
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,5,7,655
# training-eval,[0.020644091069698334, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,1,2,336
# validation-eval,[0.016864020377397537, 0.9939393997192383]
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,6,7,661
# training-eval,[0.025958234444260597, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,327,1,2,330
# validation-eval,[0.018357640132308006, 0.9954545497894287]
# ........................................
# Th=83, Revised NN Structure: layers=1, neurons: [9], complexity: 432
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,656,8,2,674
# training-eval,[0.02019532024860382, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,332,4,7,317
# validation-eval,[0.13396595418453217, 0.9833333492279053]
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,650,4,8,678
# training-eval,[0.023076146841049194, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,344,2,2,312
# validation-eval,[0.018042223528027534, 0.9939393997192383]
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,3,8,669
# training-eval,[0.021960031241178513, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,334,3,7,316
# validation-eval,[0.03342529758810997, 0.989393949508667]
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,7,1,672
# training-eval,[0.01576973870396614, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,325,8,4,323
# validation-eval,[0.04748218506574631, 0.989393949508667]
# ........................................
# Th=82, Revised NN Structure: layers=1, neurons: [7], complexity: 336
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,8,6,667
# training-eval,[0.02331627532839775, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,330,3,8,319
# validation-eval,[0.04642491042613983, 0.9833333492279053]
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,4,6,671
# training-eval,[0.0192490816116333, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,3,4,319
# validation-eval,[0.029028529301285744, 0.9878787994384766]
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,654,5,5,676
# training-eval,[0.017720412462949753, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,339,2,7,312
# validation-eval,[0.07587738335132599, 0.9848484992980957]
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,4,7,659
# training-eval,[0.023941265419125557, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,3,2,332
# validation-eval,[0.014607870019972324, 0.9954545497894287]
# ........................................
# Th=81, Revised NN Structure: layers=1, neurons: [5], complexity: 240
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,683,2,8,647
# training-eval,[0.027585385367274284, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,2,6,339
# validation-eval,[0.05125923082232475, 0.9878787994384766]
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,4,5,662
# training-eval,[0.017516277730464935, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,324,3,5,328
# validation-eval,[0.08300965279340744, 0.989393949508667]
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,648,4,9,679
# training-eval,[0.023725345730781555, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,344,4,2,310
# validation-eval,[0.022492049261927605, 0.9878787994384766]
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,5,7,657
# training-eval,[0.021007893607020378, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,321,3,5,331
# validation-eval,[0.08258841186761856, 0.9878787994384766]
# ........................................
# Th=80, Revised NN Structure: layers=1, neurons: [4], complexity: 192
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.99,674,5,8,653
# training-eval,[0.025600561872124672, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,313,8,5,334
# validation-eval,[0.04011352360248566, 0.978787899017334]
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.99,663,4,8,665
# training-eval,[0.023787878453731537, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,329,4,6,321
# validation-eval,[0.0358029305934906, 0.9833333492279053]
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,5,10,661
# training-eval,[0.03163216635584831, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,0,4,325
# validation-eval,[0.024382328614592552, 0.9939393997192383]
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,6,8,658
# training-eval,[0.022174155339598656, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,3,4,330
# validation-eval,[0.027489133179187775, 0.989393949508667]
# ........................................
# Th=79, Revised NN Structure: layers=1, neurons: [3], complexity: 144
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.99,697,5,8,630
# training-eval,[0.025671333074569702, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,297,1,8,354
# validation-eval,[0.07603614032268524, 0.9727272987365723]
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.99,656,4,7,673
# training-eval,[0.026436708867549896, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,3,3,317
# validation-eval,[0.029687130823731422, 0.9909090995788574]
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.98,645,13,9,673
# training-eval,[0.025952516123652458, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,326,16,5,313
# validation-eval,[0.03316261246800423, 0.9909090995788574]
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.99,680,4,8,648
# training-eval,[0.019223710522055626, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,312,4,5,339
# validation-eval,[0.04818875715136528, 0.9878787994384766]
# ........................................
# Th=78, Revised NN Structure: layers=1, neurons: [2], complexity: 96
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.99,652,5,15,668
# training-eval,[0.03687887266278267, 0.987313449382782]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,341,2,6,311
# validation-eval,[0.03169465437531471, 0.9909090995788574]
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.97,655,32,8,645
# training-eval,[0.04158083349466324, 0.9843283295631409]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,292,21,7,340
# validation-eval,[0.11966395378112793, 0.9772727489471436]
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.98,671,21,8,640
# training-eval,[0.06826764345169067, 0.9805970191955566]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,298,10,6,346
# validation-eval,[0.12390497326850891, 0.9772727489471436]
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.99,654,7,11,668
# training-eval,[0.042715683579444885, 0.9858208894729614]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,6,1,320
# validation-eval,[0.034265149384737015, 0.9878787994384766]
# ........................................
# Th=77, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,674,4,12,650
# training-eval,[0.045396532863378525, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,321,1,8,330
# validation-eval,[0.08487942069768906, 0.9878787994384766]
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,664,1,20,655
# training-eval,[0.06564001739025116, 0.9813432693481445]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,1,7,318
# validation-eval,[0.054749250411987305, 0.9878787994384766]
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,679,2,22,637
# training-eval,[0.06701693683862686, 0.983582079410553]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,319,0,14,327
# validation-eval,[0.08841178566217422, 0.978787899017334]
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,666,1,26,647
# training-eval,[0.08146332949399948, 0.9791044592857361]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,332,1,12,315
# validation-eval,[0.08345448970794678, 0.9803030490875244]
# ........................................
# Th=76, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,606,40,7,687
# training-eval,[0.12503646314144135, 0.9664179086685181]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,335,19,5,301
# validation-eval,[0.13261359930038452, 0.9651514887809753]
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,679,1,18,642
# training-eval,[0.06403308361768723, 0.9850746393203735]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,319,1,17,323
# validation-eval,[0.11280042678117752, 0.9727272987365723]
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,650,19,10,661
# training-eval,[0.08422746509313583, 0.9798507690429688]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,323,8,7,322
# validation-eval,[0.09332320094108582, 0.9772727489471436]
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.95,630,51,10,649
# training-eval,[0.15248627960681915, 0.9574626684188843]
# title,acc,tn,fp,fn,tp
# validation-cm,0.95,292,27,3,338
# validation-eval,[0.16115258634090424, 0.9545454382896423]
# ........................................
# Th=75, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,685,2,9,644
# training-eval,[0.034386809915304184, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,313,0,12,335
# validation-eval,[0.07597676664590836, 0.9818181991577148]
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,3,10,663
# training-eval,[0.03480107709765434, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,2,7,320
# validation-eval,[0.048782624304294586, 0.9863636493682861]
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,665,0,11,664
# training-eval,[0.04196140915155411, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,334,1,11,314
# validation-eval,[0.0783524438738823, 0.9818181991577148]
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,5,7,666
# training-eval,[0.03357856348156929, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,330,3,9,318
# validation-eval,[0.07026422023773193, 0.9803030490875244]
# ........................................
# Th=74, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,621,39,7,673
# training-eval,[0.12498211860656738, 0.9656716585159302]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,320,20,7,313
# validation-eval,[0.13982559740543365, 0.9575757384300232]
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,683,1,20,636
# training-eval,[0.06468960642814636, 0.9820895791053772]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,315,1,16,328
# validation-eval,[0.10809152573347092, 0.9742424488067627]
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,668,9,12,651
# training-eval,[0.05568481609225273, 0.9865671396255493]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,319,4,7,330
# validation-eval,[0.04332883283495903, 0.989393949508667]
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,629,40,11,660
# training-eval,[0.1345529854297638, 0.9611940383911133]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,311,20,2,327
# validation-eval,[0.12343276292085648, 0.9666666388511658]
# ........................................
# Th=73, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,4,7,658
# training-eval,[0.03786326199769974, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,321,4,7,328
# validation-eval,[0.06306160241365433, 0.9833333492279053]
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,673,0,25,642
# training-eval,[0.08043330907821655, 0.9813432693481445]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,327,0,12,321
# validation-eval,[0.07944470643997192, 0.9818181991577148]
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,676,2,23,639
# training-eval,[0.07135273516178131, 0.9820895791053772]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,322,0,10,328
# validation-eval,[0.06824406236410141, 0.9848484992980957]
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,623,38,7,672
# training-eval,[0.12449243664741516, 0.967164158821106]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,318,21,5,316
# validation-eval,[0.1361391246318817, 0.9636363387107849]
# ........................................
# Th=72, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,665,2,18,655
# training-eval,[0.06017746403813362, 0.9828358292579651]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,0,6,321
# validation-eval,[0.048975974321365356, 0.9909090995788574]
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,652,4,12,672
# training-eval,[0.04986325651407242, 0.987313449382782]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,340,4,6,310
# validation-eval,[0.05733465775847435, 0.9848484992980957]
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,2,15,655
# training-eval,[0.05284027010202408, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,330,0,13,317
# validation-eval,[0.07972600311040878, 0.9803030490875244]
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,2,12,656
# training-eval,[0.04362226277589798, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,0,8,324
# validation-eval,[0.049511246383190155, 0.9878787994384766]
# ........................................
# Th=71, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,663,1,11,665
# training-eval,[0.036320820450782776, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,1,6,318
# validation-eval,[0.048755813390016556, 0.9878787994384766]
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,625,44,7,664
# training-eval,[0.134094700217247, 0.9641790986061096]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,316,15,7,322
# validation-eval,[0.12283754348754883, 0.9681817889213562]
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,1,14,663
# training-eval,[0.04192296043038368, 0.987313449382782]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,336,1,4,319
# validation-eval,[0.0343952439725399, 0.9909090995788574]
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,3,11,666
# training-eval,[0.04482226073741913, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,4,2,321
# validation-eval,[0.04394114390015602, 0.9909090995788574]
# processing 2.benign.csv rows = 1000
# processing 2.gafgyt.combo.csv rows = 100
# processing 2.gafgyt.junk.csv rows = 100
# processing 2.gafgyt.scan.csv rows = 100
# processing 2.gafgyt.tcp.csv rows = 100
# processing 2.gafgyt.udp.csv rows = 100
# processing 2.mirai.ack.csv rows = 100
# processing 2.mirai.scan.csv rows = 100
# processing 2.mirai.syn.csv rows = 100
# processing 2.mirai.udp.csv rows = 100
# processing 2.mirai.udpplain.csv rows = 100
# ############################[2 - Ecobee_Thermostat]##########################
# ========Ecobee_Thermostat========
# Features=54
# NN Structure: layers=5, neurons: [88, 52, 66, 58, 75]
# complexity: 20397
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,0,4,680
# training-eval,[0.013092231936752796, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,344,0,0,316
# validation-eval,[0.0026809743139892817, 1.0]
# ........................................
# Th=100, Revised NN Structure: layers=5, neurons: [88 52 66 58 75], complexity: 20397
# ========Ecobee_Thermostat-100========
# Features=54
# NN Structure: layers=5, neurons: [88 52 66 58 75]
# complexity: 20397
# title,acc,tn,fp,fn,tp
# training-cm,1.00,676,0,3,661
# training-eval,[0.012770210392773151, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,324,0,2,334
# validation-eval,[0.01335501205176115, 0.9969696998596191]
# ========Ecobee_Thermostat-100========
# Features=54
# NN Structure: layers=5, neurons: [88 52 66 58 75]
# complexity: 20397
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,0,2,682
# training-eval,[0.008953211829066277, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,344,0,3,313
# validation-eval,[0.016556713730096817, 0.9954545497894287]
# ========Ecobee_Thermostat-100========
# Features=54
# NN Structure: layers=5, neurons: [88 52 66 58 75]
# complexity: 20397
# title,acc,tn,fp,fn,tp
# training-cm,1.00,658,0,2,680
# training-eval,[0.007271097507327795, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,342,0,3,315
# validation-eval,[0.03048856370151043, 0.9954545497894287]
# ========Ecobee_Thermostat-100========
# Features=54
# NN Structure: layers=5, neurons: [88 52 66 58 75]
# complexity: 20397
# title,acc,tn,fp,fn,tp
# training-cm,1.00,681,0,1,658
# training-eval,[0.004604921210557222, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,319,0,5,336
# validation-eval,[0.04091301187872887, 0.9924242496490479]
# ........................................
# Th=99, Revised NN Structure: layers=4, neurons: [87 51 65 57], complexity: 15603
# ========Ecobee_Thermostat-99========
# Features=54
# NN Structure: layers=4, neurons: [87 51 65 57]
# complexity: 15603
# title,acc,tn,fp,fn,tp
# training-cm,1.00,660,0,2,678
# training-eval,[0.008073578588664532, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,339,1,2,318
# validation-eval,[0.020279735326766968, 0.9954545497894287]
# ========Ecobee_Thermostat-99========
# Features=54
# NN Structure: layers=4, neurons: [87 51 65 57]
# complexity: 15603
# title,acc,tn,fp,fn,tp
# training-cm,1.00,658,0,3,679
# training-eval,[0.01171694416552782, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,340,2,1,317
# validation-eval,[0.028620323166251183, 0.9954545497894287]
# ========Ecobee_Thermostat-99========
# Features=54
# NN Structure: layers=4, neurons: [87 51 65 57]
# complexity: 15603
# title,acc,tn,fp,fn,tp
# training-cm,1.00,688,0,2,650
# training-eval,[0.007162642199546099, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,312,0,3,345
# validation-eval,[0.02032451331615448, 0.9954545497894287]
# ========Ecobee_Thermostat-99========
# Features=54
# NN Structure: layers=4, neurons: [87 51 65 57]
# complexity: 15603
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,0,2,665
# training-eval,[0.008324488066136837, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,326,1,2,331
# validation-eval,[0.01888931170105934, 0.9954545497894287]
# ........................................
# Th=98, Revised NN Structure: layers=3, neurons: [85 50 55], complexity: 11050
# ========Ecobee_Thermostat-98========
# Features=54
# NN Structure: layers=3, neurons: [85 50 55]
# complexity: 11050
# title,acc,tn,fp,fn,tp
# training-cm,1.00,650,0,3,687
# training-eval,[0.010602370835840702, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,350,0,2,308
# validation-eval,[0.011780447326600552, 0.9969696998596191]
# ========Ecobee_Thermostat-98========
# Features=54
# NN Structure: layers=3, neurons: [85 50 55]
# complexity: 11050
# title,acc,tn,fp,fn,tp
# training-cm,1.00,682,2,1,655
# training-eval,[0.014165487140417099, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,3,2,342
# validation-eval,[0.02840873785316944, 0.9924242496490479]
# ========Ecobee_Thermostat-98========
# Features=54
# NN Structure: layers=3, neurons: [85 50 55]
# complexity: 11050
# title,acc,tn,fp,fn,tp
# training-cm,1.00,678,0,3,659
# training-eval,[0.010499105788767338, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,322,0,1,337
# validation-eval,[0.011114382185041904, 0.9969696998596191]
# ========Ecobee_Thermostat-98========
# Features=54
# NN Structure: layers=3, neurons: [85 50 55]
# complexity: 11050
# title,acc,tn,fp,fn,tp
# ...
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,314,0,1,345
# validation-eval,[0.029489748179912567, 0.9984848499298096]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-81========
# Features=44
# NN Structure: layers=1, neurons: [5]
# complexity: 285
# title,acc,tn,fp,fn,tp
# training-cm,1.00,665,0,3,672
# training-eval,[0.01194002479314804, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,334,1,1,324
# validation-eval,[0.016119251027703285, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-81========
# Features=44
# NN Structure: layers=1, neurons: [5]
# complexity: 285
# title,acc,tn,fp,fn,tp
# training-cm,1.00,675,1,4,660
# training-eval,[0.015479955822229385, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,324,0,1,335
# validation-eval,[0.026819245889782906, 0.9984848499298096]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-81========
# Features=44
# NN Structure: layers=1, neurons: [5]
# complexity: 285
# title,acc,tn,fp,fn,tp
# training-cm,1.00,649,1,4,686
# training-eval,[0.01646129973232746, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,350,0,1,309
# validation-eval,[0.009956522844731808, 0.9984848499298096]
# ........................................
# Th=80, Revised NN Structure: layers=1, neurons: [4], complexity: 228
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-80========
# Features=44
# NN Structure: layers=1, neurons: [4]
# complexity: 228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,1,4,665
# training-eval,[0.016386909410357475, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,328,1,1,330
# validation-eval,[0.012375779449939728, 0.9984848499298096]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-80========
# Features=44
# NN Structure: layers=1, neurons: [4]
# complexity: 228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,682,1,3,654
# training-eval,[0.013069051317870617, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,317,0,1,342
# validation-eval,[0.009881333447992802, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-80========
# Features=44
# NN Structure: layers=1, neurons: [4]
# complexity: 228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,689,1,1,649
# training-eval,[0.006549181882292032, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,310,0,3,347
# validation-eval,[0.02488027699291706, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-80========
# Features=44
# NN Structure: layers=1, neurons: [4]
# complexity: 228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,669,1,2,668
# training-eval,[0.010216126218438148, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,330,0,3,327
# validation-eval,[0.04176958650350571, 0.9954545497894287]
# ........................................
# Th=79, Revised NN Structure: layers=1, neurons: [3], complexity: 171
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-79========
# Features=44
# NN Structure: layers=1, neurons: [3]
# complexity: 171
# title,acc,tn,fp,fn,tp
# training-cm,1.00,653,0,4,683
# training-eval,[0.015314934775233269, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,345,2,0,313
# validation-eval,[0.010479971766471863, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-79========
# Features=44
# NN Structure: layers=1, neurons: [3]
# complexity: 171
# title,acc,tn,fp,fn,tp
# training-cm,1.00,676,0,2,662
# training-eval,[0.010296234861016273, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,323,1,2,334
# validation-eval,[0.018424732610583305, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-79========
# Features=44
# NN Structure: layers=1, neurons: [3]
# complexity: 171
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,0,6,670
# training-eval,[0.018855417147278786, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,335,1,2,322
# validation-eval,[0.023416368290781975, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-79========
# Features=44
# NN Structure: layers=1, neurons: [3]
# complexity: 171
# title,acc,tn,fp,fn,tp
# training-cm,1.00,675,0,4,661
# training-eval,[0.013817534781992435, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,325,0,2,333
# validation-eval,[0.010926160030066967, 0.9969696998596191]
# ........................................
# Th=78, Revised NN Structure: layers=1, neurons: [2], complexity: 114
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-78========
# Features=44
# NN Structure: layers=1, neurons: [2]
# complexity: 114
# title,acc,tn,fp,fn,tp
# training-cm,1.00,684,1,4,651
# training-eval,[0.017649156972765923, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,315,0,1,344
# validation-eval,[0.0788741335272789, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-78========
# Features=44
# NN Structure: layers=1, neurons: [2]
# complexity: 114
# title,acc,tn,fp,fn,tp
# training-cm,1.00,680,1,4,655
# training-eval,[0.015380927361547947, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,319,0,1,340
# validation-eval,[0.008764929138123989, 0.9984848499298096]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-78========
# Features=44
# NN Structure: layers=1, neurons: [2]
# complexity: 114
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,1,3,668
# training-eval,[0.01321410108357668, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,331,0,2,327
# validation-eval,[0.01994815655052662, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-78========
# Features=44
# NN Structure: layers=1, neurons: [2]
# complexity: 114
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,0,1,666
# training-eval,[0.006027927156537771, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,1,4,329
# validation-eval,[0.033502209931612015, 0.9924242496490479]
# ........................................
# Th=77, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-77========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,1,3,674
# training-eval,[0.015348690561950207, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,337,0,2,321
# validation-eval,[0.016408026218414307, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-77========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,684,0,2,654
# training-eval,[0.012334829196333885, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,315,1,2,342
# validation-eval,[0.020553989335894585, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-77========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,663,0,2,675
# training-eval,[0.011789299547672272, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,4,2,321
# validation-eval,[0.03454285115003586, 0.9924242496490479]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-77========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,686,0,4,650
# training-eval,[0.018371867015957832, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,314,0,4,342
# validation-eval,[0.03460808843374252, 0.9939393997192383]
# ........................................
# Th=76, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-76========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,0,12,669
# training-eval,[0.044921886175870895, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,341,0,3,316
# validation-eval,[0.027861688286066055, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-76========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,0,4,657
# training-eval,[0.018867045640945435, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,0,2,337
# validation-eval,[0.014809045009315014, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-76========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,1,3,674
# training-eval,[0.014573185704648495, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,337,0,2,321
# validation-eval,[0.01850435510277748, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-76========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,687,0,4,649
# training-eval,[0.01524958573281765, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,0,4,343
# validation-eval,[0.03177041932940483, 0.9939393997192383]
# ........................................
# Th=75, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-75========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.97,629,42,3,666
# training-eval,[0.13038936257362366, 0.9664179086685181]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,308,21,1,330
# validation-eval,[0.12554597854614258, 0.9681817889213562]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-75========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,659,1,2,678
# training-eval,[0.012716853991150856, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,339,1,2,318
# validation-eval,[0.02701260894536972, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-75========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,665,1,3,671
# training-eval,[0.01406394224613905, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,334,0,2,324
# validation-eval,[0.05533774942159653, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-75========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,0,3,664
# training-eval,[0.012645785696804523, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,326,1,2,331
# validation-eval,[0.06935453414916992, 0.9954545497894287]
# ........................................
# Th=74, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-74========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,677,0,2,661
# training-eval,[0.011768748983740807, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,322,1,2,335
# validation-eval,[0.02238665148615837, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-74========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.97,635,40,3,662
# training-eval,[0.12588976323604584, 0.9679104685783386]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,303,22,1,334
# validation-eval,[0.13353753089904785, 0.9651514887809753]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-74========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,646,1,4,689
# training-eval,[0.016661176458001137, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,353,0,1,306
# validation-eval,[0.014386539347469807, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-74========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,1,3,663
# training-eval,[0.014274448156356812, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,326,0,2,332
# validation-eval,[0.053802549839019775, 0.9969696998596191]
# ........................................
# Th=73, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-73========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,1,4,679
# training-eval,[0.01858511008322239, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,338,5,0,317
# validation-eval,[0.045166049152612686, 0.9909090995788574]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-73========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,672,1,4,663
# training-eval,[0.01785261183977127, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,327,0,2,331
# validation-eval,[0.013553930446505547, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-73========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,0,3,666
# training-eval,[0.013609113171696663, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,324,5,2,329
# validation-eval,[0.034356389194726944, 0.989393949508667]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-73========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.97,648,40,3,649
# training-eval,[0.12518368661403656, 0.9679104685783386]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,290,22,1,347
# validation-eval,[0.13469503819942474, 0.9651514887809753]
# ........................................
# Th=72, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-72========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.86,505,183,2,650
# training-eval,[0.3356626331806183, 0.8611940145492554]
# title,acc,tn,fp,fn,tp
# validation-cm,0.85,215,97,2,346
# validation-eval,[0.36822256445884705, 0.8500000238418579]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-72========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.86,483,187,4,666
# training-eval,[0.348903089761734, 0.8574627041816711]
# title,acc,tn,fp,fn,tp
# validation-cm,0.86,238,92,2,328
# validation-eval,[0.3488709628582001, 0.8560606241226196]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-72========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,2,1,670
# training-eval,[0.008055075071752071, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,3,3,326
# validation-eval,[0.03213856741786003, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-72========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,678,0,4,658
# training-eval,[0.01928204484283924, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,1,0,338
# validation-eval,[0.009882571175694466, 0.9984848499298096]
# ........................................
# Th=71, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-71========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,1,4,665
# training-eval,[0.018845487385988235, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,329,0,1,330
# validation-eval,[0.011250115931034088, 0.9984848499298096]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-71========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,1,3,666
# training-eval,[0.015533589757978916, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,329,0,2,329
# validation-eval,[0.016326365992426872, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-71========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,3,2,664
# training-eval,[0.02092825248837471, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,322,4,3,331
# validation-eval,[0.04199543595314026, 0.989393949508667]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-71========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,659,1,4,676
# training-eval,[0.018548717722296715, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,339,1,1,319
# validation-eval,[0.01241276878863573, 0.9984848499298096]

# %%
def print_summary(title, table_header, record):
    print(f"-------------------------{title}-------------------------")
    print(table_header)
    for item in record:
        print(item)

# %%
print(f"****************************[Summary]****************************")
print_summary('time complexities', output_title, output_cplx_all_devices)
print_summary('training accuracy', output_title, output_acc_t_all_devices)
print_summary('validation accuracy', output_title, output_acc_v_all_devices)
# Out:
# ****************************[Summary]****************************
# -------------------------time complexities-------------------------
# device_name,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71
# Danmini_Doorbell,28539.0,23431.0,19228.0,14833.0,9893.0,3713.0,2112.0,1920.0,1728.0,1536.0,1344.0,1200.0,1056.0,912.0,768.0,624.0,528.0,432.0,336.0,240.0,192.0,144.0,96.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0
# Ecobee_Thermostat,20397.0,15603.0,11050.0,4853.0,2400.0,2256.0,2112.0,1920.0,1728.0,1536.0,1344.0,1200.0,1056.0,912.0,768.0,624.0,528.0,432.0,336.0,240.0,192.0,144.0,96.0,48.0,48.0,48.0,48.0,48.0,48.0,48.0
# Ennio_Doorbell,11104.0,9622.0,6115.0,4544.0,3817.0,2400.0,2220.0,2040.0,1860.0,1680.0,1500.0,1320.0,1140.0,960.0,780.0,660.0,540.0,420.0,300.0,240.0,180.0,120.0,60.0,60.0,60.0,60.0,60.0,60.0,60.0,60.