# %%
# Imports

########################################################################
# Python Standard Libraries
import os
import multiprocessing
from timeit import default_timer as timer
import random
import math

########################################################################
# Numpy Library
import numpy as np # linear algebra

########################################################################
# Pandas Library
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

########################################################################
# MATPLOT Library
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
# %matplotlib inline

########################################################################
# SKLearn Library
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_recall_curve, classification_report, confusion_matrix, average_precision_score, roc_curve, auc, multilabel_confusion_matrix

########################################################################
# SCIPY Library
from scipy.stats import gaussian_kde
import scipy.stats as st


########################################################################
# Keras Library
from keras.models import Sequential
from keras.layers import Dense

########################################################################
# Init random seed
#seed = 13
#np.random.seed(seed)

# %%
# Utility functions
########################################################################
# Print system information
def print_system_info():
    mem_bytes = os.sysconf('SC_PAGE_SIZE') * os.sysconf('SC_PHYS_PAGES')  # e.g. 4015976448
    mem_gib = mem_bytes/(1024.**3)  # e.g. 3.74
    print("{:<23}{:f} GB".format('RAM:', mem_gib))
    print("{:<23}{:d}".format('CORES:', multiprocessing.cpu_count()))
    # !lscpu

########################################################################
# Walk through input files
def print_input_files():
    # Input data files are available in the "../input/" directory.
    for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            print(os.path.join(dirname, filename))

########################################################################
# Dump text files
def dump_text_file(fname):
    with open(fname, 'r') as f:
        print(f.read())

########################################################################
# Dump CSV files
def dump_csv_file(fname, count=5):
    # count: 0 - column names only, -1 - all rows, default = 5 rows max
    df = pd.read_csv(fname)
    if count < 0:
        count = df.shape[0]
    return df.head(count)

########################################################################
# Dataset related functions
ds_nbaiot = '/kaggle/input/nbaiot-dataset'
dn_nbaiot = ['Danmini_Doorbell', 'Ecobee_Thermostat', 'Ennio_Doorbell', 'Philips_B120N10_Baby_Monitor', 'Provision_PT_737E_Security_Camera', 'Provision_PT_838_Security_Camera', 'Samsung_SNH_1011_N_Webcam', 'SimpleHome_XCS7_1002_WHT_Security_Camera', 'SimpleHome_XCS7_1003_WHT_Security_Camera']

def fname(ds, f):
    if '.csv' not in f:
        f = f'{f}.csv'
    return os.path.join(ds, f)

def fname_nbaiot(f):
    return fname(ds_nbaiot, f)

def get_nbaiot_device_files():
    nbaiot_all_files = dump_csv_file(fname_nbaiot('data_summary'), -1)
    nbaiot_all_files = nbaiot_all_files.iloc[:,0:1].values
    device_id = 1
    indices = []
    for j in range(len(nbaiot_all_files)):
        if str(device_id) not in str(nbaiot_all_files[j]):
            indices.append(j)
            device_id += 1
    nbaiot_device_files = np.split(nbaiot_all_files, indices)
    return nbaiot_device_files

def get_nbaiot_device_data(device_id, count_norm=-1, count_anom=-1):
    if device_id < 1 or device_id > 9:
        assert False, "Please provide a valid device ID 1-9, both inclusive"
    if count_anom == -1:
        count_anom = count_norm
    device_index = device_id -1
    device_files = get_nbaiot_device_files()
    device_file = device_files[device_index]
    df = pd.DataFrame()
    y = []
    for i in range(len(device_file)):
        fname = str(device_file[i][0])
        df_c = pd.read_csv(fname_nbaiot(fname))
        count = count_anom
        if 'benign' in fname:
            count = count_norm
        count = min(count, df_c.shape[0]) if count >=0 else df_c.shape[0]
        rows = count
        print("processing", fname, "rows =", rows)
        y_np = np.ones(rows) if 'benign' in fname else np.zeros(rows)
        y.extend(y_np.tolist())
        df = pd.concat([df.iloc[:,:].reset_index(drop=True),
                      df_c.iloc[:rows,:].reset_index(drop=True)], axis=0)
    X = df.iloc[:,:].values
    y = np.array(y)
    Xdf = df
    return (X, y, Xdf)

def get_nbaiot_devices_data():
    devices_data = []
    for i in range(9):
        device_id = i + 1
        (X, y) = get_nbaiot_device_data(device_id)
        devices_data.append((X, y))
    return devices_data
#print_input_files()
print_system_info()
# Out:
# RAM:                   18.571419 GB
# CORES:                 4
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              4
# On-line CPU(s) list: 0-3
# Thread(s) per core:  2
# Core(s) per socket:  2
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           AuthenticAMD
# CPU family:          23
# Model:               49
# Model name:          AMD EPYC 7B12
# Stepping:            0
# CPU MHz:             2249.998
# BogoMIPS:            4499.99
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            512K
# L3 cache:            16384K
# NUMA node0 CPU(s):   0-3
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid

# %%
def remove_correlated_features(df, threshold):
    df = df.copy()
    # Create correlation matrix
    corr_matrix = df.corr().abs()

    # Select upper triangle of correlation matrix
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

    # Find features with correlation greater than a threshold
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

    # Drop features 
    df.drop(to_drop, axis=1, inplace=True)
    return df.iloc[:,:].values

def mark_important_features(vector, pc_keep): # pc_keep is the percentage (0-100) of labels to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    important_bool = (vector >= th)
    important_int = important_bool.astype(int)
    return important_int

def select_features(X, X_norm, X_anom, threshold):
    rows_n = X_norm.shape[0]
    rows_a = X_anom.shape[0]
    if rows_n == 0 or rows_a == 0:
        return X

    y_norm = np.ones(rows_n)
    y_anom = -1 * np.ones(rows_a)

    reg_n = LinearRegression(fit_intercept=False)
    reg_n.fit(X_norm, y_norm)
    coef_n = abs(reg_n.coef_)
    n = mark_important_features(coef_n, threshold)

    reg_a = LinearRegression(fit_intercept=False)
    reg_a.fit(X_anom, y_anom)
    coef_a = abs(reg_a.coef_)
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel

# %%
def create_binary_classifier(hidden_layers, input_dim):
    layers = []
    for hl in hidden_layers:
        if hl > 0:
            layers.append(hl)

    layer_count = len(layers)
    assert layer_count >= 1, 'at least 1 non-zero hidden layer is needed'
    model = Sequential()
    model.add(Dense(layers[0],input_dim=input_dim,activation='relu'))
    for i in range(1, layer_count):
        model.add(Dense(layers[i],activation='relu'))

    model.add(Dense(1,activation='sigmoid'))
    #model.summary()
    model.compile(loss = 'binary_crossentropy',
             optimizer ='adam',metrics=['accuracy'])
    return model

# %%
def compute_time_complexity_single_pass(neurons_input, structure, neurons_output):
    count_hidden_layers = len(structure)
    neurons = [neurons_input, *structure, neurons_output]
    complexity = 0
    for i in range(count_hidden_layers + 1):
        complexity += neurons[i] * neurons[i+1]
    return complexity

# %%
def keep_mask(vector, pc_keep): # pc_keep is the percentage (0-100) of items to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    mask_bool = (vector >= th)
    mask_int = mask_bool.astype(int)
    return (mask_bool, mask_int)

# %%
'''
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel
'''
# Out:
# '\n    a = mark_important_features(coef_a, threshold)\n   \n    mask = np.bitwise_or(n,a)\n    mask = mask == 1 # convert to Boolean\n    X_sel = X[:, mask]\n    return X_sel\n'

# %%
def analyze_ranks(model, threshold):
    w_d = 0
    b_d = 0
    layer_count = len(model.layers)
    layer_ranks = []
    new_structure = []
    for i in range(layer_count-1):
        (w_c, b_c) = model.layers[i+1].get_weights() # current weigths and biases
        rows = w_c.shape[0]
        cols = w_c.shape[1]
        w_c_abs = np.absolute(w_c)
        rank_neurons = np.sum(w_c_abs, axis=1) / cols
        rank_layer = np.sum(rank_neurons) / rows
        layer_ranks.append(rank_layer)
        (mask_bool, mask_int) = keep_mask(rank_neurons, threshold)
        new_neuron_count = np.sum(mask_int)
        new_structure.append(new_neuron_count)
        #print(f'{i+1}: {rank_neurons.shape} {rank_layer} {mask_int} {new_neuron_count}')
    layer_ranks = np.array(layer_ranks)
    new_structure = np.array(new_structure)
    (mask_bool, mask_int) = keep_mask(layer_ranks, threshold)
    new_structure = new_structure[mask_bool]
    #new_structure_masked = new_structure
    #print(f'layer mask: {mask_int} {new_structure}')
    return new_structure

# %%
model = None
def compute_report(title, model, X, y):
    y_pred = model.predict(X)
    y_pred = (y_pred > 0.25)
    #print(y_pred)
    #y_pred[y_pred <= 0] = -1 # convert negative values as 0 for anomaly
    #y_pred[y_pred > 0] = 1 # convert positive values as 1 for normal
    acc = accuracy_score(y, y_pred)
    tn, fp, fn, tp = confusion_matrix(y, y_pred, labels=[0,1]).ravel()
    cr = classification_report(y, y_pred)
    print("title,acc,tn,fp,fn,tp")
    print(f'{title}-cm,{acc:.2f},{tn},{fp},{fn},{tp}')
    #print(f'{cr}')
    results = model.evaluate(X, y, verbose=0)
    print(f'{title}-eval,{results}')
    return results[1] # accuracy

def rank_computation(title, X, y, structure, fc):
    global model
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    print (f"========{title}========")
    feature_count = X.shape[1]
    print(f'Features={feature_count}')
    print(f'NN Structure: layers={len(structure)}, neurons: {structure}')
    complexity = compute_time_complexity_single_pass(fc, structure, 1)
    print(f'complexity: {complexity}')
    model = create_binary_classifier(structure, feature_count)
    model.fit(X_train,y_train,epochs=150,batch_size=10,verbose=0)
    #analyze_ranks(model, 95)
    acc_t = compute_report('training', model, X_train, y_train)
    acc_v = compute_report('validation', model, X_test, y_test)
    return (complexity, acc_t, acc_v)

# %%
output_title = ''
output_cplx_all_devices = []  # time complexity
output_acc_t_all_devices = [] # training accuracy
output_acc_v_all_devices = [] # validation accuracy

# %%
debug_flag = True

# %%
if debug_flag:
    count_norm = 1000
    count_anom = 100
    #device_indices = [0]
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]
else:
    count_norm = -1
    count_anom = -1
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]

structures = {
    '0': [97, 83, 73, 64, 58, 53, 48],
    '1': [88, 75, 66, 58, 52],
    '2': [57, 49, 43, 38, 34, 31],
    '3': [101, 75, 67, 60, 55, 50, 46],
    '4': [87, 75, 58, 52, 47, 43],
    '5': [88, 75, 58, 52, 48, 44],
    '6': [59, 50, 44, 39, 35, 32],
    '7': [76, 67, 59, 53, 48],
    '8': [88, 76, 59, 53, 48]
}

fcs = [47, 47, 59, 51, 40, 42, 56, 56, 56]
for i in device_indices:
    global output_title
    device_index = i
    device_id = device_index + 1
    device_name = dn_nbaiot[device_index]
    (X, y, Xdf) = get_nbaiot_device_data(device_id, count_norm, count_anom)
    X = remove_correlated_features(Xdf, 0.98)
    X_std = StandardScaler().fit_transform(X)
    indices_norm = np.where(y >= 0.5)
    indices_anom = np.where(y <= 0.5)
    X_norm_all = X_std[indices_norm]
    X_anom_all = X_std[indices_anom]
    X_std = select_features(X_std, X_norm_all, X_anom_all,75)
    fc = fcs[i]
    print(f'############################[{i+1} - {device_name}]##########################')
    (complexity, acc_t, acc_v) = rank_computation(device_name, X_std, y, structures.get(f'{i}'), fc)
    thresholds = [100, 99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88, 87, 86, 85]
    output_title = 'device_name'
    output_cplx = f'{device_name}'
    output_acc_t = f'{device_name}'
    output_acc_v = f'{device_name}'
    main_model = [model]
    main_model = main_model[0]
    for th_i in range(30):
        threshold = 100 - th_i
        main_model = model
        output_title = f'{output_title},{threshold}'
        new_structure = analyze_ranks(main_model, threshold)
        new_complexity = compute_time_complexity_single_pass(fc, new_structure, 1)
        print("........................................")
        print(f'Th={threshold}, Revised NN Structure: layers={len(new_structure)}, neurons: {new_structure}, complexity: {new_complexity}')
        samples = 4
        (avg_complexity, avg_acc_t, avg_acc_v) = (0., 0., 0.)
        for k in range(samples):
            (complexity, acc_t, acc_v) = rank_computation(f'{device_name}-{threshold}', X_std, y, new_structure, fc)
            avg_complexity += complexity
            avg_acc_t += acc_t
            avg_acc_v += acc_v

        avg_complexity = avg_complexity / samples
        avg_acc_t = avg_acc_t / samples
        avg_acc_v = avg_acc_v / samples

        output_cplx = f'{output_cplx},{avg_complexity}'
        output_acc_t = f'{output_acc_t},{avg_acc_t}'
        output_acc_v = f'{output_acc_v},{avg_acc_v}'
    output_cplx_all_devices.append(output_cplx)
    output_acc_t_all_devices.append(output_acc_t)
    output_acc_v_all_devices.append(output_acc_v)
# Out:
# processing 1.benign.csv rows = 1000
# processing 1.gafgyt.combo.csv rows = 100
# processing 1.gafgyt.junk.csv rows = 100
# processing 1.gafgyt.scan.csv rows = 100
# processing 1.gafgyt.tcp.csv rows = 100
# processing 1.gafgyt.udp.csv rows = 100
# processing 1.mirai.ack.csv rows = 100
# processing 1.mirai.scan.csv rows = 100
# processing 1.mirai.syn.csv rows = 100
# processing 1.mirai.udp.csv rows = 100
# processing 1.mirai.udpplain.csv rows = 100
# ############################[1 - Danmini_Doorbell]##########################
# ========Danmini_Doorbell========
# Features=43
# NN Structure: layers=7, neurons: [97, 83, 73, 64, 58, 53, 48]
# complexity: 32719
# title,acc,tn,fp,fn,tp
# training-cm,0.99,680,10,1,649
# training-eval,[0.016154484823346138, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,304,6,1,349
# validation-eval,[0.030288375914096832, 0.9878787994384766]
# ........................................
# Th=100, Revised NN Structure: layers=7, neurons: [97 83 73 64 58 53 48], complexity: 32719
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 83 73 64 58 53 48]
# complexity: 32719
# title,acc,tn,fp,fn,tp
# training-cm,0.99,676,7,1,656
# training-eval,[0.009839803911745548, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,4,2,341
# validation-eval,[0.0460689440369606, 0.9878787994384766]
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 83 73 64 58 53 48]
# complexity: 32719
# title,acc,tn,fp,fn,tp
# training-cm,0.99,661,7,2,670
# training-eval,[0.026908226311206818, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,327,5,5,323
# validation-eval,[0.05736229196190834, 0.9848484992980957]
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 83 73 64 58 53 48]
# complexity: 32719
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,5,1,664
# training-eval,[0.010136651806533337, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,324,1,1,334
# validation-eval,[0.016729366034269333, 0.9924242496490479]
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 83 73 64 58 53 48]
# complexity: 32719
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,3,1,672
# training-eval,[0.011105604469776154, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,4,3,324
# validation-eval,[0.49948546290397644, 0.9878787994384766]
# ........................................
# Th=99, Revised NN Structure: layers=6, neurons: [82 72 63 57 52 47], complexity: 23340
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [82 72 63 57 52 47]
# complexity: 23340
# title,acc,tn,fp,fn,tp
# training-cm,1.00,685,5,0,650
# training-eval,[0.005474386271089315, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,307,3,2,348
# validation-eval,[0.48025479912757874, 0.989393949508667]
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [82 72 63 57 52 47]
# complexity: 23340
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,4,1,667
# training-eval,[0.010387650690972805, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,3,1,331
# validation-eval,[0.029044948518276215, 0.9939393997192383]
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [82 72 63 57 52 47]
# complexity: 23340
# title,acc,tn,fp,fn,tp
# training-cm,0.99,645,6,1,688
# training-eval,[0.011220987886190414, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,349,0,1,310
# validation-eval,[0.016689641401171684, 0.9909090995788574]
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [82 72 63 57 52 47]
# complexity: 23340
# title,acc,tn,fp,fn,tp
# training-cm,1.00,655,2,1,682
# training-eval,[0.008440840058028698, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,339,4,1,316
# validation-eval,[0.024901635944843292, 0.9924242496490479]
# ........................................
# Th=98, Revised NN Structure: layers=5, neurons: [70 61 55 50 46], complexity: 16011
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [70 61 55 50 46]
# complexity: 16011
# title,acc,tn,fp,fn,tp
# training-cm,1.00,676,1,1,662
# training-eval,[0.006386386230587959, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,317,6,1,336
# validation-eval,[0.07944577187299728, 0.9878787994384766]
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [70 61 55 50 46]
# complexity: 16011
# title,acc,tn,fp,fn,tp
# training-cm,0.99,655,6,1,678
# training-eval,[0.010623384267091751, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,8,1,320
# validation-eval,[0.13646380603313446, 0.9939393997192383]
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [70 61 55 50 46]
# complexity: 16011
# title,acc,tn,fp,fn,tp
# training-cm,1.00,657,3,1,679
# training-eval,[0.008878746069967747, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,3,2,318
# validation-eval,[0.03218667954206467, 0.9924242496490479]
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [70 61 55 50 46]
# complexity: 16011
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,5,1,668
# training-eval,[0.011268415488302708, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,327,2,1,330
# validation-eval,[0.013445384800434113, 0.9939393997192383]
# ........................................
# Th=97, Revised NN Structure: layers=4, neurons: [67 59 53 48], complexity: 12821
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [67 59 53 48]
# complexity: 12821
# title,acc,tn,fp,fn,tp
# training-cm,1.00,655,2,1,682
# training-eval,[0.007890544831752777, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,341,2,2,315
# validation-eval,[0.03353070095181465, 0.9924242496490479]
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [67 59 53 48]
# complexity: 12821
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,1,2,666
# training-eval,[0.009827665984630585, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,324,4,3,329
# validation-eval,[0.03471942991018295, 0.989393949508667]
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [67 59 53 48]
# complexity: 12821
# title,acc,tn,fp,fn,tp
# training-cm,1.00,675,4,1,660
# training-eval,[0.008109135553240776, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,0,3,336
# validation-eval,[0.20719733834266663, 0.9924242496490479]
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [67 59 53 48]
# complexity: 12821
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,3,2,673
# training-eval,[0.011638450436294079, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,3,2,323
# validation-eval,[0.04082450643181801, 0.9924242496490479]
# ........................................
# Th=96, Revised NN Structure: layers=3, neurons: [56 50 46], complexity: 7778
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [56 50 46]
# complexity: 7778
# title,acc,tn,fp,fn,tp
# training-cm,0.99,636,5,2,697
# training-eval,[0.0142454132437706, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,353,6,0,301
# validation-eval,[0.013397140428423882, 0.9939393997192383]
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [56 50 46]
# complexity: 7778
# title,acc,tn,fp,fn,tp
# training-cm,1.00,686,1,2,651
# training-eval,[0.012715920805931091, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,312,1,2,345
# validation-eval,[0.017956743016839027, 0.989393949508667]
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [56 50 46]
# complexity: 7778
# title,acc,tn,fp,fn,tp
# training-cm,1.00,661,5,0,674
# training-eval,[0.006132205482572317, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,2,2,324
# validation-eval,[0.0403294637799263, 0.9924242496490479]
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [56 50 46]
# complexity: 7778
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,4,2,663
# training-eval,[0.012537301518023014, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,321,4,2,333
# validation-eval,[0.03234032914042473, 0.989393949508667]
# ........................................
# Th=95, Revised NN Structure: layers=2, neurons: [47 43], complexity: 4273
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [47 43]
# complexity: 4273
# title,acc,tn,fp,fn,tp
# training-cm,1.00,680,3,2,655
# training-eval,[0.012645674869418144, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,4,1,342
# validation-eval,[0.06521157920360565, 0.9924242496490479]
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [47 43]
# complexity: 4273
# title,acc,tn,fp,fn,tp
# training-cm,1.00,649,1,1,689
# training-eval,[0.0071573322638869286, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,343,7,2,308
# validation-eval,[0.12111275643110275, 0.9863636493682861]
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [47 43]
# complexity: 4273
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,3,2,665
# training-eval,[0.013359411619603634, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,4,3,330
# validation-eval,[0.08185791224241257, 0.989393949508667]
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [47 43]
# complexity: 4273
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,3,2,679
# training-eval,[0.013289527036249638, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,339,2,2,317
# validation-eval,[0.029892319813370705, 0.9924242496490479]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [40], complexity: 1920
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,5,8,668
# training-eval,[0.02212335355579853, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,335,1,1,323
# validation-eval,[0.008597230538725853, 0.9969696998596191]
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,7,1,661
# training-eval,[0.014779403805732727, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,317,5,2,336
# validation-eval,[0.027428684756159782, 0.9939393997192383]
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,7,0,667
# training-eval,[0.009716195054352283, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,324,3,2,331
# validation-eval,[0.029624367132782936, 0.9939393997192383]
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,0.99,655,4,9,672
# training-eval,[0.022189011797308922, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,4,2,317
# validation-eval,[0.029574457556009293, 0.9924242496490479]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [37], complexity: 1776
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [37]
# complexity: 1776
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,5,7,662
# training-eval,[0.021538279950618744, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,327,2,2,329
# validation-eval,[0.026943828910589218, 0.9939393997192383]
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [37]
# complexity: 1776
# title,acc,tn,fp,fn,tp
# training-cm,0.99,672,4,9,655
# training-eval,[0.02333330363035202, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,3,0,336
# validation-eval,[0.008474297821521759, 0.9954545497894287]
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [37]
# complexity: 1776
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,3,7,657
# training-eval,[0.021203206852078438, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,322,2,4,332
# validation-eval,[0.14866182208061218, 0.9939393997192383]
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [37]
# complexity: 1776
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,5,7,657
# training-eval,[0.017370140179991722, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,1,3,333
# validation-eval,[0.037986207753419876, 0.9939393997192383]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [34], complexity: 1632
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [34]
# complexity: 1632
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,6,0,655
# training-eval,[0.007179649546742439, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,303,12,2,343
# validation-eval,[0.14799600839614868, 0.9818181991577148]
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [34]
# complexity: 1632
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,9,2,665
# training-eval,[0.02518683671951294, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,4,0,333
# validation-eval,[0.01836344413459301, 0.9954545497894287]
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [34]
# complexity: 1632
# title,acc,tn,fp,fn,tp
# training-cm,0.99,678,1,8,653
# training-eval,[0.018807262182235718, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,320,1,3,336
# validation-eval,[0.020518258213996887, 0.9939393997192383]
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [34]
# complexity: 1632
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,2,3,673
# training-eval,[0.01597241871058941, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,3,2,322
# validation-eval,[0.02370111271739006, 0.9939393997192383]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [31], complexity: 1488
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [31]
# complexity: 1488
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,2,4,668
# training-eval,[0.011335660703480244, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,327,5,5,323
# validation-eval,[0.0464341901242733, 0.9878787994384766]
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [31]
# complexity: 1488
# title,acc,tn,fp,fn,tp
# training-cm,1.00,672,3,3,662
# training-eval,[0.013366377912461758, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,320,5,6,329
# validation-eval,[0.04407259076833725, 0.989393949508667]
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [31]
# complexity: 1488
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,5,8,665
# training-eval,[0.02015530690550804, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,331,2,1,326
# validation-eval,[0.019367527216672897, 0.9939393997192383]
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [31]
# complexity: 1488
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,2,7,671
# training-eval,[0.02059202268719673, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,3,5,317
# validation-eval,[0.20854267477989197, 0.9878787994384766]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [28], complexity: 1344
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,0.99,692,1,6,641
# training-eval,[0.01616293005645275, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,305,2,3,350
# validation-eval,[0.046714358031749725, 0.9924242496490479]
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,0.99,686,3,8,643
# training-eval,[0.019650617614388466, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,309,2,4,345
# validation-eval,[0.11340059340000153, 0.9909090995788574]
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,4,4,672
# training-eval,[0.012384505942463875, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,333,3,13,311
# validation-eval,[0.5285183191299438, 0.978787899017334]
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,0.99,677,2,6,655
# training-eval,[0.01458798348903656, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,321,0,8,331
# validation-eval,[0.219988614320755, 0.9878787994384766]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [25], complexity: 1200
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,686,4,4,646
# training-eval,[0.015506773255765438, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,305,5,2,348
# validation-eval,[0.032574258744716644, 0.9878787994384766]
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,6,7,668
# training-eval,[0.01893041655421257, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,334,1,2,323
# validation-eval,[0.018358998000621796, 0.9939393997192383]
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,3,7,666
# training-eval,[0.01983635127544403, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,3,2,325
# validation-eval,[0.023109769448637962, 0.9924242496490479]
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,4,10,656
# training-eval,[0.027196798473596573, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,324,2,3,331
# validation-eval,[0.11264421790838242, 0.9909090995788574]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [22], complexity: 1056
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,4,9,660
# training-eval,[0.024067290127277374, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,327,2,2,329
# validation-eval,[0.01616106927394867, 0.9909090995788574]
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,0.99,661,6,8,665
# training-eval,[0.021882236003875732, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,3,1,326
# validation-eval,[0.012984300032258034, 0.9954545497894287]
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,0.99,674,5,8,653
# training-eval,[0.022134890779852867, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,320,1,1,338
# validation-eval,[0.014063452370464802, 0.9954545497894287]
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,3,7,661
# training-eval,[0.018636636435985565, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,2,4,328
# validation-eval,[0.15158246457576752, 0.9939393997192383]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [19], complexity: 912
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,680,4,3,653
# training-eval,[0.011404966004192829, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,314,2,7,337
# validation-eval,[0.06042872369289398, 0.9878787994384766]
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,1.00,669,4,0,667
# training-eval,[0.006063821259886026, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,319,8,2,331
# validation-eval,[0.0782594308257103, 0.9848484992980957]
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,661,5,3,671
# training-eval,[0.021191254258155823, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,4,4,322
# validation-eval,[0.04840793460607529, 0.9863636493682861]
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,695,4,6,635
# training-eval,[0.017209647223353386, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,297,4,3,356
# validation-eval,[0.032691050320863724, 0.9939393997192383]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [16], complexity: 768
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,674,4,5,657
# training-eval,[0.01726984791457653, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,320,2,5,333
# validation-eval,[0.04131551459431648, 0.989393949508667]
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,8,7,665
# training-eval,[0.025177789852023125, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,3,2,326
# validation-eval,[0.030318161472678185, 0.9924242496490479]
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,650,6,9,675
# training-eval,[0.02328215166926384, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,344,0,1,315
# validation-eval,[0.013082019053399563, 0.9984848499298096]
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,672,6,5,657
# training-eval,[0.018330510705709457, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,322,0,4,334
# validation-eval,[0.025034725666046143, 0.9909090995788574]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [13], complexity: 624
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,0.99,687,4,7,642
# training-eval,[0.021175704896450043, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,306,3,2,349
# validation-eval,[0.03162558749318123, 0.9909090995788574]
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,1,5,664
# training-eval,[0.014022702351212502, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,4,4,327
# validation-eval,[0.06910218298435211, 0.9863636493682861]
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,4,4,673
# training-eval,[0.015649540349841118, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,2,5,318
# validation-eval,[0.026409287005662918, 0.9924242496490479]
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,1,4,668
# training-eval,[0.0162190031260252, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,1,5,323
# validation-eval,[0.04338289424777031, 0.9909090995788574]
# ........................................
# Th=84, Revised NN Structure: layers=1, neurons: [11], complexity: 528
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,5,6,656
# training-eval,[0.01948920078575611, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,4,3,335
# validation-eval,[0.04761115461587906, 0.9878787994384766]
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,4,10,659
# training-eval,[0.02284974232316017, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,3,5,326
# validation-eval,[0.03050566092133522, 0.989393949508667]
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,651,5,3,681
# training-eval,[0.021621810272336006, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,7,1,315
# validation-eval,[0.027862071990966797, 0.989393949508667]
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,648,5,6,681
# training-eval,[0.017519084736704826, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,342,5,5,308
# validation-eval,[0.02848770283162594, 0.989393949508667]
# ........................................
# Th=83, Revised NN Structure: layers=1, neurons: [9], complexity: 432
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,4,7,670
# training-eval,[0.01976699009537697, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,5,4,319
# validation-eval,[0.09774298220872879, 0.9863636493682861]
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,2,7,663
# training-eval,[0.01487644575536251, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,4,4,326
# validation-eval,[0.03156239911913872, 0.989393949508667]
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,5,5,657
# training-eval,[0.018920153379440308, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,318,4,6,332
# validation-eval,[0.05464072525501251, 0.9848484992980957]
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,8,3,662
# training-eval,[0.01697968877851963, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,317,8,2,333
# validation-eval,[0.05391796678304672, 0.9833333492279053]
# ........................................
# Th=82, Revised NN Structure: layers=1, neurons: [7], complexity: 336
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,3,10,665
# training-eval,[0.024856938049197197, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,3,4,321
# validation-eval,[0.02211531437933445, 0.9939393997192383]
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,1,6,663
# training-eval,[0.02533644251525402, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,1,4,327
# validation-eval,[0.027311021462082863, 0.9939393997192383]
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,681,6,7,646
# training-eval,[0.02550434321165085, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,310,3,3,344
# validation-eval,[0.05069224163889885, 0.9909090995788574]
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,3,7,672
# training-eval,[0.01840151660144329, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,336,3,6,315
# validation-eval,[0.09816565364599228, 0.9863636493682861]
# ........................................
# Th=81, Revised NN Structure: layers=1, neurons: [5], complexity: 240
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,3,6,673
# training-eval,[0.018486877903342247, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,4,5,316
# validation-eval,[0.037111394107341766, 0.9848484992980957]
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,5,5,666
# training-eval,[0.01913733221590519, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,327,4,6,323
# validation-eval,[0.04935457184910774, 0.9863636493682861]
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,648,9,7,676
# training-eval,[0.024001434445381165, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,338,5,3,314
# validation-eval,[0.052641671150922775, 0.9909090995788574]
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,5,8,663
# training-eval,[0.023255979642271996, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,3,3,326
# validation-eval,[0.03242351487278938, 0.9909090995788574]
# ........................................
# Th=80, Revised NN Structure: layers=1, neurons: [4], complexity: 192
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,6,6,658
# training-eval,[0.02390255406498909, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,1,5,331
# validation-eval,[0.0249189343303442, 0.9909090995788574]
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,5,8,668
# training-eval,[0.022713985294103622, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,2,5,319
# validation-eval,[0.17421598732471466, 0.9863636493682861]
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.98,658,14,8,660
# training-eval,[0.03206253796815872, 0.9843283295631409]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,313,15,5,327
# validation-eval,[0.05179152637720108, 0.9681817889213562]
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,8,6,659
# training-eval,[0.020848333835601807, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,320,5,5,330
# validation-eval,[0.07254055887460709, 0.9878787994384766]
# ........................................
# Th=79, Revised NN Structure: layers=1, neurons: [3], complexity: 144
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.99,684,1,10,645
# training-eval,[0.030525892972946167, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,312,3,10,335
# validation-eval,[0.06977739185094833, 0.9818181991577148]
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.99,675,7,5,653
# training-eval,[0.023690231144428253, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,5,4,338
# validation-eval,[0.07182250171899796, 0.9863636493682861]
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.99,683,1,12,644
# training-eval,[0.04171264171600342, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,314,2,5,339
# validation-eval,[0.03480226919054985, 0.989393949508667]
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.99,661,8,7,664
# training-eval,[0.0230433139950037, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,3,5,324
# validation-eval,[0.031355928629636765, 0.989393949508667]
# ........................................
# Th=78, Revised NN Structure: layers=1, neurons: [2], complexity: 96
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.99,676,5,10,649
# training-eval,[0.032582733780145645, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,3,6,335
# validation-eval,[0.034927140921354294, 0.9878787994384766]
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.98,635,23,7,675
# training-eval,[0.034707508981227875, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,339,3,11,307
# validation-eval,[0.06400255858898163, 0.978787899017334]
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,3,10,654
# training-eval,[0.02812696062028408, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,320,4,7,329
# validation-eval,[0.03871799632906914, 0.989393949508667]
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.98,661,2,21,656
# training-eval,[0.06026015058159828, 0.9843283295631409]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,0,7,316
# validation-eval,[0.050221048295497894, 0.989393949508667]
# ........................................
# Th=77, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,652,2,10,676
# training-eval,[0.028864948078989983, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,341,5,6,308
# validation-eval,[0.106719471514225, 0.9878787994384766]
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,1,19,647
# training-eval,[0.06494779884815216, 0.983582079410553]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,1,7,327
# validation-eval,[0.05072852596640587, 0.9863636493682861]
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,655,4,10,671
# training-eval,[0.04003727808594704, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,335,6,4,315
# validation-eval,[0.059610169380903244, 0.9818181991577148]
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,674,2,17,647
# training-eval,[0.05416174232959747, 0.987313449382782]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,324,0,13,323
# validation-eval,[0.08244864642620087, 0.9803030490875244]
# ........................................
# Th=76, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,681,1,14,644
# training-eval,[0.04907151311635971, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,317,1,6,336
# validation-eval,[0.04480963572859764, 0.9878787994384766]
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.94,610,68,11,651
# training-eval,[0.1888573169708252, 0.9432835578918457]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,301,21,2,336
# validation-eval,[0.13385064899921417, 0.9666666388511658]
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.95,613,62,10,655
# training-eval,[0.17640413343906403, 0.9485074877738953]
# title,acc,tn,fp,fn,tp
# validation-cm,0.95,298,27,4,331
# validation-eval,[0.15763473510742188, 0.9560605883598328]
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,640,20,9,671
# training-eval,[0.08839567750692368, 0.9783582091331482]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,335,5,8,312
# validation-eval,[0.08413656800985336, 0.978787899017334]
# ........................................
# Th=75, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,678,1,13,648
# training-eval,[0.04982651770114899, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,320,1,11,328
# validation-eval,[0.07676156610250473, 0.9818181991577148]
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,661,2,22,655
# training-eval,[0.07024436444044113, 0.9828358292579651]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,337,0,14,309
# validation-eval,[0.09111478179693222, 0.978787899017334]
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,659,2,26,653
# training-eval,[0.08201491832733154, 0.9805970191955566]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,338,1,13,308
# validation-eval,[0.0942196324467659, 0.978787899017334]
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,5,9,656
# training-eval,[0.04487118870019913, 0.987313449382782]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,321,4,8,327
# validation-eval,[0.09601554274559021, 0.9818181991577148]
# ........................................
# Th=74, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,629,32,9,670
# training-eval,[0.1136777251958847, 0.9701492786407471]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,312,27,2,319
# validation-eval,[0.16041675209999084, 0.9575757384300232]
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.95,624,58,11,647
# training-eval,[0.1696757823228836, 0.9485074877738953]
# title,acc,tn,fp,fn,tp
# validation-cm,0.95,287,31,3,339
# validation-eval,[0.17380551993846893, 0.9484848380088806]
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,652,1,15,672
# training-eval,[0.05235789716243744, 0.9858208894729614]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,346,1,8,305
# validation-eval,[0.05602071434259415, 0.9863636493682861]
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,642,6,11,681
# training-eval,[0.051311690360307693, 0.9843283295631409]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,350,2,3,305
# validation-eval,[0.03766993433237076, 0.9924242496490479]
# ........................................
# Th=73, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,5,11,664
# training-eval,[0.0456395223736763, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,331,4,9,316
# validation-eval,[0.06883265823125839, 0.9833333492279053]
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,641,32,6,661
# training-eval,[0.11420606076717377, 0.9716417789459229]
# title,acc,tn,fp,fn,tp
# validation-cm,0.95,305,22,8,325
# validation-eval,[0.16015367209911346, 0.9545454382896423]
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,679,2,16,643
# training-eval,[0.048233505338430405, 0.987313449382782]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,319,0,9,332
# validation-eval,[0.05981678143143654, 0.9848484992980957]
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,664,19,10,647
# training-eval,[0.08355580270290375, 0.9783582091331482]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,309,8,6,337
# validation-eval,[0.09057564288377762, 0.978787899017334]
# ........................................
# Th=72, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,2,15,652
# training-eval,[0.04685413837432861, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,327,0,7,326
# validation-eval,[0.0430137999355793, 0.989393949508667]
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,671,2,19,648
# training-eval,[0.06394936144351959, 0.9813432693481445]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,327,0,14,319
# validation-eval,[0.09313766658306122, 0.978787899017334]
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,1,11,669
# training-eval,[0.03563673794269562, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,339,1,6,314
# validation-eval,[0.04791320487856865, 0.9878787994384766]
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,664,2,20,654
# training-eval,[0.06402509659528732, 0.9813432693481445]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,0,9,317
# validation-eval,[0.06983546912670135, 0.9848484992980957]
# ........................................
# Th=71, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,644,33,13,650
# training-eval,[0.1299561858177185, 0.9641790986061096]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,302,21,1,336
# validation-eval,[0.1336165964603424, 0.9651514887809753]
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,680,1,21,638
# training-eval,[0.07017476856708527, 0.9828358292579651]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,318,1,11,330
# validation-eval,[0.06834008544683456, 0.9818181991577148]
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,2,17,648
# training-eval,[0.056767385452985764, 0.983582079410553]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,0,9,326
# validation-eval,[0.06302540749311447, 0.9863636493682861]
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,5,12,656
# training-eval,[0.044009413570165634, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,2,4,328
# validation-eval,[0.04088461771607399, 0.9909090995788574]
# processing 2.benign.csv rows = 1000
# processing 2.gafgyt.combo.csv rows = 100
# processing 2.gafgyt.junk.csv rows = 100
# processing 2.gafgyt.scan.csv rows = 100
# processing 2.gafgyt.tcp.csv rows = 100
# processing 2.gafgyt.udp.csv rows = 100
# processing 2.mirai.ack.csv rows = 100
# processing 2.mirai.scan.csv rows = 100
# processing 2.mirai.syn.csv rows = 100
# processing 2.mirai.udp.csv rows = 100
# processing 2.mirai.udpplain.csv rows = 100
# ############################[2 - Ecobee_Thermostat]##########################
# ========Ecobee_Thermostat========
# Features=54
# NN Structure: layers=5, neurons: [88, 75, 66, 58, 52]
# complexity: 22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,0,3,670
# training-eval,[0.009907705709338188, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,1,4,323
# validation-eval,[0.12044235318899155, 0.9924242496490479]
# ........................................
# Th=100, Revised NN Structure: layers=5, neurons: [88 75 66 58 52], complexity: 22582
# ========Ecobee_Thermostat-100========
# Features=54
# NN Structure: layers=5, neurons: [88 75 66 58 52]
# complexity: 22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,3,3,672
# training-eval,[0.012686179019510746, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,3,1,324
# validation-eval,[0.023733222857117653, 0.9969696998596191]
# ========Ecobee_Thermostat-100========
# Features=54
# NN Structure: layers=5, neurons: [88 75 66 58 52]
# complexity: 22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,3,0,667
# training-eval,[0.0040289112366735935, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,2,5,328
# validation-eval,[0.0338815338909626, 0.9924242496490479]
# ========Ecobee_Thermostat-100========
# Features=54
# NN Structure: layers=5, neurons: [88 75 66 58 52]
# complexity: 22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,645,0,4,691
# training-eval,[0.01388023141771555, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,354,1,0,305
# validation-eval,[0.037458259612321854, 0.9984848499298096]
# ========Ecobee_Thermostat-100========
# Features=54
# NN Structure: layers=5, neurons: [88 75 66 58 52]
# complexity: 22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,672,0,3,665
# training-eval,[0.011001133359968662, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,0,4,328
# validation-eval,[0.019746756181120872, 0.9939393997192383]
# ........................................
# Th=99, Revised NN Structure: layers=4, neurons: [87 74 65 57], complexity: 19099
# ========Ecobee_Thermostat-99========
# Features=54
# NN Structure: layers=4, neurons: [87 74 65 57]
# complexity: 19099
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,0,3,670
# training-eval,[0.010575306601822376, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,0,6,321
# validation-eval,[0.07939089834690094, 0.9909090995788574]
# ========Ecobee_Thermostat-99========
# Features=54
# NN Structure: layers=4, neurons: [87 74 65 57]
# complexity: 19099
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,0,3,666
# training-eval,[0.010840894654393196, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,327,2,1,330
# validation-eval,[0.016030529513955116, 0.9969696998596191]
# ========Ecobee_Thermostat-99========
# Features=54
# NN Structure: layers=4, neurons: [87 74 65 57]
# complexity: 19099
# title,acc,tn,fp,fn,tp
# training-cm,1.00,663,0,2,675
# training-eval,[0.007405802141875029, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,337,0,3,320
# validation-eval,[0.018625600263476372, 0.9939393997192383]
# ========Ecobee_Thermostat-99========
# Features=54
# NN Structure: layers=4, neurons: [87 74 65 57]
# complexity: 19099
# title,acc,tn,fp,fn,tp
# training-cm,1.00,681,0,1,658
# training-eval,[0.004937824793159962, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,319,0,5,336
# validation-eval,[0.029392777010798454, 0.9924242496490479]
# ........................................
# Th=98, Revised NN Structure: layers=3, neurons: [85 72 63], complexity: 14714
# ========Ecobee_Thermostat-98========
# Features=54
# NN Structure: layers=3, neurons: [85 72 63]
# complexity: 14714
# title,acc,tn,fp,fn,tp
# training-cm,1.00,683,0,2,655
# training-eval,[0.008026462979614735, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,317,0,5,338
# validation-eval,[0.04067649319767952, 0.9924242496490479]
# ========Ecobee_Thermostat-98========
# Features=54
# NN Structure: layers=3, neurons: [85 72 63]
# complexity: 14714
# title,acc,tn,fp,fn,tp
# training-cm,1.00,661,0,2,677
# training-eval,[0.00786037277430296, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,339,0,4,317
# validation-eval,[0.05481326952576637, 0.9939393997192383]
# ========Ecobee_Thermostat-98========
# Features=54
# NN Structure: layers=3, neurons: [85 72 63]
# complexity: 14714
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,0,3,671
# training-eval,[0.01645730435848236, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,334,0,3,323
# validation-eval,[0.021421460434794426, 0.9954545497894287]
# ========Ecobee_Thermostat-98========
# Features=54
# NN Structure: layers=3, neurons: [85 72 63]
# complexity: 14714
# ...
# training-eval,[0.008836472406983376, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,320,0,3,337
# validation-eval,[0.04497591406106949, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-81========
# Features=44
# NN Structure: layers=1, neurons: [4]
# complexity: 228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,0,4,674
# training-eval,[0.014156535267829895, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,5,1,321
# validation-eval,[0.08914419263601303, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-81========
# Features=44
# NN Structure: layers=1, neurons: [4]
# complexity: 228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,677,0,2,661
# training-eval,[0.008209670893847942, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,322,1,2,335
# validation-eval,[0.021875770762562752, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-81========
# Features=44
# NN Structure: layers=1, neurons: [4]
# complexity: 228
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,0,3,670
# training-eval,[0.01190925296396017, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,0,4,323
# validation-eval,[0.03576633706688881, 0.9939393997192383]
# ........................................
# Th=80, Revised NN Structure: layers=1, neurons: [3], complexity: 171
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-80========
# Features=44
# NN Structure: layers=1, neurons: [3]
# complexity: 171
# title,acc,tn,fp,fn,tp
# training-cm,1.00,677,0,4,659
# training-eval,[0.014934007078409195, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,322,1,1,336
# validation-eval,[0.015278789214789867, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-80========
# Features=44
# NN Structure: layers=1, neurons: [3]
# complexity: 171
# title,acc,tn,fp,fn,tp
# training-cm,1.00,691,1,2,646
# training-eval,[0.010357514023780823, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,307,1,3,349
# validation-eval,[0.02439030446112156, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-80========
# Features=44
# NN Structure: layers=1, neurons: [3]
# complexity: 171
# title,acc,tn,fp,fn,tp
# training-cm,1.00,663,0,4,673
# training-eval,[0.01565602794289589, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,336,1,3,320
# validation-eval,[0.1009722426533699, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-80========
# Features=44
# NN Structure: layers=1, neurons: [3]
# complexity: 171
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,0,4,670
# training-eval,[0.014484548941254616, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,333,1,2,324
# validation-eval,[0.010013834573328495, 0.9969696998596191]
# ........................................
# Th=79, Revised NN Structure: layers=1, neurons: [2], complexity: 114
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-79========
# Features=44
# NN Structure: layers=1, neurons: [2]
# complexity: 114
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,0,5,665
# training-eval,[0.017353404313325882, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,1,3,327
# validation-eval,[0.02132868953049183, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-79========
# Features=44
# NN Structure: layers=1, neurons: [2]
# complexity: 114
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,1,3,674
# training-eval,[0.015106163918972015, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,336,1,2,321
# validation-eval,[0.019238945096731186, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-79========
# Features=44
# NN Structure: layers=1, neurons: [2]
# complexity: 114
# title,acc,tn,fp,fn,tp
# training-cm,1.00,681,0,4,655
# training-eval,[0.014433146454393864, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,319,0,3,338
# validation-eval,[0.019850285723805428, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-79========
# Features=44
# NN Structure: layers=1, neurons: [2]
# complexity: 114
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,0,4,680
# training-eval,[0.01583082042634487, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,342,2,4,312
# validation-eval,[0.15084867179393768, 0.9924242496490479]
# ........................................
# Th=78, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-78========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,1,3,669
# training-eval,[0.016775008291006088, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,331,1,1,327
# validation-eval,[0.01653130166232586, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-78========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,681,0,3,656
# training-eval,[0.012459943071007729, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,318,1,2,339
# validation-eval,[0.026065994054079056, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-78========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.96,620,50,3,667
# training-eval,[0.1464187353849411, 0.9604477882385254]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,318,12,1,329
# validation-eval,[0.09338501840829849, 0.9803030490875244]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-78========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.97,637,44,2,657
# training-eval,[0.13074010610580444, 0.9656716585159302]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,304,15,2,339
# validation-eval,[0.10860681533813477, 0.9742424488067627]
# ........................................
# Th=77, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-77========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,1,5,678
# training-eval,[0.02199799194931984, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,343,0,0,317
# validation-eval,[0.005965410731732845, 1.0]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-77========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,663,1,4,672
# training-eval,[0.017284179106354713, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,336,0,1,323
# validation-eval,[0.05021132156252861, 0.9984848499298096]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-77========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,0,5,668
# training-eval,[0.021062146872282028, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,0,6,321
# validation-eval,[0.04611876606941223, 0.9909090995788574]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-77========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.86,487,192,2,659
# training-eval,[0.3472055196762085, 0.8552238941192627]
# title,acc,tn,fp,fn,tp
# validation-cm,0.86,234,87,5,334
# validation-eval,[0.36348089575767517, 0.8606060743331909]
# ........................................
# Th=76, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-76========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,690,1,4,645
# training-eval,[0.020100004971027374, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,309,0,0,351
# validation-eval,[0.00946673471480608, 0.9984848499298096]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-76========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,675,0,4,661
# training-eval,[0.01836148463189602, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,0,7,328
# validation-eval,[0.05608852952718735, 0.989393949508667]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-76========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,0,2,665
# training-eval,[0.009636717848479748, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,2,3,330
# validation-eval,[0.0818144753575325, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-76========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,653,0,3,684
# training-eval,[0.012653685174882412, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,345,2,2,311
# validation-eval,[0.06014014035463333, 0.9954545497894287]
# ........................................
# Th=75, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-75========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,690,1,5,644
# training-eval,[0.02081536315381527, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,309,0,1,350
# validation-eval,[0.008509217761456966, 0.9984848499298096]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-75========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.96,608,46,2,684
# training-eval,[0.1362740695476532, 0.9641790986061096]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,329,17,2,312
# validation-eval,[0.11339462548494339, 0.9727272987365723]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-75========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,659,1,5,675
# training-eval,[0.021327126771211624, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,340,0,0,320
# validation-eval,[0.0054547893814742565, 1.0]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-75========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,0,4,670
# training-eval,[0.017976993694901466, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,332,2,0,326
# validation-eval,[0.01817162148654461, 0.9969696998596191]
# ........................................
# Th=74, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-74========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.97,641,41,3,655
# training-eval,[0.12766872346401215, 0.967164158821106]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,297,21,2,340
# validation-eval,[0.13980412483215332, 0.9651514887809753]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-74========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.95,616,59,3,662
# training-eval,[0.16541865468025208, 0.9529850482940674]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,300,25,4,331
# validation-eval,[0.16280636191368103, 0.9545454382896423]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-74========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.96,619,53,4,664
# training-eval,[0.15432919561862946, 0.9567164182662964]
# title,acc,tn,fp,fn,tp
# validation-cm,0.95,297,31,1,331
# validation-eval,[0.20160846412181854, 0.9515151381492615]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-74========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,0,2,667
# training-eval,[0.00920890923589468, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,1,5,326
# validation-eval,[0.0505722351372242, 0.9909090995788574]
# ........................................
# Th=73, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-73========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,657,0,3,680
# training-eval,[0.01434070523828268, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,343,0,4,313
# validation-eval,[0.03463609516620636, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-73========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,684,1,1,654
# training-eval,[0.009239155799150467, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,2,3,342
# validation-eval,[0.029335834085941315, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-73========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,677,1,4,658
# training-eval,[0.018116172403097153, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,1,2,336
# validation-eval,[0.014540274627506733, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-73========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.97,628,36,2,674
# training-eval,[0.1144028753042221, 0.9716417789459229]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,310,26,2,322
# validation-eval,[0.15749220550060272, 0.9575757384300232]
# ........................................
# Th=72, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-72========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,1,9,668
# training-eval,[0.0361606627702713, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,336,1,2,321
# validation-eval,[0.016805261373519897, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-72========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,2,3,664
# training-eval,[0.01602669060230255, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,4,1,332
# validation-eval,[0.021418094635009766, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-72========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,675,0,5,660
# training-eval,[0.02206331118941307, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,0,4,331
# validation-eval,[0.03326701372861862, 0.9939393997192383]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-72========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,0,5,662
# training-eval,[0.02204926870763302, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,327,0,5,328
# validation-eval,[0.0422503724694252, 0.9924242496490479]
# ........................................
# Th=71, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-71========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,659,0,6,675
# training-eval,[0.025639235973358154, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,341,0,3,316
# validation-eval,[0.02445533685386181, 0.9954545497894287]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-71========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,672,1,3,664
# training-eval,[0.01539058517664671, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,4,1,332
# validation-eval,[0.017174795269966125, 0.9969696998596191]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-71========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.86,472,189,3,676
# training-eval,[0.3497137129306793, 0.8567163944244385]
# title,acc,tn,fp,fn,tp
# validation-cm,0.86,248,91,1,320
# validation-eval,[0.3408709764480591, 0.8575757741928101]
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-71========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,669,0,5,666
# training-eval,[0.022028177976608276, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,331,0,3,326
# validation-eval,[0.027652980759739876, 0.9939393997192383]

# %%
def print_summary(title, table_header, record):
    print(f"-------------------------{title}-------------------------")
    print(table_header)
    for item in record:
        print(item)

# %%
print(f"****************************[Summary]****************************")
print_summary('time complexities', output_title, output_cplx_all_devices)
print_summary('training accuracy', output_title, output_acc_t_all_devices)
print_summary('validation accuracy', output_title, output_acc_v_all_devices)
# Out:
# ****************************[Summary]****************************
# -------------------------time complexities-------------------------
# device_name,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71
# Danmini_Doorbell,32719.0,23340.0,16011.0,12821.0,7778.0,4273.0,1920.0,1776.0,1632.0,1488.0,1344.0,1200.0,1056.0,912.0,768.0,624.0,528.0,432.0,336.0,240.0,192.0,144.0,96.0,48.0,48.0,48.0,48.0,48.0,48.0,48.