# %%
# Imports

########################################################################
# Python Standard Libraries
import os
import multiprocessing
from timeit import default_timer as timer
import random
import math

########################################################################
# Numpy Library
import numpy as np # linear algebra

########################################################################
# Pandas Library
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

########################################################################
# MATPLOT Library
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
# %matplotlib inline

########################################################################
# SKLearn Library
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_recall_curve, classification_report, confusion_matrix, average_precision_score, roc_curve, auc, multilabel_confusion_matrix

########################################################################
# SCIPY Library
from scipy.stats import gaussian_kde
import scipy.stats as st


########################################################################
# Keras Library
from keras.models import Sequential
from keras.layers import Dense

########################################################################
# Init random seed
#seed = 13
#np.random.seed(seed)

# %%
# Utility functions
########################################################################
# Print system information
def print_system_info():
    mem_bytes = os.sysconf('SC_PAGE_SIZE') * os.sysconf('SC_PHYS_PAGES')  # e.g. 4015976448
    mem_gib = mem_bytes/(1024.**3)  # e.g. 3.74
    print("{:<23}{:f} GB".format('RAM:', mem_gib))
    print("{:<23}{:d}".format('CORES:', multiprocessing.cpu_count()))
    # !lscpu

########################################################################
# Walk through input files
def print_input_files():
    # Input data files are available in the "../input/" directory.
    for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            print(os.path.join(dirname, filename))

########################################################################
# Dump text files
def dump_text_file(fname):
    with open(fname, 'r') as f:
        print(f.read())

########################################################################
# Dump CSV files
def dump_csv_file(fname, count=5):
    # count: 0 - column names only, -1 - all rows, default = 5 rows max
    df = pd.read_csv(fname)
    if count < 0:
        count = df.shape[0]
    return df.head(count)

########################################################################
# Dataset related functions
ds_nbaiot = '/kaggle/input/nbaiot-dataset'
dn_nbaiot = ['Danmini_Doorbell', 'Ecobee_Thermostat', 'Ennio_Doorbell', 'Philips_B120N10_Baby_Monitor', 'Provision_PT_737E_Security_Camera', 'Provision_PT_838_Security_Camera', 'Samsung_SNH_1011_N_Webcam', 'SimpleHome_XCS7_1002_WHT_Security_Camera', 'SimpleHome_XCS7_1003_WHT_Security_Camera']

def fname(ds, f):
    if '.csv' not in f:
        f = f'{f}.csv'
    return os.path.join(ds, f)

def fname_nbaiot(f):
    return fname(ds_nbaiot, f)

def get_nbaiot_device_files():
    nbaiot_all_files = dump_csv_file(fname_nbaiot('data_summary'), -1)
    nbaiot_all_files = nbaiot_all_files.iloc[:,0:1].values
    device_id = 1
    indices = []
    for j in range(len(nbaiot_all_files)):
        if str(device_id) not in str(nbaiot_all_files[j]):
            indices.append(j)
            device_id += 1
    nbaiot_device_files = np.split(nbaiot_all_files, indices)
    return nbaiot_device_files

def get_nbaiot_device_data(device_id, count_norm=-1, count_anom=-1):
    if device_id < 1 or device_id > 9:
        assert False, "Please provide a valid device ID 1-9, both inclusive"
    if count_anom == -1:
        count_anom = count_norm
    device_index = device_id -1
    device_files = get_nbaiot_device_files()
    device_file = device_files[device_index]
    df = pd.DataFrame()
    y = []
    for i in range(len(device_file)):
        fname = str(device_file[i][0])
        df_c = pd.read_csv(fname_nbaiot(fname))
        count = count_anom
        if 'benign' in fname:
            count = count_norm
        count = min(count, df_c.shape[0]) if count >=0 else df_c.shape[0]
        rows = count
        print("processing", fname, "rows =", rows)
        y_np = np.ones(rows) if 'benign' in fname else np.zeros(rows)
        y.extend(y_np.tolist())
        df = pd.concat([df.iloc[:,:].reset_index(drop=True),
                      df_c.iloc[:rows,:].reset_index(drop=True)], axis=0)
    X = df.iloc[:,:].values
    y = np.array(y)
    Xdf = df
    return (X, y, Xdf)

def get_nbaiot_devices_data():
    devices_data = []
    for i in range(9):
        device_id = i + 1
        (X, y) = get_nbaiot_device_data(device_id)
        devices_data.append((X, y))
    return devices_data
#print_input_files()
print_system_info()
# Out:
# RAM:                   18.621841 GB
# CORES:                 4
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              4
# On-line CPU(s) list: 0-3
# Thread(s) per core:  2
# Core(s) per socket:  2
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               79
# Model name:          Intel(R) Xeon(R) CPU @ 2.20GHz
# Stepping:            0
# CPU MHz:             2200.000
# BogoMIPS:            4400.00
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            56320K
# NUMA node0 CPU(s):   0-3
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities

# %%
def remove_correlated_features(df, threshold):
    df = df.copy()
    # Create correlation matrix
    corr_matrix = df.corr().abs()

    # Select upper triangle of correlation matrix
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

    # Find features with correlation greater than a threshold
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

    # Drop features 
    df.drop(to_drop, axis=1, inplace=True)
    return df.iloc[:,:].values

def mark_important_features(vector, pc_keep): # pc_keep is the percentage (0-100) of labels to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    important_bool = (vector >= th)
    important_int = important_bool.astype(int)
    return important_int

def select_features(X, X_norm, X_anom, threshold):
    rows_n = X_norm.shape[0]
    rows_a = X_anom.shape[0]
    if rows_n == 0 or rows_a == 0:
        return X

    y_norm = np.ones(rows_n)
    y_anom = -1 * np.ones(rows_a)

    reg_n = LinearRegression(fit_intercept=False)
    reg_n.fit(X_norm, y_norm)
    coef_n = abs(reg_n.coef_)
    n = mark_important_features(coef_n, threshold)

    reg_a = LinearRegression(fit_intercept=False)
    reg_a.fit(X_anom, y_anom)
    coef_a = abs(reg_a.coef_)
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel

# %%
def create_binary_classifier(hidden_layers, input_dim):
    layers = []
    for hl in hidden_layers:
        if hl > 0:
            layers.append(hl)

    layer_count = len(layers)
    assert layer_count >= 1, 'at least 1 non-zero hidden layer is needed'
    model = Sequential()
    model.add(Dense(layers[0],input_dim=input_dim,activation='relu'))
    for i in range(1, layer_count):
        model.add(Dense(layers[i],activation='relu'))

    model.add(Dense(1,activation='sigmoid'))
    #model.summary()
    model.compile(loss = 'binary_crossentropy',
             optimizer ='adam',metrics=['accuracy'])
    return model

# %%
def compute_time_complexity_single_pass(neurons_input, structure, neurons_output):
    count_hidden_layers = len(structure)
    neurons = [neurons_input, *structure, neurons_output]
    complexity = 0
    for i in range(count_hidden_layers + 1):
        complexity += neurons[i] * neurons[i+1]
    return complexity

# %%
def keep_mask(vector, pc_keep): # pc_keep is the percentage (0-100) of items to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    mask_bool = (vector >= th)
    mask_int = mask_bool.astype(int)
    return (mask_bool, mask_int)

# %%
'''
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel
'''
# Out:
# '\n    a = mark_important_features(coef_a, threshold)\n   \n    mask = np.bitwise_or(n,a)\n    mask = mask == 1 # convert to Boolean\n    X_sel = X[:, mask]\n    return X_sel\n'

# %%
def analyze_ranks(model, threshold):
    w_d = 0
    b_d = 0
    layer_count = len(model.layers)
    layer_ranks = []
    new_structure = []
    for i in range(layer_count-1):
        (w_c, b_c) = model.layers[i+1].get_weights() # current weigths and biases
        rows = w_c.shape[0]
        cols = w_c.shape[1]
        w_c_abs = np.absolute(w_c)
        rank_neurons = np.sum(w_c_abs, axis=1) / cols
        rank_layer = np.sum(rank_neurons) / rows
        layer_ranks.append(rank_layer)
        (mask_bool, mask_int) = keep_mask(rank_neurons, threshold)
        new_neuron_count = np.sum(mask_int)
        new_structure.append(new_neuron_count)
        #print(f'{i+1}: {rank_neurons.shape} {rank_layer} {mask_int} {new_neuron_count}')
    layer_ranks = np.array(layer_ranks)
    new_structure = np.array(new_structure)
    (mask_bool, mask_int) = keep_mask(layer_ranks, threshold)
    new_structure = new_structure[mask_bool]
    #new_structure_masked = new_structure
    #print(f'layer mask: {mask_int} {new_structure}')
    return new_structure

# %%
model = None
def compute_report(title, model, X, y):
    y_pred = model.predict(X)
    y_pred = (y_pred > 0.25)
    #print(y_pred)
    #y_pred[y_pred <= 0] = -1 # convert negative values as 0 for anomaly
    #y_pred[y_pred > 0] = 1 # convert positive values as 1 for normal
    acc = accuracy_score(y, y_pred)
    tn, fp, fn, tp = confusion_matrix(y, y_pred, labels=[0,1]).ravel()
    cr = classification_report(y, y_pred)
    print("title,acc,tn,fp,fn,tp")
    print(f'{title}-cm,{acc:.2f},{tn},{fp},{fn},{tp}')
    #print(f'{cr}')
    results = model.evaluate(X, y, verbose=0)
    print(f'{title}-eval,{results}')

def rank_computation(title, X, y, structure, fc):
    global model
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    print (f"========{title}========")
    feature_count = X.shape[1]
    print(f'Features={feature_count}')
    print(f'NN Structure: layers={len(structure)}, neurons: {structure}')
    print('complexity: ', compute_time_complexity_single_pass(fc, structure, 1))
    model = create_binary_classifier(structure, feature_count)
    model.fit(X_train,y_train,epochs=150,batch_size=10,verbose=0)
    #analyze_ranks(model, 95)
    compute_report('training', model, X_train, y_train)
    compute_report('validation', model, X_test, y_test)

# %%
debug_flag = True

# %%
if debug_flag:
    count_norm = 1000
    count_anom = 100
    #device_indices = [0]
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]
else:
    count_norm = -1
    count_anom = -1
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]

structures = {
    '0': [97, 83, 73, 64, 58, 53, 48],
    '1': [88, 75, 66, 58, 52],
    '2': [57, 49, 43, 38, 34, 31],
    '3': [101, 75, 67, 60, 55, 50, 46],
    '4': [87, 75, 58, 52, 47, 43],
    '5': [88, 75, 58, 52, 48, 44],
    '6': [59, 50, 44, 39, 35, 32],
    '7': [76, 67, 59, 53, 48],
    '8': [88, 76, 59, 53, 48]
}
fcs = [47, 47, 59, 51, 40, 42, 56, 56, 56]
for i in device_indices:
    device_index = i
    device_id = device_index + 1
    device_name = dn_nbaiot[device_index]
    (X, y, Xdf) = get_nbaiot_device_data(device_id, count_norm, count_anom)
    X = remove_correlated_features(Xdf, 0.98)
    X_std = StandardScaler().fit_transform(X)
    indices_norm = np.where(y >= 0.5)
    indices_anom = np.where(y <= 0.5)
    X_norm_all = X_std[indices_norm]
    X_anom_all = X_std[indices_anom]
    X_std = select_features(X_std, X_norm_all, X_anom_all,75)
    fc = fcs[i]
    print(f'############################[{i+1} - {device_name}]##########################')
    rank_computation(device_name, X_std, y, structures.get(f'{i}'), fc)
    thresholds = [100, 99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88, 87, 86, 85]
    for threshold in thresholds:
        #threshold = 95
        new_structure = analyze_ranks(model, threshold)
        new_complexity = compute_time_complexity_single_pass(fc, new_structure, 1)
        print("........................................")
        print(f'Th={threshold}, Revised NN Structure: layers={len(new_structure)}, neurons: {new_structure}, complexity: {new_complexity}')
        rank_computation(f'{device_name}-{threshold}', X_std, y, new_structure, fc)
# Out:
# processing 1.benign.csv rows = 1000
# processing 1.gafgyt.combo.csv rows = 100
# processing 1.gafgyt.junk.csv rows = 100
# processing 1.gafgyt.scan.csv rows = 100
# processing 1.gafgyt.tcp.csv rows = 100
# processing 1.gafgyt.udp.csv rows = 100
# processing 1.mirai.ack.csv rows = 100
# processing 1.mirai.scan.csv rows = 100
# processing 1.mirai.syn.csv rows = 100
# processing 1.mirai.udp.csv rows = 100
# processing 1.mirai.udpplain.csv rows = 100
# ############################[1 - Danmini_Doorbell]##########################
# ========Danmini_Doorbell========
# Features=43
# NN Structure: layers=7, neurons: [97, 83, 73, 64, 58, 53, 48]
# complexity:  32719
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,4,3,664
# training-eval,[0.014118663966655731, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,4,3,330
# validation-eval,[0.059035271406173706, 0.989393949508667]
# ........................................
# Th=100, Revised NN Structure: layers=7, neurons: [97 83 73 64 58 53 48], complexity: 32719
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 83 73 64 58 53 48]
# complexity:  32719
# title,acc,tn,fp,fn,tp
# training-cm,0.99,651,8,1,680
# training-eval,[0.010357504710555077, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,6,1,318
# validation-eval,[0.03015577234327793, 0.9924242496490479]
# ........................................
# Th=99, Revised NN Structure: layers=6, neurons: [96 82 72 63 57 52], complexity: 29431
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [96 82 72 63 57 52]
# complexity:  29431
# title,acc,tn,fp,fn,tp
# training-cm,0.99,679,9,1,651
# training-eval,[0.013617262244224548, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,308,4,3,345
# validation-eval,[0.2530823349952698, 0.989393949508667]
# ........................................
# Th=98, Revised NN Structure: layers=5, neurons: [94 80 70 61 55], complexity: 25218
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [94 80 70 61 55]
# complexity:  25218
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,6,1,673
# training-eval,[0.012088085524737835, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,333,1,1,325
# validation-eval,[0.014811670407652855, 0.9954545497894287]
# ........................................
# Th=97, Revised NN Structure: layers=4, neurons: [77 67 59 53], complexity: 15911
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [77 67 59 53]
# complexity:  15911
# title,acc,tn,fp,fn,tp
# training-cm,1.00,680,4,1,655
# training-eval,[0.01219826191663742, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,314,2,1,343
# validation-eval,[0.017770472913980484, 0.9909090995788574]
# ........................................
# Th=96, Revised NN Structure: layers=3, neurons: [64 56 50], complexity: 9442
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [64 56 50]
# complexity:  9442
# title,acc,tn,fp,fn,tp
# training-cm,1.00,653,4,2,681
# training-eval,[0.014735782518982887, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,341,2,0,317
# validation-eval,[0.0019205042626708746, 1.0]
# ........................................
# Th=95, Revised NN Structure: layers=2, neurons: [53 47], complexity: 5029
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [53 47]
# complexity:  5029
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,5,1,667
# training-eval,[0.008094150573015213, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,322,6,1,331
# validation-eval,[0.02923550084233284, 0.9924242496490479]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [44], complexity: 2112
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [44]
# complexity:  2112
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,1,4,656
# training-eval,[0.014933325350284576, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,2,5,335
# validation-eval,[0.1444707214832306, 0.9878787994384766]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [40], complexity: 1920
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity:  1920
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,3,6,660
# training-eval,[0.012919622473418713, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,3,3,331
# validation-eval,[0.03460131958127022, 0.9939393997192383]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [36], complexity: 1728
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [36]
# complexity:  1728
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,3,4,673
# training-eval,[0.014848886989057064, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,3,5,318
# validation-eval,[0.026069400832057, 0.9924242496490479]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [32], complexity: 1536
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [32]
# complexity:  1536
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,4,5,673
# training-eval,[0.01735370047390461, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,3,5,317
# validation-eval,[0.03126628324389458, 0.9909090995788574]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [28], complexity: 1344
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity:  1344
# title,acc,tn,fp,fn,tp
# training-cm,0.99,677,5,6,652
# training-eval,[0.019998498260974884, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,2,3,339
# validation-eval,[0.04259740933775902, 0.9909090995788574]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [25], complexity: 1200
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity:  1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,678,5,6,651
# training-eval,[0.01877470128238201, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,314,3,3,340
# validation-eval,[0.02045631967484951, 0.9909090995788574]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [22], complexity: 1056
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity:  1056
# title,acc,tn,fp,fn,tp
# training-cm,0.99,678,2,5,655
# training-eval,[0.014111769385635853, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,314,6,4,336
# validation-eval,[0.08093493431806564, 0.9848484992980957]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [19], complexity: 912
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity:  912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,682,5,7,646
# training-eval,[0.021812602877616882, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,311,2,2,345
# validation-eval,[0.014411410316824913, 0.9954545497894287]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [16], complexity: 768
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity:  768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,3,5,674
# training-eval,[0.017136571928858757, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,5,4,317
# validation-eval,[0.025262778624892235, 0.9924242496490479]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [13], complexity: 624
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity:  624
# title,acc,tn,fp,fn,tp
# training-cm,0.99,675,4,5,656
# training-eval,[0.017062993720173836, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,3,4,335
# validation-eval,[0.022677794098854065, 0.989393949508667]
# processing 2.benign.csv rows = 1000
# processing 2.gafgyt.combo.csv rows = 100
# processing 2.gafgyt.junk.csv rows = 100
# processing 2.gafgyt.scan.csv rows = 100
# processing 2.gafgyt.tcp.csv rows = 100
# processing 2.gafgyt.udp.csv rows = 100
# processing 2.mirai.ack.csv rows = 100
# processing 2.mirai.scan.csv rows = 100
# processing 2.mirai.syn.csv rows = 100
# processing 2.mirai.udp.csv rows = 100
# processing 2.mirai.udpplain.csv rows = 100
# ############################[2 - Ecobee_Thermostat]##########################
# ========Ecobee_Thermostat========
# Features=53
# NN Structure: layers=5, neurons: [88, 75, 66, 58, 52]
# complexity:  22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,648,0,2,690
# training-eval,[0.007228962145745754, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,352,0,4,304
# validation-eval,[0.030626416206359863, 0.9939393997192383]
# ........................................
# Th=100, Revised NN Structure: layers=5, neurons: [88 75 66 58 52], complexity: 22582
# ========Ecobee_Thermostat-100========
# Features=53
# NN Structure: layers=5, neurons: [88 75 66 58 52]
# complexity:  22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,672,0,3,665
# training-eval,[0.011245491914451122, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,328,0,3,329
# validation-eval,[0.020565470680594444, 0.9954545497894287]
# ........................................
# Th=99, Revised NN Structure: layers=4, neurons: [87 74 65 57], complexity: 19099
# ========Ecobee_Thermostat-99========
# Features=53
# NN Structure: layers=4, neurons: [87 74 65 57]
# complexity:  19099
# title,acc,tn,fp,fn,tp
# training-cm,1.00,694,0,4,642
# training-eval,[0.013471671380102634, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,306,0,2,352
# validation-eval,[0.007929887622594833, 0.9969696998596191]
# ........................................
# Th=98, Revised NN Structure: layers=3, neurons: [85 72 63], complexity: 14714
# ========Ecobee_Thermostat-98========
# Features=53
# NN Structure: layers=3, neurons: [85 72 63]
# complexity:  14714
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,0,2,668
# training-eval,[0.00850155670195818, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,330,0,2,328
# validation-eval,[0.015078212134540081, 0.9969696998596191]
# ........................................
# Th=97, Revised NN Structure: layers=2, neurons: [69 61], complexity: 7513
# ========Ecobee_Thermostat-97========
# Features=53
# NN Structure: layers=2, neurons: [69 61]
# complexity:  7513
# title,acc,tn,fp,fn,tp
# training-cm,1.00,674,0,2,664
# training-eval,[0.008159630931913853, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,325,1,2,332
# validation-eval,[0.028410974889993668, 0.9954545497894287]
# ........................................
# Th=96, Revised NN Structure: layers=1, neurons: [58], complexity: 2784
# ========Ecobee_Thermostat-96========
# Features=53
# NN Structure: layers=1, neurons: [58]
# complexity:  2784
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,0,4,672
# training-eval,[0.01315215788781643, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,336,0,1,323
# validation-eval,[0.010861653834581375, 0.9969696998596191]
# ........................................
# Th=95, Revised NN Structure: layers=1, neurons: [55], complexity: 2640
# ========Ecobee_Thermostat-95========
# Features=53
# NN Structure: layers=1, neurons: [55]
# complexity:  2640
# title,acc,tn,fp,fn,tp
# training-cm,0.99,656,3,4,677
# training-eval,[0.012890394777059555, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,339,2,0,319
# validation-eval,[0.005121882073581219, 1.0]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [51], complexity: 2448
# ========Ecobee_Thermostat-94========
# Features=53
# NN Structure: layers=1, neurons: [51]
# complexity:  2448
# title,acc,tn,fp,fn,tp
# training-cm,1.00,697,0,2,641
# training-eval,[0.007020787335932255, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,303,0,2,355
# validation-eval,[0.020632248371839523, 0.9969696998596191]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [47], complexity: 2256
# ========Ecobee_Thermostat-93========
# Features=53
# NN Structure: layers=1, neurons: [47]
# complexity:  2256
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,0,4,670
# training-eval,[0.016362007707357407, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,334,0,0,326
# validation-eval,[0.0014843783574178815, 1.0]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [43], complexity: 2064
# ========Ecobee_Thermostat-92========
# Features=53
# NN Structure: layers=1, neurons: [43]
# complexity:  2064
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,0,3,671
# training-eval,[0.010312739759683609, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,334,0,2,324
# validation-eval,[0.016861217096447945, 0.9969696998596191]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [39], complexity: 1872
# ========Ecobee_Thermostat-91========
# Features=53
# NN Structure: layers=1, neurons: [39]
# complexity:  1872
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,0,4,666
# training-eval,[0.01319863647222519, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,330,0,0,330
# validation-eval,[0.004084363114088774, 0.9984848499298096]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [35], complexity: 1680
# ========Ecobee_Thermostat-90========
# Features=53
# NN Structure: layers=1, neurons: [35]
# complexity:  1680
# title,acc,tn,fp,fn,tp
# training-cm,1.00,672,0,3,665
# training-eval,[0.010020622983574867, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,3,2,330
# validation-eval,[0.04738129302859306, 0.9909090995788574]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [31], complexity: 1488
# ========Ecobee_Thermostat-89========
# Features=53
# NN Structure: layers=1, neurons: [31]
# complexity:  1488
# title,acc,tn,fp,fn,tp
# training-cm,1.00,661,3,3,673
# training-eval,[0.009889254346489906, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,334,2,1,323
# validation-eval,[0.009276051074266434, 0.9984848499298096]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [27], complexity: 1296
# ========Ecobee_Thermostat-88========
# Features=53
# NN Structure: layers=1, neurons: [27]
# complexity:  1296
# title,acc,tn,fp,fn,tp
# training-cm,1.00,691,0,2,647
# training-eval,[0.00870896689593792, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,309,0,4,347
# validation-eval,[0.029732488095760345, 0.9939393997192383]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [23], complexity: 1104
# ========Ecobee_Thermostat-87========
# Features=53
# NN Structure: layers=1, neurons: [23]
# complexity:  1104
# title,acc,tn,fp,fn,tp
# training-cm,1.00,665,0,3,672
# training-eval,[0.011746370233595371, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,335,0,2,323
# validation-eval,[0.008938876911997795, 0.9969696998596191]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [19], complexity: 912
# ========Ecobee_Thermostat-86========
# Features=53
# NN Structure: layers=1, neurons: [19]
# complexity:  912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,4,3,675
# training-eval,[0.011184560135006905, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,337,1,1,321
# validation-eval,[0.008475804701447487, 0.9984848499298096]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [16], complexity: 768
# ========Ecobee_Thermostat-85========
# Features=53
# NN Structure: layers=1, neurons: [16]
# complexity:  768
# title,acc,tn,fp,fn,tp
# training-cm,1.00,657,0,2,681
# training-eval,[0.008522727526724339, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,343,0,3,314
# validation-eval,[0.01845085434615612, 0.9954545497894287]
# processing 3.benign.csv rows = 1000
# processing 3.gafgyt.combo.csv rows = 100
# processing 3.gafgyt.junk.csv rows = 100
# processing 3.gafgyt.scan.csv rows = 100
# processing 3.gafgyt.tcp.csv rows = 100
# processing 3.gafgyt.udp.csv rows = 100
# ############################[3 - Ennio_Doorbell]##########################
# ========Ennio_Doorbell========
# Features=53
# NN Structure: layers=6, neurons: [57, 49, 43, 38, 34, 31]
# complexity:  12274
# title,acc,tn,fp,fn,tp
# training-cm,1.00,334,0,1,670
# training-eval,[0.0063662901520729065, 0.9990049600601196]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,166,0,1,328
# validation-eval,[0.06117318570613861, 0.9979798197746277]
# ........................................
# Th=100, Revised NN Structure: layers=6, neurons: [57 49 43 38 34 31], complexity: 12274
# ========Ennio_Doorbell-100========
# Features=53
# NN Structure: layers=6, neurons: [57 49 43 38 34 31]
# complexity:  12274
# title,acc,tn,fp,fn,tp
# training-cm,1.00,325,0,1,679
# training-eval,[0.006081062369048595, 0.9990049600601196]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,174,1,1,319
# validation-eval,[0.15068069100379944, 0.9959595799446106]
# ........................................
# Th=99, Revised NN Structure: layers=5, neurons: [48 42 37 33 30], complexity: 8643
# ========Ennio_Doorbell-99========
# Features=53
# NN Structure: layers=5, neurons: [48 42 37 33 30]
# complexity:  8643
# title,acc,tn,fp,fn,tp
# training-cm,1.00,336,0,1,668
# training-eval,[0.005849645473062992, 0.9990049600601196]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,164,0,0,331
# validation-eval,[0.0007645566365681589, 1.0]
# ........................................
# Th=98, Revised NN Structure: layers=4, neurons: [41 36 32 29], complexity: 6004
# ========Ennio_Doorbell-98========
# Features=53
# NN Structure: layers=4, neurons: [41 36 32 29]
# complexity:  6004
# title,acc,tn,fp,fn,tp
# training-cm,1.00,333,0,1,671
# training-eval,[0.00595066137611866, 0.9990049600601196]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,167,0,1,327
# validation-eval,[0.008348383940756321, 0.9979798197746277]
# ........................................
# Th=97, Revised NN Structure: layers=3, neurons: [34 31 28], complexity: 3956
# ========Ennio_Doorbell-97========
# Features=53
# NN Structure: layers=3, neurons: [34 31 28]
# complexity:  3956
# title,acc,tn,fp,fn,tp
# training-cm,1.00,339,0,0,666
# training-eval,[2.8982907451791107e-07, 1.0]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,160,1,1,333
# validation-eval,[0.03454872593283653, 0.9959595799446106]
# ........................................
# Th=96, Revised NN Structure: layers=2, neurons: [29 26], complexity: 2491
# ========Ennio_Doorbell-96========
# Features=53
# NN Structure: layers=2, neurons: [29 26]
# complexity:  2491
# title,acc,tn,fp,fn,tp
# training-cm,1.00,333,0,0,672
# training-eval,[8.573538252676371e-07, 1.0]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,166,1,7,321
# validation-eval,[1.7806172370910645, 0.9818181991577148]
# ........................................
# Th=95, Revised NN Structure: layers=1, neurons: [24], complexity: 1440
# ========Ennio_Doorbell-95========
# Features=53
# NN Structure: layers=1, neurons: [24]
# complexity:  1440
# title,acc,tn,fp,fn,tp
# training-cm,1.00,327,0,1,677
# training-eval,[0.007755032274872065, 0.998009979724884]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,172,1,1,321
# validation-eval,[0.06445740163326263, 0.991919219493866]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [22], complexity: 1320
# ========Ennio_Doorbell-94========
# Features=53
# NN Structure: layers=1, neurons: [22]
# complexity:  1320
# title,acc,tn,fp,fn,tp
# training-cm,1.00,333,0,0,672
# training-eval,[1.8580578398541547e-05, 1.0]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,167,0,4,324
# validation-eval,[0.05517932027578354, 0.991919219493866]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [20], complexity: 1200
# ========Ennio_Doorbell-93========
# Features=53
# NN Structure: layers=1, neurons: [20]
# complexity:  1200
# title,acc,tn,fp,fn,tp
# training-cm,1.00,341,0,0,664
# training-eval,[0.0011015962809324265, 1.0]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,158,1,5,331
# validation-eval,[0.09264169633388519, 0.9878787994384766]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [18], complexity: 1080
# ========Ennio_Doorbell-92========
# Features=53
# NN Structure: layers=1, neurons: [18]
# complexity:  1080
# title,acc,tn,fp,fn,tp
# training-cm,1.00,344,0,1,660
# training-eval,[0.006863008253276348, 0.9990049600601196]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,156,0,2,337
# validation-eval,[0.01702839694917202, 0.9939393997192383]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [16], complexity: 960
# ========Ennio_Doorbell-91========
# Features=53
# NN Structure: layers=1, neurons: [16]
# complexity:  960
# title,acc,tn,fp,fn,tp
# training-cm,1.00,344,0,1,660
# training-eval,[0.006819835398346186, 0.9990049600601196]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,156,0,5,334
# validation-eval,[0.14634943008422852, 0.9898989796638489]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [14], complexity: 840
# ========Ennio_Doorbell-90========
# Features=53
# NN Structure: layers=1, neurons: [14]
# complexity:  840
# title,acc,tn,fp,fn,tp
# training-cm,1.00,339,0,2,664
# training-eval,[0.00903613306581974, 0.998009979724884]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,161,0,1,333
# validation-eval,[0.005112160928547382, 0.9979798197746277]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [12], complexity: 720
# ========Ennio_Doorbell-89========
# Features=53
# NN Structure: layers=1, neurons: [12]
# complexity:  720
# title,acc,tn,fp,fn,tp
# training-cm,1.00,332,0,1,672
# training-eval,[0.007592490874230862, 0.998009979724884]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,167,1,5,322
# validation-eval,[0.05872524529695511, 0.9878787994384766]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [10], complexity: 600
# ========Ennio_Doorbell-88========
# Features=53
# NN Structure: layers=1, neurons: [10]
# complexity:  600
# title,acc,tn,fp,fn,tp
# training-cm,1.00,317,0,0,688
# training-eval,[0.0015768447192385793, 1.0]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,180,3,1,311
# validation-eval,[0.03455125540494919, 0.991919219493866]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [8], complexity: 480
# ========Ennio_Doorbell-87========
# Features=53
# NN Structure: layers=1, neurons: [8]
# complexity:  480
# title,acc,tn,fp,fn,tp
# training-cm,1.00,350,0,2,653
# training-eval,[0.009489632211625576, 0.998009979724884]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,149,1,3,342
# validation-eval,[0.1240508109331131, 0.9939393997192383]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [7], complexity: 420
# ========Ennio_Doorbell-86========
# Features=53
# NN Structure: layers=1, neurons: [7]
# complexity:  420
# title,acc,tn,fp,fn,tp
# training-cm,1.00,348,0,2,655
# training-eval,[0.012770293280482292, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,151,1,3,340
# validation-eval,[0.021446995437145233, 0.991919219493866]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [6], complexity: 360
# ========Ennio_Doorbell-85========
# Features=53
# NN Structure: layers=1, neurons: [6]
# complexity:  360
# title,acc,tn,fp,fn,tp
# training-cm,1.00,331,0,2,672
# training-eval,[0.007445142604410648, 0.998009979724884]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,169,0,3,323
# validation-eval,[0.09770067781209946, 0.9939393997192383]
# processing 4.benign.csv rows = 1000
# processing 4.gafgyt.combo.csv rows = 100
# processing 4.gafgyt.junk.csv rows = 100
# processing 4.gafgyt.scan.csv rows = 100
# processing 4.gafgyt.tcp.csv rows = 100
# processing 4.gafgyt.udp.csv rows = 100
# processing 4.mirai.ack.csv rows = 100
# processing 4.mirai.scan.csv rows = 100
# processing 4.mirai.syn.csv rows = 100
# processing 4.mirai.udp.csv rows = 100
# processing 4.mirai.udpplain.csv rows = 100
# ############################[4 - Philips_B120N10_Baby_Monitor]##########################
# ========Philips_B120N10_Baby_Monitor========
# Features=53
# NN Structure: layers=7, neurons: [101, 75, 67, 60, 55, 50, 46]
# complexity:  30167
# title,acc,tn,fp,fn,tp
# training-cm,1.00,655,3,3,679
# training-eval,[0.015008457936346531, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,340,2,5,313
# validation-eval,[0.030304720625281334, 0.9924242496490479]
# ........................................
# Th=100, Revised NN Structure: layers=7, neurons: [101  75  67  60  55  50  46], complexity: 30167
# ========Philips_B120N10_Baby_Monitor-100========
# Features=53
# NN Structure: layers=7, neurons: [101  75  67  60  55  50  46]
# complexity:  30167
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,3,3,667
# training-eval,[0.014255540445446968, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,327,3,3,327
# validation-eval,[0.025709005072712898, 0.9924242496490479]
# ........................................
# Th=99, Revised NN Structure: layers=6, neurons: [100  74  66  59  54  49], complexity: 27159
# ========Philips_B120N10_Baby_Monitor-99========
# Features=53
# NN Structure: layers=6, neurons: [100  74  66  59  54  49]
# complexity:  27159
# title,acc,tn,fp,fn,tp
# training-cm,1.00,674,2,4,660
# training-eval,[0.016755571588873863, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,321,3,2,334
# validation-eval,[0.018206866458058357, 0.9954545497894287]
# ........................................
# Th=98, Revised NN Structure: layers=5, neurons: [98 72 64 57 52], complexity: 23326
# ========Philips_B120N10_Baby_Monitor-98========
# Features=53
# NN Structure: layers=5, neurons: [98 72 64 57 52]
# complexity:  23326
# title,acc,tn,fp,fn,tp
# training-cm,1.00,659,0,5,676
# training-eval,[0.016415990889072418, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,341,0,6,313
# validation-eval,[0.17828892171382904, 0.9909090995788574]
# ........................................
# Th=97, Revised NN Structure: layers=4, neurons: [69 62 55 50], complexity: 14007
# ========Philips_B120N10_Baby_Monitor-97========
# Features=53
# NN Structure: layers=4, neurons: [69 62 55 50]
# complexity:  14007
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,3,5,666
# training-eval,[0.019463734701275826, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,329,2,1,328
# validation-eval,[0.012951398268342018, 0.9954545497894287]
# ........................................
# Th=96, Revised NN Structure: layers=3, neurons: [66 59 48], complexity: 10140
# ========Philips_B120N10_Baby_Monitor-96========
# Features=53
# NN Structure: layers=3, neurons: [66 59 48]
# complexity:  10140
# title,acc,tn,fp,fn,tp
# training-cm,0.99,687,3,4,646
# training-eval,[0.017107564955949783, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,308,2,2,348
# validation-eval,[0.01813783310353756, 0.9969696998596191]
# ........................................
# Th=95, Revised NN Structure: layers=2, neurons: [56 45], complexity: 5421
# ========Philips_B120N10_Baby_Monitor-95========
# Features=53
# NN Structure: layers=2, neurons: [56 45]
# complexity:  5421
# title,acc,tn,fp,fn,tp
# training-cm,1.00,658,0,6,676
# training-eval,[0.018393374979496002, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,341,1,5,313
# validation-eval,[0.02135429158806801, 0.9924242496490479]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [42], complexity: 2184
# ========Philips_B120N10_Baby_Monitor-94========
# Features=53
# NN Structure: layers=1, neurons: [42]
# complexity:  2184
# title,acc,tn,fp,fn,tp
# training-cm,1.00,661,2,1,676
# training-eval,[0.008612019941210747, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,0,6,317
# validation-eval,[0.05519942566752434, 0.989393949508667]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [39], complexity: 2028
# ========Philips_B120N10_Baby_Monitor-93========
# Features=53
# NN Structure: layers=1, neurons: [39]
# complexity:  2028
# title,acc,tn,fp,fn,tp
# training-cm,1.00,674,0,6,660
# training-eval,[0.018154939636588097, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,0,4,330
# validation-eval,[0.020999060943722725, 0.9909090995788574]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [35], complexity: 1820
# ========Philips_B120N10_Baby_Monitor-92========
# Features=53
# NN Structure: layers=1, neurons: [35]
# complexity:  1820
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,1,9,663
# training-eval,[0.023228192701935768, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,331,1,1,327
# validation-eval,[0.006696326192468405, 0.9969696998596191]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [31], complexity: 1612
# ========Philips_B120N10_Baby_Monitor-91========
# Features=53
# NN Structure: layers=1, neurons: [31]
# complexity:  1612
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,3,2,656
# training-eval,[0.011555474251508713, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,2,5,337
# validation-eval,[0.03735043853521347, 0.9909090995788574]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [28], complexity: 1456
# ========Philips_B120N10_Baby_Monitor-90========
# Features=53
# NN Structure: layers=1, neurons: [28]
# complexity:  1456
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,1,6,666
# training-eval,[0.021582510322332382, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,4,0,328
# validation-eval,[0.008266559801995754, 0.9939393997192383]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [25], complexity: 1300
# ========Philips_B120N10_Baby_Monitor-89========
# Features=53
# NN Structure: layers=1, neurons: [25]
# complexity:  1300
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,3,5,661
# training-eval,[0.02097739279270172, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,325,1,2,332
# validation-eval,[0.01461491733789444, 0.9954545497894287]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [22], complexity: 1144
# ========Philips_B120N10_Baby_Monitor-88========
# Features=53
# NN Structure: layers=1, neurons: [22]
# complexity:  1144
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,0,4,669
# training-eval,[0.012900637462735176, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,2,6,321
# validation-eval,[0.07696809619665146, 0.9848484992980957]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [19], complexity: 988
# ========Philips_B120N10_Baby_Monitor-87========
# Features=53
# NN Structure: layers=1, neurons: [19]
# complexity:  988
# title,acc,tn,fp,fn,tp
# training-cm,1.00,660,2,4,674
# training-eval,[0.016673609614372253, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,338,0,3,319
# validation-eval,[0.017996134236454964, 0.9939393997192383]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [16], complexity: 832
# ========Philips_B120N10_Baby_Monitor-86========
# Features=53
# NN Structure: layers=1, neurons: [16]
# complexity:  832
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,0,4,665
# training-eval,[0.012880912981927395, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,0,6,325
# validation-eval,[0.034367237240076065, 0.989393949508667]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [13], complexity: 676
# ========Philips_B120N10_Baby_Monitor-85========
# Features=53
# NN Structure: layers=1, neurons: [13]
# complexity:  676
# title,acc,tn,fp,fn,tp
# training-cm,1.00,672,2,4,662
# training-eval,[0.017206838354468346, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,322,4,2,332
# validation-eval,[0.018817950040102005, 0.9939393997192383]
# processing 5.benign.csv rows = 1000
# processing 5.gafgyt.combo.csv rows = 100
# processing 5.gafgyt.junk.csv rows = 100
# processing 5.gafgyt.scan.csv rows = 100
# processing 5.gafgyt.tcp.csv rows = 100
# processing 5.gafgyt.udp.csv rows = 100
# processing 5.mirai.ack.csv rows = 100
# processing 5.mirai.scan.csv rows = 100
# processing 5.mirai.syn.csv rows = 100
# processing 5.mirai.udp.csv rows = 100
# processing 5.mirai.udpplain.csv rows = 100
# ############################[5 - Provision_PT_737E_Security_Camera]##########################
# ========Provision_PT_737E_Security_Camera========
# Features=36
# NN Structure: layers=6, neurons: [87, 75, 58, 52, 47, 43]
# complexity:  21879
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,0,9,667
# training-eval,[0.029641909524798393, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,2,6,318
# validation-eval,[0.0928400307893753, 0.9863636493682861]
# ........................................
# Th=100, Revised NN Structure: layers=6, neurons: [87 75 58 52 47 43], complexity: 21879
# ========Provision_PT_737E_Security_Camera-100========
# Features=36
# NN Structure: layers=6, neurons: [87 75 58 52 47 43]
# complexity:  21879
# title,acc,tn,fp,fn,tp
# training-cm,0.99,675,0,7,658
# training-eval,[0.02124273031949997, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,324,1,8,327
# validation-eval,[0.08300179243087769, 0.9863636493682861]
# ........................................
# Th=99, Revised NN Structure: layers=5, neurons: [74 57 51 46 42], complexity: 14405
# ========Provision_PT_737E_Security_Camera-99========
# Features=36
# NN Structure: layers=5, neurons: [74 57 51 46 42]
# complexity:  14405
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,10,4,660
# training-eval,[0.019080888479948044, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,321,3,9,327
# validation-eval,[0.09029252827167511, 0.9833333492279053]
# ........................................
# Th=98, Revised NN Structure: layers=4, neurons: [72 55 45 41], complexity: 11201
# ========Provision_PT_737E_Security_Camera-98========
# Features=36
# NN Structure: layers=4, neurons: [72 55 45 41]
# complexity:  11201
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,0,4,674
# training-eval,[0.013335499912500381, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,333,5,10,312
# validation-eval,[0.3314967155456543, 0.9757575988769531]
# ........................................
# Th=97, Revised NN Structure: layers=3, neurons: [53 43 39], complexity: 6115
# ========Provision_PT_737E_Security_Camera-97========
# Features=36
# NN Structure: layers=3, neurons: [53 43 39]
# complexity:  6115
# title,acc,tn,fp,fn,tp
# training-cm,1.00,682,0,5,653
# training-eval,[0.014284593984484673, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,0,9,333
# validation-eval,[0.05542553588747978, 0.9848484992980957]
# ........................................
# Th=96, Revised NN Structure: layers=2, neurons: [41 37], complexity: 3194
# ========Provision_PT_737E_Security_Camera-96========
# Features=36
# NN Structure: layers=2, neurons: [41 37]
# complexity:  3194
# title,acc,tn,fp,fn,tp
# training-cm,0.99,681,0,10,649
# training-eval,[0.024510081857442856, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,319,0,2,339
# validation-eval,[0.01935485750436783, 0.9954545497894287]
# ........................................
# Th=95, Revised NN Structure: layers=1, neurons: [35], complexity: 1435
# ========Provision_PT_737E_Security_Camera-95========
# Features=36
# NN Structure: layers=1, neurons: [35]
# complexity:  1435
# title,acc,tn,fp,fn,tp
# training-cm,1.00,646,0,6,688
# training-eval,[0.02060934156179428, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,353,1,7,299
# validation-eval,[0.0539800226688385, 0.989393949508667]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [32], complexity: 1312
# ========Provision_PT_737E_Security_Camera-94========
# Features=36
# NN Structure: layers=1, neurons: [32]
# complexity:  1312
# title,acc,tn,fp,fn,tp
# training-cm,0.99,653,0,8,679
# training-eval,[0.02512594498693943, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,347,0,5,308
# validation-eval,[0.029555823653936386, 0.9924242496490479]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [29], complexity: 1189
# ========Provision_PT_737E_Security_Camera-93========
# Features=36
# NN Structure: layers=1, neurons: [29]
# complexity:  1189
# title,acc,tn,fp,fn,tp
# training-cm,0.99,655,4,8,673
# training-eval,[0.024581709876656532, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,339,2,5,314
# validation-eval,[0.04294334724545479, 0.989393949508667]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [26], complexity: 1066
# ========Provision_PT_737E_Security_Camera-92========
# Features=36
# NN Structure: layers=1, neurons: [26]
# complexity:  1066
# title,acc,tn,fp,fn,tp
# training-cm,0.99,647,4,6,683
# training-eval,[0.02112751267850399, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,338,11,7,304
# validation-eval,[0.06571479141712189, 0.9833333492279053]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [23], complexity: 943
# ========Provision_PT_737E_Security_Camera-91========
# Features=36
# NN Structure: layers=1, neurons: [23]
# complexity:  943
# title,acc,tn,fp,fn,tp
# training-cm,0.99,665,3,10,662
# training-eval,[0.028125790879130363, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,4,4,324
# validation-eval,[0.04347377270460129, 0.989393949508667]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [20], complexity: 820
# ========Provision_PT_737E_Security_Camera-90========
# Features=36
# NN Structure: layers=1, neurons: [20]
# complexity:  820
# title,acc,tn,fp,fn,tp
# training-cm,0.99,638,4,8,690
# training-eval,[0.022633787244558334, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,355,3,5,297
# validation-eval,[0.07824612408876419, 0.9863636493682861]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [17], complexity: 697
# ========Provision_PT_737E_Security_Camera-89========
# Features=36
# NN Structure: layers=1, neurons: [17]
# complexity:  697
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,0,8,663
# training-eval,[0.025818120688199997, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,1,5,324
# validation-eval,[0.030123453587293625, 0.9924242496490479]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [15], complexity: 615
# ========Provision_PT_737E_Security_Camera-88========
# Features=36
# NN Structure: layers=1, neurons: [15]
# complexity:  615
# title,acc,tn,fp,fn,tp
# training-cm,0.99,675,1,7,657
# training-eval,[0.024344993755221367, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,322,2,5,331
# validation-eval,[0.03667107969522476, 0.9909090995788574]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [13], complexity: 533
# ========Provision_PT_737E_Security_Camera-87========
# Features=36
# NN Structure: layers=1, neurons: [13]
# complexity:  533
# title,acc,tn,fp,fn,tp
# training-cm,0.99,675,0,7,658
# training-eval,[0.025422170758247375, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,0,6,329
# validation-eval,[0.03843266889452934, 0.9909090995788574]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [11], complexity: 451
# ========Provision_PT_737E_Security_Camera-86========
# Features=36
# NN Structure: layers=1, neurons: [11]
# complexity:  451
# title,acc,tn,fp,fn,tp
# training-cm,0.99,661,0,7,672
# training-eval,[0.022848647087812424, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,4,5,316
# validation-eval,[0.04235348850488663, 0.9878787994384766]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [9], complexity: 369
# ========Provision_PT_737E_Security_Camera-85========
# Features=36
# NN Structure: layers=1, neurons: [9]
# complexity:  369
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,0,10,661
# training-eval,[0.02975982055068016, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,0,4,325
# validation-eval,[0.02795201726257801, 0.9939393997192383]
# processing 6.benign.csv rows = 1000
# processing 6.gafgyt.combo.csv rows = 100
# processing 6.gafgyt.junk.csv rows = 100
# processing 6.gafgyt.scan.csv rows = 100
# processing 6.gafgyt.tcp.csv rows = 100
# processing 6.gafgyt.udp.csv rows = 100
# processing 6.mirai.ack.csv rows = 100
# processing 6.mirai.scan.csv rows = 100
# processing 6.mirai.syn.csv rows = 100
# processing 6.mirai.udp.csv rows = 100
# processing 6.mirai.udpplain.csv rows = 100
# ############################[6 - Provision_PT_838_Security_Camera]##########################
# ========Provision_PT_838_Security_Camera========
# Features=41
# NN Structure: layers=6, neurons: [88, 75, 58, 52, 48, 44]
# complexity:  22314
# title,acc,tn,fp,fn,tp
# training-cm,0.99,650,8,2,680
# training-eval,[0.01370747946202755, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,332,10,4,314
# validation-eval,[1.1802951097488403, 0.978787899017334]
# ........................................
# Th=100, Revised NN Structure: layers=6, neurons: [88 75 58 52 48 44], complexity: 22314
# ========Provision_PT_838_Security_Camera-100========
# Features=41
# NN Structure: layers=6, neurons: [88 75 58 52 48 44]
# complexity:  22314
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,0,7,674
# training-eval,[0.01659286953508854, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,341,0,6,313
# validation-eval,[0.15154364705085754, 0.9909090995788574]
# ........................................
# Th=99, Revised NN Structure: layers=5, neurons: [74 57 51 47 43], complexity: 14694
# ========Provision_PT_838_Security_Camera-99========
# Features=41
# NN Structure: layers=5, neurons: [74 57 51 47 43]
# complexity:  14694
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,5,3,659
# training-eval,[0.016879700124263763, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,319,3,7,331
# validation-eval,[0.22522491216659546, 0.9863636493682861]
# ........................................
# Th=98, Revised NN Structure: layers=4, neurons: [55 50 46 42], complexity: 9334
# ========Provision_PT_838_Security_Camera-98========
# Features=41
# NN Structure: layers=4, neurons: [55 50 46 42]
# complexity:  9334
# title,acc,tn,fp,fn,tp
# training-cm,0.99,652,8,3,677
# training-eval,[0.012522834353148937, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,5,3,317
# validation-eval,[0.026963841170072556, 0.9909090995788574]
# ........................................
# Th=97, Revised NN Structure: layers=3, neurons: [48 44 40], complexity: 5928
# ========Provision_PT_838_Security_Camera-97========
# Features=41
# NN Structure: layers=3, neurons: [48 44 40]
# complexity:  5928
# title,acc,tn,fp,fn,tp
# training-cm,0.99,665,11,2,662
# training-eval,[0.021953048184514046, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,315,9,4,332
# validation-eval,[0.05666829273104668, 0.9878787994384766]
# ........................................
# Th=96, Revised NN Structure: layers=2, neurons: [42 38], complexity: 3398
# ========Provision_PT_838_Security_Camera-96========
# Features=41
# NN Structure: layers=2, neurons: [42 38]
# complexity:  3398
# title,acc,tn,fp,fn,tp
# training-cm,0.99,676,1,7,656
# training-eval,[0.020188920199871063, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,0,4,333
# validation-eval,[0.21856388449668884, 0.9939393997192383]
# ........................................
# Th=95, Revised NN Structure: layers=1, neurons: [36], complexity: 1548
# ========Provision_PT_838_Security_Camera-95========
# Features=41
# NN Structure: layers=1, neurons: [36]
# complexity:  1548
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,4,6,668
# training-eval,[0.01819741167128086, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,1,5,321
# validation-eval,[0.12852373719215393, 0.989393949508667]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [33], complexity: 1419
# ========Provision_PT_838_Security_Camera-94========
# Features=41
# NN Structure: layers=1, neurons: [33]
# complexity:  1419
# title,acc,tn,fp,fn,tp
# training-cm,1.00,687,0,6,647
# training-eval,[0.018079517409205437, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,312,1,6,341
# validation-eval,[0.05314399674534798, 0.989393949508667]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [30], complexity: 1290
# ========Provision_PT_838_Security_Camera-93========
# Features=41
# NN Structure: layers=1, neurons: [30]
# complexity:  1290
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,0,4,672
# training-eval,[0.01294222753494978, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,1,8,316
# validation-eval,[0.04815667122602463, 0.9863636493682861]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [27], complexity: 1161
# ========Provision_PT_838_Security_Camera-92========
# Features=41
# NN Structure: layers=1, neurons: [27]
# complexity:  1161
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,4,8,655
# training-eval,[0.024035954847931862, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,322,1,10,327
# validation-eval,[0.13965120911598206, 0.9818181991577148]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [24], complexity: 1032
# ========Provision_PT_838_Security_Camera-91========
# Features=41
# NN Structure: layers=1, neurons: [24]
# complexity:  1032
# title,acc,tn,fp,fn,tp
# training-cm,0.99,659,4,6,671
# training-eval,[0.021089524030685425, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,336,1,6,317
# validation-eval,[0.14236965775489807, 0.989393949508667]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [21], complexity: 903
# ========Provision_PT_838_Security_Camera-90========
# Features=41
# NN Structure: layers=1, neurons: [21]
# complexity:  903
# title,acc,tn,fp,fn,tp
# training-cm,0.99,655,11,4,670
# training-eval,[0.0264220479875803, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,324,10,4,322
# validation-eval,[0.18015363812446594, 0.9878787994384766]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [18], complexity: 774
# ========Provision_PT_838_Security_Camera-89========
# Features=41
# NN Structure: layers=1, neurons: [18]
# complexity:  774
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,6,6,660
# training-eval,[0.020762421190738678, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,3,5,329
# validation-eval,[0.15044988691806793, 0.9909090995788574]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [15], complexity: 645
# ========Provision_PT_838_Security_Camera-88========
# Features=41
# NN Structure: layers=1, neurons: [15]
# complexity:  645
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,2,6,663
# training-eval,[0.023384854197502136, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,4,3,328
# validation-eval,[0.10460884869098663, 0.9909090995788574]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [13], complexity: 559
# ========Provision_PT_838_Security_Camera-87========
# Features=41
# NN Structure: layers=1, neurons: [13]
# complexity:  559
# title,acc,tn,fp,fn,tp
# training-cm,1.00,694,0,5,641
# training-eval,[0.015069592744112015, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,305,1,7,347
# validation-eval,[0.04514479637145996, 0.9878787994384766]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [11], complexity: 473
# ========Provision_PT_838_Security_Camera-86========
# Features=41
# NN Structure: layers=1, neurons: [11]
# complexity:  473
# title,acc,tn,fp,fn,tp
# training-cm,0.99,665,8,9,658
# training-eval,[0.027459004893898964, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,322,5,3,330
# validation-eval,[0.027380021288990974, 0.9909090995788574]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [9], complexity: 387
# ========Provision_PT_838_Security_Camera-85========
# Features=41
# NN Structure: layers=1, neurons: [9]
# complexity:  387
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,0,8,663
# training-eval,[0.02411060407757759, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,1,6,323
# validation-eval,[0.03576871007680893, 0.9878787994384766]
# processing 7.benign.csv rows = 1000
# processing 7.gafgyt.combo.csv rows = 100
# ...
# NN Structure: layers=5, neurons: [76, 67, 59, 53, 48]
# complexity:  19020
# title,acc,tn,fp,fn,tp
# training-cm,1.00,657,0,4,679
# training-eval,[0.012546542100608349, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,342,1,12,305
# validation-eval,[0.23502333462238312, 0.9803030490875244]
# ........................................
# Th=100, Revised NN Structure: layers=5, neurons: [76 67 59 53 48], complexity: 19020
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-100========
# Features=51
# NN Structure: layers=5, neurons: [76 67 59 53 48]
# complexity:  19020
# title,acc,tn,fp,fn,tp
# training-cm,1.00,647,0,5,688
# training-eval,[0.008554819040000439, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,352,1,7,300
# validation-eval,[0.08967989683151245, 0.9878787994384766]
# ........................................
# Th=99, Revised NN Structure: layers=4, neurons: [66 58 52 47], complexity: 13031
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-99========
# Features=51
# NN Structure: layers=4, neurons: [66 58 52 47]
# complexity:  13031
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,11,2,663
# training-eval,[0.01467251405119896, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,2,2,333
# validation-eval,[0.1923939287662506, 0.9954545497894287]
# ........................................
# Th=98, Revised NN Structure: layers=3, neurons: [56 50 46], complexity: 8282
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-98========
# Features=51
# NN Structure: layers=3, neurons: [56 50 46]
# complexity:  8282
# title,acc,tn,fp,fn,tp
# training-cm,1.00,680,3,2,655
# training-eval,[0.01386929303407669, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,309,8,2,341
# validation-eval,[0.39223411679267883, 0.9924242496490479]
# ........................................
# Th=97, Revised NN Structure: layers=2, neurons: [48 44], complexity: 4844
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-97========
# Features=51
# NN Structure: layers=2, neurons: [48 44]
# complexity:  4844
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,0,4,668
# training-eval,[0.012585418298840523, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,1,8,320
# validation-eval,[0.04005508869886398, 0.9863636493682861]
# ........................................
# Th=96, Revised NN Structure: layers=1, neurons: [42], complexity: 2394
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-96========
# Features=51
# NN Structure: layers=1, neurons: [42]
# complexity:  2394
# title,acc,tn,fp,fn,tp
# training-cm,0.99,685,4,4,647
# training-eval,[0.013262948952615261, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,310,1,5,344
# validation-eval,[0.02639053575694561, 0.9924242496490479]
# ........................................
# Th=95, Revised NN Structure: layers=1, neurons: [39], complexity: 2223
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-95========
# Features=51
# NN Structure: layers=1, neurons: [39]
# complexity:  2223
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,5,6,659
# training-eval,[0.01789143495261669, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,2,5,330
# validation-eval,[0.6239948272705078, 0.989393949508667]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [36], complexity: 2052
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-94========
# Features=51
# NN Structure: layers=1, neurons: [36]
# complexity:  2052
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,4,7,656
# training-eval,[0.019264379516243935, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,322,1,2,335
# validation-eval,[0.015351425856351852, 0.9939393997192383]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [33], complexity: 1881
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-93========
# Features=51
# NN Structure: layers=1, neurons: [33]
# complexity:  1881
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,4,8,662
# training-eval,[0.021340982988476753, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,2,7,323
# validation-eval,[0.24154286086559296, 0.9878787994384766]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [30], complexity: 1710
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-92========
# Features=51
# NN Structure: layers=1, neurons: [30]
# complexity:  1710
# title,acc,tn,fp,fn,tp
# training-cm,0.99,676,3,8,653
# training-eval,[0.017542598769068718, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,3,5,334
# validation-eval,[0.11965271830558777, 0.9878787994384766]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [27], complexity: 1539
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-91========
# Features=51
# NN Structure: layers=1, neurons: [27]
# complexity:  1539
# title,acc,tn,fp,fn,tp
# training-cm,0.99,655,3,6,676
# training-eval,[0.017919296398758888, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,340,2,5,313
# validation-eval,[0.029924491420388222, 0.9924242496490479]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [24], complexity: 1368
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-90========
# Features=51
# NN Structure: layers=1, neurons: [24]
# complexity:  1368
# title,acc,tn,fp,fn,tp
# training-cm,0.99,648,6,8,678
# training-eval,[0.01792725920677185, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,340,6,1,313
# validation-eval,[0.025767162442207336, 0.989393949508667]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [21], complexity: 1197
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-89========
# Features=51
# NN Structure: layers=1, neurons: [21]
# complexity:  1197
# title,acc,tn,fp,fn,tp
# training-cm,0.99,637,3,6,694
# training-eval,[0.01637628860771656, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,358,2,3,297
# validation-eval,[0.020392267033457756, 0.9909090995788574]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [18], complexity: 1026
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-88========
# Features=51
# NN Structure: layers=1, neurons: [18]
# complexity:  1026
# title,acc,tn,fp,fn,tp
# training-cm,0.99,672,0,7,661
# training-eval,[0.018273575231432915, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,0,6,326
# validation-eval,[0.027371486648917198, 0.9909090995788574]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [15], complexity: 855
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-87========
# Features=51
# NN Structure: layers=1, neurons: [15]
# complexity:  855
# title,acc,tn,fp,fn,tp
# training-cm,0.99,676,3,5,656
# training-eval,[0.017535986378788948, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,319,2,6,333
# validation-eval,[0.02553626522421837, 0.9878787994384766]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [13], complexity: 741
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-86========
# Features=51
# NN Structure: layers=1, neurons: [13]
# complexity:  741
# title,acc,tn,fp,fn,tp
# training-cm,0.98,646,22,0,672
# training-eval,[0.029964504763484, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,323,9,5,323
# validation-eval,[0.27162331342697144, 0.9878787994384766]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [11], complexity: 627
# ========SimpleHome_XCS7_1002_WHT_Security_Camera-85========
# Features=51
# NN Structure: layers=1, neurons: [11]
# complexity:  627
# title,acc,tn,fp,fn,tp
# training-cm,0.99,657,4,7,672
# training-eval,[0.018697408959269524, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,335,4,4,317
# validation-eval,[0.023990226909518242, 0.9924242496490479]
# processing 9.benign.csv rows = 1000
# processing 9.gafgyt.combo.csv rows = 100
# processing 9.gafgyt.junk.csv rows = 100
# processing 9.gafgyt.scan.csv rows = 100
# processing 9.gafgyt.tcp.csv rows = 100
# processing 9.gafgyt.udp.csv rows = 100
# processing 9.mirai.ack.csv rows = 100
# processing 9.mirai.scan.csv rows = 100
# processing 9.mirai.syn.csv rows = 100
# processing 9.mirai.udp.csv rows = 100
# processing 9.mirai.udpplain.csv rows = 100
# ############################[9 - SimpleHome_XCS7_1003_WHT_Security_Camera]##########################
# ========SimpleHome_XCS7_1003_WHT_Security_Camera========
# Features=44
# NN Structure: layers=5, neurons: [88, 76, 59, 53, 48]
# complexity:  21819
# title,acc,tn,fp,fn,tp
# training-cm,1.00,658,0,3,679
# training-eval,[0.011534055694937706, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,342,0,1,317
# validation-eval,[0.008195663802325726, 0.9984848499298096]
# ........................................
# Th=100, Revised NN Structure: layers=5, neurons: [88 76 59 53 48], complexity: 21819
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-100========
# Features=44
# NN Structure: layers=5, neurons: [88 76 59 53 48]
# complexity:  21819
# title,acc,tn,fp,fn,tp
# training-cm,1.00,689,1,4,646
# training-eval,[0.015056934207677841, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,310,0,3,347
# validation-eval,[0.35867244005203247, 0.9954545497894287]
# ........................................
# Th=99, Revised NN Structure: layers=4, neurons: [87 58 52 47], complexity: 15425
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-99========
# Features=44
# NN Structure: layers=4, neurons: [87 58 52 47]
# complexity:  15425
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,0,2,667
# training-eval,[0.007972991093993187, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,4,3,328
# validation-eval,[0.12184237688779831, 0.989393949508667]
# ........................................
# Th=98, Revised NN Structure: layers=3, neurons: [56 50 46], complexity: 8282
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-98========
# Features=44
# NN Structure: layers=3, neurons: [56 50 46]
# complexity:  8282
# title,acc,tn,fp,fn,tp
# training-cm,1.00,663,0,3,674
# training-eval,[0.01084426511079073, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,337,0,1,322
# validation-eval,[0.009020078927278519, 0.9984848499298096]
# ........................................
# Th=97, Revised NN Structure: layers=2, neurons: [54 44], complexity: 5444
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-97========
# Features=44
# NN Structure: layers=2, neurons: [54 44]
# complexity:  5444
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,0,3,664
# training-eval,[0.010975552722811699, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,327,0,2,331
# validation-eval,[0.05980563163757324, 0.9969696998596191]
# ........................................
# Th=96, Revised NN Structure: layers=1, neurons: [42], complexity: 2394
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-96========
# Features=44
# NN Structure: layers=1, neurons: [42]
# complexity:  2394
# title,acc,tn,fp,fn,tp
# training-cm,1.00,682,0,1,657
# training-eval,[0.004802252631634474, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,0,4,338
# validation-eval,[0.026987731456756592, 0.9939393997192383]
# ........................................
# Th=95, Revised NN Structure: layers=1, neurons: [39], complexity: 2223
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-95========
# Features=44
# NN Structure: layers=1, neurons: [39]
# complexity:  2223
# title,acc,tn,fp,fn,tp
# training-cm,1.00,674,0,4,662
# training-eval,[0.014565840363502502, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,326,0,2,332
# validation-eval,[0.09780601412057877, 0.9969696998596191]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [36], complexity: 2052
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-94========
# Features=44
# NN Structure: layers=1, neurons: [36]
# complexity:  2052
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,1,4,665
# training-eval,[0.01445846538990736, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,328,1,0,331
# validation-eval,[0.00532587431371212, 0.9984848499298096]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [33], complexity: 1881
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-93========
# Features=44
# NN Structure: layers=1, neurons: [33]
# complexity:  1881
# title,acc,tn,fp,fn,tp
# training-cm,1.00,653,0,2,685
# training-eval,[0.00837456900626421, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,345,2,2,311
# validation-eval,[0.026932144537568092, 0.9939393997192383]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [30], complexity: 1710
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-92========
# Features=44
# NN Structure: layers=1, neurons: [30]
# complexity:  1710
# title,acc,tn,fp,fn,tp
# training-cm,1.00,690,1,3,646
# training-eval,[0.011985299177467823, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,309,0,1,350
# validation-eval,[0.009738646447658539, 0.9984848499298096]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [27], complexity: 1539
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-91========
# Features=44
# NN Structure: layers=1, neurons: [27]
# complexity:  1539
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,0,3,666
# training-eval,[0.01142509002238512, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,1,3,328
# validation-eval,[0.047769512981176376, 0.9939393997192383]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [24], complexity: 1368
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-90========
# Features=44
# NN Structure: layers=1, neurons: [24]
# complexity:  1368
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,0,1,675
# training-eval,[0.004791663959622383, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,336,0,4,320
# validation-eval,[0.05975940451025963, 0.9939393997192383]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [21], complexity: 1197
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-89========
# Features=44
# NN Structure: layers=1, neurons: [21]
# complexity:  1197
# title,acc,tn,fp,fn,tp
# training-cm,1.00,682,0,2,656
# training-eval,[0.008162309415638447, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,2,2,340
# validation-eval,[0.024623243138194084, 0.9939393997192383]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [18], complexity: 1026
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-88========
# Features=44
# NN Structure: layers=1, neurons: [18]
# complexity:  1026
# title,acc,tn,fp,fn,tp
# training-cm,1.00,661,0,2,677
# training-eval,[0.007928005419671535, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,338,1,3,318
# validation-eval,[0.07729323208332062, 0.9939393997192383]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [15], complexity: 855
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-87========
# Features=44
# NN Structure: layers=1, neurons: [15]
# complexity:  855
# title,acc,tn,fp,fn,tp
# training-cm,1.00,666,0,3,671
# training-eval,[0.01141725480556488, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,333,1,2,324
# validation-eval,[0.0574551485478878, 0.9939393997192383]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [13], complexity: 741
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-86========
# Features=44
# NN Structure: layers=1, neurons: [13]
# complexity:  741
# title,acc,tn,fp,fn,tp
# training-cm,1.00,669,0,3,668
# training-eval,[0.011396641843020916, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,327,4,2,327
# validation-eval,[0.06127294525504112, 0.9939393997192383]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [11], complexity: 627
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-85========
# Features=44
# NN Structure: layers=1, neurons: [11]
# complexity:  627
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,1,3,672
# training-eval,[0.012731983326375484, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,335,0,2,323
# validation-eval,[0.010956861078739166, 0.9969696998596191]
