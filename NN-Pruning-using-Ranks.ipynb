# %%
# Imports

########################################################################
# Python Standard Libraries
import os
import multiprocessing
from timeit import default_timer as timer
import random
import math

########################################################################
# Numpy Library
import numpy as np # linear algebra

########################################################################
# Pandas Library
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

########################################################################
# MATPLOT Library
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
# %matplotlib inline

########################################################################
# SKLearn Library
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_recall_curve, classification_report, confusion_matrix, average_precision_score, roc_curve, auc, multilabel_confusion_matrix

########################################################################
# SCIPY Library
from scipy.stats import gaussian_kde
import scipy.stats as st


########################################################################
# Keras Library
from keras.models import Sequential
from keras.layers import Dense

########################################################################
# Init random seed
#seed = 13
#np.random.seed(seed)

# %%
# Utility functions
########################################################################
# Print system information
def print_system_info():
    mem_bytes = os.sysconf('SC_PAGE_SIZE') * os.sysconf('SC_PHYS_PAGES')  # e.g. 4015976448
    mem_gib = mem_bytes/(1024.**3)  # e.g. 3.74
    print("{:<23}{:f} GB".format('RAM:', mem_gib))
    print("{:<23}{:d}".format('CORES:', multiprocessing.cpu_count()))
    # !lscpu

########################################################################
# Walk through input files
def print_input_files():
    # Input data files are available in the "../input/" directory.
    for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            print(os.path.join(dirname, filename))

########################################################################
# Dump text files
def dump_text_file(fname):
    with open(fname, 'r') as f:
        print(f.read())

########################################################################
# Dump CSV files
def dump_csv_file(fname, count=5):
    # count: 0 - column names only, -1 - all rows, default = 5 rows max
    df = pd.read_csv(fname)
    if count < 0:
        count = df.shape[0]
    return df.head(count)

########################################################################
# Dataset related functions
ds_nbaiot = '/kaggle/input/nbaiot-dataset'
dn_nbaiot = ['Danmini_Doorbell', 'Ecobee_Thermostat', 'Ennio_Doorbell', 'Philips_B120N10_Baby_Monitor', 'Provision_PT_737E_Security_Camera', 'Provision_PT_838_Security_Camera', 'Samsung_SNH_1011_N_Webcam', 'SimpleHome_XCS7_1002_WHT_Security_Camera', 'SimpleHome_XCS7_1003_WHT_Security_Camera']

def fname(ds, f):
    if '.csv' not in f:
        f = f'{f}.csv'
    return os.path.join(ds, f)

def fname_nbaiot(f):
    return fname(ds_nbaiot, f)

def get_nbaiot_device_files():
    nbaiot_all_files = dump_csv_file(fname_nbaiot('data_summary'), -1)
    nbaiot_all_files = nbaiot_all_files.iloc[:,0:1].values
    device_id = 1
    indices = []
    for j in range(len(nbaiot_all_files)):
        if str(device_id) not in str(nbaiot_all_files[j]):
            indices.append(j)
            device_id += 1
    nbaiot_device_files = np.split(nbaiot_all_files, indices)
    return nbaiot_device_files

def get_nbaiot_device_data(device_id, count_norm=-1, count_anom=-1):
    if device_id < 1 or device_id > 9:
        assert False, "Please provide a valid device ID 1-9, both inclusive"
    if count_anom == -1:
        count_anom = count_norm
    device_index = device_id -1
    device_files = get_nbaiot_device_files()
    device_file = device_files[device_index]
    df = pd.DataFrame()
    y = []
    for i in range(len(device_file)):
        fname = str(device_file[i][0])
        df_c = pd.read_csv(fname_nbaiot(fname))
        count = count_anom
        if 'benign' in fname:
            count = count_norm
        count = min(count, df_c.shape[0]) if count >=0 else df_c.shape[0]
        rows = count
        print("processing", fname, "rows =", rows)
        y_np = np.ones(rows) if 'benign' in fname else np.zeros(rows)
        y.extend(y_np.tolist())
        df = pd.concat([df.iloc[:,:].reset_index(drop=True),
                      df_c.iloc[:rows,:].reset_index(drop=True)], axis=0)
    X = df.iloc[:,:].values
    y = np.array(y)
    Xdf = df
    return (X, y, Xdf)

def get_nbaiot_devices_data():
    devices_data = []
    for i in range(9):
        device_id = i + 1
        (X, y) = get_nbaiot_device_data(device_id)
        devices_data.append((X, y))
    return devices_data
#print_input_files()
print_system_info()
# Out:
# RAM:                   18.621841 GB
# CORES:                 4
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              4
# On-line CPU(s) list: 0-3
# Thread(s) per core:  2
# Core(s) per socket:  2
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               79
# Model name:          Intel(R) Xeon(R) CPU @ 2.20GHz
# Stepping:            0
# CPU MHz:             2200.000
# BogoMIPS:            4400.00
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            56320K
# NUMA node0 CPU(s):   0-3
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities

# %%
def remove_correlated_features(df, threshold):
    df = df.copy()
    # Create correlation matrix
    corr_matrix = df.corr().abs()

    # Select upper triangle of correlation matrix
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

    # Find features with correlation greater than a threshold
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

    # Drop features 
    df.drop(to_drop, axis=1, inplace=True)
    return df.iloc[:,:].values

def mark_important_features(vector, pc_keep): # pc_keep is the percentage (0-100) of labels to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    important_bool = (vector >= th)
    important_int = important_bool.astype(int)
    return important_int

def select_features(X, X_norm, X_anom, threshold):
    rows_n = X_norm.shape[0]
    rows_a = X_anom.shape[0]
    if rows_n == 0 or rows_a == 0:
        return X

    y_norm = np.ones(rows_n)
    y_anom = -1 * np.ones(rows_a)

    reg_n = LinearRegression(fit_intercept=False)
    reg_n.fit(X_norm, y_norm)
    coef_n = abs(reg_n.coef_)
    n = mark_important_features(coef_n, threshold)

    reg_a = LinearRegression(fit_intercept=False)
    reg_a.fit(X_anom, y_anom)
    coef_a = abs(reg_a.coef_)
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel

# %%
def create_binary_classifier(hidden_layers, input_dim):
    layers = []
    for hl in hidden_layers:
        if hl > 0:
            layers.append(hl)

    layer_count = len(layers)
    assert layer_count >= 1, 'at least 1 non-zero hidden layer is needed'
    model = Sequential()
    model.add(Dense(layers[0],input_dim=input_dim,activation='relu'))
    for i in range(1, layer_count):
        model.add(Dense(layers[i],activation='relu'))

    model.add(Dense(1,activation='sigmoid'))
    #model.summary()
    model.compile(loss = 'binary_crossentropy',
             optimizer ='adam',metrics=['accuracy'])
    return model

# %%
def compute_time_complexity_single_pass(neurons_input, structure, neurons_output):
    count_hidden_layers = len(structure)
    neurons = [neurons_input, *structure, neurons_output]
    complexity = 0
    for i in range(count_hidden_layers + 1):
        complexity += neurons[i] * neurons[i+1]
    return complexity

# %%
def keep_mask(vector, pc_keep): # pc_keep is the percentage (0-100) of items to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    mask_bool = (vector >= th)
    mask_int = mask_bool.astype(int)
    return (mask_bool, mask_int)

# %%
'''
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel
'''
# Out:
# '\n    a = mark_important_features(coef_a, threshold)\n   \n    mask = np.bitwise_or(n,a)\n    mask = mask == 1 # convert to Boolean\n    X_sel = X[:, mask]\n    return X_sel\n'

# %%
def analyze_ranks(model, threshold):
    w_d = 0
    b_d = 0
    layer_count = len(model.layers)
    layer_ranks = []
    new_structure = []
    for i in range(layer_count-1):
        (w_c, b_c) = model.layers[i+1].get_weights() # current weigths and biases
        rows = w_c.shape[0]
        cols = w_c.shape[1]
        w_c_abs = np.absolute(w_c)
        rank_neurons = np.sum(w_c_abs, axis=1) / cols
        rank_layer = np.sum(rank_neurons) / rows
        layer_ranks.append(rank_layer)
        (mask_bool, mask_int) = keep_mask(rank_neurons, threshold)
        new_neuron_count = np.sum(mask_int)
        new_structure.append(new_neuron_count)
        #print(f'{i+1}: {rank_neurons.shape} {rank_layer} {mask_int} {new_neuron_count}')
    layer_ranks = np.array(layer_ranks)
    new_structure = np.array(new_structure)
    (mask_bool, mask_int) = keep_mask(layer_ranks, threshold)
    new_structure = new_structure[mask_bool]
    #new_structure_masked = new_structure
    #print(f'layer mask: {mask_int} {new_structure}')
    return new_structure

# %%
model = None
def compute_report(title, model, X, y):
    y_pred = model.predict(X)
    y_pred = (y_pred > 0.25)
    #print(y_pred)
    #y_pred[y_pred <= 0] = -1 # convert negative values as 0 for anomaly
    #y_pred[y_pred > 0] = 1 # convert positive values as 1 for normal
    acc = accuracy_score(y, y_pred)
    tn, fp, fn, tp = confusion_matrix(y, y_pred, labels=[0,1]).ravel()
    cr = classification_report(y, y_pred)
    print("title,acc,tn,fp,fn,tp")
    print(f'{title}-cm,{acc:.2f},{tn},{fp},{fn},{tp}')
    #print(f'{cr}')
    results = model.evaluate(X, y, verbose=0)
    print(f'{title}-eval,{results}')

def rank_computation(title, X, y, structure, fc):
    global model
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    print (f"========{title}========")
    feature_count = X.shape[1]
    print(f'Features={feature_count}')
    print(f'NN Structure: layers={len(structure)}, neurons: {structure}')
    print('complexity: ', compute_time_complexity_single_pass(fc, structure, 1))
    model = create_binary_classifier(structure, feature_count)
    model.fit(X_train,y_train,epochs=150,batch_size=10,verbose=0)
    #analyze_ranks(model, 95)
    compute_report('training', model, X_train, y_train)
    compute_report('validation', model, X_test, y_test)

# %%
debug_flag = True

# %%
if debug_flag:
    count_norm = 1000
    count_anom = 100
    #device_indices = [0]
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]
else:
    count_norm = -1
    count_anom = -1
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]

structures = {
    '0': [97, 83, 73, 64, 58, 53, 48],
    '1': [88, 75, 66, 58, 52],
    '2': [57, 49, 43, 38, 34, 31],
    '3': [101, 75, 67, 60, 55, 50, 46],
    '4': [87, 75, 58, 52, 47, 43],
    '5': [88, 75, 58, 52, 48, 44],
    '6': [59, 50, 44, 39, 35, 32],
    '7': [76, 67, 59, 53, 48],
    '8': [88, 76, 59, 53, 48]
}
fcs = [47, 47, 59, 51, 40, 42, 56, 56, 56]
for i in device_indices:
    device_index = i
    device_id = device_index + 1
    device_name = dn_nbaiot[device_index]
    (X, y, Xdf) = get_nbaiot_device_data(device_id, count_norm, count_anom)
    X = remove_correlated_features(Xdf, 0.98)
    X_std = StandardScaler().fit_transform(X)
    indices_norm = np.where(y >= 0.5)
    indices_anom = np.where(y <= 0.5)
    X_norm_all = X_std[indices_norm]
    X_anom_all = X_std[indices_anom]
    X_std = select_features(X_std, X_norm_all, X_anom_all,75)
    fc = fcs[i]
    rank_computation(device_name, X_std, y, structures.get(f'{i}'), fc)
    thresholds = [85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100]
    for threshold in thresholds:
        #threshold = 95
        new_structure = analyze_ranks(model, threshold)
        new_complexity = compute_time_complexity_single_pass(fc, new_structure, 1)
        print(f'Th={threshold}, Revised NN Structure: layers={len(new_structure)}, neurons: {new_structure}, complexity: {new_complexity}')
# Out:
# processing 1.benign.csv rows = 1000
# processing 1.gafgyt.combo.csv rows = 100
# processing 1.gafgyt.junk.csv rows = 100
# processing 1.gafgyt.scan.csv rows = 100
# processing 1.gafgyt.tcp.csv rows = 100
# processing 1.gafgyt.udp.csv rows = 100
# processing 1.mirai.ack.csv rows = 100
# processing 1.mirai.scan.csv rows = 100
# processing 1.mirai.syn.csv rows = 100
# processing 1.mirai.udp.csv rows = 100
# processing 1.mirai.udpplain.csv rows = 100
# ========Danmini_Doorbell========
# Features=43
# NN Structure: layers=7, neurons: [97, 83, 73, 64, 58, 53, 48]
# complexity:  32719
# title,acc,tn,fp,fn,tp
# training-cm,1.00,682,1,4,653
# training-eval,[0.012720015831291676, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,317,0,6,337
# validation-eval,[0.03779787942767143, 0.9909090995788574]
# Th=85, Revised NN Structure: layers=6, neurons: [82 70 62 54 49 45], complexity: 22178
# Th=86, Revised NN Structure: layers=6, neurons: [83 71 62 55 50 45], complexity: 22651
# Th=87, Revised NN Structure: layers=6, neurons: [84 72 63 55 50 46], complexity: 23093
# Th=88, Revised NN Structure: layers=6, neurons: [85 73 64 56 51 46], complexity: 23704
# Th=89, Revised NN Structure: layers=6, neurons: [86 73 65 57 51 47], complexity: 24121
# Th=90, Revised NN Structure: layers=6, neurons: [87 74 65 57 52 47], complexity: 24497
# Th=91, Revised NN Structure: layers=6, neurons: [88 75 66 58 52 48], complexity: 25074
# Th=92, Revised NN Structure: layers=6, neurons: [89 76 67 58 53 48], complexity: 25591
# Th=93, Revised NN Structure: layers=6, neurons: [90 77 67 59 54 49], complexity: 26153
# Th=94, Revised NN Structure: layers=6, neurons: [91 78 68 60 54 49], complexity: 26694
# Th=95, Revised NN Structure: layers=6, neurons: [92 78 69 60 55 50], complexity: 27122
# Th=96, Revised NN Structure: layers=6, neurons: [93 79 70 61 55 50], complexity: 27673
# Th=97, Revised NN Structure: layers=6, neurons: [94 80 70 62 56 51], complexity: 28257
# Th=98, Revised NN Structure: layers=6, neurons: [95 81 71 62 56 51], complexity: 28692
# Th=99, Revised NN Structure: layers=6, neurons: [96 82 72 63 57 52], complexity: 29431
# Th=100, Revised NN Structure: layers=7, neurons: [97 83 73 64 58 53 48], complexity: 32719
# processing 2.benign.csv rows = 1000
# processing 2.gafgyt.combo.csv rows = 100
# processing 2.gafgyt.junk.csv rows = 100
# processing 2.gafgyt.scan.csv rows = 100
# processing 2.gafgyt.tcp.csv rows = 100
# processing 2.gafgyt.udp.csv rows = 100
# processing 2.mirai.ack.csv rows = 100
# processing 2.mirai.scan.csv rows = 100
# processing 2.mirai.syn.csv rows = 100
# processing 2.mirai.udp.csv rows = 100
# processing 2.mirai.udpplain.csv rows = 100
# ========Ecobee_Thermostat========
# Features=53
# NN Structure: layers=5, neurons: [88, 75, 66, 58, 52]
# complexity:  22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,678,0,1,661
# training-eval,[0.003726840717718005, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,322,0,3,335
# validation-eval,[0.03444886952638626, 0.9954545497894287]
# Th=85, Revised NN Structure: layers=4, neurons: [74 63 56 49], complexity: 14461
# Th=86, Revised NN Structure: layers=4, neurons: [75 64 56 50], complexity: 14759
# Th=87, Revised NN Structure: layers=4, neurons: [76 65 57 50], complexity: 15117
# Th=88, Revised NN Structure: layers=4, neurons: [77 66 58 51], complexity: 15538
# Th=89, Revised NN Structure: layers=4, neurons: [78 66 58 51], complexity: 15651
# Th=90, Revised NN Structure: layers=4, neurons: [79 67 59 52], complexity: 16079
# Th=91, Revised NN Structure: layers=4, neurons: [80 68 60 52], complexity: 16452
# Th=92, Revised NN Structure: layers=4, neurons: [81 69 60 53], complexity: 16769
# Th=93, Revised NN Structure: layers=4, neurons: [81 69 61 54], complexity: 16953
# Th=94, Revised NN Structure: layers=4, neurons: [82 70 62 54], complexity: 17336
# Th=95, Revised NN Structure: layers=4, neurons: [83 71 62 55], complexity: 17661
# Th=96, Revised NN Structure: layers=4, neurons: [84 72 63 55], complexity: 18052
# Th=97, Revised NN Structure: layers=4, neurons: [85 72 64 56], complexity: 18363
# Th=98, Revised NN Structure: layers=4, neurons: [86 73 64 56], complexity: 18632
# Th=99, Revised NN Structure: layers=4, neurons: [87 74 65 57], complexity: 19099
# Th=100, Revised NN Structure: layers=5, neurons: [88 75 66 58 52], complexity: 22582
# processing 3.benign.csv rows = 1000
# processing 3.gafgyt.combo.csv rows = 100
# processing 3.gafgyt.junk.csv rows = 100
# processing 3.gafgyt.scan.csv rows = 100
# processing 3.gafgyt.tcp.csv rows = 100
# processing 3.gafgyt.udp.csv rows = 100
# ========Ennio_Doorbell========
# Features=53
# NN Structure: layers=6, neurons: [57, 49, 43, 38, 34, 31]
# complexity:  12274
# title,acc,tn,fp,fn,tp
# training-cm,1.00,347,0,1,657
# training-eval,[0.005911553744226694, 0.9990049600601196]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,152,1,0,342
# validation-eval,[0.03568458929657936, 0.9979798197746277]
# Th=85, Revised NN Structure: layers=5, neurons: [41 36 32 29 26], complexity: 6755
# Th=86, Revised NN Structure: layers=5, neurons: [42 37 32 29 26], complexity: 6924
# Th=87, Revised NN Structure: layers=5, neurons: [42 37 33 29 27], complexity: 7020
# Th=88, Revised NN Structure: layers=5, neurons: [43 37 33 30 27], complexity: 7176
# Th=89, Revised NN Structure: layers=5, neurons: [43 38 33 30 27], complexity: 7252
# Th=90, Revised NN Structure: layers=5, neurons: [44 38 34 30 28], complexity: 7448
# Th=91, Revised NN Structure: layers=5, neurons: [44 39 34 31 28], complexity: 7588
# Th=92, Revised NN Structure: layers=5, neurons: [45 39 35 31 28], complexity: 7756
# Th=93, Revised NN Structure: layers=5, neurons: [45 40 35 31 28], complexity: 7836
# Th=94, Revised NN Structure: layers=5, neurons: [46 40 35 32 29], complexity: 8031
# Th=95, Revised NN Structure: layers=5, neurons: [46 40 36 32 29], complexity: 8103
# Th=96, Revised NN Structure: layers=5, neurons: [47 41 36 32 29], complexity: 8285
# Th=97, Revised NN Structure: layers=5, neurons: [47 41 36 33 30], complexity: 8384
# Th=98, Revised NN Structure: layers=5, neurons: [48 42 37 33 30], complexity: 8643
# Th=99, Revised NN Structure: layers=5, neurons: [48 42 37 33 30], complexity: 8643
# Th=100, Revised NN Structure: layers=6, neurons: [57 49 43 38 34 31], complexity: 12274
# processing 4.benign.csv rows = 1000
# processing 4.gafgyt.combo.csv rows = 100
# processing 4.gafgyt.junk.csv rows = 100
# processing 4.gafgyt.scan.csv rows = 100
# processing 4.gafgyt.tcp.csv rows = 100
# processing 4.gafgyt.udp.csv rows = 100
# processing 4.mirai.ack.csv rows = 100
# processing 4.mirai.scan.csv rows = 100
# processing 4.mirai.syn.csv rows = 100
# processing 4.mirai.udp.csv rows = 100
# processing 4.mirai.udpplain.csv rows = 100
# ========Philips_B120N10_Baby_Monitor========
# Features=53
# NN Structure: layers=7, neurons: [101, 75, 67, 60, 55, 50, 46]
# complexity:  30167
# title,acc,tn,fp,fn,tp
# training-cm,0.99,653,4,4,679
# training-eval,[0.017039166763424873, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,342,1,2,315
# validation-eval,[0.019420213997364044, 0.9939393997192383]
# Th=85, Revised NN Structure: layers=6, neurons: [86 63 57 51 46 42], complexity: 20622
# Th=86, Revised NN Structure: layers=6, neurons: [87 64 57 51 47 43], complexity: 21021
# Th=87, Revised NN Structure: layers=6, neurons: [88 65 58 52 47 43], complexity: 21502
# Th=88, Revised NN Structure: layers=6, neurons: [89 66 59 52 48 44], complexity: 22027
# Th=89, Revised NN Structure: layers=6, neurons: [90 66 59 53 49 44], complexity: 22348
# Th=90, Revised NN Structure: layers=6, neurons: [91 67 60 54 49 45], complexity: 22894
# Th=91, Revised NN Structure: layers=6, neurons: [92 68 61 54 50 45], complexity: 23385
# Th=92, Revised NN Structure: layers=6, neurons: [93 69 61 55 50 46], complexity: 23820
# Th=93, Revised NN Structure: layers=6, neurons: [94 69 62 55 51 46], complexity: 24165
# Th=94, Revised NN Structure: layers=6, neurons: [95 70 63 56 51 47], complexity: 24733
# Th=95, Revised NN Structure: layers=6, neurons: [96 71 63 57 52 47], complexity: 25231
# Th=96, Revised NN Structure: layers=6, neurons: [97 72 64 57 52 48], complexity: 25695
# Th=97, Revised NN Structure: layers=6, neurons: [98 72 65 58 53 48], complexity: 26170
# Th=98, Revised NN Structure: layers=6, neurons: [99 73 65 58 53 49], complexity: 26511
# Th=99, Revised NN Structure: layers=6, neurons: [100  74  66  59  54  49], complexity: 27159
# Th=100, Revised NN Structure: layers=7, neurons: [101  75  67  60  55  50  46], complexity: 30167
# processing 5.benign.csv rows = 1000
# processing 5.gafgyt.combo.csv rows = 100
# processing 5.gafgyt.junk.csv rows = 100
# processing 5.gafgyt.scan.csv rows = 100
# processing 5.gafgyt.tcp.csv rows = 100
# processing 5.gafgyt.udp.csv rows = 100
# processing 5.mirai.ack.csv rows = 100
# processing 5.mirai.scan.csv rows = 100
# processing 5.mirai.syn.csv rows = 100
# processing 5.mirai.udp.csv rows = 100
# processing 5.mirai.udpplain.csv rows = 100
# ========Provision_PT_737E_Security_Camera========
# Features=36
# NN Structure: layers=6, neurons: [87, 75, 58, 52, 47, 43]
# complexity:  21879
# title,acc,tn,fp,fn,tp
# training-cm,1.00,678,0,3,659
# training-eval,[0.011279800906777382, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,322,0,11,327
# validation-eval,[0.07564573734998703, 0.9833333492279053]
# Th=85, Revised NN Structure: layers=5, neurons: [63 49 44 40 36], complexity: 10999
# Th=86, Revised NN Structure: layers=5, neurons: [64 50 44 40 37], complexity: 11237
# Th=87, Revised NN Structure: layers=5, neurons: [65 50 45 41 37], complexity: 11499
# Th=88, Revised NN Structure: layers=5, neurons: [66 51 45 41 37], complexity: 11700
# Th=89, Revised NN Structure: layers=5, neurons: [66 51 46 41 38], complexity: 11834
# Th=90, Revised NN Structure: layers=5, neurons: [67 52 46 42 38], complexity: 12122
# Th=91, Revised NN Structure: layers=5, neurons: [68 52 47 42 39], complexity: 12351
# Th=92, Revised NN Structure: layers=5, neurons: [69 53 47 43 39], complexity: 12645
# Th=93, Revised NN Structure: layers=5, neurons: [69 54 48 43 40], complexity: 12902
# Th=94, Revised NN Structure: layers=5, neurons: [70 54 48 44 40], complexity: 13084
# Th=95, Revised NN Structure: layers=5, neurons: [71 55 49 44 40], complexity: 13396
# Th=96, Revised NN Structure: layers=5, neurons: [72 55 49 45 41], complexity: 13626
# Th=97, Revised NN Structure: layers=5, neurons: [72 56 50 45 41], complexity: 13848
# Th=98, Revised NN Structure: layers=5, neurons: [73 56 50 46 42], complexity: 14082
# Th=99, Revised NN Structure: layers=5, neurons: [74 57 51 46 42], complexity: 14405
# Th=100, Revised NN Structure: layers=6, neurons: [87 75 58 52 47 43], complexity: 21879
# processing 6.benign.csv rows = 1000
# processing 6.gafgyt.combo.csv rows = 100
# processing 6.gafgyt.junk.csv rows = 100
# processing 6.gafgyt.scan.csv rows = 100
# processing 6.gafgyt.tcp.csv rows = 100
# processing 6.gafgyt.udp.csv rows = 100
# processing 6.mirai.ack.csv rows = 100
# processing 6.mirai.scan.csv rows = 100
# processing 6.mirai.syn.csv rows = 100
# processing 6.mirai.udp.csv rows = 100
# processing 6.mirai.udpplain.csv rows = 100
# ========Provision_PT_838_Security_Camera========
# Features=41
# NN Structure: layers=6, neurons: [88, 75, 58, 52, 48, 44]
# complexity:  22314
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,0,10,663
# training-eval,[0.026360495015978813, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,333,0,4,323
# validation-eval,[0.6381382942199707, 0.9939393997192383]
# Th=85, Revised NN Structure: layers=5, neurons: [63 49 44 40 37], complexity: 11166
# Th=86, Revised NN Structure: layers=5, neurons: [64 50 44 41 37], complexity: 11446
# Th=87, Revised NN Structure: layers=5, neurons: [65 50 45 41 38], complexity: 11671
# Th=88, Revised NN Structure: layers=5, neurons: [66 51 45 42 38], complexity: 11957
# Th=89, Revised NN Structure: layers=5, neurons: [66 51 46 42 39], complexity: 12093
# Th=90, Revised NN Structure: layers=5, neurons: [67 52 46 43 39], complexity: 12384
# Th=91, Revised NN Structure: layers=5, neurons: [68 52 47 43 40], complexity: 12617
# Th=92, Revised NN Structure: layers=5, neurons: [69 53 47 44 40], complexity: 12914
# Th=93, Revised NN Structure: layers=5, neurons: [69 54 48 44 40], complexity: 13128
# Th=94, Revised NN Structure: layers=5, neurons: [70 54 48 45 41], complexity: 13358
# Th=95, Revised NN Structure: layers=5, neurons: [71 55 49 45 41], complexity: 13673
# Th=96, Revised NN Structure: layers=5, neurons: [72 55 49 46 42], complexity: 13907
# Th=97, Revised NN Structure: layers=5, neurons: [72 56 50 46 42], complexity: 14130
# Th=98, Revised NN Structure: layers=5, neurons: [73 56 50 47 43], complexity: 14368
# Th=99, Revised NN Structure: layers=5, neurons: [74 57 51 47 43], complexity: 14694
# Th=100, Revised NN Structure: layers=6, neurons: [88 75 58 52 48 44], complexity: 22314
# processing 7.benign.csv rows = 1000
# processing 7.gafgyt.combo.csv rows = 100
# processing 7.gafgyt.junk.csv rows = 100
# processing 7.gafgyt.scan.csv rows = 100
# processing 7.gafgyt.tcp.csv rows = 100
# processing 7.gafgyt.udp.csv rows = 100
# ========Samsung_SNH_1011_N_Webcam========
# Features=47
# NN Structure: layers=6, neurons: [59, 50, 44, 39, 35, 32]
# complexity:  12687
# title,acc,tn,fp,fn,tp
# training-cm,1.00,343,0,1,661
# training-eval,[0.007040092721581459, 0.9990049600601196]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,157,0,3,335
# validation-eval,[0.036119092255830765, 0.9939393997192383]
# Th=85, Revised NN Structure: layers=5, neurons: [42 37 33 29 27], complexity: 6894
# Th=86, Revised NN Structure: layers=5, neurons: [43 37 33 30 27], complexity: 7047
# Th=87, Revised NN Structure: layers=5, neurons: [43 38 34 30 27], complexity: 7191
# Th=88, Revised NN Structure: layers=5, neurons: [44 38 34 30 28], complexity: 7316
# Th=89, Revised NN Structure: layers=5, neurons: [44 39 34 31 28], complexity: 7456
# Th=90, Revised NN Structure: layers=5, neurons: [45 39 35 31 28], complexity: 7621
# Th=91, Revised NN Structure: layers=5, neurons: [45 40 35 31 29], complexity: 7733
# Th=92, Revised NN Structure: layers=5, neurons: [46 40 35 32 29], complexity: 7893
# Th=93, Revised NN Structure: layers=5, neurons: [46 40 36 32 29], complexity: 7965
# Th=94, Revised NN Structure: layers=5, neurons: [47 41 36 32 30], complexity: 8177
# Th=95, Revised NN Structure: layers=5, neurons: [47 41 37 33 30], complexity: 8317
# Th=96, Revised NN Structure: layers=5, neurons: [48 42 37 33 30], complexity: 8499
# Th=97, Revised NN Structure: layers=5, neurons: [48 42 37 33 31], complexity: 8533
# Th=98, Revised NN Structure: layers=5, neurons: [49 43 38 34 31], complexity: 8862
# Th=99, Revised NN Structure: layers=5, neurons: [49 43 38 34 31], complexity: 8862
# Th=100, Revised NN Structure: layers=6, neurons: [59 50 44 39 35 32], complexity: 12687
# processing 8.benign.csv rows = 1000
# processing 8.gafgyt.combo.csv rows = 100
# processing 8.gafgyt.junk.csv rows = 100
# processing 8.gafgyt.scan.csv rows = 100
# processing 8.gafgyt.tcp.csv rows = 100
# processing 8.gafgyt.udp.csv rows = 100
# processing 8.mirai.ack.csv rows = 100
# processing 8.mirai.scan.csv rows = 100
# processing 8.mirai.syn.csv rows = 100
# processing 8.mirai.udp.csv rows = 100
# processing 8.mirai.udpplain.csv rows = 100
# ========SimpleHome_XCS7_1002_WHT_Security_Camera========
# Features=51
# NN Structure: layers=5, neurons: [76, 67, 59, 53, 48]
# complexity:  19020
# title,acc,tn,fp,fn,tp
# training-cm,0.99,647,16,0,677
# training-eval,[0.009885727427899837, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,325,12,3,320
# validation-eval,[0.31499454379081726, 0.9863636493682861]
# Th=85, Revised NN Structure: layers=4, neurons: [57 50 45 40], complexity: 10132
# Th=86, Revised NN Structure: layers=4, neurons: [57 50 45 41], complexity: 10178
# Th=87, Revised NN Structure: layers=4, neurons: [58 51 46 41], complexity: 10479
# Th=88, Revised NN Structure: layers=4, neurons: [59 52 46 42], complexity: 10738
# Th=89, Revised NN Structure: layers=4, neurons: [59 52 47 42], complexity: 10832
# Th=90, Revised NN Structure: layers=4, neurons: [60 53 47 43], complexity: 11095
# Th=91, Revised NN Structure: layers=4, neurons: [61 53 48 43], complexity: 11300
# Th=92, Revised NN Structure: layers=4, neurons: [61 54 48 44], complexity: 11458
# Th=93, Revised NN Structure: layers=4, neurons: [62 54 49 44], complexity: 11666
# Th=94, Revised NN Structure: layers=4, neurons: [63 55 49 45], complexity: 11938
# Th=95, Revised NN Structure: layers=4, neurons: [63 56 50 45], complexity: 12151
# Th=96, Revised NN Structure: layers=4, neurons: [64 56 50 46], complexity: 12314
# Th=97, Revised NN Structure: layers=4, neurons: [65 57 51 46], complexity: 12644
# Th=98, Revised NN Structure: layers=4, neurons: [65 57 51 47], complexity: 12696
# Th=99, Revised NN Structure: layers=4, neurons: [66 58 52 47], complexity: 13031
# Th=100, Revised NN Structure: layers=5, neurons: [76 67 59 53 48], complexity: 19020
# processing 9.benign.csv rows = 1000
# processing 9.gafgyt.combo.csv rows = 100
# processing 9.gafgyt.junk.csv rows = 100
# processing 9.gafgyt.scan.csv rows = 100
# processing 9.gafgyt.tcp.csv rows = 100
# processing 9.gafgyt.udp.csv rows = 100
# processing 9.mirai.ack.csv rows = 100
# processing 9.mirai.scan.csv rows = 100
# processing 9.mirai.syn.csv rows = 100
# processing 9.mirai.udp.csv rows = 100
# processing 9.mirai.udpplain.csv rows = 100
# ========SimpleHome_XCS7_1003_WHT_Security_Camera========
# Features=44
# NN Structure: layers=5, neurons: [88, 76, 59, 53, 48]
# complexity:  21819
# title,acc,tn,fp,fn,tp
# training-cm,1.00,684,0,3,653
# training-eval,[0.011170309968292713, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,316,0,3,341
# validation-eval,[0.16553372144699097, 0.9954545497894287]
# Th=85, Revised NN Structure: layers=4, neurons: [74 64 50 45], complexity: 14375
# Th=86, Revised NN Structure: layers=4, neurons: [75 65 50 45], complexity: 14620
# Th=87, Revised NN Structure: layers=4, neurons: [76 66 51 46], complexity: 15030
# Th=88, Revised NN Structure: layers=4, neurons: [77 67 52 46], complexity: 15393
# Th=89, Revised NN Structure: layers=4, neurons: [78 67 52 47], complexity: 15569
# Th=90, Revised NN Structure: layers=4, neurons: [79 68 53 47], complexity: 15938
# Th=91, Revised NN Structure: layers=4, neurons: [80 69 53 48], complexity: 16249
# Th=92, Revised NN Structure: layers=4, neurons: [81 70 54 48], complexity: 16626
# Th=93, Revised NN Structure: layers=4, neurons: [81 70 54 49], complexity: 16681
# Th=94, Revised NN Structure: layers=4, neurons: [82 71 55 49], complexity: 17063
# Th=95, Revised NN Structure: layers=4, neurons: [83 72 56 50], complexity: 17506
# Th=96, Revised NN Structure: layers=4, neurons: [84 73 56 50], complexity: 17774
# Th=97, Revised NN Structure: layers=4, neurons: [85 73 57 51], complexity: 18084
# Th=98, Revised NN Structure: layers=4, neurons: [86 74 57 51], complexity: 18356
# Th=99, Revised NN Structure: layers=4, neurons: [87 75 58 52], complexity: 18815
# Th=100, Revised NN Structure: layers=5, neurons: [88 76 59 53 48], complexity: 21819
