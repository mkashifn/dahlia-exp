# %%
# Imports

########################################################################
# Python Standard Libraries
import os
import multiprocessing
from timeit import default_timer as timer
import random
import math

########################################################################
# Numpy Library
import numpy as np # linear algebra

########################################################################
# Pandas Library
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

########################################################################
# MATPLOT Library
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
# %matplotlib inline

########################################################################
# SKLearn Library
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_recall_curve, classification_report, confusion_matrix, average_precision_score, roc_curve, auc, multilabel_confusion_matrix

########################################################################
# SCIPY Library
from scipy.stats import gaussian_kde
import scipy.stats as st


########################################################################
# Keras Library
from keras.models import Sequential
from keras.layers import Dense

########################################################################
# Init random seed
#seed = 13
#np.random.seed(seed)

# %%
# Utility functions
########################################################################
# Print system information
def print_system_info():
    mem_bytes = os.sysconf('SC_PAGE_SIZE') * os.sysconf('SC_PHYS_PAGES')  # e.g. 4015976448
    mem_gib = mem_bytes/(1024.**3)  # e.g. 3.74
    print("{:<23}{:f} GB".format('RAM:', mem_gib))
    print("{:<23}{:d}".format('CORES:', multiprocessing.cpu_count()))
    # !lscpu

########################################################################
# Walk through input files
def print_input_files():
    # Input data files are available in the "../input/" directory.
    for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            print(os.path.join(dirname, filename))

########################################################################
# Dump text files
def dump_text_file(fname):
    with open(fname, 'r') as f:
        print(f.read())

########################################################################
# Dump CSV files
def dump_csv_file(fname, count=5):
    # count: 0 - column names only, -1 - all rows, default = 5 rows max
    df = pd.read_csv(fname)
    if count < 0:
        count = df.shape[0]
    return df.head(count)

########################################################################
# Dataset related functions
ds_nbaiot = '/kaggle/input/nbaiot-dataset'
dn_nbaiot = ['Danmini_Doorbell', 'Ecobee_Thermostat', 'Ennio_Doorbell', 'Philips_B120N10_Baby_Monitor', 'Provision_PT_737E_Security_Camera', 'Provision_PT_838_Security_Camera', 'Samsung_SNH_1011_N_Webcam', 'SimpleHome_XCS7_1002_WHT_Security_Camera', 'SimpleHome_XCS7_1003_WHT_Security_Camera']

def fname(ds, f):
    if '.csv' not in f:
        f = f'{f}.csv'
    return os.path.join(ds, f)

def fname_nbaiot(f):
    return fname(ds_nbaiot, f)

def get_nbaiot_device_files():
    nbaiot_all_files = dump_csv_file(fname_nbaiot('data_summary'), -1)
    nbaiot_all_files = nbaiot_all_files.iloc[:,0:1].values
    device_id = 1
    indices = []
    for j in range(len(nbaiot_all_files)):
        if str(device_id) not in str(nbaiot_all_files[j]):
            indices.append(j)
            device_id += 1
    nbaiot_device_files = np.split(nbaiot_all_files, indices)
    return nbaiot_device_files

def get_nbaiot_device_data(device_id, count_norm=-1, count_anom=-1):
    if device_id < 1 or device_id > 9:
        assert False, "Please provide a valid device ID 1-9, both inclusive"
    if count_anom == -1:
        count_anom = count_norm
    device_index = device_id -1
    device_files = get_nbaiot_device_files()
    device_file = device_files[device_index]
    df = pd.DataFrame()
    y = []
    for i in range(len(device_file)):
        fname = str(device_file[i][0])
        df_c = pd.read_csv(fname_nbaiot(fname))
        count = count_anom
        if 'benign' in fname:
            count = count_norm
        count = min(count, df_c.shape[0]) if count >=0 else df_c.shape[0]
        rows = count
        print("processing", fname, "rows =", rows)
        y_np = np.ones(rows) if 'benign' in fname else np.zeros(rows)
        y.extend(y_np.tolist())
        df = pd.concat([df.iloc[:,:].reset_index(drop=True),
                      df_c.iloc[:rows,:].reset_index(drop=True)], axis=0)
    X = df.iloc[:,:].values
    y = np.array(y)
    Xdf = df
    return (X, y, Xdf)

def get_nbaiot_devices_data():
    devices_data = []
    for i in range(9):
        device_id = i + 1
        (X, y) = get_nbaiot_device_data(device_id)
        devices_data.append((X, y))
    return devices_data
#print_input_files()
print_system_info()
# Out:
# RAM:                   18.621841 GB
# CORES:                 4
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              4
# On-line CPU(s) list: 0-3
# Thread(s) per core:  2
# Core(s) per socket:  2
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               85
# Model name:          Intel(R) Xeon(R) CPU @ 2.00GHz
# Stepping:            3
# CPU MHz:             2000.164
# BogoMIPS:            4000.32
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            1024K
# L3 cache:            39424K
# NUMA node0 CPU(s):   0-3
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities

# %%
def remove_correlated_features(df, threshold):
    df = df.copy()
    # Create correlation matrix
    corr_matrix = df.corr().abs()

    # Select upper triangle of correlation matrix
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

    # Find features with correlation greater than a threshold
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

    # Drop features 
    df.drop(to_drop, axis=1, inplace=True)
    return df.iloc[:,:].values

def mark_important_features(vector, pc_keep): # pc_keep is the percentage (0-100) of labels to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    important_bool = (vector >= th)
    important_int = important_bool.astype(int)
    return important_int

def select_features(X, X_norm, X_anom, threshold):
    rows_n = X_norm.shape[0]
    rows_a = X_anom.shape[0]
    if rows_n == 0 or rows_a == 0:
        return X

    y_norm = np.ones(rows_n)
    y_anom = -1 * np.ones(rows_a)

    reg_n = LinearRegression(fit_intercept=False)
    reg_n.fit(X_norm, y_norm)
    coef_n = abs(reg_n.coef_)
    n = mark_important_features(coef_n, threshold)

    reg_a = LinearRegression(fit_intercept=False)
    reg_a.fit(X_anom, y_anom)
    coef_a = abs(reg_a.coef_)
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel

# %%
def create_binary_classifier(hidden_layers, input_dim):
    layers = []
    for hl in hidden_layers:
        if hl > 0:
            layers.append(hl)

    layer_count = len(layers)
    assert layer_count >= 1, 'at least 1 non-zero hidden layer is needed'
    model = Sequential()
    model.add(Dense(layers[0],input_dim=input_dim,activation='relu'))
    for i in range(1, layer_count):
        model.add(Dense(layers[i],activation='relu'))

    model.add(Dense(1,activation='sigmoid'))
    #model.summary()
    model.compile(loss = 'binary_crossentropy',
             optimizer ='adam',metrics=['accuracy'])
    return model

# %%
def compute_time_complexity_single_pass(neurons_input, structure, neurons_output):
    count_hidden_layers = len(structure)
    neurons = [neurons_input, *structure, neurons_output]
    complexity = 0
    for i in range(count_hidden_layers + 1):
        complexity += neurons[i] * neurons[i+1]
    return complexity

# %%
def keep_mask(vector, pc_keep): # pc_keep is the percentage (0-100) of items to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    mask_bool = (vector >= th)
    mask_int = mask_bool.astype(int)
    return (mask_bool, mask_int)

# %%
'''
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel
'''
# Out:
# '\n    a = mark_important_features(coef_a, threshold)\n   \n    mask = np.bitwise_or(n,a)\n    mask = mask == 1 # convert to Boolean\n    X_sel = X[:, mask]\n    return X_sel\n'

# %%
def analyze_ranks(model, threshold):
    w_d = 0
    b_d = 0
    layer_count = len(model.layers)
    layer_ranks = []
    new_structure = []
    for i in range(layer_count-1):
        (w_c, b_c) = model.layers[i+1].get_weights() # current weigths and biases
        rows = w_c.shape[0]
        cols = w_c.shape[1]
        w_c_abs = np.absolute(w_c)
        rank_neurons = np.sum(w_c_abs, axis=1) / cols
        rank_layer = np.sum(rank_neurons) / rows
        layer_ranks.append(rank_layer)
        (mask_bool, mask_int) = keep_mask(rank_neurons, threshold)
        new_neuron_count = np.sum(mask_int)
        new_structure.append(new_neuron_count)
        #print(f'{i+1}: {rank_neurons.shape} {rank_layer} {mask_int} {new_neuron_count}')
    layer_ranks = np.array(layer_ranks)
    new_structure = np.array(new_structure)
    (mask_bool, mask_int) = keep_mask(layer_ranks, threshold)
    new_structure = new_structure[mask_bool]
    #new_structure_masked = new_structure
    #print(f'layer mask: {mask_int} {new_structure}')
    return new_structure

# %%
model = None
def compute_report(title, model, X, y):
    y_pred = model.predict(X)
    y_pred = (y_pred > 0.25)
    #print(y_pred)
    #y_pred[y_pred <= 0] = -1 # convert negative values as 0 for anomaly
    #y_pred[y_pred > 0] = 1 # convert positive values as 1 for normal
    acc = accuracy_score(y, y_pred)
    tn, fp, fn, tp = confusion_matrix(y, y_pred, labels=[0,1]).ravel()
    cr = classification_report(y, y_pred)
    print("title,acc,tn,fp,fn,tp")
    print(f'{title}-cm,{acc:.2f},{tn},{fp},{fn},{tp}')
    #print(f'{cr}')
    results = model.evaluate(X, y, verbose=0)
    print(f'{title}-eval,{results}')
    return results[1] # accuracy

def rank_computation(title, X, y, structure, fc):
    global model
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    print (f"========{title}========")
    feature_count = X.shape[1]
    print(f'Features={feature_count}')
    print(f'NN Structure: layers={len(structure)}, neurons: {structure}')
    complexity = compute_time_complexity_single_pass(fc, structure, 1)
    print(f'complexity: {complexity}')
    model = create_binary_classifier(structure, feature_count)
    model.fit(X_train,y_train,epochs=150,batch_size=10,verbose=0)
    #analyze_ranks(model, 95)
    acc_t = compute_report('training', model, X_train, y_train)
    acc_v = compute_report('validation', model, X_test, y_test)
    return (complexity, acc_t, acc_v)

# %%
output_title = 'device_name'
output_cplx_all_devices = []  # time complexity
output_acc_t_all_devices = [] # training accuracy
output_acc_v_all_devices = [] # validation accuracy

# %%
debug_flag = True

# %%
if debug_flag:
    count_norm = 1000
    count_anom = 100
    #device_indices = [0]
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]
else:
    count_norm = -1
    count_anom = -1
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]

structures = {
    '0': [97, 83, 73, 64, 58, 53, 48],
    '1': [88, 75, 66, 58, 52],
    '2': [57, 49, 43, 38, 34, 31],
    '3': [101, 75, 67, 60, 55, 50, 46],
    '4': [87, 75, 58, 52, 47, 43],
    '5': [88, 75, 58, 52, 48, 44],
    '6': [59, 50, 44, 39, 35, 32],
    '7': [76, 67, 59, 53, 48],
    '8': [88, 76, 59, 53, 48]
}

fcs = [47, 47, 59, 51, 40, 42, 56, 56, 56]
for i in device_indices:
    device_index = i
    device_id = device_index + 1
    device_name = dn_nbaiot[device_index]
    (X, y, Xdf) = get_nbaiot_device_data(device_id, count_norm, count_anom)
    X = remove_correlated_features(Xdf, 0.98)
    X_std = StandardScaler().fit_transform(X)
    indices_norm = np.where(y >= 0.5)
    indices_anom = np.where(y <= 0.5)
    X_norm_all = X_std[indices_norm]
    X_anom_all = X_std[indices_anom]
    X_std = select_features(X_std, X_norm_all, X_anom_all,75)
    fc = fcs[i]
    print(f'############################[{i+1} - {device_name}]##########################')
    (complexity, acc_t, acc_v) = rank_computation(device_name, X_std, y, structures.get(f'{i}'), fc)
    thresholds = [100, 99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88, 87, 86, 85]
    output_cplx = f'{device_name}'
    output_acc_t = f'{device_name}'
    output_acc_v = f'{device_name}'
    for th_i in range(75):
        threshold = 100 - th_i
        output_title = f'{output_title},{threshold}'
        new_structure = analyze_ranks(model, threshold)
        new_complexity = compute_time_complexity_single_pass(fc, new_structure, 1)
        print("........................................")
        print(f'Th={threshold}, Revised NN Structure: layers={len(new_structure)}, neurons: {new_structure}, complexity: {new_complexity}')
        #(complexity, acc_t, acc_v) = (0+threshold,1+threshold,2+threshold)
        (complexity, acc_t, acc_v) = rank_computation(f'{device_name}-{threshold}', X_std, y, new_structure, fc)
        output_cplx = f'{output_cplx},{complexity}'
        output_acc_t = f'{output_acc_t},{acc_t}'
        output_acc_v = f'{output_acc_v},{acc_v}'
    output_cplx_all_devices.append(output_cplx)
    output_acc_t_all_devices.append(output_acc_t)
    output_acc_v_all_devices.append(output_acc_v)
# Out:
# processing 1.benign.csv rows = 1000
# processing 1.gafgyt.combo.csv rows = 100
# processing 1.gafgyt.junk.csv rows = 100
# processing 1.gafgyt.scan.csv rows = 100
# processing 1.gafgyt.tcp.csv rows = 100
# processing 1.gafgyt.udp.csv rows = 100
# processing 1.mirai.ack.csv rows = 100
# processing 1.mirai.scan.csv rows = 100
# processing 1.mirai.syn.csv rows = 100
# processing 1.mirai.udp.csv rows = 100
# processing 1.mirai.udpplain.csv rows = 100
# ############################[1 - Danmini_Doorbell]##########################
# ========Danmini_Doorbell========
# Features=43
# NN Structure: layers=7, neurons: [97, 83, 73, 64, 58, 53, 48]
# complexity: 32719
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,4,2,672
# training-eval,[0.012913655489683151, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,4,0,326
# validation-eval,[0.020760023966431618, 0.9939393997192383]
# ........................................
# Th=100, Revised NN Structure: layers=7, neurons: [97 83 73 64 58 53 48], complexity: 32719
# ========Danmini_Doorbell-100========
# Features=43
# NN Structure: layers=7, neurons: [97 83 73 64 58 53 48]
# complexity: 32719
# title,acc,tn,fp,fn,tp
# training-cm,0.99,677,5,2,656
# training-eval,[0.013140732422471046, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,313,5,2,340
# validation-eval,[0.11272580921649933, 0.9939393997192383]
# ........................................
# Th=99, Revised NN Structure: layers=6, neurons: [96 82 72 63 57 52], complexity: 29431
# ========Danmini_Doorbell-99========
# Features=43
# NN Structure: layers=6, neurons: [96 82 72 63 57 52]
# complexity: 29431
# title,acc,tn,fp,fn,tp
# training-cm,1.00,675,4,1,660
# training-eval,[0.010263094678521156, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,319,2,1,338
# validation-eval,[0.01852184720337391, 0.9909090995788574]
# ........................................
# Th=98, Revised NN Structure: layers=5, neurons: [94 80 70 61 55], complexity: 25218
# ========Danmini_Doorbell-98========
# Features=43
# NN Structure: layers=5, neurons: [94 80 70 61 55]
# complexity: 25218
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,2,2,680
# training-eval,[0.01134143490344286, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,5,0,318
# validation-eval,[0.11957088857889175, 0.9924242496490479]
# ........................................
# Th=97, Revised NN Structure: layers=4, neurons: [77 67 59 53], complexity: 15911
# ========Danmini_Doorbell-97========
# Features=43
# NN Structure: layers=4, neurons: [77 67 59 53]
# complexity: 15911
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,10,0,666
# training-eval,[0.007618870120495558, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,319,7,4,330
# validation-eval,[0.21018114686012268, 0.9878787994384766]
# ........................................
# Th=96, Revised NN Structure: layers=3, neurons: [73 64 50], complexity: 11353
# ========Danmini_Doorbell-96========
# Features=43
# NN Structure: layers=3, neurons: [73 64 50]
# complexity: 11353
# title,acc,tn,fp,fn,tp
# training-cm,1.00,657,4,1,678
# training-eval,[0.010160124860703945, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,336,3,1,320
# validation-eval,[0.17761273682117462, 0.9939393997192383]
# ........................................
# Th=95, Revised NN Structure: layers=2, neurons: [60 47], complexity: 5687
# ========Danmini_Doorbell-95========
# Features=43
# NN Structure: layers=2, neurons: [60 47]
# complexity: 5687
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,4,0,672
# training-eval,[0.006487726699560881, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,2,2,326
# validation-eval,[0.03012874722480774, 0.9924242496490479]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [44], complexity: 2112
# ========Danmini_Doorbell-94========
# Features=43
# NN Structure: layers=1, neurons: [44]
# complexity: 2112
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,0,4,672
# training-eval,[0.01267810259014368, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,334,2,5,319
# validation-eval,[0.04293239489197731, 0.989393949508667]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [40], complexity: 1920
# ========Danmini_Doorbell-93========
# Features=43
# NN Structure: layers=1, neurons: [40]
# complexity: 1920
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,0,6,666
# training-eval,[0.016327010467648506, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,0,6,322
# validation-eval,[0.13053998351097107, 0.989393949508667]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [36], complexity: 1728
# ========Danmini_Doorbell-92========
# Features=43
# NN Structure: layers=1, neurons: [36]
# complexity: 1728
# title,acc,tn,fp,fn,tp
# training-cm,0.99,677,3,5,655
# training-eval,[0.015770472586154938, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,4,4,336
# validation-eval,[0.029259519651532173, 0.9924242496490479]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [32], complexity: 1536
# ========Danmini_Doorbell-91========
# Features=43
# NN Structure: layers=1, neurons: [32]
# complexity: 1536
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,6,5,660
# training-eval,[0.017237816005945206, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,0,4,331
# validation-eval,[0.022500110790133476, 0.9939393997192383]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [28], complexity: 1344
# ========Danmini_Doorbell-90========
# Features=43
# NN Structure: layers=1, neurons: [28]
# complexity: 1344
# title,acc,tn,fp,fn,tp
# training-cm,0.99,650,5,7,678
# training-eval,[0.02071516215801239, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,343,2,2,313
# validation-eval,[0.019737787544727325, 0.9939393997192383]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [25], complexity: 1200
# ========Danmini_Doorbell-89========
# Features=43
# NN Structure: layers=1, neurons: [25]
# complexity: 1200
# title,acc,tn,fp,fn,tp
# training-cm,0.99,680,7,6,647
# training-eval,[0.019544120877981186, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,311,2,3,344
# validation-eval,[0.03112749569118023, 0.9909090995788574]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [22], complexity: 1056
# ========Danmini_Doorbell-88========
# Features=43
# NN Structure: layers=1, neurons: [22]
# complexity: 1056
# title,acc,tn,fp,fn,tp
# training-cm,1.00,678,3,3,656
# training-eval,[0.011552908457815647, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,3,6,335
# validation-eval,[0.03848903626203537, 0.989393949508667]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [19], complexity: 912
# ========Danmini_Doorbell-87========
# Features=43
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,0.99,675,2,8,655
# training-eval,[0.020528342574834824, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,318,5,1,336
# validation-eval,[0.11893823742866516, 0.9909090995788574]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [16], complexity: 768
# ========Danmini_Doorbell-86========
# Features=43
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,0.99,681,4,5,650
# training-eval,[0.01617150753736496, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,311,4,4,341
# validation-eval,[0.0272996723651886, 0.9909090995788574]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [13], complexity: 624
# ========Danmini_Doorbell-85========
# Features=43
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,0.99,656,1,7,676
# training-eval,[0.019272401928901672, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,340,3,2,315
# validation-eval,[0.05723206326365471, 0.9909090995788574]
# ........................................
# Th=84, Revised NN Structure: layers=1, neurons: [11], complexity: 528
# ========Danmini_Doorbell-84========
# Features=43
# NN Structure: layers=1, neurons: [11]
# complexity: 528
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,3,8,662
# training-eval,[0.020199010148644447, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,2,4,326
# validation-eval,[0.07953278720378876, 0.989393949508667]
# ........................................
# Th=83, Revised NN Structure: layers=1, neurons: [9], complexity: 432
# ========Danmini_Doorbell-83========
# Features=43
# NN Structure: layers=1, neurons: [9]
# complexity: 432
# title,acc,tn,fp,fn,tp
# training-cm,0.99,672,9,8,651
# training-eval,[0.02495250664651394, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,317,2,3,338
# validation-eval,[0.021721327677369118, 0.9924242496490479]
# ........................................
# Th=82, Revised NN Structure: layers=1, neurons: [7], complexity: 336
# ========Danmini_Doorbell-82========
# Features=43
# NN Structure: layers=1, neurons: [7]
# complexity: 336
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,5,6,658
# training-eval,[0.023202097043395042, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,321,3,3,333
# validation-eval,[0.020159121602773666, 0.989393949508667]
# ........................................
# Th=81, Revised NN Structure: layers=1, neurons: [5], complexity: 240
# ========Danmini_Doorbell-81========
# Features=43
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,638,9,7,686
# training-eval,[0.023995134979486465, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,352,1,6,301
# validation-eval,[0.029484491795301437, 0.9863636493682861]
# ........................................
# Th=80, Revised NN Structure: layers=1, neurons: [4], complexity: 192
# ========Danmini_Doorbell-80========
# Features=43
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,0.99,662,8,8,662
# training-eval,[0.026311533525586128, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,4,3,327
# validation-eval,[0.05438942834734917, 0.989393949508667]
# ........................................
# Th=79, Revised NN Structure: layers=1, neurons: [3], complexity: 144
# ========Danmini_Doorbell-79========
# Features=43
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,0.99,672,7,7,654
# training-eval,[0.029518451541662216, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,317,4,9,330
# validation-eval,[0.0574931800365448, 0.9833333492279053]
# ........................................
# Th=78, Revised NN Structure: layers=1, neurons: [2], complexity: 96
# ========Danmini_Doorbell-78========
# Features=43
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,0.97,654,34,8,644
# training-eval,[0.04395388811826706, 0.9843283295631409]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,294,18,9,339
# validation-eval,[0.06847872585058212, 0.9772727489471436]
# ........................................
# Th=77, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-77========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,627,42,8,663
# training-eval,[0.13399489223957062, 0.9634328484535217]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,314,17,4,325
# validation-eval,[0.11552003771066666, 0.9712121486663818]
# ........................................
# Th=76, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-76========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,682,1,18,639
# training-eval,[0.06160217896103859, 0.9843283295631409]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,1,7,336
# validation-eval,[0.051287852227687836, 0.9863636493682861]
# ........................................
# Th=75, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-75========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,2,14,657
# training-eval,[0.04295029491186142, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,0,5,324
# validation-eval,[0.03131745383143425, 0.9924242496490479]
# ........................................
# Th=74, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-74========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,683,2,17,638
# training-eval,[0.05441579595208168, 0.987313449382782]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,315,0,9,336
# validation-eval,[0.05281571298837662, 0.9863636493682861]
# ........................................
# Th=73, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-73========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,635,41,11,653
# training-eval,[0.1339665949344635, 0.9604477882385254]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,305,19,2,334
# validation-eval,[0.12393135577440262, 0.9681817889213562]
# ........................................
# Th=72, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-72========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,634,44,7,655
# training-eval,[0.1343540996313095, 0.9641790986061096]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,307,15,6,332
# validation-eval,[0.11741028726100922, 0.9696969985961914]
# ........................................
# Th=71, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-71========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,2,13,655
# training-eval,[0.04395538568496704, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,0,8,324
# validation-eval,[0.044928595423698425, 0.9878787994384766]
# ........................................
# Th=70, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-70========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,2,17,661
# training-eval,[0.05310219153761864, 0.9850746393203735]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,338,0,10,312
# validation-eval,[0.0679507702589035, 0.9848484992980957]
# ........................................
# Th=69, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-69========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,3,10,659
# training-eval,[0.03479029983282089, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,1,8,323
# validation-eval,[0.1292993426322937, 0.9863636493682861]
# ........................................
# Th=68, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-68========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,1,15,656
# training-eval,[0.05301305279135704, 0.9858208894729614]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,1,8,321
# validation-eval,[0.05538443848490715, 0.9848484992980957]
# ........................................
# Th=67, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-67========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,4,10,657
# training-eval,[0.02764851227402687, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,324,3,8,325
# validation-eval,[0.12306037545204163, 0.9848484992980957]
# ........................................
# Th=66, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-66========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,658,19,13,650
# training-eval,[0.09585623443126678, 0.9776119589805603]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,314,9,6,331
# validation-eval,[0.09084942191839218, 0.978787899017334]
# ........................................
# Th=65, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-65========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,621,42,9,668
# training-eval,[0.13436564803123474, 0.9634328484535217]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,320,17,3,320
# validation-eval,[0.11568731814622879, 0.9712121486663818]
# ........................................
# Th=64, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-64========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,653,14,11,662
# training-eval,[0.0803244486451149, 0.9805970191955566]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,322,11,5,322
# validation-eval,[0.0998896136879921, 0.9742424488067627]
# ........................................
# Th=63, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-63========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,621,39,9,671
# training-eval,[0.12729887664318085, 0.9664179086685181]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,320,20,4,316
# validation-eval,[0.13261575996875763, 0.9651514887809753]
# ........................................
# Th=62, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-62========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,668,1,11,660
# training-eval,[0.03640713915228844, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,1,6,323
# validation-eval,[0.043971456587314606, 0.9878787994384766]
# ........................................
# Th=61, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-61========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,661,2,22,655
# training-eval,[0.06527496129274368, 0.983582079410553]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,337,0,11,312
# validation-eval,[0.07715149968862534, 0.9818181991577148]
# ........................................
# Th=60, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-60========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,659,17,8,656
# training-eval,[0.08136685192584991, 0.9798507690429688]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,314,10,6,330
# validation-eval,[0.0966726765036583, 0.9742424488067627]
# ........................................
# Th=59, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-59========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,628,39,11,662
# training-eval,[0.13205747306346893, 0.9649253487586975]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,313,20,3,324
# validation-eval,[0.12471500784158707, 0.9681817889213562]
# ........................................
# Th=58, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-58========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,633,35,8,664
# training-eval,[0.12633545696735382, 0.9679104685783386]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,313,19,7,321
# validation-eval,[0.1433979719877243, 0.960606038570404]
# ........................................
# Th=57, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-57========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,1,14,656
# training-eval,[0.03937236964702606, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,1,5,325
# validation-eval,[0.03938563913106918, 0.989393949508667]
# ........................................
# Th=56, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-56========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,645,5,11,679
# training-eval,[0.04186961427330971, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,348,2,5,305
# validation-eval,[0.05014479532837868, 0.9878787994384766]
# ........................................
# Th=55, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-55========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,619,45,11,665
# training-eval,[0.14729371666908264, 0.9597014784812927]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,322,14,3,321
# validation-eval,[0.09498130530118942, 0.978787899017334]
# ........................................
# Th=54, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-54========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,621,45,6,668
# training-eval,[0.14261269569396973, 0.9619402885437012]
# title,acc,tn,fp,fn,tp
# validation-cm,0.95,306,28,8,318
# validation-eval,[0.18508517742156982, 0.9454545378684998]
# ........................................
# Th=53, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-53========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,2,16,656
# training-eval,[0.05514512583613396, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,0,5,323
# validation-eval,[0.03624560683965683, 0.9924242496490479]
# ........................................
# Th=52, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-52========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,2,16,664
# training-eval,[0.0497795008122921, 0.9865671396255493]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,340,0,8,312
# validation-eval,[0.0541875995695591, 0.9878787994384766]
# ........................................
# Th=51, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-51========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,2,14,658
# training-eval,[0.049362439662218094, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,332,0,10,318
# validation-eval,[0.06569980829954147, 0.9848484992980957]
# ........................................
# Th=50, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-50========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,664,4,12,660
# training-eval,[0.04439132660627365, 0.9888059496879578]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,326,6,6,322
# validation-eval,[0.0658227950334549, 0.9863636493682861]
# ........................................
# Th=49, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-49========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,632,39,9,660
# training-eval,[0.12567412853240967, 0.967164158821106]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,309,20,5,326
# validation-eval,[0.13704080879688263, 0.9636363387107849]
# ........................................
# Th=48, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-48========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,676,1,8,655
# training-eval,[0.027056552469730377, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,322,1,11,326
# validation-eval,[0.06824453175067902, 0.9818181991577148]
# ........................................
# Th=47, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-47========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.94,601,69,8,662
# training-eval,[0.18185997009277344, 0.9462686777114868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,310,20,6,324
# validation-eval,[0.14806094765663147, 0.960606038570404]
# ........................................
# Th=46, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-46========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,666,5,10,659
# training-eval,[0.04189575836062431, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,325,4,10,321
# validation-eval,[0.07853381335735321, 0.9818181991577148]
# ........................................
# Th=45, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-45========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,2,13,667
# training-eval,[0.04309699311852455, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,340,0,11,309
# validation-eval,[0.0677267462015152, 0.9833333492279053]
# ........................................
# Th=44, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-44========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,665,2,10,663
# training-eval,[0.034058962017297745, 0.9917910695075989]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,331,2,13,314
# validation-eval,[0.07801351696252823, 0.9803030490875244]
# ........................................
# Th=43, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-43========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,617,44,9,670
# training-eval,[0.14113333821296692, 0.9619402885437012]
# title,acc,tn,fp,fn,tp
# validation-cm,0.94,305,34,4,317
# validation-eval,[0.18768709897994995, 0.9454545378684998]
# ........................................
# Th=42, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-42========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,635,33,10,662
# training-eval,[0.11530230939388275, 0.967164158821106]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,308,24,4,324
# validation-eval,[0.14950481057167053, 0.9575757384300232]
# ........................................
# Th=41, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-41========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,660,6,10,664
# training-eval,[0.04003854840993881, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,331,3,8,318
# validation-eval,[0.06944697350263596, 0.9848484992980957]
# ........................................
# Th=40, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-40========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.95,620,55,8,657
# training-eval,[0.1573335975408554, 0.9559701681137085]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,302,23,6,329
# validation-eval,[0.15253767371177673, 0.9575757384300232]
# ........................................
# Th=39, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-39========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,637,38,8,657
# training-eval,[0.12492477893829346, 0.9649253487586975]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,304,21,5,330
# validation-eval,[0.1383020281791687, 0.9590908885002136]
# ........................................
# Th=38, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-38========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,669,5,16,650
# training-eval,[0.04830193519592285, 0.9880596995353699]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,324,2,9,325
# validation-eval,[0.14568237960338593, 0.9833333492279053]
# ........................................
# Th=37, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-37========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.97,636,23,13,668
# training-eval,[0.10254979878664017, 0.9731343388557434]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,4,3,316
# validation-eval,[0.05634770169854164, 0.989393949508667]
# ........................................
# Th=36, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-36========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,680,1,19,640
# training-eval,[0.0645994022488594, 0.9843283295631409]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,317,2,11,330
# validation-eval,[0.12576726078987122, 0.978787899017334]
# ........................................
# Th=35, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-35========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,1,10,660
# training-eval,[0.0325993150472641, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,1,6,324
# validation-eval,[0.04331597685813904, 0.9878787994384766]
# ........................................
# Th=34, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-34========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,625,42,9,664
# training-eval,[0.13574588298797607, 0.9634328484535217]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,316,17,2,325
# validation-eval,[0.11082062870264053, 0.9727272987365723]
# ........................................
# Th=33, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-33========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,604,44,7,685
# training-eval,[0.14376632869243622, 0.9619402885437012]
# title,acc,tn,fp,fn,tp
# validation-cm,0.93,312,40,7,301
# validation-eval,[0.2325008064508438, 0.9272727370262146]
# ........................................
# Th=32, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-32========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,627,45,10,658
# training-eval,[0.14259018003940582, 0.9574626684188843]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,313,15,2,330
# validation-eval,[0.10438508540391922, 0.9727272987365723]
# ........................................
# Th=31, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-31========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,5,13,664
# training-eval,[0.04120418056845665, 0.9895522594451904]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,331,6,5,318
# validation-eval,[0.06652449071407318, 0.9863636493682861]
# ........................................
# Th=30, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-30========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,655,4,13,668
# training-eval,[0.03680872172117233, 0.9902985095977783]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,335,6,6,313
# validation-eval,[0.10743400454521179, 0.9878787994384766]
# ........................................
# Th=29, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-29========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,1,17,651
# training-eval,[0.05958501994609833, 0.9858208894729614]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,327,1,19,313
# validation-eval,[0.12130443751811981, 0.9681817889213562]
# ........................................
# Th=28, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-28========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,681,2,20,637
# training-eval,[0.06721401959657669, 0.9850746393203735]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,317,0,14,329
# validation-eval,[0.08380156755447388, 0.978787899017334]
# ........................................
# Th=27, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-27========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.95,610,63,8,659
# training-eval,[0.1744556427001953, 0.949999988079071]
# title,acc,tn,fp,fn,tp
# validation-cm,0.95,301,26,6,327
# validation-eval,[0.16804826259613037, 0.9515151381492615]
# ........................................
# Th=26, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Danmini_Doorbell-26========
# Features=43
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.98,653,1,20,666
# training-eval,[0.06811964511871338, 0.983582079410553]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,345,1,7,307
# validation-eval,[0.05356167256832123, 0.9878787994384766]
# processing 2.benign.csv rows = 1000
# processing 2.gafgyt.combo.csv rows = 100
# processing 2.gafgyt.junk.csv rows = 100
# processing 2.gafgyt.scan.csv rows = 100
# processing 2.gafgyt.tcp.csv rows = 100
# processing 2.gafgyt.udp.csv rows = 100
# processing 2.mirai.ack.csv rows = 100
# processing 2.mirai.scan.csv rows = 100
# processing 2.mirai.syn.csv rows = 100
# processing 2.mirai.udp.csv rows = 100
# processing 2.mirai.udpplain.csv rows = 100
# ############################[2 - Ecobee_Thermostat]##########################
# ========Ecobee_Thermostat========
# Features=53
# NN Structure: layers=5, neurons: [88, 75, 66, 58, 52]
# complexity: 22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,660,0,4,676
# training-eval,[0.014278410002589226, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,340,0,1,319
# validation-eval,[0.020736824721097946, 0.9984848499298096]
# ........................................
# Th=100, Revised NN Structure: layers=5, neurons: [88 75 66 58 52], complexity: 22582
# ========Ecobee_Thermostat-100========
# Features=53
# NN Structure: layers=5, neurons: [88 75 66 58 52]
# complexity: 22582
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,0,2,682
# training-eval,[0.007368280552327633, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,344,0,3,313
# validation-eval,[0.02128474786877632, 0.9939393997192383]
# ........................................
# Th=99, Revised NN Structure: layers=4, neurons: [87 74 65 57], complexity: 19099
# ========Ecobee_Thermostat-99========
# Features=53
# NN Structure: layers=4, neurons: [87 74 65 57]
# complexity: 19099
# title,acc,tn,fp,fn,tp
# training-cm,1.00,674,0,2,664
# training-eval,[0.009148995392024517, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,326,0,2,332
# validation-eval,[0.014297437854111195, 0.9969696998596191]
# ........................................
# Th=98, Revised NN Structure: layers=3, neurons: [85 72 63], complexity: 14714
# ========Ecobee_Thermostat-98========
# Features=53
# NN Structure: layers=3, neurons: [85 72 63]
# complexity: 14714
# title,acc,tn,fp,fn,tp
# training-cm,1.00,657,0,1,682
# training-eval,[0.0048086997121572495, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,343,0,4,313
# validation-eval,[0.029990870505571365, 0.9939393997192383]
# ........................................
# Th=97, Revised NN Structure: layers=2, neurons: [69 61], complexity: 7513
# ========Ecobee_Thermostat-97========
# Features=53
# NN Structure: layers=2, neurons: [69 61]
# complexity: 7513
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,0,1,675
# training-eval,[0.002947002649307251, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,336,0,9,315
# validation-eval,[0.1922343224287033, 0.9863636493682861]
# ........................................
# Th=96, Revised NN Structure: layers=1, neurons: [58], complexity: 2784
# ========Ecobee_Thermostat-96========
# Features=53
# NN Structure: layers=1, neurons: [58]
# complexity: 2784
# title,acc,tn,fp,fn,tp
# training-cm,1.00,677,0,3,660
# training-eval,[0.010484570637345314, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,323,0,1,336
# validation-eval,[0.010199803858995438, 0.9984848499298096]
# ........................................
# Th=95, Revised NN Structure: layers=1, neurons: [55], complexity: 2640
# ========Ecobee_Thermostat-95========
# Features=53
# NN Structure: layers=1, neurons: [55]
# complexity: 2640
# title,acc,tn,fp,fn,tp
# training-cm,1.00,655,0,2,683
# training-eval,[0.0083562470972538, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,345,0,2,313
# validation-eval,[0.012177655473351479, 0.9969696998596191]
# ........................................
# Th=94, Revised NN Structure: layers=1, neurons: [51], complexity: 2448
# ========Ecobee_Thermostat-94========
# Features=53
# NN Structure: layers=1, neurons: [51]
# complexity: 2448
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,0,3,669
# training-eval,[0.010145378299057484, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,331,1,4,324
# validation-eval,[0.09674306213855743, 0.9909090995788574]
# ........................................
# Th=93, Revised NN Structure: layers=1, neurons: [47], complexity: 2256
# ========Ecobee_Thermostat-93========
# Features=53
# NN Structure: layers=1, neurons: [47]
# complexity: 2256
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,0,3,658
# training-eval,[0.011876269243657589, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,0,2,337
# validation-eval,[0.008694328367710114, 0.9969696998596191]
# ........................................
# Th=92, Revised NN Structure: layers=1, neurons: [43], complexity: 2064
# ========Ecobee_Thermostat-92========
# Features=53
# NN Structure: layers=1, neurons: [43]
# complexity: 2064
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,0,4,668
# training-eval,[0.014315980486571789, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,332,0,2,326
# validation-eval,[0.028028754517436028, 0.9954545497894287]
# ........................................
# Th=91, Revised NN Structure: layers=1, neurons: [39], complexity: 1872
# ========Ecobee_Thermostat-91========
# Features=53
# NN Structure: layers=1, neurons: [39]
# complexity: 1872
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,0,4,669
# training-eval,[0.014455458149313927, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,333,0,2,325
# validation-eval,[0.010317429900169373, 0.9969696998596191]
# ........................................
# Th=90, Revised NN Structure: layers=1, neurons: [35], complexity: 1680
# ========Ecobee_Thermostat-90========
# Features=53
# NN Structure: layers=1, neurons: [35]
# complexity: 1680
# title,acc,tn,fp,fn,tp
# training-cm,1.00,652,0,3,685
# training-eval,[0.009820877574384212, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,348,0,1,311
# validation-eval,[0.010268851183354855, 0.9969696998596191]
# ........................................
# Th=89, Revised NN Structure: layers=1, neurons: [31], complexity: 1488
# ========Ecobee_Thermostat-89========
# Features=53
# NN Structure: layers=1, neurons: [31]
# complexity: 1488
# title,acc,tn,fp,fn,tp
# training-cm,1.00,664,0,3,673
# training-eval,[0.009951095096766949, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,336,0,2,322
# validation-eval,[0.015778858214616776, 0.9969696998596191]
# ........................................
# Th=88, Revised NN Structure: layers=1, neurons: [27], complexity: 1296
# ========Ecobee_Thermostat-88========
# Features=53
# NN Structure: layers=1, neurons: [27]
# complexity: 1296
# title,acc,tn,fp,fn,tp
# training-cm,1.00,685,2,2,651
# training-eval,[0.0069963946007192135, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,310,3,2,345
# validation-eval,[0.015275008976459503, 0.9969696998596191]
# ........................................
# Th=87, Revised NN Structure: layers=1, neurons: [23], complexity: 1104
# ========Ecobee_Thermostat-87========
# Features=53
# NN Structure: layers=1, neurons: [23]
# complexity: 1104
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,0,1,669
# training-eval,[0.004870586562901735, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,0,5,325
# validation-eval,[0.03383458033204079, 0.9924242496490479]
# ........................................
# Th=86, Revised NN Structure: layers=1, neurons: [19], complexity: 912
# ========Ecobee_Thermostat-86========
# Features=53
# NN Structure: layers=1, neurons: [19]
# complexity: 912
# title,acc,tn,fp,fn,tp
# training-cm,1.00,677,0,1,662
# training-eval,[0.0026651329826563597, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,323,0,5,332
# validation-eval,[0.06184476241469383, 0.9924242496490479]
# ........................................
# Th=85, Revised NN Structure: layers=1, neurons: [16], complexity: 768
# ========Ecobee_Thermostat-85========
# Features=53
# NN Structure: layers=1, neurons: [16]
# complexity: 768
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,2,1,667
# training-eval,[0.0025198168586939573, 0.9992537498474121]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,3,3,329
# validation-eval,[0.026815546676516533, 0.9954545497894287]
# ........................................
# Th=84, Revised NN Structure: layers=1, neurons: [13], complexity: 624
# ========Ecobee_Thermostat-84========
# Features=53
# NN Structure: layers=1, neurons: [13]
# complexity: 624
# title,acc,tn,fp,fn,tp
# training-cm,1.00,690,0,4,646
# training-eval,[0.013894472271203995, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,310,0,0,350
# validation-eval,[0.0019631944596767426, 1.0]
# ........................................
# Th=83, Revised NN Structure: layers=1, neurons: [10], complexity: 480
# ========Ecobee_Thermostat-83========
# Features=53
# NN Structure: layers=1, neurons: [10]
# complexity: 480
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,0,3,669
# training-eval,[0.012016398832201958, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,332,0,2,326
# validation-eval,[0.009104634635150433, 0.9969696998596191]
# ........................................
# Th=82, Revised NN Structure: layers=1, neurons: [8], complexity: 384
# ========Ecobee_Thermostat-82========
# Features=53
# NN Structure: layers=1, neurons: [8]
# complexity: 384
# title,acc,tn,fp,fn,tp
# training-cm,1.00,655,0,4,681
# training-eval,[0.0137510159984231, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,345,0,1,314
# validation-eval,[0.011276711709797382, 0.9969696998596191]
# ........................................
# Th=81, Revised NN Structure: layers=1, neurons: [6], complexity: 288
# ========Ecobee_Thermostat-81========
# Features=53
# NN Structure: layers=1, neurons: [6]
# complexity: 288
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,0,2,670
# training-eval,[0.008220472373068333, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,332,0,2,326
# validation-eval,[0.01309255976229906, 0.9969696998596191]
# ........................................
# Th=80, Revised NN Structure: layers=1, neurons: [5], complexity: 240
# ========Ecobee_Thermostat-80========
# Features=53
# NN Structure: layers=1, neurons: [5]
# complexity: 240
# title,acc,tn,fp,fn,tp
# training-cm,0.99,677,8,4,651
# training-eval,[0.02110162377357483, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,311,4,2,343
# validation-eval,[0.020917586982250214, 0.9924242496490479]
# ........................................
# Th=79, Revised NN Structure: layers=1, neurons: [4], complexity: 192
# ========Ecobee_Thermostat-79========
# Features=53
# NN Structure: layers=1, neurons: [4]
# complexity: 192
# title,acc,tn,fp,fn,tp
# training-cm,1.00,646,0,4,690
# training-eval,[0.013562212698161602, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,354,0,4,302
# validation-eval,[0.0287165604531765, 0.9939393997192383]
# ........................................
# Th=78, Revised NN Structure: layers=1, neurons: [3], complexity: 144
# ========Ecobee_Thermostat-78========
# Features=53
# NN Structure: layers=1, neurons: [3]
# complexity: 144
# title,acc,tn,fp,fn,tp
# training-cm,1.00,670,1,5,664
# training-eval,[0.015742553398013115, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,3,3,328
# validation-eval,[0.02527184970676899, 0.9939393997192383]
# ........................................
# Th=77, Revised NN Structure: layers=1, neurons: [2], complexity: 96
# ========Ecobee_Thermostat-77========
# Features=53
# NN Structure: layers=1, neurons: [2]
# complexity: 96
# title,acc,tn,fp,fn,tp
# training-cm,1.00,685,0,3,652
# training-eval,[0.0147224310785532, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,313,2,1,344
# validation-eval,[0.016248928382992744, 0.9954545497894287]
# ........................................
# Th=76, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Ecobee_Thermostat-76========
# Features=53
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,671,3,7,659
# training-eval,[0.03466382250189781, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,318,8,6,328
# validation-eval,[0.05669134482741356, 0.9863636493682861]
# ........................................
# Th=75, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Ecobee_Thermostat-75========
# Features=53
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.95,603,69,3,665
# training-eval,[0.18167822062969208, 0.9462686777114868]
# title,acc,tn,fp,fn,tp
# validation-cm,0.94,287,41,1,331
# validation-eval,[0.20829680562019348, 0.9348484873771667]
# ........................................
# Th=74, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Ecobee_Thermostat-74========
# Features=53
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,656,0,12,672
# training-eval,[0.04458468034863472, 0.9910447597503662]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,344,0,4,312
# validation-eval,[0.03158518671989441, 0.9939393997192383]
# ........................................
# Th=73, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Ecobee_Thermostat-73========
# Features=53
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.96,631,47,2,660
# training-eval,[0.1369694322347641, 0.9634328484535217]
# title,acc,tn,fp,fn,tp
# validation-cm,0.97,309,13,5,333
# validation-eval,[0.11960963904857635, 0.9727272987365723]
# ........................................
# Th=72, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Ecobee_Thermostat-72========
# Features=53
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,0,10,672
# training-eval,[0.03779229521751404, 0.9925373196601868]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,342,0,3,315
# validation-eval,[0.027312353253364563, 0.9939393997192383]
# ........................................
# Th=71, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Ecobee_Thermostat-71========
# Features=53
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,1.00,663,0,6,671
# training-eval,[0.023518968373537064, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,337,0,6,317
# validation-eval,[0.0468011312186718, 0.9909090995788574]
# ........................................
# Th=70, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Ecobee_Thermostat-70========
# Features=53
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,685,3,7,645
# training-eval,[0.0276031456887722, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,310,2,2,346
# validation-eval,[0.022320955991744995, 0.9969696998596191]
# ........................................
# Th=69, Revised NN Structure: layers=1, neurons: [1], complexity: 48
# ========Ecobee_Thermostat-69========
# Features=53
# NN Structure: layers=1, neurons: [1]
# complexity: 48
# title,acc,tn,fp,fn,tp
# training-cm,0.99,658,8,7,667
# training-eval,[0.030384952202439308, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,329,5,1,325
# validation-eval,[0.018807627260684967, 0.9984848499298096]
# ........................................
# ...
# training-eval,[0.014398978091776371, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,324,0,5,331
# validation-eval,[0.04254784807562828, 0.9924242496490479]
# ........................................
# Th=60, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-60========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,669,0,4,667
# training-eval,[0.016865910962224007, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,330,1,1,328
# validation-eval,[0.017134232446551323, 0.9969696998596191]
# ........................................
# Th=59, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-59========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,1,2,664
# training-eval,[0.012090510688722134, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,326,0,3,331
# validation-eval,[0.025503123179078102, 0.9954545497894287]
# ........................................
# Th=58, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-58========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,652,1,4,683
# training-eval,[0.016315313056111336, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,347,0,2,311
# validation-eval,[0.015391367487609386, 0.9969696998596191]
# ........................................
# Th=57, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-57========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,661,0,4,675
# training-eval,[0.018271587789058685, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,339,0,4,317
# validation-eval,[0.034352533519268036, 0.9939393997192383]
# ........................................
# Th=56, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-56========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,0,3,666
# training-eval,[0.01215616799890995, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,328,1,2,329
# validation-eval,[0.02702919952571392, 0.9954545497894287]
# ........................................
# Th=55, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-55========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,673,1,3,663
# training-eval,[0.01397008914500475, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,325,1,3,331
# validation-eval,[0.04928920045495033, 0.9939393997192383]
# ........................................
# Th=54, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-54========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,1,3,668
# training-eval,[0.015788167715072632, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,328,3,2,327
# validation-eval,[0.028112705796957016, 0.9924242496490479]
# ........................................
# Th=53, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-53========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,638,0,4,698
# training-eval,[0.017539329826831818, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,359,3,0,298
# validation-eval,[0.018235113471746445, 0.9969696998596191]
# ........................................
# Th=52, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-52========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,1,3,668
# training-eval,[0.014790155924856663, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,326,5,1,328
# validation-eval,[0.024180853739380836, 0.9954545497894287]
# ........................................
# Th=51, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-51========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,0,3,675
# training-eval,[0.012404915876686573, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,338,0,4,318
# validation-eval,[0.03054841421544552, 0.9939393997192383]
# ........................................
# Th=50, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-50========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,674,0,4,662
# training-eval,[0.0156476479023695, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,322,4,1,333
# validation-eval,[0.07449246197938919, 0.9924242496490479]
# ........................................
# Th=49, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-49========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.97,645,39,3,653
# training-eval,[0.12349791824817657, 0.9686567187309265]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,293,23,1,343
# validation-eval,[0.13870349526405334, 0.9636363387107849]
# ........................................
# Th=48, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-48========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.86,479,191,0,670
# training-eval,[0.34008505940437317, 0.8574627041816711]
# title,acc,tn,fp,fn,tp
# validation-cm,0.86,241,89,4,326
# validation-eval,[0.3974010646343231, 0.8590909242630005]
# ........................................
# Th=47, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-47========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,686,1,2,651
# training-eval,[0.01196199283003807, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,312,1,2,345
# validation-eval,[0.020993396639823914, 0.9939393997192383]
# ........................................
# Th=46, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-46========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.95,610,59,3,668
# training-eval,[0.16360507905483246, 0.9537313580513]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,306,25,2,327
# validation-eval,[0.1852060854434967, 0.9590908885002136]
# ........................................
# Th=45, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-45========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,1,3,657
# training-eval,[0.014969911426305771, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,319,1,1,339
# validation-eval,[0.023232512176036835, 0.9939393997192383]
# ........................................
# Th=44, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-44========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.99,673,0,8,659
# training-eval,[0.032477471977472305, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,327,0,1,332
# validation-eval,[0.012815874069929123, 0.9984848499298096]
# ........................................
# Th=43, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-43========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,661,1,2,676
# training-eval,[0.01366594061255455, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,338,0,2,320
# validation-eval,[0.018636567518115044, 0.9969696998596191]
# ........................................
# Th=42, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-42========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,0,5,673
# training-eval,[0.019505057483911514, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,337,1,0,322
# validation-eval,[0.011704360134899616, 0.9984848499298096]
# ........................................
# Th=41, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-41========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,656,1,3,680
# training-eval,[0.01581006497144699, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,343,0,2,315
# validation-eval,[0.014459557831287384, 0.9969696998596191]
# ........................................
# Th=40, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-40========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.86,474,181,3,682
# training-eval,[0.34203362464904785, 0.8626865744590759]
# title,acc,tn,fp,fn,tp
# validation-cm,0.85,247,98,4,311
# validation-eval,[0.37081342935562134, 0.8454545736312866]
# ........................................
# Th=39, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-39========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,662,1,3,674
# training-eval,[0.016155023127794266, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,337,0,2,321
# validation-eval,[0.01763196848332882, 0.9969696998596191]
# ........................................
# Th=38, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-38========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.86,481,190,1,668
# training-eval,[0.34267792105674744, 0.858208954334259]
# title,acc,tn,fp,fn,tp
# validation-cm,0.86,239,90,3,328
# validation-eval,[0.35607627034187317, 0.8575757741928101]
# ........................................
# Th=37, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-37========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.99,688,0,8,644
# training-eval,[0.032614629715681076, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,312,0,1,347
# validation-eval,[0.013298849575221539, 0.9984848499298096]
# ........................................
# Th=36, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-36========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,671,1,5,663
# training-eval,[0.020897276699543, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,328,0,2,330
# validation-eval,[0.011618092656135559, 0.9954545497894287]
# ........................................
# Th=35, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-35========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,658,0,5,677
# training-eval,[0.021966632455587387, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,341,1,3,315
# validation-eval,[0.029843991622328758, 0.9939393997192383]
# ........................................
# Th=34, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-34========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,686,1,4,649
# training-eval,[0.02036542072892189, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,312,1,0,347
# validation-eval,[0.01012545358389616, 0.9984848499298096]
# ........................................
# Th=33, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-33========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,651,0,3,686
# training-eval,[0.013673459179699421, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,347,2,2,309
# validation-eval,[0.026169568300247192, 0.9939393997192383]
# ........................................
# Th=32, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-32========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.97,631,40,2,667
# training-eval,[0.1228550374507904, 0.9686567187309265]
# title,acc,tn,fp,fn,tp
# validation-cm,0.96,307,22,2,329
# validation-eval,[0.1404677927494049, 0.9636363387107849]
# ........................................
# Th=31, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-31========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.86,499,182,3,656
# training-eval,[0.3367413282394409, 0.8649253845214844]
# title,acc,tn,fp,fn,tp
# validation-cm,0.89,249,70,1,340
# validation-eval,[0.29993557929992676, 0.8924242258071899]
# ........................................
# Th=30, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-30========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,1,4,668
# training-eval,[0.019374940544366837, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,332,0,1,327
# validation-eval,[0.010633639059960842, 0.9984848499298096]
# ........................................
# Th=29, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-29========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,0.96,630,55,4,651
# training-eval,[0.15820051729679108, 0.9559701681137085]
# title,acc,tn,fp,fn,tp
# validation-cm,0.95,286,29,1,344
# validation-eval,[0.20069506764411926, 0.9545454382896423]
# ........................................
# Th=28, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-28========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,674,1,4,661
# training-eval,[0.01872292347252369, 0.996268630027771]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,325,0,1,334
# validation-eval,[0.010651004500687122, 0.9984848499298096]
# ........................................
# Th=27, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-27========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,667,0,2,671
# training-eval,[0.00935409776866436, 0.9985074400901794]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,332,1,3,324
# validation-eval,[0.061033982783555984, 0.9939393997192383]
# ........................................
# Th=26, Revised NN Structure: layers=1, neurons: [1], complexity: 57
# ========SimpleHome_XCS7_1003_WHT_Security_Camera-26========
# Features=44
# NN Structure: layers=1, neurons: [1]
# complexity: 57
# title,acc,tn,fp,fn,tp
# training-cm,1.00,649,1,4,686
# training-eval,[0.0188913457095623, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,349,1,1,309
# validation-eval,[0.012807580642402172, 0.9969696998596191]

# %%
def print_summary(title, table_header, record):
    print(f"-------------------------{title}-------------------------")
    print(table_header)
    for item in record:
        print(item)

# %%
print(f"****************************[Summary]****************************")
print_summary('time complexities', output_title, output_cplx_all_devices)
print_summary('training accuracy', output_title, output_acc_t_all_devices)
print_summary('validation accuracy', output_title, output_acc_v_all_devices)
# Out:
# ****************************[Summary]****************************
# -------------------------time complexities-------------------------
# device_name,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26
# Danmini_Doorbell,32719,29431,25218,15911,11353,5687,2112,1920,1728,1536,1344,1200,1056,912,768,624,528,432,336,240,192,144,96,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48
# Ecobee_Thermostat,22582,19099,14714,7513,2784,2640,2448,2256,2064,1872,1680,1488,1296,1104,912,768,624,480,384,288,240,192,144,96,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48,48
# Ennio_Doorbell,12274,8643,6004,3956,2491,1440,1320,1200,1080,960,840,720,600,480,420,360,300,240,180,120,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,60
# Philips_B120N10_Baby_Monitor,30167,24948,20450,11243,8070,3687,1820,1664,1508,1352,1196,1040,884,728,624,520,416,312,260,208,156,104,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52,52
# Provision_PT_737E_Security_Camera,21879,17898,10616,5700,3194,1435,1312,1189,1066,943,820,697,615,533,451,369,287,205,164,123,82,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41
# Provision_PT_838_Security_Camera,22314,14694,9334,5928,3398,1548,1419,1290,1161,1032,903,774,645,559,473,387,301,215,172,129,86,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43
# Samsung_SNH_1011_N_Webcam,12687,11157,7512,4792,3298,1596,1482,1368,1254,1140,1026,912,798,684,570,456,342,285,228,171,114,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57
# SimpleHome_XCS7_1002_WHT_Security_Camera,19020,13031,8282,4844,2394,2223,2052,1881,1710,1539,1368,1197,1026,855,741,627,513,399,285,228,171,114,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57
# SimpleHome_XCS7_1003_WHT_Security_Camera,21819,18815,15109,10402,3819,3591,3363,3078,2793,2508,2223,1938,1710,1482,1254,1026,855,684,570,456,342,228,171,114,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57,57
# -------------------------training accuracy-------------------------
# device_name,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,26,100,99,98,97,96,95,94,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,51,50,49,48,47,46,45,44,43,42,41,40,39,38,37,36,35,34,33,32,31,30,29,28,27,