# %% [markdown]
# # The Problem
#
# Given and array A containing N numbers sorted by some algorithm (say A1, A2, A3, ..., AN after sorting),
#
# Minimize the sum of products: A1A2 + A2A3 + .. A(N-1)AN
#
# ### The problem:
# `
# Give an array A, find an ordering of all the elements of A such that the total sum of the product of each pair of two adjacent elements is minimized:
# `

# %%
import itertools
import operator
import random

# %%
def compute_sum_of_products(A):
    res = 0
    for i in range(len(A)-1):
        res += A[i]*A[i+1]
    #print(A, '=>',res)
    return res

# %%
def compute_sum_of_products_algo_large(A):
    A.sort(reverse=True)
    A_len = len(A)
    mid = int( A_len / 2)
    mid += 0 if A_len % 2 == 0 else 1
    J = A[0 : mid]
    K = A[mid: ]
    j = 0
    k = 0
    res = []
    for i in range(A_len):
        print('    !', i, ': ', J, K)
        if i % 2 == 0:
            if (len(J) == 1 and len(K) == 1):
                val = [K[0], J[0]]
                res.extend(val)
                break
            elif j % 2 == 0:
                val = J[0]
            else:
                val = J[-1]
            J.remove(val)
            j += 1
        else:
            if k % 2 == 0:
                val = K[-1]
            else:
                val = K[0]
            K.remove(val)
            k += 1
        res.append(val)
    return res

# %%
def compute_sum_of_products_algo_large_2(A):
    A.sort()
    A_len = len(A)
    res = []
    left = []
    right = []
    i = 0
    while len(A) > 0:
        #print('    !', i, ': ', A, left, right)
        if len(A) >= 4:
            val = [A[-1], A[0]]
            left.extend(val)
            del A[0]
            del A[-1]
            val = [A[-1], A[0]]
            right.extend(val)
            del A[0]
            del A[-1]
        elif len(A) == 3:
            right.append(A[1])
            del A[1]
        elif len(A) == 2:
            left.append(A[-1])
            right.append(A[0])
            del A[0]
            del A[-1]
        else:
            left.append(A[0])
            del A[0]
        i += 1
    #print('    !', i, ': ', A, left, right)
    res = left
    right.reverse()
    res.extend(right)
    return res

# %%
def opt(a):
    #print('!!', a)
    if len(a) == 0:
        return []
    if len(a) == 1:
        return [a[0]]
    if len(a) == 2:
        return [a[-1], a[0]]
    #return [a[-1], a[0]].append(opt(a[1:-1]).reverse())
    x = [a[-1], a[0]]
    y = opt(a[1:-1])
    y.reverse()
    x.extend(y)
    return x

def compute_sum_of_products_algo_large_r(a):
    a.sort()
    return opt(a)

# %%
def print_sum_of_products_algo(A):
    A = compute_sum_of_products_algo_large_2(A)
    sum_c = compute_sum_of_products(A)
    print('', A, '=>',sum_c, '')
    return sum_c

# %%
def compute_sum_of_products_permute(A):
    Ac = A # copy the original list
    Ap = list(itertools.permutations(A))
    res_l = []
    for A in Ap:
        A = list(A)
        sum_c = compute_sum_of_products(A)
        res_l.append((sum_c, A))
    return (Ac, res_l)

# %%
def print_sum_of_products(res, count=-1):
    (Ac, res_l) = res
    Ac.sort()
    res_l.sort(key = operator.itemgetter(0))
    perm_count = len(res_l)
    i = 0
    count = perm_count if count < 0 else count
    print(f'The problem: {Ac}')
    print(f'Permutations: total({perm_count}), display({count})')
    j = 0
    (sum_c_old, A) = res_l[0]
    sum_c_lowest = sum_c_old
    for i in range(count):
        loop = True
        while loop:
            (sum_c, A) = res_l[j]
            if sum_c == sum_c_old:
                heading = 'P'
                print(heading, A, '=>', sum_c)
                j = j + 1
            else:
                loop = False
            sum_c_old = sum_c
    return sum_c_lowest

# %%
def compute_print_sum_of_products_permute(A, count=-1):
    res = compute_sum_of_products_permute(A)
    sum_c_permute = print_sum_of_products(res, count)
    sum_c_algo = print_sum_of_products_algo(A)
    if sum_c_permute != sum_c_algo:
        print('  failure for: ', A)

# %%
NO_OF_ROWS_TO_PRINT = 1

# %%
data_large_l = [
    [30, 20, 10, 5, 3, 2],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12, 37, 39],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 12],
    [30, 20, 10, 25, 12, 32],
]

# %%
data_small_l = [
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12, 15, 18],
]

# %%
data_small_2l = [
    [30, 20, 10, 5, 3, 2],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12, 37, 39],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 12],
    [30, 20, 10, 25, 12, 32],
]

# %%
data_medium_l = [
    [30, 20, 10, 25, 33, 12],
]

# %%
def evaluate_cases(data_l):
    for data in data_l:
        print("..................................")
        A = data
        compute_print_sum_of_products_permute(A, NO_OF_ROWS_TO_PRINT)

# %%
def evaluate_cases_random():
    for i in range(3, 11):
        for k in range(50):
            A = []
            for j in range(i):
                A.append(random.randint(5, 200))
            print("..................................")
            compute_print_sum_of_products_permute(A, NO_OF_ROWS_TO_PRINT)

# %%
data_large_2l = [
    [30, 20, 10, 5, 3, 2, 6],
    [30, 20, 10, 25, 12, 32, 8],
    [30, 20, 10, 25, 12, 32, 8, 30, 31],
    [30, 20, 10, 25, 12, 32, 8, 30, 31, 48],
]

# %%
evaluate_cases(data_large_l)
# Out:
# ..................................
# The problem: [2, 3, 5, 10, 20, 30]
# Permutations: total(720), display(1)
# P [30, 2, 10, 5, 3, 20] => 205
# P [20, 3, 5, 10, 2, 30] => 205
#  [30, 2, 10, 5, 3, 20] => 205
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30, 33, 37, 39]
# Permutations: total(40320), display(1)
# P [37, 12, 30, 25, 20, 33, 10, 39] => 3434
# P [39, 10, 33, 20, 25, 30, 12, 37] => 3434
#  [39, 10, 33, 20, 25, 30, 12, 37] => 3434
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30]
# Permutations: total(120), display(1)
# P [30, 10, 20, 12, 25] => 1040
# P [25, 12, 20, 10, 30] => 1040
#  [30, 10, 20, 12, 25] => 1040
# ..................................
# The problem: [10, 12, 20, 25, 30, 32]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 32] => 1670
# P [32, 10, 25, 20, 12, 30] => 1670
#  [32, 10, 25, 20, 12, 30] => 1670

# %%
evaluate_cases(data_large_2l)
# Out:
# ..................................
# The problem: [2, 3, 5, 6, 10, 20, 30]
# Permutations: total(5040), display(1)
# P [30, 2, 10, 5, 6, 3, 20] => 238
# P [20, 3, 6, 5, 10, 2, 30] => 238
#  [30, 2, 10, 5, 6, 3, 20] => 238
# ..................................
# The problem: [8, 10, 12, 20, 25, 30, 32]
# Permutations: total(5040), display(1)
# P [30, 10, 20, 12, 25, 8, 32] => 1496
# P [32, 8, 25, 12, 20, 10, 30] => 1496
#  [32, 8, 25, 12, 20, 10, 30] => 1496
# ..................................
# The problem: [8, 10, 12, 20, 25, 30, 30, 31, 32]
# Permutations: total(362880), display(1)
# P [32, 8, 30, 20, 25, 12, 30, 10, 31] => 2866
# P [32, 8, 30, 12, 25, 20, 30, 10, 31] => 2866
# P [32, 8, 30, 20, 25, 12, 30, 10, 31] => 2866
# P [32, 8, 30, 12, 25, 20, 30, 10, 31] => 2866
# P [31, 10, 30, 20, 25, 12, 30, 8, 32] => 2866
# P [31, 10, 30, 12, 25, 20, 30, 8, 32] => 2866
# P [31, 10, 30, 20, 25, 12, 30, 8, 32] => 2866
# P [31, 10, 30, 12, 25, 20, 30, 8, 32] => 2866
#  [32, 8, 30, 12, 25, 20, 30, 10, 31] => 2866
# ..................................
# The problem: [8, 10, 12, 20, 25, 30, 30, 31, 32, 48]
# Permutations: total(3628800), display(1)
# P [32, 10, 30, 20, 25, 30, 12, 31, 8, 48] => 3834
# P [32, 10, 30, 25, 20, 30, 12, 31, 8, 48] => 3834
# P [32, 10, 30, 20, 25, 30, 12, 31, 8, 48] => 3834
# P [32, 10, 30, 25, 20, 30, 12, 31, 8, 48] => 3834
# P [48, 8, 31, 12, 30, 20, 25, 30, 10, 32] => 3834
# P [48, 8, 31, 12, 30, 25, 20, 30, 10, 32] => 3834
# P [48, 8, 31, 12, 30, 20, 25, 30, 10, 32] => 3834
# P [48, 8, 31, 12, 30, 25, 20, 30, 10, 32] => 3834
#  [48, 8, 31, 12, 30, 25, 20, 30, 10, 32] => 3834

# %%
evaluate_cases(data_small_l)
# Out:
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 20, 25, 30, 33]
# Permutations: total(120), display(1)
# P [30, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 30] => 1680
#  [33, 10, 25, 20, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 15, 18, 20, 25, 30, 33]
# Permutations: total(40320), display(1)
# P [30, 12, 20, 18, 15, 25, 10, 33] => 2185
# P [33, 10, 25, 15, 18, 20, 12, 30] => 2185
#  [33, 10, 25, 15, 18, 20, 12, 30] => 2185

# %%
evaluate_cases(data_medium_l)
# Out:
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680

# %%
evaluate_cases_random()
# Out:
# ..................................
# The problem: [105, 111, 132]
# Permutations: total(6), display(1)
# P [132, 105, 111] => 25515
# P [111, 105, 132] => 25515
#  [132, 105, 111] => 25515
# ..................................
# The problem: [154, 177, 190]
# Permutations: total(6), display(1)
# P [190, 154, 177] => 56518
# P [177, 154, 190] => 56518
#  [190, 154, 177] => 56518
# ..................................
# The problem: [44, 133, 181]
# Permutations: total(6), display(1)
# P [181, 44, 133] => 13816
# P [133, 44, 181] => 13816
#  [181, 44, 133] => 13816
# ..................................
# The problem: [22, 23, 190]
# Permutations: total(6), display(1)
# P [190, 22, 23] => 4686
# P [23, 22, 190] => 4686
#  [190, 22, 23] => 4686
# ..................................
# The problem: [82, 192, 195]
# Permutations: total(6), display(1)
# P [192, 82, 195] => 31734
# P [195, 82, 192] => 31734
#  [195, 82, 192] => 31734
# ..................................
# The problem: [78, 111, 159]
# Permutations: total(6), display(1)
# P [111, 78, 159] => 21060
# P [159, 78, 111] => 21060
#  [159, 78, 111] => 21060
# ..................................
# The problem: [136, 160, 193]
# Permutations: total(6), display(1)
# P [160, 136, 193] => 48008
# P [193, 136, 160] => 48008
#  [193, 136, 160] => 48008
# ..................................
# The problem: [88, 91, 197]
# Permutations: total(6), display(1)
# P [91, 88, 197] => 25344
# P [197, 88, 91] => 25344
#  [197, 88, 91] => 25344
# ..................................
# The problem: [68, 113, 185]
# Permutations: total(6), display(1)
# P [113, 68, 185] => 20264
# P [185, 68, 113] => 20264
#  [185, 68, 113] => 20264
# ..................................
# The problem: [60, 107, 140]
# Permutations: total(6), display(1)
# P [140, 60, 107] => 14820
# P [107, 60, 140] => 14820
#  [140, 60, 107] => 14820
# ..................................
# The problem: [34, 68, 192]
# Permutations: total(6), display(1)
# P [192, 34, 68] => 8840
# P [68, 34, 192] => 8840
#  [192, 34, 68] => 8840
# ..................................
# The problem: [39, 74, 103]
# Permutations: total(6), display(1)
# P [74, 39, 103] => 6903
# P [103, 39, 74] => 6903
#  [103, 39, 74] => 6903
# ..................................
# The problem: [60, 141, 147]
# Permutations: total(6), display(1)
# P [147, 60, 141] => 17280
# P [141, 60, 147] => 17280
#  [147, 60, 141] => 17280
# ..................................
# The problem: [143, 145, 197]
# Permutations: total(6), display(1)
# P [145, 143, 197] => 48906
# P [197, 143, 145] => 48906
#  [197, 143, 145] => 48906
# ..................................
# The problem: [35, 39, 139]
# Permutations: total(6), display(1)
# P [139, 35, 39] => 6230
# P [39, 35, 139] => 6230
#  [139, 35, 39] => 6230
# ..................................
# The problem: [8, 17, 155]
# Permutations: total(6), display(1)
# P [155, 8, 17] => 1376
# P [17, 8, 155] => 1376
#  [155, 8, 17] => 1376
# ..................................
# The problem: [47, 74, 156]
# Permutations: total(6), display(1)
# P [156, 47, 74] => 10810
# P [74, 47, 156] => 10810
#  [156, 47, 74] => 10810
# ..................................
# The problem: [14, 62, 161]
# Permutations: total(6), display(1)
# P [161, 14, 62] => 3122
# P [62, 14, 161] => 3122
#  [161, 14, 62] => 3122
# ..................................
# The problem: [11, 149, 172]
# Permutations: total(6), display(1)
# P [149, 11, 172] => 3531
# P [172, 11, 149] => 3531
#  [172, 11, 149] => 3531
# ..................................
# The problem: [40, 63, 91]
# Permutations: total(6), display(1)
# P [63, 40, 91] => 6160
# P [91, 40, 63] => 6160
#  [91, 40, 63] => 6160
# ..................................
# The problem: [154, 175, 199]
# Permutations: total(6), display(1)
# P [175, 154, 199] => 57596
# P [199, 154, 175] => 57596
#  [199, 154, 175] => 57596
# ..................................
# The problem: [41, 182, 193]
# Permutations: total(6), display(1)
# P [182, 41, 193] => 15375
# P [193, 41, 182] => 15375
#  [193, 41, 182] => 15375
# ..................................
# The problem: [70, 78, 81]
# Permutations: total(6), display(1)
# P [81, 70, 78] => 11130
# P [78, 70, 81] => 11130
#  [81, 70, 78] => 11130
# ..................................
# The problem: [29, 124, 130]
# Permutations: total(6), display(1)
# P [124, 29, 130] => 7366
# P [130, 29, 124] => 7366
#  [130, 29, 124] => 7366
# ..................................
# The problem: [122, 156, 195]
# Permutations: total(6), display(1)
# P [195, 122, 156] => 42822
# P [156, 122, 195] => 42822
#  [195, 122, 156] => 42822
# ..................................
# The problem: [89, 150, 177]
# Permutations: total(6), display(1)
# P [150, 89, 177] => 29103
# P [177, 89, 150] => 29103
#  [177, 89, 150] => 29103
# ..................................
# The problem: [55, 109, 158]
# Permutations: total(6), display(1)
# P [109, 55, 158] => 14685
# P [158, 55, 109] => 14685
#  [158, 55, 109] => 14685
# ..................................
# The problem: [52, 55, 62]
# Permutations: total(6), display(1)
# P [55, 52, 62] => 6084
# P [62, 52, 55] => 6084
#  [62, 52, 55] => 6084
# ..................................
# The problem: [53, 91, 144]
# Permutations: total(6), display(1)
# P [91, 53, 144] => 12455
# P [144, 53, 91] => 12455
#  [144, 53, 91] => 12455
# ..................................
# The problem: [110, 139, 147]
# Permutations: total(6), display(1)
# P [147, 110, 139] => 31460
# P [139, 110, 147] => 31460
#  [147, 110, 139] => 31460
# ..................................
# The problem: [109, 122, 141]
# Permutations: total(6), display(1)
# P [141, 109, 122] => 28667
# P [122, 109, 141] => 28667
#  [141, 109, 122] => 28667
# ..................................
# The problem: [174, 191, 199]
# Permutations: total(6), display(1)
# P [191, 174, 199] => 67860
# P [199, 174, 191] => 67860
#  [199, 174, 191] => 67860
# ..................................
# The problem: [47, 69, 147]
# Permutations: total(6), display(1)
# P [69, 47, 147] => 10152
# P [147, 47, 69] => 10152
#  [147, 47, 69] => 10152
# ..................................
# The problem: [89, 93, 163]
# Permutations: total(6), display(1)
# P [163, 89, 93] => 22784
# P [93, 89, 163] => 22784
#  [163, 89, 93] => 22784
# ..................................
# The problem: [22, 106, 127]
# Permutations: total(6), display(1)
# P [106, 22, 127] => 5126
# P [127, 22, 106] => 5126
#  [127, 22, 106] => 5126
# ..................................
# The problem: [53, 124, 164]
# Permutations: total(6), display(1)
# P [124, 53, 164] => 15264
# P [164, 53, 124] => 15264
#  [164, 53, 124] => 15264
# ..................................
# The problem: [10, 22, 37]
# Permutations: total(6), display(1)
# P [37, 10, 22] => 590
# P [22, 10, 37] => 590
#  [37, 10, 22] => 590
# ..................................
# The problem: [8, 40, 70]
# Permutations: total(6), display(1)
# P [40, 8, 70] => 880
# P [70, 8, 40] => 880
#  [70, 8, 40] => 880
# ..................................
# The problem: [101, 140, 146]
# Permutations: total(6), display(1)
# P [146, 101, 140] => 28886
# P [140, 101, 146] => 28886
#  [146, 101, 140] => 28886
# ..................................
# The problem: [113, 113, 136]
# Permutations: total(6), display(1)
# P [113, 113, 136] => 28137
# P [113, 113, 136] => 28137
# P [136, 113, 113] => 28137
# P [136, 113, 113] => 28137
#  [136, 113, 113] => 28137
# ..................................
# The problem: [31, 53, 86]
# Permutations: total(6), display(1)
# P [86, 31, 53] => 4309
# P [53, 31, 86] => 4309
#  [86, 31, 53] => 4309
# ..................................
# The problem: [31, 113, 184]
# Permutations: total(6), display(1)
# P [113, 31, 184] => 9207
# P [184, 31, 113] => 9207
#  [184, 31, 113] => 9207
# ..................................
# The problem: [47, 66, 168]
# Permutations: total(6), display(1)
# P [168, 47, 66] => 10998
# P [66, 47, 168] => 10998
#  [168, 47, 66] => 10998
# ..................................
# The problem: [11, 32, 178]
# Permutations: total(6), display(1)
# P [32, 11, 178] => 2310
# P [178, 11, 32] => 2310
#  [178, 11, 32] => 2310
# ..................................
# The problem: [82, 158, 175]
# Permutations: total(6), display(1)
# P [175, 82, 158] => 27306
# P [158, 82, 175] => 27306
#  [175, 82, 158] => 27306
# ..................................
# The problem: [85, 101, 153]
# Permutations: total(6), display(1)
# P [101, 85, 153] => 21590
# P [153, 85, 101] => 21590
#  [153, 85, 101] => 21590
# ..................................
# The problem: [68, 131, 154]
# Permutations: total(6), display(1)
# P [154, 68, 131] => 19380
# P [131, 68, 154] => 19380
#  [154, 68, 131] => 19380
# ..................................
# The problem: [75, 75, 89]
# Permutations: total(6), display(1)
# P [75, 75, 89] => 12300
# P [89, 75, 75] => 12300
# P [89, 75, 75] => 12300
# P [75, 75, 89] => 12300
#  [89, 75, 75] => 12300
# ..................................
# The problem: [47, 102, 164]
# Permutations: total(6), display(1)
# P [164, 47, 102] => 12502
# P [102, 47, 164] => 12502
#  [164, 47, 102] => 12502
# ..................................
# The problem: [40, 72, 133]
# Permutations: total(6), display(1)
# P [72, 40, 133] => 8200
# P [133, 40, 72] => 8200
#  [133, 40, 72] => 8200
# ..................................
# The problem: [20, 84, 111, 191]
# Permutations: total(24), display(1)
# P [191, 20, 84, 111] => 14824
# P [111, 84, 20, 191] => 14824
#  [191, 20, 84, 111] => 14824
# ..................................
# The problem: [12, 70, 107, 151]
# Permutations: total(24), display(1)
# P [107, 70, 12, 151] => 10142
# P [151, 12, 70, 107] => 10142
#  [151, 12, 70, 107] => 10142
# ..................................
# The problem: [32, 136, 183, 198]
# Permutations: total(24), display(1)
# P [183, 136, 32, 198] => 35576
# P [198, 32, 136, 183] => 35576
#  [198, 32, 136, 183] => 35576
# ..................................
# The problem: [12, 38, 41, 115]
# Permutations: total(24), display(1)
# P [115, 12, 38, 41] => 3394
# P [41, 38, 12, 115] => 3394
#  [115, 12, 38, 41] => 3394
# ..................................
# The problem: [21, 66, 171, 175]
# Permutations: total(24), display(1)
# P [175, 21, 66, 171] => 16347
# P [171, 66, 21, 175] => 16347
#  [175, 21, 66, 171] => 16347
# ..................................
# The problem: [61, 112, 179, 185]
# Permutations: total(24), display(1)
# P [179, 112, 61, 185] => 38165
# P [185, 61, 112, 179] => 38165
#  [185, 61, 112, 179] => 38165
# ..................................
# The problem: [72, 91, 124, 181]
# Permutations: total(24), display(1)
# P [181, 72, 91, 124] => 30868
# P [124, 91, 72, 181] => 30868
#  [181, 72, 91, 124] => 30868
# ..................................
# The problem: [10, 71, 76, 184]
# Permutations: total(24), display(1)
# P [184, 10, 71, 76] => 7946
# P [76, 71, 10, 184] => 7946
#  [184, 10, 71, 76] => 7946
# ..................................
# The problem: [31, 44, 168, 181]
# Permutations: total(24), display(1)
# P [168, 44, 31, 181] => 14367
# P [181, 31, 44, 168] => 14367
#  [181, 31, 44, 168] => 14367
# ..................................
# The problem: [35, 50, 120, 134]
# Permutations: total(24), display(1)
# P [120, 50, 35, 134] => 12440
# P [134, 35, 50, 120] => 12440
#  [134, 35, 50, 120] => 12440
# ..................................
# The problem: [18, 47, 51, 71]
# Permutations: total(24), display(1)
# P [51, 47, 18, 71] => 4521
# P [71, 18, 47, 51] => 4521
#  [71, 18, 47, 51] => 4521
# ..................................
# The problem: [62, 74, 85, 99]
# Permutations: total(24), display(1)
# P [85, 74, 62, 99] => 17016
# P [99, 62, 74, 85] => 17016
#  [99, 62, 74, 85] => 17016
# ..................................
# The problem: [38, 41, 75, 126]
# Permutations: total(24), display(1)
# P [126, 38, 41, 75] => 9421
# P [75, 41, 38, 126] => 9421
#  [126, 38, 41, 75] => 9421
# ..................................
# The problem: [62, 112, 147, 149]
# Permutations: total(24), display(1)
# P [149, 62, 112, 147] => 32646
# P [147, 112, 62, 149] => 32646
#  [149, 62, 112, 147] => 32646
# ..................................
# The problem: [61, 92, 120, 176]
# Permutations: total(24), display(1)
# P [120, 92, 61, 176] => 27388
# P [176, 61, 92, 120] => 27388
#  [176, 61, 92, 120] => 27388
# ..................................
# The problem: [11, 45, 151, 171]
# Permutations: total(24), display(1)
# P [151, 45, 11, 171] => 9171
# P [171, 11, 45, 151] => 9171
#  [171, 11, 45, 151] => 9171
# ..................................
# The problem: [27, 129, 145, 199]
# Permutations: total(24), display(1)
# P [199, 27, 129, 145] => 27561
# P [145, 129, 27, 199] => 27561
#  [199, 27, 129, 145] => 27561
# ..................................
# The problem: [57, 134, 169, 173]
# Permutations: total(24), display(1)
# P [169, 134, 57, 173] => 40145
# P [173, 57, 134, 169] => 40145
#  [173, 57, 134, 169] => 40145
# ..................................
# The problem: [25, 54, 129, 199]
# Permutations: total(24), display(1)
# P [129, 54, 25, 199] => 13291
# P [199, 25, 54, 129] => 13291
#  [199, 25, 54, 129] => 13291
# ..................................
# The problem: [134, 150, 183, 198]
# Permutations: total(24), display(1)
# P [183, 150, 134, 198] => 74082
# P [198, 134, 150, 183] => 74082
#  [198, 134, 150, 183] => 74082
# ..................................
# The problem: [19, 48, 116, 200]
# Permutations: total(24), display(1)
# P [200, 19, 48, 116] => 10280
# P [116, 48, 19, 200] => 10280
#  [200, 19, 48, 116] => 10280
# ..................................
# The problem: [104, 131, 166, 195]
# Permutations: total(24), display(1)
# P [195, 104, 131, 166] => 55650
# P [166, 131, 104, 195] => 55650
#  [195, 104, 131, 166] => 55650
# ..................................
# The problem: [16, 37, 64, 175]
# Permutations: total(24), display(1)
# P [175, 16, 37, 64] => 5760
# P [64, 37, 16, 175] => 5760
#  [175, 16, 37, 64] => 5760
# ..................................
# The problem: [34, 65, 141, 156]
# Permutations: total(24), display(1)
# P [141, 65, 34, 156] => 16679
# P [156, 34, 65, 141] => 16679
#  [156, 34, 65, 141] => 16679
# ..................................
# The problem: [31, 50, 55, 180]
# Permutations: total(24), display(1)
# P [180, 31, 50, 55] => 9880
# P [55, 50, 31, 180] => 9880
#  [180, 31, 50, 55] => 9880
# ..................................
# The problem: [52, 94, 121, 146]
# Permutations: total(24), display(1)
# P [146, 52, 94, 121] => 23854
# P [121, 94, 52, 146] => 23854
#  [146, 52, 94, 121] => 23854
# ..................................
# The problem: [48, 88, 88, 114]
# Permutations: total(24), display(1)
# P [114, 48, 88, 88] => 17440
# P [114, 48, 88, 88] => 17440
# P [88, 88, 48, 114] => 17440
# P [88, 88, 48, 114] => 17440
#  [114, 48, 88, 88] => 17440
# ..................................
# The problem: [22, 166, 172, 181]
# Permutations: total(24), display(1)
# P [181, 22, 166, 172] => 36186
# P [172, 166, 22, 181] => 36186
#  [181, 22, 166, 172] => 36186
# ..................................
# The problem: [14, 61, 113, 166]
# Permutations: total(24), display(1)
# P [166, 14, 61, 113] => 10071
# P [113, 61, 14, 166] => 10071
#  [166, 14, 61, 113] => 10071
# ..................................
# The problem: [20, 32, 87, 143]
# Permutations: total(24), display(1)
# P [87, 32, 20, 143] => 6284
# P [143, 20, 32, 87] => 6284
#  [143, 20, 32, 87] => 6284
# ..................................
# The problem: [42, 88, 124, 139]
# Permutations: total(24), display(1)
# P [139, 42, 88, 124] => 20446
# P [124, 88, 42, 139] => 20446
#  [139, 42, 88, 124] => 20446
# ..................................
# The problem: [61, 132, 143, 155]
# Permutations: total(24), display(1)
# P [143, 132, 61, 155] => 36383
# P [155, 61, 132, 143] => 36383
#  [155, 61, 132, 143] => 36383
# ..................................
# The problem: [30, 80, 163, 179]
# Permutations: total(24), display(1)
# P [179, 30, 80, 163] => 20810
# P [163, 80, 30, 179] => 20810
#  [179, 30, 80, 163] => 20810
# ..................................
# The problem: [72, 96, 123, 177]
# Permutations: total(24), display(1)
# P [177, 72, 96, 123] => 31464
# P [123, 96, 72, 177] => 31464
#  [177, 72, 96, 123] => 31464
# ..................................
# The problem: [44, 68, 72, 77]
# Permutations: total(24), display(1)
# P [77, 44, 68, 72] => 11276
# P [72, 68, 44, 77] => 11276
#  [77, 44, 68, 72] => 11276
# ..................................
# The problem: [39, 54, 94, 149]
# Permutations: total(24), display(1)
# P [94, 54, 39, 149] => 12993
# P [149, 39, 54, 94] => 12993
#  [149, 39, 54, 94] => 12993
# ..................................
# The problem: [40, 86, 122, 141]
# Permutations: total(24), display(1)
# P [141, 40, 86, 122] => 19572
# P [122, 86, 40, 141] => 19572
#  [141, 40, 86, 122] => 19572
# ..................................
# The problem: [9, 42, 59, 88]
# Permutations: total(24), display(1)
# P [59, 42, 9, 88] => 3648
# P [88, 9, 42, 59] => 3648
#  [88, 9, 42, 59] => 3648
# ..................................
# The problem: [37, 44, 60, 73]
# Permutations: total(24), display(1)
# P [73, 37, 44, 60] => 6969
# P [60, 44, 37, 73] => 6969
#  [73, 37, 44, 60] => 6969
# ..................................
# The problem: [17, 63, 72, 199]
# Permutations: total(24), display(1)
# P [199, 17, 63, 72] => 8990
# P [72, 63, 17, 199] => 8990
#  [199, 17, 63, 72] => 8990
# ..................................
# The problem: [60, 83, 121, 136]
# Permutations: total(24), display(1)
# P [136, 60, 83, 121] => 23183
# P [121, 83, 60, 136] => 23183
#  [136, 60, 83, 121] => 23183
# ..................................
# The problem: [24, 67, 117, 118]
# Permutations: total(24), display(1)
# P [117, 67, 24, 118] => 12279
# P [118, 24, 67, 117] => 12279
#  [118, 24, 67, 117] => 12279
# ..................................
# The problem: [69, 153, 162, 173]
# Permutations: total(24), display(1)
# P [162, 153, 69, 173] => 47280
# P [173, 69, 153, 162] => 47280
#  [173, 69, 153, 162] => 47280
# ..................................
# The problem: [7, 27, 116, 177]
# Permutations: total(24), display(1)
# P [177, 7, 27, 116] => 4560
# P [116, 27, 7, 177] => 4560
#  [177, 7, 27, 116] => 4560
# ..................................
# The problem: [12, 105, 136, 138]
# Permutations: total(24), display(1)
# P [136, 105, 12, 138] => 17196
# P [138, 12, 105, 136] => 17196
#  [138, 12, 105, 136] => 17196
# ..................................
# The problem: [24, 70, 76, 172]
# Permutations: total(24), display(1)
# P [172, 24, 70, 76] => 11128
# P [76, 70, 24, 172] => 11128
#  [172, 24, 70, 76] => 11128
# ..................................
# The problem: [96, 138, 158, 164]
# Permutations: total(24), display(1)
# P [164, 96, 138, 158] => 50796
# P [158, 138, 96, 164] => 50796
#  [164, 96, 138, 158] => 50796
# ..................................
# The problem: [10, 180, 189, 197]
# Permutations: total(24), display(1)
# P [189, 180, 10, 197] => 37790
# P [197, 10, 180, 189] => 37790
#  [197, 10, 180, 189] => 37790
# ..................................
# The problem: [52, 86, 164, 178]
# Permutations: total(24), display(1)
# P [164, 86, 52, 178] => 27832
# P [178, 52, 86, 164] => 27832
#  [178, 52, 86, 164] => 27832
# ..................................
# The problem: [13, 87, 116, 170]
# Permutations: total(24), display(1)
# P [170, 13, 87, 116] => 13433
# P [116, 87, 13, 170] => 13433
#  [170, 13, 87, 116] => 13433
# ..................................
# The problem: [35, 106, 113, 158, 173]
# Permutations: total(120), display(1)
# P [158, 106, 113, 35, 173] => 38736
# P [173, 35, 113, 106, 158] => 38736
#  [173, 35, 113, 106, 158] => 38736
# ..................................
# The problem: [72, 82, 148, 168, 171]
# Permutations: total(120), display(1)
# P [168, 82, 148, 72, 171] => 48880
# P [171, 72, 148, 82, 168] => 48880
#  [171, 72, 148, 82, 168] => 48880
# ..................................
# The problem: [50, 90, 103, 115, 170]
# Permutations: total(120), display(1)
# P [170, 50, 103, 90, 115] => 33270
# P [115, 90, 103, 50, 170] => 33270
#  [170, 50, 103, 90, 115] => 33270
# ..................................
# The problem: [44, 56, 130, 168, 187]
# Permutations: total(120), display(1)
# P [187, 44, 130, 56, 168] => 30636
# P [168, 56, 130, 44, 187] => 30636
#  [187, 44, 130, 56, 168] => 30636
# ..................................
# The problem: [24, 53, 96, 128, 138]
# Permutations: total(120), display(1)
# P [138, 24, 96, 53, 128] => 17488
# P [128, 53, 96, 24, 138] => 17488
#  [138, 24, 96, 53, 128] => 17488
# ..................................
# The problem: [12, 34, 71, 127, 141]
# Permutations: total(120), display(1)
# P [141, 12, 71, 34, 127] => 9276
# P [127, 34, 71, 12, 141] => 9276
#  [141, 12, 71, 34, 127] => 9276
# ..................................
# The problem: [63, 77, 101, 159, 185]
# Permutations: total(120), display(1)
# P [159, 77, 101, 63, 185] => 38038
# P [185, 63, 101, 77, 159] => 38038
#  [185, 63, 101, 77, 159] => 38038
# ..................................
# The problem: [18, 53, 62, 175, 182]
# Permutations: total(120), display(1)
# P [182, 18, 62, 53, 175] => 16953
# P [175, 53, 62, 18, 182] => 16953
#  [182, 18, 62, 53, 175] => 16953
# ..................................
# The problem: [21, 26, 145, 157, 190]
# Permutations: total(120), display(1)
# P [190, 21, 145, 26, 157] => 14887
# P [157, 26, 145, 21, 190] => 14887
#  [190, 21, 145, 26, 157] => 14887
# ..................................
# The problem: [65, 111, 119, 153, 195]
# Permutations: total(120), display(1)
# P [153, 111, 119, 65, 195] => 50602
# P [195, 65, 119, 111, 153] => 50602
#  [195, 65, 119, 111, 153] => 50602
# ..................................
# The problem: [16, 38, 49, 135, 156]
# Permutations: total(120), display(1)
# P [135, 38, 49, 16, 156] => 10272
# P [156, 16, 49, 38, 135] => 10272
#  [156, 16, 49, 38, 135] => 10272
# ..................................
# The problem: [76, 89, 121, 152, 156]
# Permutations: total(120), display(1)
# P [156, 76, 121, 89, 152] => 45349
# P [152, 89, 121, 76, 156] => 45349
#  [156, 76, 121, 89, 152] => 45349
# ..................................
# The problem: [9, 14, 123, 136, 147]
# Permutations: total(120), display(1)
# P [147, 9, 123, 14, 136] => 6056
# P [136, 14, 123, 9, 147] => 6056
#  [147, 9, 123, 14, 136] => 6056
# ..................................
# The problem: [14, 60, 133, 156, 187]
# Permutations: total(120), display(1)
# P [156, 60, 133, 14, 187] => 21820
# P [187, 14, 133, 60, 156] => 21820
#  [187, 14, 133, 60, 156] => 21820
# ..................................
# The problem: [37, 150, 164, 174, 190]
# Permutations: total(120), display(1)
# P [190, 37, 164, 150, 174] => 63798
# P [174, 150, 164, 37, 190] => 63798
#  [190, 37, 164, 150, 174] => 63798
# ..................................
# The problem: [28, 50, 76, 110, 182]
# Permutations: total(120), display(1)
# P [110, 50, 76, 28, 182] => 16524
# P [182, 28, 76, 50, 110] => 16524
#  [182, 28, 76, 50, 110] => 16524
# ..................................
# The problem: [39, 57, 106, 124, 159]
# Permutations: total(120), display(1)
# P [159, 39, 106, 57, 124] => 23445
# P [124, 57, 106, 39, 159] => 23445
#  [159, 39, 106, 57, 124] => 23445
# ..................................
# The problem: [49, 64, 91, 128, 183]
# Permutations: total(120), display(1)
# P [128, 64, 91, 49, 183] => 27442
# P [183, 49, 91, 64, 128] => 27442
#  [183, 49, 91, 64, 128] => 27442
# ..................................
# The problem: [9, 38, 103, 128, 194]
# Permutations: total(120), display(1)
# P [194, 9, 103, 38, 128] => 11451
# P [128, 38, 103, 9, 194] => 11451
#  [194, 9, 103, 38, 128] => 11451
# ..................................
# The problem: [146, 152, 166, 171, 190]
# Permutations: total(120), display(1)
# P [190, 146, 166, 152, 171] => 103200
# P [171, 152, 166, 146, 190] => 103200
#  [190, 146, 166, 152, 171] => 103200
# ..................................
# The problem: [73, 90, 99, 141, 152]
# Permutations: total(120), display(1)
# P [141, 90, 99, 73, 152] => 39923
# P [152, 73, 99, 90, 141] => 39923
#  [152, 73, 99, 90, 141] => 39923
# ..................................
# The problem: [81, 108, 154, 155, 175]
# Permutations: total(120), display(1)
# P [155, 108, 154, 81, 175] => 60021
# P [175, 81, 154, 108, 155] => 60021
#  [175, 81, 154, 108, 155] => 60021
# ..................................
# The problem: [17, 94, 112, 114, 180]
# Permutations: total(120), display(1)
# P [180, 17, 112, 94, 114] => 26208
# P [114, 94, 112, 17, 180] => 26208
#  [180, 17, 112, 94, 114] => 26208
# ..................................
# The problem: [44, 86, 99, 123, 168]
# Permutations: total(120), display(1)
# P [123, 86, 99, 44, 168] => 30840
# P [168, 44, 99, 86, 123] => 30840
#  [168, 44, 99, 86, 123] => 30840
# ..................................
# The problem: [8, 24, 62, 137, 165]
# Permutations: total(120), display(1)
# P [137, 24, 62, 8, 165] => 6592
# P [165, 8, 62, 24, 137] => 6592
#  [165, 8, 62, 24, 137] => 6592
# ..................................
# The problem: [13, 58, 61, 84, 90]
# Permutations: total(120), display(1)
# P [90, 13, 61, 58, 84] => 10373
# P [84, 58, 61, 13, 90] => 10373
#  [90, 13, 61, 58, 84] => 10373
# ..................................
# The problem: [75, 91, 94, 103, 182]
# Permutations: total(120), display(1)
# P [182, 75, 94, 91, 103] => 38627
# P [103, 91, 94, 75, 182] => 38627
#  [182, 75, 94, 91, 103] => 38627
# ..................................
# The problem: [73, 78, 133, 194, 199]
# Permutations: total(120), display(1)
# P [199, 73, 133, 78, 194] => 49742
# P [194, 78, 133, 73, 199] => 49742
#  [199, 73, 133, 78, 194] => 49742
# ..................................
# The problem: [41, 57, 59, 131, 135]
# Permutations: total(120), display(1)
# P [135, 41, 59, 57, 131] => 18784
# P [131, 57, 59, 41, 135] => 18784
#  [135, 41, 59, 57, 131] => 18784
# ..................................
# The problem: [27, 36, 106, 109, 110]
# Permutations: total(120), display(1)
# P [109, 36, 106, 27, 110] => 13572
# P [110, 27, 106, 36, 109] => 13572
#  [110, 27, 106, 36, 109] => 13572
# ..................................
# The problem: [39, 43, 47, 49, 158]
# Permutations: total(120), display(1)
# P [49, 43, 47, 39, 158] => 12123
# P [158, 39, 47, 43, 49] => 12123
#  [158, 39, 47, 43, 49] => 12123
# ..................................
# The problem: [75, 154, 156, 177, 181]
# Permutations: total(120), display(1)
# P [177, 154, 156, 75, 181] => 76557
# P [181, 75, 156, 154, 177] => 76557
#  [181, 75, 156, 154, 177] => 76557
# ..................................
# The problem: [36, 59, 60, 105, 143]
# Permutations: total(120), display(1)
# P [143, 36, 60, 59, 105] => 17043
# P [105, 59, 60, 36, 143] => 17043
#  [143, 36, 60, 59, 105] => 17043
# ..................................
# The problem: [97, 106, 130, 134, 186]
# Permutations: total(120), display(1)
# P [134, 106, 130, 97, 186] => 58636
# P [186, 97, 130, 106, 134] => 58636
#  [186, 97, 130, 106, 134] => 58636
# ..................................
# The problem: [16, 26, 149, 187, 196]
# Permutations: total(120), display(1)
# P [196, 16, 149, 26, 187] => 14256
# P [187, 26, 149, 16, 196] => 14256
#  [196, 16, 149, 26, 187] => 14256
# ..................................
# The problem: [41, 41, 146, 146, 184]
# Permutations: total(120), display(1)
# P [184, 41, 146, 41, 146] => 25502
# P [184, 41, 146, 41, 146] => 25502
# P [184, 41, 146, 41, 146] => 25502
# P [184, 41, 146, 41, 146] => 25502
# P [146, 41, 146, 41, 184] => 25502
# P [146, 41, 146, 41, 184] => 25502
# P [146, 41, 146, 41, 184] => 25502
# P [146, 41, 146, 41, 184] => 25502
#  [184, 41, 146, 41, 146] => 25502
# ..................................
# The problem: [31, 53, 72, 104, 145]
# Permutations: total(120), display(1)
# P [145, 31, 72, 53, 104] => 16055
# P [104, 53, 72, 31, 145] => 16055
#  [145, 31, 72, 53, 104] => 16055
# ..................................
# The problem: [10, 10, 36, 50, 61]
# Permutations: total(120), display(1)
# P [61, 10, 36, 10, 50] => 1830
# P [61, 10, 36, 10, 50] => 1830
# P [50, 10, 36, 10, 61] => 1830
# P [50, 10, 36, 10, 61] => 1830
#  [61, 10, 36, 10, 50] => 1830
# ..................................
# The problem: [115, 122, 131, 131, 193]
# Permutations: total(120), display(1)
# P [131, 122, 131, 115, 193] => 69224
# P [131, 122, 131, 115, 193] => 69224
# P [193, 115, 131, 122, 131] => 69224
# P [193, 115, 131, 122, 131] => 69224
#  [193, 115, 131, 122, 131] => 69224
# ..................................
# The problem: [8, 9, 21, 183, 199]
# Permutations: total(120), display(1)
# P [199, 8, 21, 9, 183] => 3596
# P [183, 9, 21, 8, 199] => 3596
#  [199, 8, 21, 9, 183] => 3596
# ..................................
# The problem: [10, 33, 49, 152, 163]
# Permutations: total(120), display(1)
# P [163, 10, 49, 33, 152] => 8753
# P [152, 33, 49, 10, 163] => 8753
#  [163, 10, 49, 33, 152] => 8753
# ..................................
# The problem: [68, 106, 163, 180, 196]
# Permutations: total(120), display(1)
# P [196, 68, 163, 106, 180] => 60770
# P [180, 106, 163, 68, 196] => 60770
#  [196, 68, 163, 106, 180] => 60770
# ..................................
# The problem: [25, 52, 117, 140, 186]
# Permutations: total(120), display(1)
# P [140, 52, 117, 25, 186] => 20939
# P [186, 25, 117, 52, 140] => 20939
#  [186, 25, 117, 52, 140] => 20939
# ..................................
# The problem: [36, 76, 131, 138, 167]
# Permutations: total(120), display(1)
# P [138, 76, 131, 36, 167] => 31172
# P [167, 36, 131, 76, 138] => 31172
#  [167, 36, 131, 76, 138] => 31172
# ..................................
# The problem: [12, 42, 91, 95, 198]
# Permutations: total(120), display(1)
# P [198, 12, 91, 42, 95] => 11280
# P [95, 42, 91, 12, 198] => 11280
#  [198, 12, 91, 42, 95] => 11280
# ..................................
# The problem: [47, 159, 165, 166, 170]
# Permutations: total(120), display(1)
# P [170, 47, 165, 159, 166] => 68374
# P [166, 159, 165, 47, 170] => 68374
#  [170, 47, 165, 159, 166] => 68374
# ..................................
# The problem: [68, 107, 138, 162, 183]
# Permutations: total(120), display(1)
# P [183, 68, 138, 107, 162] => 53928
# P [162, 107, 138, 68, 183] => 53928
#  [183, 68, 138, 107, 162] => 53928
# ..................................
# The problem: [40, 40, 79, 167, 195]
# Permutations: total(120), display(1)
# P [195, 40, 79, 40, 167] => 20800
# P [195, 40, 79, 40, 167] => 20800
# P [167, 40, 79, 40, 195] => 20800
# P [167, 40, 79, 40, 195] => 20800
#  [195, 40, 79, 40, 167] => 20800
# ..................................
# The problem: [26, 97, 111, 139, 181]
# Permutations: total(120), display(1)
# P [181, 26, 111, 97, 139] => 31842
# P [139, 97, 111, 26, 181] => 31842
#  [181, 26, 111, 97, 139] => 31842
# ..................................
# The problem: [6, 46, 80, 115, 144]
# Permutations: total(120), display(1)
# P [144, 6, 80, 46, 115] => 10314
# P [115, 46, 80, 6, 144] => 10314
#  [144, 6, 80, 46, 115] => 10314
# ..................................
# The problem: [23, 79, 128, 130, 141, 144]
# Permutations: total(720), display(1)
# P [141, 79, 128, 130, 23, 144] => 44193
# P [144, 23, 130, 128, 79, 141] => 44193
#  [144, 23, 130, 128, 79, 141] => 44193
# ..................................
# The problem: [6, 8, 18, 65, 156, 191]
# Permutations: total(720), display(1)
# P [156, 8, 18, 65, 6, 191] => 4098
# P [191, 6, 65, 18, 8, 156] => 4098
#  [191, 6, 65, 18, 8, 156] => 4098
# ..................................
# The problem: [20, 29, 33, 124, 156, 199]
# Permutations: total(720), display(1)
# P [156, 29, 33, 124, 20, 199] => 16033
# P [199, 20, 124, 33, 29, 156] => 16033
#  [199, 20, 124, 33, 29, 156] => 16033
# ..................................
# The problem: [36, 91, 102, 124, 130, 177]
# Permutations: total(720), display(1)
# P [130, 91, 102, 124, 36, 177] => 44596
# P [177, 36, 124, 102, 91, 130] => 44596
#  [177, 36, 124, 102, 91, 130] => 44596
# ..................................
# The problem: [21, 37, 86, 129, 174, 174]
# Permutations: total(720), display(1)
# P [174, 21, 129, 86, 37, 174] => 27077
# P [174, 37, 86, 129, 21, 174] => 27077
# P [174, 21, 129, 86, 37, 174] => 27077
# P [174, 37, 86, 129, 21, 174] => 27077
#  [174, 21, 129, 86, 37, 174] => 27077
# ..................................
# The problem: [14, 66, 71, 117, 159, 179]
# Permutations: total(720), display(1)
# P [159, 66, 71, 117, 14, 179] => 27631
# P [179, 14, 117, 71, 66, 159] => 27631
#  [179, 14, 117, 71, 66, 159] => 27631
# ..................................
# The problem: [11, 39, 56, 75, 153, 168]
# Permutations: total(720), display(1)
# P [153, 39, 56, 75, 11, 168] => 15024
# P [168, 11, 75, 56, 39, 153] => 15024
#  [168, 11, 75, 56, 39, 153] => 15024
# ..................................
# The problem: [22, 27, 32, 44, 165, 172]
# Permutations: total(720), display(1)
# P [172, 22, 44, 32, 27, 165] => 11479
# P [165, 27, 32, 44, 22, 172] => 11479
#  [172, 22, 44, 32, 27, 165] => 11479
# ..................................
# The problem: [5, 50, 89, 106, 148, 192]
# Permutations: total(720), display(1)
# P [192, 5, 106, 89, 50, 148] => 22774
# P [148, 50, 89, 106, 5, 192] => 22774
#  [192, 5, 106, 89, 50, 148] => 22774
# ..................................
# The problem: [27, 43, 59, 60, 78, 141]
# Permutations: total(720), display(1)
# P [141, 27, 60, 59, 43, 78] => 14858
# P [78, 43, 59, 60, 27, 141] => 14858
#  [141, 27, 60, 59, 43, 78] => 14858
# ..................................
# The problem: [16, 52, 110, 165, 167, 171]
# Permutations: total(720), display(1)
# P [171, 16, 165, 110, 52, 167] => 37930
# P [167, 52, 110, 165, 16, 171] => 37930
#  [171, 16, 165, 110, 52, 167] => 37930
# ..................................
# The problem: [78, 86, 91, 117, 125, 192]
# Permutations: total(720), display(1)
# P [192, 78, 117, 91, 86, 125] => 53325
# P [125, 86, 91, 117, 78, 192] => 53325
#  [192, 78, 117, 91, 86, 125] => 53325
# ..................................
# The problem: [67, 107, 153, 154, 184, 192]
# Permutations: total(720), display(1)
# P [184, 107, 153, 154, 67, 192] => 82803
# P [192, 67, 154, 153, 107, 184] => 82803
#  [192, 67, 154, 153, 107, 184] => 82803
# ..................................
# The problem: [101, 116, 136, 145, 175, 200]
# Permutations: total(720), display(1)
# P [175, 116, 136, 145, 101, 200] => 90641
# P [200, 101, 145, 136, 116, 175] => 90641
#  [200, 101, 145, 136, 116, 175] => 90641
# ..................................
# The problem: [57, 86, 105, 107, 195, 200]
# Permutations: total(720), display(1)
# P [195, 86, 105, 107, 57, 200] => 54534
# P [200, 57, 107, 105, 86, 195] => 54534
#  [200, 57, 107, 105, 86, 195] => 54534
# ..................................
# The problem: [24, 45, 47, 124, 158, 173]
# Permutations: total(720), display(1)
# P [173, 24, 124, 47, 45, 158] => 22181
# P [158, 45, 47, 124, 24, 173] => 22181
#  [173, 24, 124, 47, 45, 158] => 22181
# ..................................
# The problem: [37, 53, 98, 107, 173, 180]
# Permutations: total(720), display(1)
# P [180, 37, 107, 98, 53, 173] => 35468
# P [173, 53, 98, 107, 37, 180] => 35468
#  [180, 37, 107, 98, 53, 173] => 35468
# ..................................
# The problem: [95, 104, 114, 115, 186, 195]
# Permutations: total(720), display(1)
# P [186, 104, 114, 115, 95, 195] => 73760
# P [195, 95, 115, 114, 104, 186] => 73760
#  [195, 95, 115, 114, 104, 186] => 73760
# ..................................
# The problem: [21, 36, 111, 121, 124, 164]
# Permutations: total(720), display(1)
# P [124, 36, 111, 121, 21, 164] => 27876
# P [164, 21, 121, 111, 36, 124] => 27876
#  [164, 21, 121, 111, 36, 124] => 27876
# ..................................
# The problem: [13, 91, 108, 114, 148, 171]
# Permutations: total(720), display(1)
# P [171, 13, 114, 108, 91, 148] => 39313
# P [148, 91, 108, 114, 13, 171] => 39313
#  [171, 13, 114, 108, 91, 148] => 39313
# ..................................
# The problem: [6, 80, 98, 115, 136, 162]
# Permutations: total(720), display(1)
# P [136, 80, 98, 115, 6, 162] => 31652
# P [162, 6, 115, 98, 80, 136] => 31652
#  [162, 6, 115, 98, 80, 136] => 31652
# ..................................
# The problem: [9, 68, 71, 91, 133, 143]
# Permutations: total(720), display(1)
# P [143, 9, 91, 71, 68, 133] => 22439
# P [133, 68, 71, 91, 9, 143] => 22439
#  [143, 9, 91, 71, 68, 133] => 22439
# ..................................
# The problem: [5, 13, 41, 68, 144, 169]
# Permutations: total(720), display(1)
# P [169, 5, 68, 41, 13, 144] => 6378
# P [144, 13, 41, 68, 5, 169] => 6378
#  [169, 5, 68, 41, 13, 144] => 6378
# ..................................
# The problem: [12, 15, 31, 55, 96, 153]
# Permutations: total(720), display(1)
# P [153, 12, 55, 31, 15, 96] => 6106
# P [96, 15, 31, 55, 12, 153] => 6106
#  [153, 12, 55, 31, 15, 96] => 6106
# ..................................
# The problem: [25, 53, 134, 153, 170, 176]
# Permutations: total(720), display(1)
# P [170, 53, 134, 153, 25, 176] => 44839
# P [176, 25, 153, 134, 53, 170] => 44839
#  [176, 25, 153, 134, 53, 170] => 44839
# ..................................
# The problem: [51, 73, 80, 129, 189, 195]
# Permutations: total(720), display(1)
# P [189, 73, 80, 129, 51, 195] => 46481
# P [195, 51, 129, 80, 73, 189] => 46481
#  [195, 51, 129, 80, 73, 189] => 46481
# ..................................
# The problem: [10, 29, 32, 156, 169, 197]
# Permutations: total(720), display(1)
# P [169, 29, 32, 156, 10, 197] => 14351
# P [197, 10, 156, 32, 29, 169] => 14351
#  [197, 10, 156, 32, 29, 169] => 14351
# ..................................
# The problem: [82, 121, 164, 166, 168, 186]
# Permutations: total(720), display(1)
# P [168, 121, 164, 166, 82, 186] => 96260
# P [186, 82, 166, 164, 121, 168] => 96260
#  [186, 82, 166, 164, 121, 168] => 96260
# ..................................
# The problem: [5, 94, 136, 153, 159, 195]
# Permutations: total(720), display(1)
# P [159, 94, 136, 153, 5, 195] => 50278
# P [195, 5, 153, 136, 94, 159] => 50278
#  [195, 5, 153, 136, 94, 159] => 50278
# ..................................
# The problem: [124, 141, 150, 150, 189, 193]
# Permutations: total(720), display(1)
# P [193, 124, 150, 150, 141, 189] => 112831
# P [193, 124, 150, 150, 141, 189] => 112831
# P [189, 141, 150, 150, 124, 193] => 112831
# P [189, 141, 150, 150, 124, 193] => 112831
#  [193, 124, 150, 150, 141, 189] => 112831
# ..................................
# The problem: [29, 36, 60, 90, 96, 125]
# Permutations: total(720), display(1)
# P [96, 36, 60, 90, 29, 125] => 17251
# P [125, 29, 90, 60, 36, 96] => 17251
#  [125, 29, 90, 60, 36, 96] => 17251
# ..................................
# The problem: [40, 54, 68, 127, 128, 184]
# Permutations: total(720), display(1)
# P [128, 54, 68, 127, 40, 184] => 31660
# P [184, 40, 127, 68, 54, 128] => 31660
#  [184, 40, 127, 68, 54, 128] => 31660
# ..................................
# The problem: [8, 52, 67, 84, 86, 173]
# Permutations: total(720), display(1)
# P [86, 52, 67, 84, 8, 173] => 15640
# P [173, 8, 84, 67, 52, 86] => 15640
#  [173, 8, 84, 67, 52, 86] => 15640
# ..................................
# The problem: [14, 49, 78, 87, 125, 128]
# Permutations: total(720), display(1)
# P [128, 14, 87, 78, 49, 125] => 19743
# P [125, 49, 78, 87, 14, 128] => 19743
#  [128, 14, 87, 78, 49, 125] => 19743
# ..................................
# The problem: [8, 36, 62, 103, 128, 134]
# Permutations: total(720), display(1)
# P [134, 8, 103, 62, 36, 128] => 15122
# P [128, 36, 62, 103, 8, 134] => 15122
#  [134, 8, 103, 62, 36, 128] => 15122
# ..................................
# The problem: [30, 30, 34, 53, 56, 97]
# Permutations: total(720), display(1)
# P [56, 30, 53, 34, 30, 97] => 9002
# P [56, 30, 34, 53, 30, 97] => 9002
# P [56, 30, 53, 34, 30, 97] => 9002
# P [56, 30, 34, 53, 30, 97] => 9002
# P [97, 30, 53, 34, 30, 56] => 9002
# P [97, 30, 34, 53, 30, 56] => 9002
# P [97, 30, 53, 34, 30, 56] => 9002
# P [97, 30, 34, 53, 30, 56] => 9002
#  [97, 30, 53, 34, 30, 56] => 9002
# ..................................
# The problem: [62, 99, 115, 138, 192, 196]
# Permutations: total(720), display(1)
# P [192, 99, 115, 138, 62, 196] => 66971
# P [196, 62, 138, 115, 99, 192] => 66971
#  [196, 62, 138, 115, 99, 192] => 66971
# ..................................
# The problem: [60, 101, 132, 135, 173, 177]
# Permutations: total(720), display(1)
# P [177, 60, 135, 132, 101, 173] => 67345
# P [173, 101, 132, 135, 60, 177] => 67345
#  [177, 60, 135, 132, 101, 173] => 67345
# ..................................
# The problem: [30, 39, 77, 92, 196, 200]
# Permutations: total(720), display(1)
# P [196, 39, 77, 92, 30, 200] => 26491
# P [200, 30, 92, 77, 39, 196] => 26491
#  [200, 30, 92, 77, 39, 196] => 26491
# ..................................
# The problem: [28, 33, 33, 56, 132, 171]
# Permutations: total(720), display(1)
# P [171, 28, 56, 33, 33, 132] => 13649
# P [171, 28, 56, 33, 33, 132] => 13649
# P [132, 33, 33, 56, 28, 171] => 13649
# P [132, 33, 33, 56, 28, 171] => 13649
#  [171, 28, 56, 33, 33, 132] => 13649
# ..................................
# The problem: [53, 60, 65, 92, 94, 198]
# Permutations: total(720), display(1)
# P [94, 60, 65, 92, 53, 198] => 30890
# P [198, 53, 92, 65, 60, 94] => 30890
#  [198, 53, 92, 65, 60, 94] => 30890
# ..................................
# The problem: [11, 40, 65, 82, 91, 121]
# Permutations: total(720), display(1)
# P [121, 11, 82, 65, 40, 91] => 13803
# P [91, 40, 65, 82, 11, 121] => 13803
#  [121, 11, 82, 65, 40, 91] => 13803
# ..................................
# The problem: [73, 74, 128, 151, 152, 169]
# Permutations: total(720), display(1)
# P [152, 74, 128, 151, 73, 169] => 63408
# P [169, 73, 151, 128, 74, 152] => 63408
#  [169, 73, 151, 128, 74, 152] => 63408
# ..................................
# The problem: [22, 48, 53, 74, 137, 156]
# Permutations: total(720), display(1)
# P [156, 22, 74, 53, 48, 137] => 18102
# P [137, 48, 53, 74, 22, 156] => 18102
#  [156, 22, 74, 53, 48, 137] => 18102
# ..................................
# The problem: [11, 56, 114, 163, 188, 196]
# Permutations: total(720), display(1)
# P [196, 11, 163, 114, 56, 188] => 39443
# P [188, 56, 114, 163, 11, 196] => 39443
#  [196, 11, 163, 114, 56, 188] => 39443
# ..................................
# The problem: [8, 38, 48, 76, 150, 151]
# Permutations: total(720), display(1)
# P [150, 38, 48, 76, 8, 151] => 12988
# P [151, 8, 76, 48, 38, 150] => 12988
#  [151, 8, 76, 48, 38, 150] => 12988
# ..................................
# The problem: [13, 29, 31, 48, 63, 132]
# Permutations: total(720), display(1)
# P [63, 29, 31, 48, 13, 132] => 6554
# P [132, 13, 48, 31, 29, 63] => 6554
#  [132, 13, 48, 31, 29, 63] => 6554
# ..................................
# The problem: [22, 95, 125, 178, 193, 197]
# Permutations: total(720), display(1)
# P [197, 22, 178, 125, 95, 193] => 60710
# P [193, 95, 125, 178, 22, 197] => 60710
#  [197, 22, 178, 125, 95, 193] => 60710
# ..................................
# The problem: [31, 34, 36, 102, 110, 168]
# Permutations: total(720), display(1)
# P [168, 31, 102, 36, 34, 110] => 17006
# P [110, 34, 36, 102, 31, 168] => 17006
#  [168, 31, 102, 36, 34, 110] => 17006
# ..................................
# The problem: [24, 80, 106, 126, 169, 199]
# Permutations: total(720), display(1)
# P [199, 24, 126, 106, 80, 169] => 43156
# P [169, 80, 106, 126, 24, 199] => 43156
#  [199, 24, 126, 106, 80, 169] => 43156
# ..................................
# The problem: [19, 27, 62, 98, 108, 112, 156]
# Permutations: total(5040), display(1)
# P [112, 27, 98, 62, 108, 19, 156] => 23458
# P [156, 19, 108, 62, 98, 27, 112] => 23458
#  [156, 19, 108, 62, 98, 27, 112] => 23458
# ..................................
# The problem: [15, 75, 93, 94, 98, 134, 176]
# Permutations: total(5040), display(1)
# P [176, 15, 98, 93, 94, 75, 134] => 39066
# P [134, 75, 94, 93, 98, 15, 176] => 39066
#  [176, 15, 98, 93, 94, 75, 134] => 39066
# ..................................
# The problem: [39, 43, 48, 56, 84, 105, 188]
# Permutations: total(5040), display(1)
# P [188, 39, 84, 48, 56, 43, 105] => 24251
# P [105, 43, 56, 48, 84, 39, 188] => 24251
#  [188, 39, 84, 48, 56, 43, 105] => 24251
# ..................................
# The problem: [37, 85, 128, 141, 154, 156, 170]
# Permutations: total(5040), display(1)
# P [170, 37, 154, 128, 141, 85, 156] => 74993
# P [156, 85, 141, 128, 154, 37, 170] => 74993
#  [170, 37, 154, 128, 141, 85, 156] => 74993
# ..................................
# The problem: [23, 68, 72, 86, 101, 127, 141]
# Permutations: total(5040), display(1)
# P [127, 68, 86, 72, 101, 23, 141] => 33514
# P [141, 23, 101, 72, 86, 68, 127] => 33514
#  [141, 23, 101, 72, 86, 68, 127] => 33514
# ..................................
# The problem: [28, 31, 83, 91, 147, 153, 162]
# Permutations: total(5040), display(1)
# P [153, 31, 91, 83, 147, 28, 162] => 35970
# P [162, 28, 147, 83, 91, 31, 153] => 35970
#  [162, 28, 147, 83, 91, 31, 153] => 35970
# ..................................
# The problem: [27, 119, 121, 131, 135, 139, 171]
# Permutations: total(5040), display(1)
# P [171, 27, 135, 121, 131, 119, 139] => 72578
# P [139, 119, 131, 121, 135, 27, 171] => 72578
#  [171, 27, 135, 121, 131, 119, 139] => 72578
# ..................................
# The problem: [11, 31, 68, 89, 110, 146, 164]
# Permutations: total(5040), display(1)
# P [164, 11, 110, 68, 89, 31, 146] => 23831
# P [146, 31, 89, 68, 110, 11, 164] => 23831
#  [164, 11, 110, 68, 89, 31, 146] => 23831
# ..................................
# The problem: [45, 107, 118, 160, 170, 183, 185]
# Permutations: total(5040), display(1)
# P [185, 45, 170, 118, 160, 107, 183] => 91616
# P [183, 107, 160, 118, 170, 45, 185] => 91616
#  [185, 45, 170, 118, 160, 107, 183] => 91616
# ..................................
# The problem: [24, 26, 66, 82, 93, 129, 142]
# Permutations: total(5040), display(1)
# P [129, 26, 82, 66, 93, 24, 142] => 22676
# P [142, 24, 93, 66, 82, 26, 129] => 22676
#  [142, 24, 93, 66, 82, 26, 129] => 22676
# ..................................
# The problem: [66, 68, 76, 123, 140, 140, 145]
# Permutations: total(5040), display(1)
# P [140, 68, 123, 76, 140, 66, 145] => 56682
# P [140, 76, 123, 68, 140, 66, 145] => 56682
# P [145, 66, 140, 68, 123, 76, 140] => 56682
# P [145, 66, 140, 76, 123, 68, 140] => 56682
# P [145, 66, 140, 68, 123, 76, 140] => 56682
# P [145, 66, 140, 76, 123, 68, 140] => 56682
# P [140, 68, 123, 76, 140, 66, 145] => 56682
# P [140, 76, 123, 68, 140, 66, 145] => 56682
#  [145, 66, 140, 76, 123, 68, 140] => 56682
# ..................................
# The problem: [5, 73, 129, 131, 134, 152, 170]
# Permutations: total(5040), display(1)
# P [152, 73, 131, 129, 134, 5, 170] => 56364
# P [170, 5, 134, 129, 131, 73, 152] => 56364
#  [170, 5, 134, 129, 131, 73, 152] => 56364
# ..................................
# The problem: [15, 58, 121, 138, 171, 187, 198]
# Permutations: total(5040), display(1)
# P [198, 15, 171, 121, 138, 58, 187] => 61774
# P [187, 58, 138, 121, 171, 15, 198] => 61774
#  [198, 15, 171, 121, 138, 58, 187] => 61774
# ..................................
# The problem: [20, 76, 80, 95, 96, 118, 118]
# Permutations: total(5040), display(1)
# P [118, 20, 96, 80, 95, 76, 118] => 35748
# P [118, 76, 95, 80, 96, 20, 118] => 35748
# P [118, 20, 96, 80, 95, 76, 118] => 35748
# P [118, 76, 95, 80, 96, 20, 118] => 35748
#  [118, 20, 96, 80, 95, 76, 118] => 35748
# ..................................
# The problem: [10, 14, 62, 69, 71, 78, 125]
# Permutations: total(5040), display(1)
# P [78, 14, 69, 62, 71, 10, 125] => 12698
# P [125, 10, 71, 62, 69, 14, 78] => 12698
#  [125, 10, 71, 62, 69, 14, 78] => 12698
# ..................................
# The problem: [32, 82, 92, 92, 157, 157, 200]
# Permutations: total(5040), display(1)
# P [157, 92, 92, 82, 157, 32, 200] => 54750
# P [157, 92, 92, 82, 157, 32, 200] => 54750
# P [157, 82, 92, 92, 157, 32, 200] => 54750
# P [157, 82, 92, 92, 157, 32, 200] => 54750
# P [200, 32, 157, 92, 92, 82, 157] => 54750
# P [200, 32, 157, 92, 92, 82, 157] => 54750
# P [200, 32, 157, 82, 92, 92, 157] => 54750
# P [200, 32, 157, 82, 92, 92, 157] => 54750
# P [200, 32, 157, 92, 92, 82, 157] => 54750
# P [200, 32, 157, 92, 92, 82, 157] => 54750
# P [200, 32, 157, 82, 92, 92, 157] => 54750
# P [200, 32, 157, 82, 92, 92, 157] => 54750
# P [157, 92, 92, 82, 157, 32, 200] => 54750
# P [157, 92, 92, 82, 157, 32, 200] => 54750
# P [157, 82, 92, 92, 157, 32, 200] => 54750
# P [157, 82, 92, 92, 157, 32, 200] => 54750
#  [200, 32, 157, 92, 92, 82, 157] => 54750
# ..................................
# The problem: [23, 69, 99, 132, 159, 181, 190]
# Permutations: total(5040), display(1)
# P [181, 69, 132, 99, 159, 23, 190] => 58433
# P [190, 23, 159, 99, 132, 69, 181] => 58433
#  [190, 23, 159, 99, 132, 69, 181] => 58433
# ..................................
# The problem: [54, 63, 101, 134, 156, 169, 179]
# Permutations: total(5040), display(1)
# P [169, 63, 134, 101, 156, 54, 179] => 66469
# P [179, 54, 156, 101, 134, 63, 169] => 66469
#  [179, 54, 156, 101, 134, 63, 169] => 66469
# ..................................
# The problem: [10, 39, 47, 57, 121, 135, 170]
# Permutations: total(5040), display(1)
# P [135, 39, 57, 47, 121, 10, 170] => 18764
# P [170, 10, 121, 47, 57, 39, 135] => 18764
#  [170, 10, 121, 47, 57, 39, 135] => 18764
# ..................................
# The problem: [52, 72, 96, 149, 159, 180, 186]
# Permutations: total(5040), display(1)
# P [180, 72, 149, 96, 159, 52, 186] => 71196
# P [186, 52, 159, 96, 149, 72, 180] => 71196
#  [186, 52, 159, 96, 149, 72, 180] => 71196
# ..................................
# The problem: [10, 24, 32, 163, 174, 186, 198]
# Permutations: total(5040), display(1)
# P [198, 10, 174, 32, 163, 24, 186] => 22880
# P [186, 24, 163, 32, 174, 10, 198] => 22880
#  [198, 10, 174, 32, 163, 24, 186] => 22880
# ..................................
# The problem: [7, 16, 22, 111, 143, 156, 175]
# Permutations: total(5040), display(1)
# P [156, 16, 111, 22, 143, 7, 175] => 12086
# P [175, 7, 143, 22, 111, 16, 156] => 12086
#  [175, 7, 143, 22, 111, 16, 156] => 12086
# ..................................
# The problem: [78, 116, 137, 149, 159, 198, 200]
# Permutations: total(5040), display(1)
# P [198, 116, 149, 137, 159, 78, 200] => 110450
# P [200, 78, 159, 137, 149, 116, 198] => 110450
# ...
# ..................................
# The problem: [17, 50, 74, 84, 86, 106, 120, 124, 167, 182]
# Permutations: total(3628800), display(1)
# P [167, 50, 120, 84, 86, 106, 74, 124, 17, 182] => 62992
# P [182, 17, 124, 74, 106, 86, 84, 120, 50, 167] => 62992
#  [182, 17, 124, 74, 106, 86, 84, 120, 50, 167] => 62992
# ..................................
# The problem: [29, 31, 42, 43, 69, 94, 116, 122, 175, 187]
# Permutations: total(3628800), display(1)
# P [187, 29, 122, 42, 94, 69, 43, 116, 31, 175] => 41495
# P [175, 31, 116, 43, 69, 94, 42, 122, 29, 187] => 41495
#  [187, 29, 122, 42, 94, 69, 43, 116, 31, 175] => 41495
# ..................................
# The problem: [18, 24, 34, 46, 72, 75, 111, 169, 172, 190]
# Permutations: total(3628800), display(1)
# P [172, 24, 111, 46, 72, 75, 34, 169, 18, 190] => 35368
# P [190, 18, 169, 34, 75, 72, 46, 111, 24, 172] => 35368
#  [190, 18, 169, 34, 75, 72, 46, 111, 24, 172] => 35368
# ..................................
# The problem: [16, 60, 72, 91, 93, 110, 146, 175, 180, 200]
# Permutations: total(3628800), display(1)
# P [200, 16, 175, 72, 110, 93, 91, 146, 60, 180] => 78059
# P [180, 60, 146, 91, 93, 110, 72, 175, 16, 200] => 78059
#  [200, 16, 175, 72, 110, 93, 91, 146, 60, 180] => 78059
# ..................................
# The problem: [29, 85, 104, 133, 150, 174, 175, 194, 195, 196]
# Permutations: total(3628800), display(1)
# P [196, 29, 194, 104, 174, 150, 133, 175, 85, 195] => 150357
# P [195, 85, 175, 133, 150, 174, 104, 194, 29, 196] => 150357
#  [196, 29, 194, 104, 174, 150, 133, 175, 85, 195] => 150357
# ..................................
# The problem: [33, 37, 75, 85, 91, 99, 129, 149, 172, 199]
# Permutations: total(3628800), display(1)
# P [199, 33, 149, 75, 99, 91, 85, 129, 37, 172] => 68930
# P [172, 37, 129, 85, 91, 99, 75, 149, 33, 199] => 68930
#  [199, 33, 149, 75, 99, 91, 85, 129, 37, 172] => 68930
# ..................................
# The problem: [5, 13, 24, 30, 42, 48, 126, 128, 147, 176]
# Permutations: total(3628800), display(1)
# P [176, 5, 128, 24, 48, 42, 30, 126, 13, 147] => 16349
# P [147, 13, 126, 30, 42, 48, 24, 128, 5, 176] => 16349
#  [176, 5, 128, 24, 48, 42, 30, 126, 13, 147] => 16349
# ..................................
# The problem: [31, 36, 44, 56, 58, 122, 122, 150, 190, 193]
# Permutations: total(3628800), display(1)
# P [193, 31, 150, 44, 122, 58, 56, 122, 36, 190] => 50989
# P [193, 31, 150, 44, 122, 56, 58, 122, 36, 190] => 50989
# P [193, 31, 150, 44, 122, 58, 56, 122, 36, 190] => 50989
# P [193, 31, 150, 44, 122, 56, 58, 122, 36, 190] => 50989
# P [190, 36, 122, 58, 56, 122, 44, 150, 31, 193] => 50989
# P [190, 36, 122, 56, 58, 122, 44, 150, 31, 193] => 50989
# P [190, 36, 122, 58, 56, 122, 44, 150, 31, 193] => 50989
# P [190, 36, 122, 56, 58, 122, 44, 150, 31, 193] => 50989
#  [193, 31, 150, 44, 122, 58, 56, 122, 36, 190] => 50989
# ..................................
# The problem: [28, 32, 51, 56, 58, 99, 145, 146, 151, 173]
# Permutations: total(3628800), display(1)
# P [151, 32, 145, 56, 58, 99, 51, 146, 28, 173] => 48009
# P [173, 28, 146, 51, 99, 58, 56, 145, 32, 151] => 48009
#  [173, 28, 146, 51, 99, 58, 56, 145, 32, 151] => 48009
# ..................................
# The problem: [10, 14, 23, 48, 113, 117, 119, 119, 130, 196]
# Permutations: total(3628800), display(1)
# P [130, 14, 119, 48, 113, 117, 23, 119, 10, 196] => 36421
# P [130, 14, 119, 23, 117, 113, 48, 119, 10, 196] => 36421
# P [130, 14, 119, 48, 113, 117, 23, 119, 10, 196] => 36421
# P [130, 14, 119, 23, 117, 113, 48, 119, 10, 196] => 36421
# P [196, 10, 119, 48, 113, 117, 23, 119, 14, 130] => 36421
# P [196, 10, 119, 23, 117, 113, 48, 119, 14, 130] => 36421
# P [196, 10, 119, 48, 113, 117, 23, 119, 14, 130] => 36421
# P [196, 10, 119, 23, 117, 113, 48, 119, 14, 130] => 36421
#  [196, 10, 119, 23, 117, 113, 48, 119, 14, 130] => 36421
# ..................................
# The problem: [13, 22, 47, 82, 91, 123, 140, 147, 154, 198]
# Permutations: total(3628800), display(1)
# P [198, 13, 147, 47, 123, 91, 82, 140, 22, 154] => 53778
# P [154, 22, 140, 82, 91, 123, 47, 147, 13, 198] => 53778
#  [198, 13, 147, 47, 123, 91, 82, 140, 22, 154] => 53778
# ..................................
# The problem: [19, 25, 49, 52, 91, 107, 138, 138, 146, 157]
# Permutations: total(3628800), display(1)
# P [146, 25, 138, 52, 91, 107, 49, 138, 19, 157] => 46355
# P [146, 25, 138, 49, 107, 91, 52, 138, 19, 157] => 46355
# P [146, 25, 138, 52, 91, 107, 49, 138, 19, 157] => 46355
# P [146, 25, 138, 49, 107, 91, 52, 138, 19, 157] => 46355
# P [157, 19, 138, 52, 91, 107, 49, 138, 25, 146] => 46355
# P [157, 19, 138, 49, 107, 91, 52, 138, 25, 146] => 46355
# P [157, 19, 138, 52, 91, 107, 49, 138, 25, 146] => 46355
# P [157, 19, 138, 49, 107, 91, 52, 138, 25, 146] => 46355
#  [157, 19, 138, 49, 107, 91, 52, 138, 25, 146] => 46355
# ..................................
# The problem: [13, 42, 77, 87, 96, 115, 131, 136, 183, 195]
# Permutations: total(3628800), display(1)
# P [183, 42, 131, 87, 96, 115, 77, 136, 13, 195] => 67607
# P [195, 13, 136, 77, 115, 96, 87, 131, 42, 183] => 67607
#  [195, 13, 136, 77, 115, 96, 87, 131, 42, 183] => 67607
# ..................................
# The problem: [16, 49, 63, 64, 70, 73, 120, 121, 132, 138]
# Permutations: total(3628800), display(1)
# P [138, 16, 121, 63, 73, 70, 64, 120, 49, 132] => 45984
# P [132, 49, 120, 64, 70, 73, 63, 121, 16, 138] => 45984
#  [138, 16, 121, 63, 73, 70, 64, 120, 49, 132] => 45984
# ..................................
# The problem: [26, 45, 53, 61, 78, 81, 85, 139, 145, 195]
# Permutations: total(3628800), display(1)
# P [195, 26, 139, 53, 81, 78, 61, 85, 45, 145] => 46955
# P [145, 45, 85, 61, 78, 81, 53, 139, 26, 195] => 46955
#  [195, 26, 139, 53, 81, 78, 61, 85, 45, 145] => 46955
# ..................................
# The problem: [6, 78, 93, 95, 100, 131, 147, 168, 179, 190]
# Permutations: total(3628800), display(1)
# P [179, 78, 147, 95, 100, 131, 93, 168, 6, 190] => 91948
# P [190, 6, 168, 93, 131, 100, 95, 147, 78, 179] => 91948
#  [190, 6, 168, 93, 131, 100, 95, 147, 78, 179] => 91948
# ..................................
# The problem: [7, 38, 58, 82, 117, 119, 140, 148, 159, 173]
# Permutations: total(3628800), display(1)
# P [159, 38, 140, 82, 117, 119, 58, 148, 7, 173] => 64092
# P [173, 7, 148, 58, 119, 117, 82, 140, 38, 159] => 64092
#  [173, 7, 148, 58, 119, 117, 82, 140, 38, 159] => 64092
# ..................................
# The problem: [17, 24, 102, 104, 122, 139, 140, 153, 173, 199]
# Permutations: total(3628800), display(1)
# P [173, 24, 140, 104, 122, 139, 102, 153, 17, 199] => 87486
# P [199, 17, 153, 102, 139, 122, 104, 140, 24, 173] => 87486
#  [199, 17, 153, 102, 139, 122, 104, 140, 24, 173] => 87486
# ..................................
# The problem: [14, 14, 37, 38, 45, 103, 120, 139, 154, 166]
# Permutations: total(3628800), display(1)
# P [166, 14, 120, 38, 45, 103, 37, 139, 14, 154] => 27965
# P [166, 14, 139, 37, 103, 45, 38, 120, 14, 154] => 27965
# P [166, 14, 120, 38, 45, 103, 37, 139, 14, 154] => 27965
# P [166, 14, 139, 37, 103, 45, 38, 120, 14, 154] => 27965
# P [154, 14, 120, 38, 45, 103, 37, 139, 14, 166] => 27965
# P [154, 14, 139, 37, 103, 45, 38, 120, 14, 166] => 27965
# P [154, 14, 120, 38, 45, 103, 37, 139, 14, 166] => 27965
# P [154, 14, 139, 37, 103, 45, 38, 120, 14, 166] => 27965
#  [166, 14, 139, 37, 103, 45, 38, 120, 14, 154] => 27965
# ..................................
# The problem: [25, 57, 71, 88, 122, 143, 154, 176, 193, 194]
# Permutations: total(3628800), display(1)
# P [193, 57, 154, 88, 122, 143, 71, 176, 25, 194] => 93412
# P [194, 25, 176, 71, 143, 122, 88, 154, 57, 193] => 93412
#  [194, 25, 176, 71, 143, 122, 88, 154, 57, 193] => 93412
# ..................................
# The problem: [19, 20, 34, 44, 45, 78, 82, 92, 93, 196]
# Permutations: total(3628800), display(1)
# P [196, 19, 92, 34, 78, 45, 44, 82, 20, 93] => 23850
# P [93, 20, 82, 44, 45, 78, 34, 92, 19, 196] => 23850
#  [196, 19, 92, 34, 78, 45, 44, 82, 20, 93] => 23850
# ..................................
# The problem: [8, 13, 23, 40, 51, 60, 90, 99, 112, 185]
# Permutations: total(3628800), display(1)
# P [112, 13, 90, 40, 51, 60, 23, 99, 8, 185] => 17255
# P [185, 8, 99, 23, 60, 51, 40, 90, 13, 112] => 17255
#  [185, 8, 99, 23, 60, 51, 40, 90, 13, 112] => 17255
# ..................................
# The problem: [20, 47, 63, 71, 78, 98, 100, 100, 121, 136]
# Permutations: total(3628800), display(1)
# P [136, 20, 100, 71, 78, 98, 63, 100, 47, 121] => 47863
# P [136, 20, 100, 63, 98, 78, 71, 100, 47, 121] => 47863
# P [136, 20, 100, 71, 78, 98, 63, 100, 47, 121] => 47863
# P [136, 20, 100, 63, 98, 78, 71, 100, 47, 121] => 47863
# P [121, 47, 100, 71, 78, 98, 63, 100, 20, 136] => 47863
# P [121, 47, 100, 63, 98, 78, 71, 100, 20, 136] => 47863
# P [121, 47, 100, 71, 78, 98, 63, 100, 20, 136] => 47863
# P [121, 47, 100, 63, 98, 78, 71, 100, 20, 136] => 47863
#  [136, 20, 100, 63, 98, 78, 71, 100, 47, 121] => 47863
# ..................................
# The problem: [19, 26, 52, 80, 97, 143, 163, 187, 199, 200]
# Permutations: total(3628800), display(1)
# P [199, 26, 163, 80, 97, 143, 52, 187, 19, 200] => 68596
# P [200, 19, 187, 52, 143, 97, 80, 163, 26, 199] => 68596
#  [200, 19, 187, 52, 143, 97, 80, 163, 26, 199] => 68596
# ..................................
# The problem: [8, 13, 37, 67, 67, 91, 134, 146, 154, 184]
# Permutations: total(3628800), display(1)
# P [154, 13, 134, 67, 67, 91, 37, 146, 8, 184] => 34717
# P [154, 13, 134, 67, 67, 91, 37, 146, 8, 184] => 34717
# P [184, 8, 146, 37, 91, 67, 67, 134, 13, 154] => 34717
# P [184, 8, 146, 37, 91, 67, 67, 134, 13, 154] => 34717
#  [184, 8, 146, 37, 91, 67, 67, 134, 13, 154] => 34717
# ..................................
# The problem: [6, 16, 18, 37, 40, 63, 89, 97, 124, 162]
# Permutations: total(3628800), display(1)
# P [124, 16, 89, 37, 40, 63, 18, 97, 6, 162] => 15135
# P [162, 6, 97, 18, 63, 40, 37, 89, 16, 124] => 15135
#  [162, 6, 97, 18, 63, 40, 37, 89, 16, 124] => 15135
# ..................................
# The problem: [44, 46, 79, 86, 98, 117, 122, 130, 162, 200]
# Permutations: total(3628800), display(1)
# P [200, 44, 130, 79, 117, 98, 86, 122, 46, 162] => 77483
# P [162, 46, 122, 86, 98, 117, 79, 130, 44, 200] => 77483
#  [200, 44, 130, 79, 117, 98, 86, 122, 46, 162] => 77483
# ..................................
# The problem: [28, 46, 56, 66, 71, 72, 84, 143, 173, 174]
# Permutations: total(3628800), display(1)
# P [174, 28, 143, 56, 72, 71, 66, 84, 46, 173] => 48080
# P [173, 46, 84, 66, 71, 72, 56, 143, 28, 174] => 48080
#  [174, 28, 143, 56, 72, 71, 66, 84, 46, 173] => 48080
# ..................................
# The problem: [35, 74, 138, 141, 157, 160, 172, 178, 180, 194]
# Permutations: total(3628800), display(1)
# P [180, 74, 172, 141, 157, 160, 138, 178, 35, 194] => 157221
# P [194, 35, 178, 138, 160, 157, 141, 172, 74, 180] => 157221
#  [194, 35, 178, 138, 160, 157, 141, 172, 74, 180] => 157221
# ..................................
# The problem: [21, 46, 59, 67, 93, 101, 127, 164, 170, 199]
# Permutations: total(3628800), display(1)
# P [170, 46, 127, 67, 93, 101, 59, 164, 21, 199] => 61053
# P [199, 21, 164, 59, 101, 93, 67, 127, 46, 170] => 61053
#  [199, 21, 164, 59, 101, 93, 67, 127, 46, 170] => 61053
# ..................................
# The problem: [19, 27, 35, 47, 53, 80, 86, 99, 115, 194]
# Permutations: total(3628800), display(1)
# P [115, 27, 86, 47, 53, 80, 35, 99, 19, 194] => 28032
# P [194, 19, 99, 35, 80, 53, 47, 86, 27, 115] => 28032
#  [194, 19, 99, 35, 80, 53, 47, 86, 27, 115] => 28032
# ..................................
# The problem: [27, 33, 39, 48, 86, 107, 110, 126, 128, 197]
# Permutations: total(3628800), display(1)
# P [128, 33, 110, 48, 86, 107, 39, 126, 27, 197] => 44272
# P [197, 27, 126, 39, 107, 86, 48, 110, 33, 128] => 44272
#  [197, 27, 126, 39, 107, 86, 48, 110, 33, 128] => 44272
# ..................................
# The problem: [44, 59, 80, 93, 93, 94, 138, 171, 182, 200]
# Permutations: total(3628800), display(1)
# P [200, 44, 171, 80, 94, 93, 93, 138, 59, 182] => 86629
# P [200, 44, 171, 80, 94, 93, 93, 138, 59, 182] => 86629
# P [182, 59, 138, 93, 93, 94, 80, 171, 44, 200] => 86629
# P [182, 59, 138, 93, 93, 94, 80, 171, 44, 200] => 86629
#  [200, 44, 171, 80, 94, 93, 93, 138, 59, 182] => 86629
# ..................................
# The problem: [7, 8, 12, 84, 87, 102, 129, 129, 161, 181]
# Permutations: total(3628800), display(1)
# P [161, 8, 129, 12, 102, 87, 84, 129, 7, 181] => 34280
# P [161, 8, 129, 84, 87, 102, 12, 129, 7, 181] => 34280
# P [161, 8, 129, 12, 102, 87, 84, 129, 7, 181] => 34280
# P [161, 8, 129, 84, 87, 102, 12, 129, 7, 181] => 34280
# P [181, 7, 129, 12, 102, 87, 84, 129, 8, 161] => 34280
# P [181, 7, 129, 84, 87, 102, 12, 129, 8, 161] => 34280
# P [181, 7, 129, 12, 102, 87, 84, 129, 8, 161] => 34280
# P [181, 7, 129, 84, 87, 102, 12, 129, 8, 161] => 34280
#  [181, 7, 129, 12, 102, 87, 84, 129, 8, 161] => 34280
# ..................................
# The problem: [40, 63, 77, 94, 95, 133, 149, 169, 175, 189]
# Permutations: total(3628800), display(1)
# P [189, 40, 169, 77, 133, 95, 94, 149, 63, 175] => 93557
# P [175, 63, 149, 94, 95, 133, 77, 169, 40, 189] => 93557
#  [189, 40, 169, 77, 133, 95, 94, 149, 63, 175] => 93557
# ..................................
# The problem: [11, 25, 40, 42, 75, 94, 134, 140, 143, 199]
# Permutations: total(3628800), display(1)
# P [143, 25, 134, 42, 75, 94, 40, 140, 11, 199] => 35842
# P [199, 11, 140, 40, 94, 75, 42, 134, 25, 143] => 35842
#  [199, 11, 140, 40, 94, 75, 42, 134, 25, 143] => 35842
# ..................................
# The problem: [18, 21, 29, 40, 49, 71, 109, 161, 190, 194]
# Permutations: total(3628800), display(1)
# P [194, 18, 161, 29, 71, 49, 40, 109, 21, 190] => 29196
# P [190, 21, 109, 40, 49, 71, 29, 161, 18, 194] => 29196
#  [194, 18, 161, 29, 71, 49, 40, 109, 21, 190] => 29196
# ..................................
# The problem: [8, 9, 27, 40, 56, 62, 107, 175, 195, 199]
# Permutations: total(3628800), display(1)
# P [199, 8, 175, 27, 62, 56, 40, 107, 9, 195] => 22101
# P [195, 9, 107, 40, 56, 62, 27, 175, 8, 199] => 22101
#  [199, 8, 175, 27, 62, 56, 40, 107, 9, 195] => 22101
# ..................................
# The problem: [27, 42, 57, 71, 84, 92, 99, 154, 170, 198]
# Permutations: total(3628800), display(1)
# P [198, 27, 154, 57, 92, 84, 71, 99, 42, 170] => 55545
# P [170, 42, 99, 71, 84, 92, 57, 154, 27, 198] => 55545
#  [198, 27, 154, 57, 92, 84, 71, 99, 42, 170] => 55545
# ..................................
# The problem: [12, 41, 86, 124, 125, 160, 163, 164, 194, 200]
# Permutations: total(3628800), display(1)
# P [194, 41, 163, 124, 125, 160, 86, 164, 12, 200] => 102581
# P [200, 12, 164, 86, 160, 125, 124, 163, 41, 194] => 102581
#  [200, 12, 164, 86, 160, 125, 124, 163, 41, 194] => 102581
# ..................................
# The problem: [15, 36, 37, 148, 159, 162, 171, 176, 187, 196]
# Permutations: total(3628800), display(1)
# P [187, 36, 171, 148, 159, 162, 37, 176, 15, 196] => 105572
# P [196, 15, 176, 37, 162, 159, 148, 171, 36, 187] => 105572
#  [196, 15, 176, 37, 162, 159, 148, 171, 36, 187] => 105572
# ..................................
# The problem: [36, 40, 89, 113, 121, 123, 160, 166, 181, 198]
# Permutations: total(3628800), display(1)
# P [181, 40, 160, 113, 121, 123, 89, 166, 36, 198] => 99101
# P [198, 36, 166, 89, 123, 121, 113, 160, 40, 181] => 99101
#  [198, 36, 166, 89, 123, 121, 113, 160, 40, 181] => 99101
# ..................................
# The problem: [29, 32, 51, 68, 69, 86, 91, 126, 132, 142]
# Permutations: total(3628800), display(1)
# P [132, 32, 91, 68, 69, 86, 51, 126, 29, 142] => 42534
# P [142, 29, 126, 51, 86, 69, 68, 91, 32, 132] => 42534
#  [142, 29, 126, 51, 86, 69, 68, 91, 32, 132] => 42534
# ..................................
# The problem: [18, 52, 98, 109, 124, 125, 141, 143, 149, 176]
# Permutations: total(3628800), display(1)
# P [176, 18, 143, 98, 125, 124, 109, 141, 52, 149] => 91471
# P [149, 52, 141, 109, 124, 125, 98, 143, 18, 176] => 91471
#  [176, 18, 143, 98, 125, 124, 109, 141, 52, 149] => 91471
# ..................................
# The problem: [21, 35, 85, 103, 112, 145, 150, 165, 169, 174]
# Permutations: total(3628800), display(1)
# P [169, 35, 150, 103, 112, 145, 85, 165, 21, 174] => 87860
# P [174, 21, 165, 85, 145, 112, 103, 150, 35, 169] => 87860
#  [174, 21, 165, 85, 145, 112, 103, 150, 35, 169] => 87860
# ..................................
