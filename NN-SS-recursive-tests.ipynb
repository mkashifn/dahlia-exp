# %% [markdown]
# # The Problem
#
# Given and array A containing N numbers sorted by some algorithm (say A1, A2, A3, ..., AN after sorting),
#
# Minimize the sum of products: A1A2 + A2A3 + .. A(N-1)AN
#
# ### The problem:
# `
# Give an array A, find an ordering of all the elements of A such that the total sum of the product of each pair of two adjacent elements is minimized:
# `

# %%
import itertools
import operator
import random

# %%
def compute_sum_of_products(A):
    res = 0
    for i in range(len(A)-1):
        res += A[i]*A[i+1]
    #print(A, '=>',res)
    return res

# %%
def compute_sum_of_products_algo_large(A):
    A.sort(reverse=True)
    A_len = len(A)
    mid = int( A_len / 2)
    mid += 0 if A_len % 2 == 0 else 1
    J = A[0 : mid]
    K = A[mid: ]
    j = 0
    k = 0
    res = []
    for i in range(A_len):
        print('    !', i, ': ', J, K)
        if i % 2 == 0:
            if (len(J) == 1 and len(K) == 1):
                val = [K[0], J[0]]
                res.extend(val)
                break
            elif j % 2 == 0:
                val = J[0]
            else:
                val = J[-1]
            J.remove(val)
            j += 1
        else:
            if k % 2 == 0:
                val = K[-1]
            else:
                val = K[0]
            K.remove(val)
            k += 1
        res.append(val)
    return res

# %%
def compute_sum_of_products_algo_large_2(A):
    A.sort()
    A_len = len(A)
    res = []
    left = []
    right = []
    i = 0
    while len(A) > 0:
        #print('    !', i, ': ', A, left, right)
        if len(A) >= 4:
            val = [A[-1], A[0]]
            left.extend(val)
            del A[0]
            del A[-1]
            val = [A[-1], A[0]]
            right.extend(val)
            del A[0]
            del A[-1]
        elif len(A) == 3:
            right.append(A[1])
            del A[1]
        elif len(A) == 2:
            left.append(A[-1])
            right.append(A[0])
            del A[0]
            del A[-1]
        else:
            left.append(A[0])
            del A[0]
        i += 1
    #print('    !', i, ': ', A, left, right)
    res = left
    right.reverse()
    res.extend(right)
    return res

# %%
def opt(a):
    #print('!!', a)
    if len(a) == 0:
        return []
    if len(a) == 1:
        return [a[0]]
    if len(a) == 2:
        return [a[-1], a[0]]
    #return [a[-1], a[0]].append(opt(a[1:-1]).reverse())
    x = [a[-1], a[0]]
    y = opt(a[1:-1])
    y.reverse()
    x.extend(y)
    return x

def compute_sum_of_products_algo_large_r(a):
    a.sort()
    return opt(a)

# %%
def print_sum_of_products_algo(A):
    A = compute_sum_of_products_algo_large_r(A)
    sum_c = compute_sum_of_products(A)
    print('', A, '=>',sum_c, '')
    return sum_c

# %%
def compute_sum_of_products_permute(A):
    Ac = A # copy the original list
    Ap = list(itertools.permutations(A))
    res_l = []
    for A in Ap:
        A = list(A)
        sum_c = compute_sum_of_products(A)
        res_l.append((sum_c, A))
    return (Ac, res_l)

# %%
def print_sum_of_products(res, count=-1):
    (Ac, res_l) = res
    Ac.sort()
    res_l.sort(key = operator.itemgetter(0))
    perm_count = len(res_l)
    i = 0
    count = perm_count if count < 0 else count
    print(f'The problem: {Ac}')
    print(f'Permutations: total({perm_count}), display({count})')
    j = 0
    (sum_c_old, A) = res_l[0]
    sum_c_lowest = sum_c_old
    for i in range(count):
        loop = True
        while loop:
            (sum_c, A) = res_l[j]
            if sum_c == sum_c_old:
                heading = 'P'
                print(heading, A, '=>', sum_c)
                j = j + 1
            else:
                loop = False
            sum_c_old = sum_c
    return sum_c_lowest

# %%
def compute_print_sum_of_products_permute(A, count=-1):
    res = compute_sum_of_products_permute(A)
    sum_c_permute = print_sum_of_products(res, count)
    sum_c_algo = print_sum_of_products_algo(A)
    if sum_c_permute != sum_c_algo:
        print('  failure for: ', A)

# %%
NO_OF_ROWS_TO_PRINT = 1

# %%
data_large_l = [
    [30, 20, 10, 5, 3, 2],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12, 37, 39],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 12],
    [30, 20, 10, 25, 12, 32],
]

# %%
data_small_l = [
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12, 15, 18],
]

# %%
data_small_2l = [
    [30, 20, 10, 5, 3, 2],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12, 37, 39],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 33, 12],
    [30, 20, 10, 25, 12],
    [30, 20, 10, 25, 12, 32],
]

# %%
data_medium_l = [
    [30, 20, 10, 25, 33, 12],
]

# %%
def evaluate_cases(data_l):
    for data in data_l:
        print("..................................")
        A = data
        compute_print_sum_of_products_permute(A, NO_OF_ROWS_TO_PRINT)

# %%
def evaluate_cases_random():
    for i in range(3, 11):
        for k in range(50):
            A = []
            for j in range(i):
                A.append(random.randint(5, 200))
            print("..................................")
            compute_print_sum_of_products_permute(A, NO_OF_ROWS_TO_PRINT)

# %%
data_large_2l = [
    [30, 20, 10, 5, 3, 2, 6],
    [30, 20, 10, 25, 12, 32, 8],
    [30, 20, 10, 25, 12, 32, 8, 30, 31],
    [30, 20, 10, 25, 12, 32, 8, 30, 31, 48],
]

# %%
evaluate_cases(data_large_l)
# Out:
# ..................................
# The problem: [2, 3, 5, 10, 20, 30]
# Permutations: total(720), display(1)
# P [30, 2, 10, 5, 3, 20] => 205
# P [20, 3, 5, 10, 2, 30] => 205
#  [30, 2, 10, 5, 3, 20] => 205
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30, 33, 37, 39]
# Permutations: total(40320), display(1)
# P [37, 12, 30, 25, 20, 33, 10, 39] => 3434
# P [39, 10, 33, 20, 25, 30, 12, 37] => 3434
#  [39, 10, 33, 20, 25, 30, 12, 37] => 3434
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30]
# Permutations: total(120), display(1)
# P [30, 10, 20, 12, 25] => 1040
# P [25, 12, 20, 10, 30] => 1040
#  [30, 10, 20, 12, 25] => 1040
# ..................................
# The problem: [10, 12, 20, 25, 30, 32]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 32] => 1670
# P [32, 10, 25, 20, 12, 30] => 1670
#  [32, 10, 25, 20, 12, 30] => 1670

# %%
evaluate_cases(data_large_2l)
# Out:
# ..................................
# The problem: [2, 3, 5, 6, 10, 20, 30]
# Permutations: total(5040), display(1)
# P [30, 2, 10, 5, 6, 3, 20] => 238
# P [20, 3, 6, 5, 10, 2, 30] => 238
#  [30, 2, 10, 5, 6, 3, 20] => 238
# ..................................
# The problem: [8, 10, 12, 20, 25, 30, 32]
# Permutations: total(5040), display(1)
# P [30, 10, 20, 12, 25, 8, 32] => 1496
# P [32, 8, 25, 12, 20, 10, 30] => 1496
#  [32, 8, 25, 12, 20, 10, 30] => 1496
# ..................................
# The problem: [8, 10, 12, 20, 25, 30, 30, 31, 32]
# Permutations: total(362880), display(1)
# P [32, 8, 30, 20, 25, 12, 30, 10, 31] => 2866
# P [32, 8, 30, 12, 25, 20, 30, 10, 31] => 2866
# P [32, 8, 30, 20, 25, 12, 30, 10, 31] => 2866
# P [32, 8, 30, 12, 25, 20, 30, 10, 31] => 2866
# P [31, 10, 30, 20, 25, 12, 30, 8, 32] => 2866
# P [31, 10, 30, 12, 25, 20, 30, 8, 32] => 2866
# P [31, 10, 30, 20, 25, 12, 30, 8, 32] => 2866
# P [31, 10, 30, 12, 25, 20, 30, 8, 32] => 2866
#  [32, 8, 30, 12, 25, 20, 30, 10, 31] => 2866
# ..................................
# The problem: [8, 10, 12, 20, 25, 30, 30, 31, 32, 48]
# Permutations: total(3628800), display(1)
# P [32, 10, 30, 20, 25, 30, 12, 31, 8, 48] => 3834
# P [32, 10, 30, 25, 20, 30, 12, 31, 8, 48] => 3834
# P [32, 10, 30, 20, 25, 30, 12, 31, 8, 48] => 3834
# P [32, 10, 30, 25, 20, 30, 12, 31, 8, 48] => 3834
# P [48, 8, 31, 12, 30, 20, 25, 30, 10, 32] => 3834
# P [48, 8, 31, 12, 30, 25, 20, 30, 10, 32] => 3834
# P [48, 8, 31, 12, 30, 20, 25, 30, 10, 32] => 3834
# P [48, 8, 31, 12, 30, 25, 20, 30, 10, 32] => 3834
#  [48, 8, 31, 12, 30, 25, 20, 30, 10, 32] => 3834

# %%
evaluate_cases(data_small_l)
# Out:
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 20, 25, 30, 33]
# Permutations: total(120), display(1)
# P [30, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 30] => 1680
#  [33, 10, 25, 20, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680
# ..................................
# The problem: [10, 12, 15, 18, 20, 25, 30, 33]
# Permutations: total(40320), display(1)
# P [30, 12, 20, 18, 15, 25, 10, 33] => 2185
# P [33, 10, 25, 15, 18, 20, 12, 30] => 2185
#  [33, 10, 25, 15, 18, 20, 12, 30] => 2185

# %%
evaluate_cases(data_medium_l)
# Out:
# ..................................
# The problem: [10, 12, 20, 25, 30, 33]
# Permutations: total(720), display(1)
# P [30, 12, 20, 25, 10, 33] => 1680
# P [33, 10, 25, 20, 12, 30] => 1680
#  [33, 10, 25, 20, 12, 30] => 1680

# %%
evaluate_cases_random()
# Out:
# ..................................
# The problem: [28, 29, 191]
# Permutations: total(6), display(1)
# P [29, 28, 191] => 6160
# P [191, 28, 29] => 6160
#  [191, 28, 29] => 6160
# ..................................
# The problem: [17, 124, 180]
# Permutations: total(6), display(1)
# P [124, 17, 180] => 5168
# P [180, 17, 124] => 5168
#  [180, 17, 124] => 5168
# ..................................
# The problem: [67, 78, 135]
# Permutations: total(6), display(1)
# P [135, 67, 78] => 14271
# P [78, 67, 135] => 14271
#  [135, 67, 78] => 14271
# ..................................
# The problem: [34, 109, 113]
# Permutations: total(6), display(1)
# P [109, 34, 113] => 7548
# P [113, 34, 109] => 7548
#  [113, 34, 109] => 7548
# ..................................
# The problem: [69, 113, 154]
# Permutations: total(6), display(1)
# P [113, 69, 154] => 18423
# P [154, 69, 113] => 18423
#  [154, 69, 113] => 18423
# ..................................
# The problem: [24, 114, 173]
# Permutations: total(6), display(1)
# P [173, 24, 114] => 6888
# P [114, 24, 173] => 6888
#  [173, 24, 114] => 6888
# ..................................
# The problem: [143, 145, 166]
# Permutations: total(6), display(1)
# P [145, 143, 166] => 44473
# P [166, 143, 145] => 44473
#  [166, 143, 145] => 44473
# ..................................
# The problem: [39, 91, 93]
# Permutations: total(6), display(1)
# P [93, 39, 91] => 7176
# P [91, 39, 93] => 7176
#  [93, 39, 91] => 7176
# ..................................
# The problem: [49, 81, 138]
# Permutations: total(6), display(1)
# P [138, 49, 81] => 10731
# P [81, 49, 138] => 10731
#  [138, 49, 81] => 10731
# ..................................
# The problem: [23, 81, 186]
# Permutations: total(6), display(1)
# P [186, 23, 81] => 6141
# P [81, 23, 186] => 6141
#  [186, 23, 81] => 6141
# ..................................
# The problem: [19, 47, 55]
# Permutations: total(6), display(1)
# P [55, 19, 47] => 1938
# P [47, 19, 55] => 1938
#  [55, 19, 47] => 1938
# ..................................
# The problem: [92, 105, 109]
# Permutations: total(6), display(1)
# P [105, 92, 109] => 19688
# P [109, 92, 105] => 19688
#  [109, 92, 105] => 19688
# ..................................
# The problem: [45, 76, 134]
# Permutations: total(6), display(1)
# P [76, 45, 134] => 9450
# P [134, 45, 76] => 9450
#  [134, 45, 76] => 9450
# ..................................
# The problem: [15, 96, 191]
# Permutations: total(6), display(1)
# P [96, 15, 191] => 4305
# P [191, 15, 96] => 4305
#  [191, 15, 96] => 4305
# ..................................
# The problem: [11, 90, 126]
# Permutations: total(6), display(1)
# P [90, 11, 126] => 2376
# P [126, 11, 90] => 2376
#  [126, 11, 90] => 2376
# ..................................
# The problem: [41, 60, 71]
# Permutations: total(6), display(1)
# P [60, 41, 71] => 5371
# P [71, 41, 60] => 5371
#  [71, 41, 60] => 5371
# ..................................
# The problem: [166, 173, 185]
# Permutations: total(6), display(1)
# P [173, 166, 185] => 59428
# P [185, 166, 173] => 59428
#  [185, 166, 173] => 59428
# ..................................
# The problem: [67, 102, 135]
# Permutations: total(6), display(1)
# P [135, 67, 102] => 15879
# P [102, 67, 135] => 15879
#  [135, 67, 102] => 15879
# ..................................
# The problem: [13, 99, 167]
# Permutations: total(6), display(1)
# P [167, 13, 99] => 3458
# P [99, 13, 167] => 3458
#  [167, 13, 99] => 3458
# ..................................
# The problem: [73, 90, 170]
# Permutations: total(6), display(1)
# P [90, 73, 170] => 18980
# P [170, 73, 90] => 18980
#  [170, 73, 90] => 18980
# ..................................
# The problem: [65, 144, 191]
# Permutations: total(6), display(1)
# P [144, 65, 191] => 21775
# P [191, 65, 144] => 21775
#  [191, 65, 144] => 21775
# ..................................
# The problem: [139, 140, 189]
# Permutations: total(6), display(1)
# P [140, 139, 189] => 45731
# P [189, 139, 140] => 45731
#  [189, 139, 140] => 45731
# ..................................
# The problem: [26, 62, 158]
# Permutations: total(6), display(1)
# P [158, 26, 62] => 5720
# P [62, 26, 158] => 5720
#  [158, 26, 62] => 5720
# ..................................
# The problem: [31, 66, 112]
# Permutations: total(6), display(1)
# P [112, 31, 66] => 5518
# P [66, 31, 112] => 5518
#  [112, 31, 66] => 5518
# ..................................
# The problem: [51, 62, 66]
# Permutations: total(6), display(1)
# P [62, 51, 66] => 6528
# P [66, 51, 62] => 6528
#  [66, 51, 62] => 6528
# ..................................
# The problem: [21, 50, 79]
# Permutations: total(6), display(1)
# P [50, 21, 79] => 2709
# P [79, 21, 50] => 2709
#  [79, 21, 50] => 2709
# ..................................
# The problem: [125, 143, 160]
# Permutations: total(6), display(1)
# P [143, 125, 160] => 37875
# P [160, 125, 143] => 37875
#  [160, 125, 143] => 37875
# ..................................
# The problem: [9, 97, 175]
# Permutations: total(6), display(1)
# P [97, 9, 175] => 2448
# P [175, 9, 97] => 2448
#  [175, 9, 97] => 2448
# ..................................
# The problem: [113, 136, 143]
# Permutations: total(6), display(1)
# P [136, 113, 143] => 31527
# P [143, 113, 136] => 31527
#  [143, 113, 136] => 31527
# ..................................
# The problem: [37, 98, 121]
# Permutations: total(6), display(1)
# P [121, 37, 98] => 8103
# P [98, 37, 121] => 8103
#  [121, 37, 98] => 8103
# ..................................
# The problem: [18, 63, 116]
# Permutations: total(6), display(1)
# P [116, 18, 63] => 3222
# P [63, 18, 116] => 3222
#  [116, 18, 63] => 3222
# ..................................
# The problem: [119, 183, 186]
# Permutations: total(6), display(1)
# P [186, 119, 183] => 43911
# P [183, 119, 186] => 43911
#  [186, 119, 183] => 43911
# ..................................
# The problem: [90, 183, 186]
# Permutations: total(6), display(1)
# P [186, 90, 183] => 33210
# P [183, 90, 186] => 33210
#  [186, 90, 183] => 33210
# ..................................
# The problem: [60, 118, 153]
# Permutations: total(6), display(1)
# P [118, 60, 153] => 16260
# P [153, 60, 118] => 16260
#  [153, 60, 118] => 16260
# ..................................
# The problem: [77, 77, 181]
# Permutations: total(6), display(1)
# P [181, 77, 77] => 19866
# P [181, 77, 77] => 19866
# P [77, 77, 181] => 19866
# P [77, 77, 181] => 19866
#  [181, 77, 77] => 19866
# ..................................
# The problem: [112, 187, 194]
# Permutations: total(6), display(1)
# P [194, 112, 187] => 42672
# P [187, 112, 194] => 42672
#  [194, 112, 187] => 42672
# ..................................
# The problem: [31, 133, 155]
# Permutations: total(6), display(1)
# P [155, 31, 133] => 8928
# P [133, 31, 155] => 8928
#  [155, 31, 133] => 8928
# ..................................
# The problem: [7, 18, 105]
# Permutations: total(6), display(1)
# P [105, 7, 18] => 861
# P [18, 7, 105] => 861
#  [105, 7, 18] => 861
# ..................................
# The problem: [22, 39, 144]
# Permutations: total(6), display(1)
# P [39, 22, 144] => 4026
# P [144, 22, 39] => 4026
#  [144, 22, 39] => 4026
# ..................................
# The problem: [37, 66, 88]
# Permutations: total(6), display(1)
# P [66, 37, 88] => 5698
# P [88, 37, 66] => 5698
#  [88, 37, 66] => 5698
# ..................................
# The problem: [35, 86, 193]
# Permutations: total(6), display(1)
# P [193, 35, 86] => 9765
# P [86, 35, 193] => 9765
#  [193, 35, 86] => 9765
# ..................................
# The problem: [89, 112, 157]
# Permutations: total(6), display(1)
# P [112, 89, 157] => 23941
# P [157, 89, 112] => 23941
#  [157, 89, 112] => 23941
# ..................................
# The problem: [36, 106, 185]
# Permutations: total(6), display(1)
# P [185, 36, 106] => 10476
# P [106, 36, 185] => 10476
#  [185, 36, 106] => 10476
# ..................................
# The problem: [102, 114, 120]
# Permutations: total(6), display(1)
# P [114, 102, 120] => 23868
# P [120, 102, 114] => 23868
#  [120, 102, 114] => 23868
# ..................................
# The problem: [106, 169, 184]
# Permutations: total(6), display(1)
# P [169, 106, 184] => 37418
# P [184, 106, 169] => 37418
#  [184, 106, 169] => 37418
# ..................................
# The problem: [27, 79, 148]
# Permutations: total(6), display(1)
# P [148, 27, 79] => 6129
# P [79, 27, 148] => 6129
#  [148, 27, 79] => 6129
# ..................................
# The problem: [8, 181, 190]
# Permutations: total(6), display(1)
# P [190, 8, 181] => 2968
# P [181, 8, 190] => 2968
#  [190, 8, 181] => 2968
# ..................................
# The problem: [36, 150, 194]
# Permutations: total(6), display(1)
# P [150, 36, 194] => 12384
# P [194, 36, 150] => 12384
#  [194, 36, 150] => 12384
# ..................................
# The problem: [21, 75, 78]
# Permutations: total(6), display(1)
# P [78, 21, 75] => 3213
# P [75, 21, 78] => 3213
#  [78, 21, 75] => 3213
# ..................................
# The problem: [60, 73, 171]
# Permutations: total(6), display(1)
# P [171, 60, 73] => 14640
# P [73, 60, 171] => 14640
#  [171, 60, 73] => 14640
# ..................................
# The problem: [62, 89, 98, 141]
# Permutations: total(24), display(1)
# P [98, 89, 62, 141] => 22982
# P [141, 62, 89, 98] => 22982
#  [141, 62, 89, 98] => 22982
# ..................................
# The problem: [98, 117, 135, 196]
# Permutations: total(24), display(1)
# P [135, 117, 98, 196] => 46469
# P [196, 98, 117, 135] => 46469
#  [196, 98, 117, 135] => 46469
# ..................................
# The problem: [64, 77, 143, 158]
# Permutations: total(24), display(1)
# P [158, 64, 77, 143] => 26051
# P [143, 77, 64, 158] => 26051
#  [158, 64, 77, 143] => 26051
# ..................................
# The problem: [20, 120, 130, 177]
# Permutations: total(24), display(1)
# P [177, 20, 120, 130] => 21540
# P [130, 120, 20, 177] => 21540
#  [177, 20, 120, 130] => 21540
# ..................................
# The problem: [35, 54, 64, 150]
# Permutations: total(24), display(1)
# P [150, 35, 54, 64] => 10596
# P [64, 54, 35, 150] => 10596
#  [150, 35, 54, 64] => 10596
# ..................................
# The problem: [75, 148, 149, 187]
# Permutations: total(24), display(1)
# P [149, 148, 75, 187] => 47177
# P [187, 75, 148, 149] => 47177
#  [187, 75, 148, 149] => 47177
# ..................................
# The problem: [59, 78, 135, 146]
# Permutations: total(24), display(1)
# P [146, 59, 78, 135] => 23746
# P [135, 78, 59, 146] => 23746
#  [146, 59, 78, 135] => 23746
# ..................................
# The problem: [48, 66, 76, 167]
# Permutations: total(24), display(1)
# P [76, 66, 48, 167] => 16200
# P [167, 48, 66, 76] => 16200
#  [167, 48, 66, 76] => 16200
# ..................................
# The problem: [12, 73, 109, 117]
# Permutations: total(24), display(1)
# P [109, 73, 12, 117] => 10237
# P [117, 12, 73, 109] => 10237
#  [117, 12, 73, 109] => 10237
# ..................................
# The problem: [48, 119, 184, 185]
# Permutations: total(24), display(1)
# P [184, 119, 48, 185] => 36488
# P [185, 48, 119, 184] => 36488
#  [185, 48, 119, 184] => 36488
# ..................................
# The problem: [11, 28, 169, 186]
# Permutations: total(24), display(1)
# P [186, 11, 28, 169] => 7086
# P [169, 28, 11, 186] => 7086
#  [186, 11, 28, 169] => 7086
# ..................................
# The problem: [7, 30, 37, 170]
# Permutations: total(24), display(1)
# P [170, 7, 30, 37] => 2510
# P [37, 30, 7, 170] => 2510
#  [170, 7, 30, 37] => 2510
# ..................................
# The problem: [120, 123, 173, 186]
# Permutations: total(24), display(1)
# P [173, 123, 120, 186] => 58359
# P [186, 120, 123, 173] => 58359
#  [186, 120, 123, 173] => 58359
# ..................................
# The problem: [25, 63, 184, 191]
# Permutations: total(24), display(1)
# P [191, 25, 63, 184] => 17942
# P [184, 63, 25, 191] => 17942
#  [191, 25, 63, 184] => 17942
# ..................................
# The problem: [28, 155, 157, 167]
# Permutations: total(24), display(1)
# P [157, 155, 28, 167] => 33351
# P [167, 28, 155, 157] => 33351
#  [167, 28, 155, 157] => 33351
# ..................................
# The problem: [25, 116, 145, 191]
# Permutations: total(24), display(1)
# P [145, 116, 25, 191] => 24495
# P [191, 25, 116, 145] => 24495
#  [191, 25, 116, 145] => 24495
# ..................................
# The problem: [10, 69, 84, 157]
# Permutations: total(24), display(1)
# P [84, 69, 10, 157] => 8056
# P [157, 10, 69, 84] => 8056
#  [157, 10, 69, 84] => 8056
# ..................................
# The problem: [25, 49, 97, 198]
# Permutations: total(24), display(1)
# P [97, 49, 25, 198] => 10928
# P [198, 25, 49, 97] => 10928
#  [198, 25, 49, 97] => 10928
# ..................................
# The problem: [65, 101, 120, 193]
# Permutations: total(24), display(1)
# P [193, 65, 101, 120] => 31230
# P [120, 101, 65, 193] => 31230
#  [193, 65, 101, 120] => 31230
# ..................................
# The problem: [58, 97, 157, 161]
# Permutations: total(24), display(1)
# P [161, 58, 97, 157] => 30193
# P [157, 97, 58, 161] => 30193
#  [161, 58, 97, 157] => 30193
# ..................................
# The problem: [84, 84, 137, 139]
# Permutations: total(24), display(1)
# P [139, 84, 84, 137] => 30240
# P [139, 84, 84, 137] => 30240
# P [137, 84, 84, 139] => 30240
# P [137, 84, 84, 139] => 30240
#  [139, 84, 84, 137] => 30240
# ..................................
# The problem: [35, 45, 134, 172]
# Permutations: total(24), display(1)
# P [172, 35, 45, 134] => 13625
# P [134, 45, 35, 172] => 13625
#  [172, 35, 45, 134] => 13625
# ..................................
# The problem: [55, 72, 95, 157]
# Permutations: total(24), display(1)
# P [95, 72, 55, 157] => 19435
# P [157, 55, 72, 95] => 19435
#  [157, 55, 72, 95] => 19435
# ..................................
# The problem: [114, 150, 151, 194]
# Permutations: total(24), display(1)
# P [151, 150, 114, 194] => 61866
# P [194, 114, 150, 151] => 61866
#  [194, 114, 150, 151] => 61866
# ..................................
# The problem: [11, 76, 126, 186]
# Permutations: total(24), display(1)
# P [186, 11, 76, 126] => 12458
# P [126, 76, 11, 186] => 12458
#  [186, 11, 76, 126] => 12458
# ..................................
# The problem: [12, 68, 130, 168]
# Permutations: total(24), display(1)
# P [130, 68, 12, 168] => 11672
# P [168, 12, 68, 130] => 11672
#  [168, 12, 68, 130] => 11672
# ..................................
# The problem: [16, 47, 88, 173]
# Permutations: total(24), display(1)
# P [173, 16, 47, 88] => 7656
# P [88, 47, 16, 173] => 7656
#  [173, 16, 47, 88] => 7656
# ..................................
# The problem: [26, 53, 148, 192]
# Permutations: total(24), display(1)
# P [148, 53, 26, 192] => 14214
# P [192, 26, 53, 148] => 14214
#  [192, 26, 53, 148] => 14214
# ..................................
# The problem: [52, 104, 129, 200]
# Permutations: total(24), display(1)
# P [200, 52, 104, 129] => 29224
# P [129, 104, 52, 200] => 29224
#  [200, 52, 104, 129] => 29224
# ..................................
# The problem: [36, 41, 43, 63]
# Permutations: total(24), display(1)
# P [63, 36, 41, 43] => 5507
# P [43, 41, 36, 63] => 5507
#  [63, 36, 41, 43] => 5507
# ..................................
# The problem: [16, 67, 135, 195]
# Permutations: total(24), display(1)
# P [195, 16, 67, 135] => 13237
# P [135, 67, 16, 195] => 13237
#  [195, 16, 67, 135] => 13237
# ..................................
# The problem: [107, 119, 164, 192]
# Permutations: total(24), display(1)
# P [164, 119, 107, 192] => 52793
# P [192, 107, 119, 164] => 52793
#  [192, 107, 119, 164] => 52793
# ..................................
# The problem: [24, 49, 115, 124]
# Permutations: total(24), display(1)
# P [115, 49, 24, 124] => 9787
# P [124, 24, 49, 115] => 9787
#  [124, 24, 49, 115] => 9787
# ..................................
# The problem: [65, 82, 156, 199]
# Permutations: total(24), display(1)
# P [199, 65, 82, 156] => 31057
# P [156, 82, 65, 199] => 31057
#  [199, 65, 82, 156] => 31057
# ..................................
# The problem: [58, 61, 124, 170]
# Permutations: total(24), display(1)
# P [124, 61, 58, 170] => 20962
# P [170, 58, 61, 124] => 20962
#  [170, 58, 61, 124] => 20962
# ..................................
# The problem: [11, 38, 95, 180]
# Permutations: total(24), display(1)
# P [180, 11, 38, 95] => 6008
# P [95, 38, 11, 180] => 6008
#  [180, 11, 38, 95] => 6008
# ..................................
# The problem: [32, 59, 94, 113]
# Permutations: total(24), display(1)
# P [113, 32, 59, 94] => 11050
# P [94, 59, 32, 113] => 11050
#  [113, 32, 59, 94] => 11050
# ..................................
# The problem: [110, 112, 134, 138]
# Permutations: total(24), display(1)
# P [134, 112, 110, 138] => 42508
# P [138, 110, 112, 134] => 42508
#  [138, 110, 112, 134] => 42508
# ..................................
# The problem: [76, 81, 142, 145]
# Permutations: total(24), display(1)
# P [142, 81, 76, 145] => 28678
# P [145, 76, 81, 142] => 28678
#  [145, 76, 81, 142] => 28678
# ..................................
# The problem: [28, 86, 148, 173]
# Permutations: total(24), display(1)
# P [173, 28, 86, 148] => 19980
# P [148, 86, 28, 173] => 19980
#  [173, 28, 86, 148] => 19980
# ..................................
# The problem: [39, 73, 161, 187]
# Permutations: total(24), display(1)
# P [161, 73, 39, 187] => 21893
# P [187, 39, 73, 161] => 21893
#  [187, 39, 73, 161] => 21893
# ..................................
# The problem: [32, 42, 89, 146]
# Permutations: total(24), display(1)
# P [146, 32, 42, 89] => 9754
# P [89, 42, 32, 146] => 9754
#  [146, 32, 42, 89] => 9754
# ..................................
# The problem: [87, 104, 126, 141]
# Permutations: total(24), display(1)
# P [126, 104, 87, 141] => 34419
# P [141, 87, 104, 126] => 34419
#  [141, 87, 104, 126] => 34419
# ..................................
# The problem: [28, 47, 92, 134]
# Permutations: total(24), display(1)
# P [134, 28, 47, 92] => 9392
# P [92, 47, 28, 134] => 9392
#  [134, 28, 47, 92] => 9392
# ..................................
# The problem: [57, 78, 157, 175]
# Permutations: total(24), display(1)
# P [175, 57, 78, 157] => 26667
# P [157, 78, 57, 175] => 26667
#  [175, 57, 78, 157] => 26667
# ..................................
# The problem: [53, 62, 131, 147]
# Permutations: total(24), display(1)
# P [131, 62, 53, 147] => 19199
# P [147, 53, 62, 131] => 19199
#  [147, 53, 62, 131] => 19199
# ..................................
# The problem: [27, 44, 85, 95]
# Permutations: total(24), display(1)
# P [95, 27, 44, 85] => 7493
# P [85, 44, 27, 95] => 7493
#  [95, 27, 44, 85] => 7493
# ..................................
# The problem: [24, 67, 144, 195]
# Permutations: total(24), display(1)
# P [144, 67, 24, 195] => 15936
# P [195, 24, 67, 144] => 15936
#  [195, 24, 67, 144] => 15936
# ..................................
# The problem: [74, 92, 183, 189]
# Permutations: total(24), display(1)
# P [183, 92, 74, 189] => 37630
# P [189, 74, 92, 183] => 37630
#  [189, 74, 92, 183] => 37630
# ..................................
# The problem: [58, 74, 150, 167]
# Permutations: total(24), display(1)
# P [150, 74, 58, 167] => 25078
# P [167, 58, 74, 150] => 25078
#  [167, 58, 74, 150] => 25078
# ..................................
# The problem: [134, 168, 174, 193, 195]
# Permutations: total(120), display(1)
# P [195, 134, 174, 168, 193] => 111102
# P [193, 168, 174, 134, 195] => 111102
#  [195, 134, 174, 168, 193] => 111102
# ..................................
# The problem: [37, 90, 125, 169, 183]
# Permutations: total(120), display(1)
# P [169, 90, 125, 37, 183] => 37856
# P [183, 37, 125, 90, 169] => 37856
#  [183, 37, 125, 90, 169] => 37856
# ..................................
# The problem: [35, 69, 108, 162, 197]
# Permutations: total(120), display(1)
# P [162, 69, 108, 35, 197] => 29305
# P [197, 35, 108, 69, 162] => 29305
#  [197, 35, 108, 69, 162] => 29305
# ..................................
# The problem: [24, 65, 107, 172, 195]
# Permutations: total(120), display(1)
# P [172, 65, 107, 24, 195] => 25383
# P [195, 24, 107, 65, 172] => 25383
#  [195, 24, 107, 65, 172] => 25383
# ..................................
# The problem: [69, 79, 84, 117, 125]
# Permutations: total(120), display(1)
# P [125, 69, 84, 79, 117] => 30300
# P [117, 79, 84, 69, 125] => 30300
#  [125, 69, 84, 79, 117] => 30300
# ..................................
# The problem: [29, 35, 56, 154, 156]
# Permutations: total(120), display(1)
# P [156, 29, 56, 35, 154] => 13498
# P [154, 35, 56, 29, 156] => 13498
#  [156, 29, 56, 35, 154] => 13498
# ..................................
# The problem: [47, 48, 93, 170, 173]
# Permutations: total(120), display(1)
# P [170, 48, 93, 47, 173] => 25126
# P [173, 47, 93, 48, 170] => 25126
#  [173, 47, 93, 48, 170] => 25126
# ..................................
# The problem: [7, 10, 54, 102, 144]
# Permutations: total(120), display(1)
# P [102, 10, 54, 7, 144] => 2946
# P [144, 7, 54, 10, 102] => 2946
#  [144, 7, 54, 10, 102] => 2946
# ..................................
# The problem: [45, 101, 110, 163, 177]
# Permutations: total(120), display(1)
# P [177, 45, 110, 101, 163] => 40488
# P [163, 101, 110, 45, 177] => 40488
#  [177, 45, 110, 101, 163] => 40488
# ..................................
# The problem: [10, 47, 95, 119, 128]
# Permutations: total(120), display(1)
# P [119, 47, 95, 10, 128] => 12288
# P [128, 10, 95, 47, 119] => 12288
#  [128, 10, 95, 47, 119] => 12288
# ..................................
# The problem: [28, 57, 71, 98, 173]
# Permutations: total(120), display(1)
# P [173, 28, 71, 57, 98] => 16465
# P [98, 57, 71, 28, 173] => 16465
#  [173, 28, 71, 57, 98] => 16465
# ..................................
# The problem: [26, 65, 75, 105, 168]
# Permutations: total(120), display(1)
# P [168, 26, 75, 65, 105] => 18018
# P [105, 65, 75, 26, 168] => 18018
#  [168, 26, 75, 65, 105] => 18018
# ..................................
# The problem: [53, 62, 103, 149, 155]
# Permutations: total(120), display(1)
# P [155, 53, 103, 62, 149] => 29298
# P [149, 62, 103, 53, 155] => 29298
#  [155, 53, 103, 62, 149] => 29298
# ..................................
# The problem: [62, 101, 121, 130, 185]
# Permutations: total(120), display(1)
# P [185, 62, 121, 101, 130] => 44323
# P [130, 101, 121, 62, 185] => 44323
#  [185, 62, 121, 101, 130] => 44323
# ..................................
# The problem: [24, 72, 73, 145, 152]
# Permutations: total(120), display(1)
# P [152, 24, 73, 72, 145] => 21096
# P [145, 72, 73, 24, 152] => 21096
#  [152, 24, 73, 72, 145] => 21096
# ..................................
# The problem: [68, 91, 163, 175, 194]
# Permutations: total(120), display(1)
# P [194, 68, 163, 91, 175] => 55034
# P [175, 91, 163, 68, 194] => 55034
#  [194, 68, 163, 91, 175] => 55034
# ..................................
# The problem: [17, 82, 87, 126, 191]
# Permutations: total(120), display(1)
# P [126, 82, 87, 17, 191] => 22192
# P [191, 17, 87, 82, 126] => 22192
#  [191, 17, 87, 82, 126] => 22192
# ..................................
# The problem: [41, 58, 64, 74, 185]
# Permutations: total(120), display(1)
# P [74, 58, 64, 41, 185] => 18213
# P [185, 41, 64, 58, 74] => 18213
#  [185, 41, 64, 58, 74] => 18213
# ..................................
# The problem: [26, 39, 110, 120, 169]
# Permutations: total(120), display(1)
# P [169, 26, 110, 39, 120] => 16224
# P [120, 39, 110, 26, 169] => 16224
#  [169, 26, 110, 39, 120] => 16224
# ..................................
# The problem: [13, 46, 120, 131, 140]
# Permutations: total(120), display(1)
# P [140, 13, 120, 46, 131] => 14926
# P [131, 46, 120, 13, 140] => 14926
#  [140, 13, 120, 46, 131] => 14926
# ..................................
# The problem: [97, 98, 178, 187, 194]
# Permutations: total(120), display(1)
# P [194, 97, 178, 98, 187] => 71854
# P [187, 98, 178, 97, 194] => 71854
#  [194, 97, 178, 98, 187] => 71854
# ..................................
# The problem: [108, 111, 115, 147, 183]
# Permutations: total(120), display(1)
# P [147, 111, 115, 108, 183] => 61266
# P [183, 108, 115, 111, 147] => 61266
#  [183, 108, 115, 111, 147] => 61266
# ..................................
# The problem: [31, 54, 63, 69, 105]
# Permutations: total(120), display(1)
# P [105, 31, 63, 54, 69] => 12336
# P [69, 54, 63, 31, 105] => 12336
#  [105, 31, 63, 54, 69] => 12336
# ..................................
# The problem: [61, 73, 118, 154, 176]
# Permutations: total(120), display(1)
# P [154, 73, 118, 61, 176] => 37790
# P [176, 61, 118, 73, 154] => 37790
#  [176, 61, 118, 73, 154] => 37790
# ..................................
# The problem: [26, 49, 66, 94, 109]
# Permutations: total(120), display(1)
# P [94, 49, 66, 26, 109] => 12390
# P [109, 26, 66, 49, 94] => 12390
#  [109, 26, 66, 49, 94] => 12390
# ..................................
# The problem: [11, 17, 78, 159, 179]
# Permutations: total(120), display(1)
# P [159, 17, 78, 11, 179] => 6856
# P [179, 11, 78, 17, 159] => 6856
#  [179, 11, 78, 17, 159] => 6856
# ..................................
# The problem: [12, 44, 74, 119, 179]
# Permutations: total(120), display(1)
# P [119, 44, 74, 12, 179] => 11528
# P [179, 12, 74, 44, 119] => 11528
#  [179, 12, 74, 44, 119] => 11528
# ..................................
# The problem: [24, 39, 98, 104, 190]
# Permutations: total(120), display(1)
# P [190, 24, 98, 39, 104] => 14790
# P [104, 39, 98, 24, 190] => 14790
#  [190, 24, 98, 39, 104] => 14790
# ..................................
# The problem: [35, 116, 126, 167, 183]
# Permutations: total(120), display(1)
# P [183, 35, 126, 116, 167] => 44803
# P [167, 116, 126, 35, 183] => 44803
#  [183, 35, 126, 116, 167] => 44803
# ..................................
# The problem: [67, 71, 74, 160, 172]
# Permutations: total(120), display(1)
# P [160, 71, 74, 67, 172] => 33096
# P [172, 67, 74, 71, 160] => 33096
#  [172, 67, 74, 71, 160] => 33096
# ..................................
# The problem: [24, 41, 74, 82, 122]
# Permutations: total(120), display(1)
# P [82, 41, 74, 24, 122] => 11100
# P [122, 24, 74, 41, 82] => 11100
#  [122, 24, 74, 41, 82] => 11100
# ..................................
# The problem: [80, 99, 114, 162, 176]
# Permutations: total(120), display(1)
# P [162, 99, 114, 80, 176] => 50524
# P [176, 80, 114, 99, 162] => 50524
#  [176, 80, 114, 99, 162] => 50524
# ..................................
# The problem: [17, 31, 84, 120, 160]
# Permutations: total(120), display(1)
# P [120, 31, 84, 17, 160] => 10472
# P [160, 17, 84, 31, 120] => 10472
#  [160, 17, 84, 31, 120] => 10472
# ..................................
# The problem: [42, 110, 150, 178, 179]
# Permutations: total(120), display(1)
# P [179, 42, 150, 110, 178] => 49898
# P [178, 110, 150, 42, 179] => 49898
#  [179, 42, 150, 110, 178] => 49898
# ..................................
# The problem: [96, 109, 114, 133, 194]
# Permutations: total(120), display(1)
# P [194, 96, 114, 109, 133] => 56491
# P [133, 109, 114, 96, 194] => 56491
#  [194, 96, 114, 109, 133] => 56491
# ..................................
# The problem: [24, 61, 76, 78, 113]
# Permutations: total(120), display(1)
# P [113, 24, 76, 61, 78] => 13930
# P [78, 61, 76, 24, 113] => 13930
#  [113, 24, 76, 61, 78] => 13930
# ..................................
# The problem: [88, 93, 95, 106, 137]
# Permutations: total(120), display(1)
# P [137, 88, 95, 93, 106] => 39109
# P [106, 93, 95, 88, 137] => 39109
#  [137, 88, 95, 93, 106] => 39109
# ..................................
# The problem: [13, 44, 64, 176, 184]
# Permutations: total(120), display(1)
# P [176, 44, 64, 13, 184] => 13784
# P [184, 13, 64, 44, 176] => 13784
#  [184, 13, 64, 44, 176] => 13784
# ..................................
# The problem: [44, 70, 120, 191, 193]
# Permutations: total(120), display(1)
# P [193, 44, 120, 70, 191] => 35542
# P [191, 70, 120, 44, 193] => 35542
#  [193, 44, 120, 70, 191] => 35542
# ..................................
# The problem: [38, 56, 73, 80, 118]
# Permutations: total(120), display(1)
# P [118, 38, 73, 56, 80] => 15826
# P [80, 56, 73, 38, 118] => 15826
#  [118, 38, 73, 56, 80] => 15826
# ..................................
# The problem: [21, 101, 124, 163, 188]
# Permutations: total(120), display(1)
# P [163, 101, 124, 21, 188] => 35539
# P [188, 21, 124, 101, 163] => 35539
#  [188, 21, 124, 101, 163] => 35539
# ..................................
# The problem: [56, 89, 147, 167, 184]
# Permutations: total(120), display(1)
# P [184, 56, 147, 89, 167] => 46482
# P [167, 89, 147, 56, 184] => 46482
#  [184, 56, 147, 89, 167] => 46482
# ..................................
# The problem: [9, 10, 63, 117, 148]
# Permutations: total(120), display(1)
# P [117, 10, 63, 9, 148] => 3699
# P [148, 9, 63, 10, 117] => 3699
#  [148, 9, 63, 10, 117] => 3699
# ..................................
# The problem: [25, 92, 94, 120, 136]
# Permutations: total(120), display(1)
# P [136, 25, 94, 92, 120] => 25438
# P [120, 92, 94, 25, 136] => 25438
#  [136, 25, 94, 92, 120] => 25438
# ..................................
# The problem: [8, 32, 50, 97, 150]
# Permutations: total(120), display(1)
# P [97, 32, 50, 8, 150] => 6304
# P [150, 8, 50, 32, 97] => 6304
#  [150, 8, 50, 32, 97] => 6304
# ..................................
# The problem: [24, 68, 142, 159, 188]
# Permutations: total(120), display(1)
# P [188, 24, 142, 68, 159] => 28388
# P [159, 68, 142, 24, 188] => 28388
#  [188, 24, 142, 68, 159] => 28388
# ..................................
# The problem: [36, 76, 103, 122, 153]
# Permutations: total(120), display(1)
# P [122, 76, 103, 36, 153] => 26316
# P [153, 36, 103, 76, 122] => 26316
#  [153, 36, 103, 76, 122] => 26316
# ..................................
# The problem: [35, 55, 74, 176, 190]
# Permutations: total(120), display(1)
# P [190, 35, 74, 55, 176] => 22990
# P [176, 55, 74, 35, 190] => 22990
#  [190, 35, 74, 55, 176] => 22990
# ..................................
# The problem: [64, 78, 79, 139, 164]
# Permutations: total(120), display(1)
# P [164, 64, 79, 78, 139] => 32556
# P [139, 78, 79, 64, 164] => 32556
#  [164, 64, 79, 78, 139] => 32556
# ..................................
# The problem: [22, 32, 44, 128, 177]
# Permutations: total(120), display(1)
# P [128, 32, 44, 22, 177] => 10366
# P [177, 22, 44, 32, 128] => 10366
#  [177, 22, 44, 32, 128] => 10366
# ..................................
# The problem: [40, 42, 93, 97, 122, 189]
# Permutations: total(720), display(1)
# P [189, 40, 97, 93, 42, 122] => 29491
# P [122, 42, 93, 97, 40, 189] => 29491
#  [189, 40, 97, 93, 42, 122] => 29491
# ..................................
# The problem: [20, 39, 63, 86, 169, 174]
# Permutations: total(720), display(1)
# P [174, 20, 86, 63, 39, 169] => 19666
# P [169, 39, 63, 86, 20, 174] => 19666
#  [174, 20, 86, 63, 39, 169] => 19666
# ..................................
# The problem: [9, 10, 54, 117, 179, 193]
# Permutations: total(720), display(1)
# P [193, 9, 117, 54, 10, 179] => 11438
# P [179, 10, 54, 117, 9, 193] => 11438
#  [193, 9, 117, 54, 10, 179] => 11438
# ..................................
# The problem: [30, 37, 72, 170, 171, 178]
# Permutations: total(720), display(1)
# P [178, 30, 170, 72, 37, 171] => 31671
# P [171, 37, 72, 170, 30, 178] => 31671
#  [178, 30, 170, 72, 37, 171] => 31671
# ..................................
# The problem: [20, 26, 41, 64, 79, 179]
# Permutations: total(720), display(1)
# P [179, 20, 64, 41, 26, 79] => 10604
# P [79, 26, 41, 64, 20, 179] => 10604
#  [179, 20, 64, 41, 26, 79] => 10604
# ..................................
# The problem: [47, 54, 71, 111, 144, 166]
# Permutations: total(720), display(1)
# P [144, 54, 71, 111, 47, 166] => 32510
# P [166, 47, 111, 71, 54, 144] => 32510
#  [166, 47, 111, 71, 54, 144] => 32510
# ..................................
# The problem: [19, 29, 74, 110, 132, 157]
# Permutations: total(720), display(1)
# P [132, 29, 74, 110, 19, 157] => 19187
# P [157, 19, 110, 74, 29, 132] => 19187
#  [157, 19, 110, 74, 29, 132] => 19187
# ..................................
# The problem: [9, 20, 52, 147, 164, 169]
# Permutations: total(720), display(1)
# P [169, 9, 147, 52, 20, 164] => 14808
# P [164, 20, 52, 147, 9, 169] => 14808
#  [169, 9, 147, 52, 20, 164] => 14808
# ..................................
# The problem: [99, 128, 131, 145, 149, 185]
# Permutations: total(720), display(1)
# P [185, 99, 145, 131, 128, 149] => 87505
# P [149, 128, 131, 145, 99, 185] => 87505
#  [185, 99, 145, 131, 128, 149] => 87505
# ..................................
# The problem: [36, 63, 101, 125, 167, 177]
# Permutations: total(720), display(1)
# P [177, 36, 125, 101, 63, 167] => 40381
# P [167, 63, 101, 125, 36, 177] => 40381
#  [177, 36, 125, 101, 63, 167] => 40381
# ..................................
# The problem: [10, 51, 79, 84, 140, 183]
# Permutations: total(720), display(1)
# P [183, 10, 84, 79, 51, 140] => 20475
# P [140, 51, 79, 84, 10, 183] => 20475
#  [183, 10, 84, 79, 51, 140] => 20475
# ..................................
# The problem: [28, 92, 93, 105, 122, 156]
# Permutations: total(720), display(1)
# P [122, 92, 93, 105, 28, 156] => 36853
# P [156, 28, 105, 93, 92, 122] => 36853
#  [156, 28, 105, 93, 92, 122] => 36853
# ..................................
# The problem: [55, 67, 96, 113, 122, 186]
# Permutations: total(720), display(1)
# P [122, 67, 96, 113, 55, 186] => 41899
# P [186, 55, 113, 96, 67, 122] => 41899
#  [186, 55, 113, 96, 67, 122] => 41899
# ..................................
# The problem: [21, 27, 102, 133, 172, 195]
# Permutations: total(720), display(1)
# P [195, 21, 133, 102, 27, 172] => 27852
# P [172, 27, 102, 133, 21, 195] => 27852
#  [195, 21, 133, 102, 27, 172] => 27852
# ..................................
# The problem: [60, 101, 124, 132, 142, 142]
# Permutations: total(720), display(1)
# P [142, 60, 132, 124, 101, 142] => 59674
# P [142, 101, 124, 132, 60, 142] => 59674
# P [142, 60, 132, 124, 101, 142] => 59674
# P [142, 101, 124, 132, 60, 142] => 59674
#  [142, 60, 132, 124, 101, 142] => 59674
# ..................................
# The problem: [70, 73, 73, 140, 146, 165]
# Permutations: total(720), display(1)
# P [165, 70, 140, 73, 73, 146] => 47557
# P [165, 70, 140, 73, 73, 146] => 47557
# P [146, 73, 73, 140, 70, 165] => 47557
# P [146, 73, 73, 140, 70, 165] => 47557
#  [165, 70, 140, 73, 73, 146] => 47557
# ..................................
# The problem: [36, 38, 40, 145, 153, 189]
# Permutations: total(720), display(1)
# P [153, 38, 40, 145, 36, 189] => 25158
# P [189, 36, 145, 40, 38, 153] => 25158
#  [189, 36, 145, 40, 38, 153] => 25158
# ..................................
# The problem: [18, 56, 62, 71, 83, 179]
# Permutations: total(720), display(1)
# P [179, 18, 71, 62, 56, 83] => 17022
# P [83, 56, 62, 71, 18, 179] => 17022
#  [179, 18, 71, 62, 56, 83] => 17022
# ..................................
# The problem: [23, 52, 73, 105, 124, 142]
# Permutations: total(720), display(1)
# P [124, 52, 73, 105, 23, 142] => 23590
# P [142, 23, 105, 73, 52, 124] => 23590
#  [142, 23, 105, 73, 52, 124] => 23590
# ..................................
# The problem: [91, 99, 99, 137, 156, 197]
# Permutations: total(720), display(1)
# P [197, 91, 137, 99, 99, 156] => 69202
# P [197, 91, 137, 99, 99, 156] => 69202
# P [156, 99, 99, 137, 91, 197] => 69202
# P [156, 99, 99, 137, 91, 197] => 69202
#  [197, 91, 137, 99, 99, 156] => 69202
# ..................................
# The problem: [22, 82, 97, 132, 173, 183]
# Permutations: total(720), display(1)
# P [173, 82, 97, 132, 22, 183] => 41874
# P [183, 22, 132, 97, 82, 173] => 41874
#  [183, 22, 132, 97, 82, 173] => 41874
# ..................................
# The problem: [23, 42, 62, 75, 140, 145]
# Permutations: total(720), display(1)
# P [140, 42, 62, 75, 23, 145] => 18194
# P [145, 23, 75, 62, 42, 140] => 18194
#  [145, 23, 75, 62, 42, 140] => 18194
# ..................................
# The problem: [28, 46, 81, 104, 143, 193]
# Permutations: total(720), display(1)
# P [193, 28, 104, 81, 46, 143] => 27044
# P [143, 46, 81, 104, 28, 193] => 27044
#  [193, 28, 104, 81, 46, 143] => 27044
# ..................................
# The problem: [22, 95, 121, 146, 146, 199]
# Permutations: total(720), display(1)
# P [146, 121, 95, 146, 22, 199] => 50621
# P [146, 95, 121, 146, 22, 199] => 50621
# P [199, 22, 146, 121, 95, 146] => 50621
# P [199, 22, 146, 95, 121, 146] => 50621
# P [199, 22, 146, 121, 95, 146] => 50621
# P [199, 22, 146, 95, 121, 146] => 50621
# P [146, 121, 95, 146, 22, 199] => 50621
# P [146, 95, 121, 146, 22, 199] => 50621
#  [199, 22, 146, 121, 95, 146] => 50621
# ..................................
# The problem: [28, 64, 64, 66, 88, 118]
# Permutations: total(720), display(1)
# P [118, 28, 66, 64, 64, 88] => 19104
# P [118, 28, 66, 64, 64, 88] => 19104
# P [88, 64, 64, 66, 28, 118] => 19104
# P [88, 64, 64, 66, 28, 118] => 19104
#  [118, 28, 66, 64, 64, 88] => 19104
# ..................................
# The problem: [16, 25, 71, 109, 141, 141]
# Permutations: total(720), display(1)
# P [141, 16, 109, 71, 25, 141] => 17039
# P [141, 25, 71, 109, 16, 141] => 17039
# P [141, 16, 109, 71, 25, 141] => 17039
# P [141, 25, 71, 109, 16, 141] => 17039
#  [141, 16, 109, 71, 25, 141] => 17039
# ..................................
# The problem: [33, 44, 74, 106, 148, 172]
# Permutations: total(720), display(1)
# P [172, 33, 106, 74, 44, 148] => 26786
# P [148, 44, 74, 106, 33, 172] => 26786
#  [172, 33, 106, 74, 44, 148] => 26786
# ..................................
# The problem: [70, 121, 123, 134, 137, 171]
# Permutations: total(720), display(1)
# P [137, 121, 123, 134, 70, 171] => 69292
# P [171, 70, 134, 123, 121, 137] => 69292
#  [171, 70, 134, 123, 121, 137] => 69292
# ..................................
# The problem: [48, 99, 144, 177, 182, 197]
# Permutations: total(720), display(1)
# P [182, 99, 144, 177, 48, 197] => 75714
# P [197, 48, 177, 144, 99, 182] => 75714
#  [197, 48, 177, 144, 99, 182] => 75714
# ..................................
# The problem: [27, 55, 64, 94, 112, 147]
# Permutations: total(720), display(1)
# P [112, 55, 64, 94, 27, 147] => 22203
# P [147, 27, 94, 64, 55, 112] => 22203
#  [147, 27, 94, 64, 55, 112] => 22203
# ..................................
# The problem: [19, 28, 86, 107, 108, 109]
# Permutations: total(720), display(1)
# P [109, 19, 107, 86, 28, 108] => 18738
# P [108, 28, 86, 107, 19, 109] => 18738
#  [109, 19, 107, 86, 28, 108] => 18738
# ..................................
# The problem: [10, 50, 117, 117, 156, 193]
# Permutations: total(720), display(1)
# P [156, 50, 117, 117, 10, 193] => 30439
# P [156, 50, 117, 117, 10, 193] => 30439
# P [193, 10, 117, 117, 50, 156] => 30439
# P [193, 10, 117, 117, 50, 156] => 30439
#  [193, 10, 117, 117, 50, 156] => 30439
# ..................................
# The problem: [16, 47, 57, 95, 121, 131]
# Permutations: total(720), display(1)
# P [131, 16, 95, 57, 47, 121] => 17397
# P [121, 47, 57, 95, 16, 131] => 17397
#  [131, 16, 95, 57, 47, 121] => 17397
# ..................................
# The problem: [13, 27, 60, 72, 100, 188]
# Permutations: total(720), display(1)
# P [188, 13, 72, 60, 27, 100] => 12020
# P [100, 27, 60, 72, 13, 188] => 12020
#  [188, 13, 72, 60, 27, 100] => 12020
# ..................................
# The problem: [65, 65, 73, 81, 119, 153]
# Permutations: total(720), display(1)
# P [119, 65, 81, 73, 65, 153] => 33603
# P [119, 65, 73, 81, 65, 153] => 33603
# P [119, 65, 81, 73, 65, 153] => 33603
# P [119, 65, 73, 81, 65, 153] => 33603
# P [153, 65, 81, 73, 65, 119] => 33603
# P [153, 65, 73, 81, 65, 119] => 33603
# P [153, 65, 81, 73, 65, 119] => 33603
# P [153, 65, 73, 81, 65, 119] => 33603
#  [153, 65, 81, 73, 65, 119] => 33603
# ..................................
# The problem: [7, 56, 64, 78, 131, 156]
# Permutations: total(720), display(1)
# P [156, 7, 78, 64, 56, 131] => 17550
# P [131, 56, 64, 78, 7, 156] => 17550
#  [156, 7, 78, 64, 56, 131] => 17550
# ..................................
# The problem: [11, 69, 127, 137, 161, 172]
# Permutations: total(720), display(1)
# P [161, 69, 127, 137, 11, 172] => 40670
# P [172, 11, 137, 127, 69, 161] => 40670
#  [172, 11, 137, 127, 69, 161] => 40670
# ..................................
# The problem: [32, 45, 82, 103, 163, 173]
# Permutations: total(720), display(1)
# P [163, 45, 82, 103, 32, 173] => 28303
# P [173, 32, 103, 82, 45, 163] => 28303
#  [173, 32, 103, 82, 45, 163] => 28303
# ..................................
# The problem: [82, 98, 124, 142, 149, 187]
# Permutations: total(720), display(1)
# P [149, 98, 124, 142, 82, 187] => 71340
# P [187, 82, 142, 124, 98, 149] => 71340
#  [187, 82, 142, 124, 98, 149] => 71340
# ..................................
# The problem: [11, 56, 72, 120, 146, 161]
# Permutations: total(720), display(1)
# P [161, 11, 120, 72, 56, 146] => 23939
# P [146, 56, 72, 120, 11, 161] => 23939
#  [161, 11, 120, 72, 56, 146] => 23939
# ..................................
# The problem: [26, 58, 146, 148, 190, 193]
# Permutations: total(720), display(1)
# P [193, 26, 148, 146, 58, 190] => 49962
# P [190, 58, 146, 148, 26, 193] => 49962
#  [193, 26, 148, 146, 58, 190] => 49962
# ..................................
# The problem: [32, 119, 120, 146, 161, 170]
# Permutations: total(720), display(1)
# P [170, 32, 146, 120, 119, 161] => 61071
# P [161, 119, 120, 146, 32, 170] => 61071
#  [170, 32, 146, 120, 119, 161] => 61071
# ..................................
# The problem: [48, 71, 71, 102, 139, 193]
# Permutations: total(720), display(1)
# P [139, 71, 71, 102, 48, 193] => 36312
# P [139, 71, 71, 102, 48, 193] => 36312
# P [193, 48, 102, 71, 71, 139] => 36312
# P [193, 48, 102, 71, 71, 139] => 36312
#  [193, 48, 102, 71, 71, 139] => 36312
# ..................................
# The problem: [43, 100, 113, 147, 182, 187]
# Permutations: total(720), display(1)
# P [182, 100, 113, 147, 43, 187] => 60473
# P [187, 43, 147, 113, 100, 182] => 60473
#  [187, 43, 147, 113, 100, 182] => 60473
# ..................................
# The problem: [14, 21, 45, 108, 169, 176]
# Permutations: total(720), display(1)
# P [176, 14, 108, 45, 21, 169] => 13330
# P [169, 21, 45, 108, 14, 176] => 13330
#  [176, 14, 108, 45, 21, 169] => 13330
# ..................................
# The problem: [24, 104, 142, 149, 181, 191]
# Permutations: total(720), display(1)
# P [191, 24, 149, 142, 104, 181] => 62910
# P [181, 104, 142, 149, 24, 191] => 62910
#  [191, 24, 149, 142, 104, 181] => 62910
# ..................................
# The problem: [38, 59, 158, 163, 168, 184]
# Permutations: total(720), display(1)
# P [184, 38, 163, 158, 59, 168] => 58174
# P [168, 59, 158, 163, 38, 184] => 58174
#  [184, 38, 163, 158, 59, 168] => 58174
# ..................................
# The problem: [15, 18, 55, 88, 111, 197]
# Permutations: total(720), display(1)
# P [197, 15, 88, 55, 18, 111] => 12103
# P [111, 18, 55, 88, 15, 197] => 12103
#  [197, 15, 88, 55, 18, 111] => 12103
# ..................................
# The problem: [7, 7, 52, 75, 117, 137]
# Permutations: total(720), display(1)
# P [137, 7, 52, 75, 7, 117] => 6567
# P [137, 7, 75, 52, 7, 117] => 6567
# P [137, 7, 52, 75, 7, 117] => 6567
# P [137, 7, 75, 52, 7, 117] => 6567
# P [117, 7, 52, 75, 7, 137] => 6567
# P [117, 7, 75, 52, 7, 137] => 6567
# P [117, 7, 52, 75, 7, 137] => 6567
# P [117, 7, 75, 52, 7, 137] => 6567
#  [137, 7, 75, 52, 7, 117] => 6567
# ..................................
# The problem: [25, 48, 71, 100, 140, 147]
# Permutations: total(720), display(1)
# P [140, 48, 71, 100, 25, 147] => 23403
# P [147, 25, 100, 71, 48, 140] => 23403
#  [147, 25, 100, 71, 48, 140] => 23403
# ..................................
# The problem: [18, 32, 58, 87, 167, 195, 200]
# Permutations: total(5040), display(1)
# P [200, 18, 167, 58, 87, 32, 195] => 30362
# P [195, 32, 87, 58, 167, 18, 200] => 30362
#  [200, 18, 167, 58, 87, 32, 195] => 30362
# ..................................
# The problem: [50, 88, 98, 99, 154, 158, 200]
# Permutations: total(5040), display(1)
# P [158, 88, 99, 98, 154, 50, 200] => 65110
# P [200, 50, 154, 98, 99, 88, 158] => 65110
#  [200, 50, 154, 98, 99, 88, 158] => 65110
# ..................................
# The problem: [12, 105, 137, 150, 150, 152, 160]
# Permutations: total(5040), display(1)
# P [152, 105, 150, 137, 150, 12, 160] => 76530
# P [152, 105, 150, 137, 150, 12, 160] => 76530
# P [160, 12, 150, 137, 150, 105, 152] => 76530
# P [160, 12, 150, 137, 150, 105, 152] => 76530
#  [160, 12, 150, 137, 150, 105, 152] => 76530
# ..................................
# The problem: [14, 23, 124, 151, 158, 159, 175]
# Permutations: total(5040), display(1)
# P [159, 23, 151, 124, 158, 14, 175] => 50108
# P [175, 14, 158, 124, 151, 23, 159] => 50108
#  [175, 14, 158, 124, 151, 23, 159] => 50108
# ..................................
# The problem: [7, 12, 68, 86, 119, 130, 174]
# Permutations: total(5040), display(1)
# P [174, 7, 119, 68, 86, 12, 130] => 18583
# P [130, 12, 86, 68, 119, 7, 174] => 18583
#  [174, 7, 119, 68, 86, 12, 130] => 18583
# ..................................
# The problem: [45, 46, 58, 61, 79, 106, 180]
# Permutations: total(5040), display(1)
# P [180, 45, 79, 58, 61, 46, 106] => 27457
# P [106, 46, 61, 58, 79, 45, 180] => 27457
#  [180, 45, 79, 58, 61, 46, 106] => 27457
# ..................................
# The problem: [19, 45, 94, 111, 140, 159, 199]
# Permutations: total(5040), display(1)
# P [199, 19, 140, 94, 111, 45, 159] => 42185
# P [159, 45, 111, 94, 140, 19, 199] => 42185
#  [199, 19, 140, 94, 111, 45, 159] => 42185
# ..................................
# The problem: [23, 60, 61, 65, 151, 168, 170]
# Permutations: total(5040), display(1)
# P [168, 60, 65, 61, 151, 23, 170] => 34539
# P [170, 23, 151, 61, 65, 60, 168] => 34539
#  [170, 23, 151, 61, 65, 60, 168] => 34539
# ..................................
# The problem: [31, 53, 143, 152, 160, 161, 168]
# Permutations: total(5040), display(1)
# P [161, 53, 152, 143, 160, 31, 168] => 71373
# P [168, 31, 160, 143, 152, 53, 161] => 71373
#  [168, 31, 160, 143, 152, 53, 161] => 71373
# ..................................
# The problem: [45, 54, 86, 123, 155, 184, 188]
# Permutations: total(5040), display(1)
# P [184, 54, 123, 86, 155, 45, 188] => 55921
# P [188, 45, 155, 86, 123, 54, 184] => 55921
#  [188, 45, 155, 86, 123, 54, 184] => 55921
# ..................................
# The problem: [29, 36, 45, 47, 89, 95, 114]
# Permutations: total(5040), display(1)
# P [95, 36, 47, 45, 89, 29, 114] => 17119
# P [114, 29, 89, 45, 47, 36, 95] => 17119
#  [114, 29, 89, 45, 47, 36, 95] => 17119
# ..................................
# The problem: [17, 93, 111, 155, 166, 176, 179]
# Permutations: total(5040), display(1)
# P [179, 17, 166, 111, 155, 93, 176] => 72279
# P [176, 93, 155, 111, 166, 17, 179] => 72279
#  [179, 17, 166, 111, 155, 93, 176] => 72279
# ..................................
# The problem: [71, 84, 84, 95, 137, 184, 195]
# Permutations: total(5040), display(1)
# P [184, 84, 95, 84, 137, 71, 195] => 66496
# P [184, 84, 95, 84, 137, 71, 195] => 66496
# P [195, 71, 137, 84, 95, 84, 184] => 66496
# P [195, 71, 137, 84, 95, 84, 184] => 66496
#  [195, 71, 137, 84, 95, 84, 184] => 66496
# ..................................
# The problem: [35, 36, 40, 77, 84, 98, 190]
# Permutations: total(5040), display(1)
# P [190, 35, 84, 40, 77, 36, 98] => 22330
# P [98, 36, 77, 40, 84, 35, 190] => 22330
#  [190, 35, 84, 40, 77, 36, 98] => 22330
# ..................................
# The problem: [11, 49, 55, 82, 117, 127, 139]
# Permutations: total(5040), display(1)
# P [127, 49, 82, 55, 117, 11, 139] => 24002
# P [139, 11, 117, 55, 82, 49, 127] => 24002
#  [139, 11, 117, 55, 82, 49, 127] => 24002
# ..................................
# The problem: [57, 72, 82, 96, 101, 116, 150]
# Permutations: total(5040), display(1)
# P [116, 72, 96, 82, 101, 57, 150] => 45725
# P [150, 57, 101, 82, 96, 72, 116] => 45725
#  [150, 57, 101, 82, 96, 72, 116] => 45725
# ..................................
# The problem: [7, 82, 84, 126, 133, 162, 184]
# Permutations: total(5040), display(1)
# P [162, 82, 126, 84, 133, 7, 184] => 47591
# P [184, 7, 133, 84, 126, 82, 162] => 47591
#  [184, 7, 133, 84, 126, 82, 162] => 47591
# ..................................
# The problem: [81, 102, 107, 134, 176, 185, 187]
# Permutations: total(5040), display(1)
# P [185, 102, 134, 107, 176, 81, 187] => 95111
# P [187, 81, 176, 107, 134, 102, 185] => 95111
#  [187, 81, 176, 107, 134, 102, 185] => 95111
# ..................................
# The problem: [10, 27, 31, 31, 133, 181, 195]
# Permutations: total(5040), display(1)
# P [195, 10, 133, 31, 31, 27, 181] => 14088
# P [195, 10, 133, 31, 31, 27, 181] => 14088
# P [181, 27, 31, 31, 133, 10, 195] => 14088
# P [181, 27, 31, 31, 133, 10, 195] => 14088
#  [195, 10, 133, 31, 31, 27, 181] => 14088
# ..................................
# The problem: [7, 72, 109, 112, 151, 188, 191]
# Permutations: total(5040), display(1)
# P [188, 72, 112, 109, 151, 7, 191] => 52661
# P [191, 7, 151, 109, 112, 72, 188] => 52661
#  [191, 7, 151, 109, 112, 72, 188] => 52661
# ..................................
# The problem: [11, 15, 103, 105, 110, 157, 174]
# Permutations: total(5040), display(1)
# P [174, 11, 110, 103, 105, 15, 157] => 29199
# P [157, 15, 105, 103, 110, 11, 174] => 29199
#  [174, 11, 110, 103, 105, 15, 157] => 29199
# ..................................
# The problem: [19, 54, 70, 78, 162, 182, 196]
# Permutations: total(5040), display(1)
# P [182, 54, 78, 70, 162, 19, 196] => 37642
# P [196, 19, 162, 70, 78, 54, 182] => 37642
#  [196, 19, 162, 70, 78, 54, 182] => 37642
# ..................................
# The problem: [30, 90, 109, 121, 147, 179, 187]
# Permutations: total(5040), display(1)
# P [187, 30, 147, 109, 121, 90, 179] => 66232
# P [179, 90, 121, 109, 147, 30, 187] => 66232
#  [187, 30, 147, 109, 121, 90, 179] => 66232
# ..................................
# The problem: [9, 10, 100, 135, 166, 186, 193]
# Permutations: total(5040), display(1)
# P [186, 10, 135, 100, 166, 9, 193] => 36541
# P [193, 9, 166, 100, 135, 10, 186] => 36541
#  [193, 9, 166, 100, 135, 10, 186] => 36541
# ..................................
# The problem: [31, 41, 76, 87, 97, 114, 180]
# Permutations: total(5040), display(1)
# ...
#  [198, 17, 161, 35, 149, 64, 56, 150, 19, 165] => 44458
# ..................................
# The problem: [75, 96, 100, 115, 118, 126, 150, 179, 185, 192]
# Permutations: total(3628800), display(1)
# P [185, 96, 150, 115, 118, 126, 100, 179, 75, 192] => 136173
# P [192, 75, 179, 100, 126, 118, 115, 150, 96, 185] => 136173
#  [192, 75, 179, 100, 126, 118, 115, 150, 96, 185] => 136173
# ..................................
# The problem: [15, 17, 23, 38, 84, 88, 96, 134, 158, 169]
# Permutations: total(3628800), display(1)
# P [169, 15, 134, 23, 88, 84, 38, 96, 17, 158] => 28201
# P [158, 17, 96, 38, 84, 88, 23, 134, 15, 169] => 28201
#  [169, 15, 134, 23, 88, 84, 38, 96, 17, 158] => 28201
# ..................................
# The problem: [31, 57, 80, 84, 101, 122, 141, 144, 152, 183]
# Permutations: total(3628800), display(1)
# P [183, 31, 144, 80, 122, 101, 84, 141, 57, 152] => 80768
# P [152, 57, 141, 84, 101, 122, 80, 144, 31, 183] => 80768
#  [183, 31, 144, 80, 122, 101, 84, 141, 57, 152] => 80768
# ..................................
# The problem: [5, 26, 31, 35, 51, 80, 89, 97, 115, 121]
# Permutations: total(3628800), display(1)
# P [121, 5, 97, 31, 80, 51, 35, 89, 26, 115] => 20861
# P [115, 26, 89, 35, 51, 80, 31, 97, 5, 121] => 20861
#  [121, 5, 97, 31, 80, 51, 35, 89, 26, 115] => 20861
# ..................................
# The problem: [38, 54, 75, 125, 128, 152, 169, 174, 180, 183]
# Permutations: total(3628800), display(1)
# P [183, 38, 174, 75, 152, 128, 125, 169, 54, 180] => 113443
# P [180, 54, 169, 125, 128, 152, 75, 174, 38, 183] => 113443
#  [183, 38, 174, 75, 152, 128, 125, 169, 54, 180] => 113443
# ..................................
# The problem: [23, 48, 63, 95, 125, 149, 150, 163, 170, 192]
# Permutations: total(3628800), display(1)
# P [170, 48, 150, 95, 125, 149, 63, 163, 23, 192] => 87931
# P [192, 23, 163, 63, 149, 125, 95, 150, 48, 170] => 87931
#  [192, 23, 163, 63, 149, 125, 95, 150, 48, 170] => 87931
# ..................................
# The problem: [21, 29, 29, 42, 47, 60, 78, 104, 145, 158]
# Permutations: total(3628800), display(1)
# P [158, 21, 104, 29, 78, 42, 47, 60, 29, 145] => 24795
# P [158, 21, 104, 29, 60, 47, 42, 78, 29, 145] => 24795
# P [158, 21, 104, 29, 78, 42, 47, 60, 29, 145] => 24795
# P [158, 21, 104, 29, 60, 47, 42, 78, 29, 145] => 24795
# P [145, 29, 78, 42, 47, 60, 29, 104, 21, 158] => 24795
# P [145, 29, 60, 47, 42, 78, 29, 104, 21, 158] => 24795
# P [145, 29, 78, 42, 47, 60, 29, 104, 21, 158] => 24795
# P [145, 29, 60, 47, 42, 78, 29, 104, 21, 158] => 24795
#  [158, 21, 104, 29, 60, 47, 42, 78, 29, 145] => 24795
# ..................................
# The problem: [23, 42, 58, 63, 69, 77, 110, 134, 180, 182]
# Permutations: total(3628800), display(1)
# P [182, 23, 134, 58, 77, 69, 63, 110, 42, 180] => 48276
# P [180, 42, 110, 63, 69, 77, 58, 134, 23, 182] => 48276
#  [182, 23, 134, 58, 77, 69, 63, 110, 42, 180] => 48276
# ..................................
# The problem: [13, 17, 17, 25, 72, 88, 88, 116, 160, 193]
# Permutations: total(3628800), display(1)
# P [160, 17, 88, 72, 25, 88, 17, 116, 13, 193] => 22037
# P [160, 17, 88, 25, 72, 88, 17, 116, 13, 193] => 22037
# P [160, 17, 88, 72, 25, 88, 17, 116, 13, 193] => 22037
# P [160, 17, 88, 25, 72, 88, 17, 116, 13, 193] => 22037
# P [160, 17, 88, 72, 25, 88, 17, 116, 13, 193] => 22037
# P [160, 17, 88, 25, 72, 88, 17, 116, 13, 193] => 22037
# P [160, 17, 88, 72, 25, 88, 17, 116, 13, 193] => 22037
# P [160, 17, 88, 25, 72, 88, 17, 116, 13, 193] => 22037
# P [193, 13, 116, 17, 88, 72, 25, 88, 17, 160] => 22037
# P [193, 13, 116, 17, 88, 25, 72, 88, 17, 160] => 22037
# P [193, 13, 116, 17, 88, 72, 25, 88, 17, 160] => 22037
# P [193, 13, 116, 17, 88, 25, 72, 88, 17, 160] => 22037
# P [193, 13, 116, 17, 88, 72, 25, 88, 17, 160] => 22037
# P [193, 13, 116, 17, 88, 25, 72, 88, 17, 160] => 22037
# P [193, 13, 116, 17, 88, 72, 25, 88, 17, 160] => 22037
# P [193, 13, 116, 17, 88, 25, 72, 88, 17, 160] => 22037
#  [193, 13, 116, 17, 88, 72, 25, 88, 17, 160] => 22037
# ..................................
# The problem: [13, 32, 119, 151, 164, 164, 170, 182, 188, 193]
# Permutations: total(3628800), display(1)
# P [188, 32, 170, 151, 164, 164, 119, 182, 13, 193] => 134835
# P [188, 32, 170, 151, 164, 164, 119, 182, 13, 193] => 134835
# P [193, 13, 182, 119, 164, 164, 151, 170, 32, 188] => 134835
# P [193, 13, 182, 119, 164, 164, 151, 170, 32, 188] => 134835
#  [193, 13, 182, 119, 164, 164, 151, 170, 32, 188] => 134835
# ..................................
# The problem: [24, 25, 40, 42, 44, 80, 104, 149, 157, 195]
# Permutations: total(3628800), display(1)
# P [195, 24, 149, 40, 80, 44, 42, 104, 25, 157] => 33677
# P [157, 25, 104, 42, 44, 80, 40, 149, 24, 195] => 33677
#  [195, 24, 149, 40, 80, 44, 42, 104, 25, 157] => 33677
# ..................................
# The problem: [32, 47, 71, 78, 92, 99, 159, 179, 182, 187]
# Permutations: total(3628800), display(1)
# P [182, 47, 159, 78, 92, 99, 71, 179, 32, 187] => 76163
# P [187, 32, 179, 71, 99, 92, 78, 159, 47, 182] => 76163
#  [187, 32, 179, 71, 99, 92, 78, 159, 47, 182] => 76163
# ..................................
# The problem: [7, 50, 53, 103, 108, 109, 156, 167, 168, 199]
# Permutations: total(3628800), display(1)
# P [199, 7, 167, 53, 109, 108, 103, 156, 50, 168] => 72354
# P [168, 50, 156, 103, 108, 109, 53, 167, 7, 199] => 72354
#  [199, 7, 167, 53, 109, 108, 103, 156, 50, 168] => 72354
# ..................................
# The problem: [19, 30, 52, 55, 65, 67, 69, 84, 146, 172]
# Permutations: total(3628800), display(1)
# P [172, 19, 84, 52, 67, 65, 55, 69, 30, 146] => 30891
# P [146, 30, 69, 55, 65, 67, 52, 84, 19, 172] => 30891
#  [172, 19, 84, 52, 67, 65, 55, 69, 30, 146] => 30891
# ..................................
# The problem: [7, 60, 101, 117, 134, 144, 155, 162, 168, 172]
# Permutations: total(3628800), display(1)
# P [168, 60, 155, 117, 134, 144, 101, 162, 7, 172] => 105733
# P [172, 7, 162, 101, 144, 134, 117, 155, 60, 168] => 105733
#  [172, 7, 162, 101, 144, 134, 117, 155, 60, 168] => 105733
# ..................................
# The problem: [14, 26, 29, 37, 112, 125, 129, 138, 146, 181]
# Permutations: total(3628800), display(1)
# P [146, 26, 129, 37, 112, 125, 29, 138, 14, 181] => 42160
# P [181, 14, 138, 29, 125, 112, 37, 129, 26, 146] => 42160
#  [181, 14, 138, 29, 125, 112, 37, 129, 26, 146] => 42160
# ..................................
# The problem: [21, 22, 53, 88, 134, 146, 175, 192, 194, 200]
# Permutations: total(3628800), display(1)
# P [200, 21, 192, 53, 146, 134, 88, 175, 22, 194] => 81020
# P [194, 22, 175, 88, 134, 146, 53, 192, 21, 200] => 81020
#  [200, 21, 192, 53, 146, 134, 88, 175, 22, 194] => 81020
# ..................................
# The problem: [8, 18, 19, 99, 138, 147, 147, 147, 164, 188]
# Permutations: total(3628800), display(1)
# P [164, 18, 147, 19, 147, 99, 138, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 138, 99, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 99, 138, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 138, 99, 147, 8, 188] => 62365
# P [164, 18, 147, 99, 138, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 99, 138, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 138, 99, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 138, 99, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 99, 138, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 138, 99, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 99, 138, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 138, 99, 147, 8, 188] => 62365
# P [164, 18, 147, 99, 138, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 99, 138, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 138, 99, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 138, 99, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 99, 138, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 138, 99, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 99, 138, 147, 8, 188] => 62365
# P [164, 18, 147, 19, 147, 138, 99, 147, 8, 188] => 62365
# P [164, 18, 147, 99, 138, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 99, 138, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 138, 99, 147, 19, 147, 8, 188] => 62365
# P [164, 18, 147, 138, 99, 147, 19, 147, 8, 188] => 62365
# P [188, 8, 147, 19, 147, 99, 138, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 138, 99, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 99, 138, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 138, 99, 147, 18, 164] => 62365
# P [188, 8, 147, 99, 138, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 99, 138, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 138, 99, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 138, 99, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 99, 138, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 138, 99, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 99, 138, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 138, 99, 147, 18, 164] => 62365
# P [188, 8, 147, 99, 138, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 99, 138, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 138, 99, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 138, 99, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 99, 138, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 138, 99, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 99, 138, 147, 18, 164] => 62365
# P [188, 8, 147, 19, 147, 138, 99, 147, 18, 164] => 62365
# P [188, 8, 147, 99, 138, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 99, 138, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 138, 99, 147, 19, 147, 18, 164] => 62365
# P [188, 8, 147, 138, 99, 147, 19, 147, 18, 164] => 62365
#  [188, 8, 147, 19, 147, 138, 99, 147, 18, 164] => 62365
# ..................................
# The problem: [16, 27, 53, 53, 92, 106, 140, 143, 173, 195]
# Permutations: total(3628800), display(1)
# P [195, 16, 143, 53, 92, 106, 53, 140, 27, 173] => 49104
# P [195, 16, 143, 53, 106, 92, 53, 140, 27, 173] => 49104
# P [195, 16, 143, 53, 92, 106, 53, 140, 27, 173] => 49104
# P [195, 16, 143, 53, 106, 92, 53, 140, 27, 173] => 49104
# P [173, 27, 140, 53, 92, 106, 53, 143, 16, 195] => 49104
# P [173, 27, 140, 53, 106, 92, 53, 143, 16, 195] => 49104
# P [173, 27, 140, 53, 92, 106, 53, 143, 16, 195] => 49104
# P [173, 27, 140, 53, 106, 92, 53, 143, 16, 195] => 49104
#  [195, 16, 143, 53, 106, 92, 53, 140, 27, 173] => 49104
# ..................................
# The problem: [29, 75, 98, 101, 101, 109, 122, 127, 155, 180]
# Permutations: total(3628800), display(1)
# P [180, 29, 127, 98, 109, 101, 101, 122, 75, 155] => 86338
# P [180, 29, 127, 98, 109, 101, 101, 122, 75, 155] => 86338
# P [155, 75, 122, 101, 101, 109, 98, 127, 29, 180] => 86338
# P [155, 75, 122, 101, 101, 109, 98, 127, 29, 180] => 86338
#  [180, 29, 127, 98, 109, 101, 101, 122, 75, 155] => 86338
# ..................................
# The problem: [9, 18, 52, 56, 66, 100, 124, 136, 146, 173]
# Permutations: total(3628800), display(1)
# P [146, 18, 124, 56, 66, 100, 52, 136, 9, 173] => 37153
# P [173, 9, 136, 52, 100, 66, 56, 124, 18, 146] => 37153
#  [173, 9, 136, 52, 100, 66, 56, 124, 18, 146] => 37153
# ..................................
# The problem: [8, 10, 16, 76, 80, 86, 118, 162, 162, 186]
# Permutations: total(3628800), display(1)
# P [162, 10, 118, 76, 80, 86, 16, 162, 8, 186] => 31480
# P [162, 16, 86, 80, 76, 118, 10, 162, 8, 186] => 31480
# P [162, 10, 118, 76, 80, 86, 16, 162, 8, 186] => 31480
# P [162, 16, 86, 80, 76, 118, 10, 162, 8, 186] => 31480
# P [186, 8, 162, 10, 118, 76, 80, 86, 16, 162] => 31480
# P [186, 8, 162, 16, 86, 80, 76, 118, 10, 162] => 31480
# P [186, 8, 162, 10, 118, 76, 80, 86, 16, 162] => 31480
# P [186, 8, 162, 16, 86, 80, 76, 118, 10, 162] => 31480
#  [186, 8, 162, 16, 86, 80, 76, 118, 10, 162] => 31480
# ..................................
# The problem: [48, 57, 60, 62, 109, 115, 121, 156, 168, 189]
# Permutations: total(3628800), display(1)
# P [168, 57, 121, 62, 109, 115, 60, 156, 48, 189] => 76088
# P [189, 48, 156, 60, 115, 109, 62, 121, 57, 168] => 76088
#  [189, 48, 156, 60, 115, 109, 62, 121, 57, 168] => 76088
# ..................................
# The problem: [30, 47, 69, 78, 96, 114, 137, 140, 150, 199]
# Permutations: total(3628800), display(1)
# P [150, 47, 137, 78, 96, 114, 69, 140, 30, 199] => 70303
# P [199, 30, 140, 69, 114, 96, 78, 137, 47, 150] => 70303
#  [199, 30, 140, 69, 114, 96, 78, 137, 47, 150] => 70303
# ..................................
# The problem: [39, 41, 43, 49, 49, 84, 96, 166, 177, 186]
# Permutations: total(3628800), display(1)
# P [177, 41, 96, 49, 49, 84, 43, 166, 39, 186] => 46892
# P [177, 41, 96, 49, 49, 84, 43, 166, 39, 186] => 46892
# P [186, 39, 166, 43, 84, 49, 49, 96, 41, 177] => 46892
# P [186, 39, 166, 43, 84, 49, 49, 96, 41, 177] => 46892
#  [186, 39, 166, 43, 84, 49, 49, 96, 41, 177] => 46892
# ..................................
# The problem: [15, 17, 40, 60, 78, 79, 142, 148, 182, 188]
# Permutations: total(3628800), display(1)
# P [182, 17, 142, 60, 78, 79, 40, 148, 15, 188] => 38990
# P [188, 15, 148, 40, 79, 78, 60, 142, 17, 182] => 38990
#  [188, 15, 148, 40, 79, 78, 60, 142, 17, 182] => 38990
# ..................................
# The problem: [6, 9, 70, 103, 115, 160, 168, 193, 195, 198]
# Permutations: total(3628800), display(1)
# P [198, 6, 193, 70, 160, 115, 103, 168, 9, 195] => 77872
# P [195, 9, 168, 103, 115, 160, 70, 193, 6, 198] => 77872
#  [198, 6, 193, 70, 160, 115, 103, 168, 9, 195] => 77872
# ..................................
# The problem: [14, 40, 77, 82, 89, 92, 102, 133, 173, 199]
# Permutations: total(3628800), display(1)
# P [199, 14, 133, 77, 92, 89, 82, 102, 40, 173] => 56823
# P [173, 40, 102, 82, 89, 92, 77, 133, 14, 199] => 56823
#  [199, 14, 133, 77, 92, 89, 82, 102, 40, 173] => 56823
# ..................................
# The problem: [11, 48, 52, 67, 139, 146, 158, 166, 169, 178]
# Permutations: total(3628800), display(1)
# P [169, 48, 158, 67, 139, 146, 52, 166, 11, 178] => 75897
# P [178, 11, 166, 52, 146, 139, 67, 158, 48, 169] => 75897
#  [178, 11, 166, 52, 146, 139, 67, 158, 48, 169] => 75897
# ..................................
# The problem: [57, 64, 94, 111, 155, 171, 172, 194, 195, 195]
# Permutations: total(3628800), display(1)
# P [195, 57, 194, 94, 171, 155, 111, 172, 64, 195] => 142773
# P [195, 64, 172, 111, 155, 171, 94, 194, 57, 195] => 142773
# P [195, 57, 194, 94, 171, 155, 111, 172, 64, 195] => 142773
# P [195, 64, 172, 111, 155, 171, 94, 194, 57, 195] => 142773
#  [195, 57, 194, 94, 171, 155, 111, 172, 64, 195] => 142773
# ..................................
# The problem: [8, 9, 23, 35, 43, 85, 112, 115, 118, 123]
# Permutations: total(3628800), display(1)
# P [123, 8, 115, 23, 85, 43, 35, 112, 9, 118] => 17654
# P [118, 9, 112, 35, 43, 85, 23, 115, 8, 123] => 17654
#  [123, 8, 115, 23, 85, 43, 35, 112, 9, 118] => 17654
# ..................................
# The problem: [12, 13, 25, 25, 80, 92, 97, 109, 123, 177]
# Permutations: total(3628800), display(1)
# P [177, 12, 109, 25, 92, 80, 25, 97, 13, 123] => 23102
# P [177, 12, 109, 25, 80, 92, 25, 97, 13, 123] => 23102
# P [177, 12, 109, 25, 92, 80, 25, 97, 13, 123] => 23102
# P [177, 12, 109, 25, 80, 92, 25, 97, 13, 123] => 23102
# P [123, 13, 97, 25, 92, 80, 25, 109, 12, 177] => 23102
# P [123, 13, 97, 25, 80, 92, 25, 109, 12, 177] => 23102
# P [123, 13, 97, 25, 92, 80, 25, 109, 12, 177] => 23102
# P [123, 13, 97, 25, 80, 92, 25, 109, 12, 177] => 23102
#  [177, 12, 109, 25, 92, 80, 25, 97, 13, 123] => 23102
# ..................................
# The problem: [36, 42, 47, 100, 125, 148, 160, 176, 179, 198]
# Permutations: total(3628800), display(1)
# P [179, 42, 160, 100, 125, 148, 47, 176, 36, 198] => 89930
# P [198, 36, 176, 47, 148, 125, 100, 160, 42, 179] => 89930
#  [198, 36, 176, 47, 148, 125, 100, 160, 42, 179] => 89930
# ..................................
# The problem: [17, 26, 42, 54, 91, 156, 162, 176, 194, 199]
# Permutations: total(3628800), display(1)
# P [194, 26, 162, 54, 91, 156, 42, 176, 17, 199] => 57433
# P [199, 17, 176, 42, 156, 91, 54, 162, 26, 194] => 57433
#  [199, 17, 176, 42, 156, 91, 54, 162, 26, 194] => 57433
# ..................................
# The problem: [74, 83, 86, 94, 116, 150, 157, 168, 175, 189]
# Permutations: total(3628800), display(1)
# P [189, 74, 168, 86, 150, 116, 94, 157, 83, 175] => 124384
# P [175, 83, 157, 94, 116, 150, 86, 168, 74, 189] => 124384
#  [189, 74, 168, 86, 150, 116, 94, 157, 83, 175] => 124384
