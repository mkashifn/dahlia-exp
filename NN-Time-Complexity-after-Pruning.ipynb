# %%
# Imports

########################################################################
# Python Standard Libraries
import os
import multiprocessing
from timeit import default_timer as timer
import random
import math

########################################################################
# Numpy Library
import numpy as np # linear algebra

########################################################################
# Pandas Library
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

########################################################################
# MATPLOT Library
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
# %matplotlib inline

########################################################################
# SKLearn Library
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_recall_curve, classification_report, confusion_matrix, average_precision_score, roc_curve, auc, multilabel_confusion_matrix

########################################################################
# SCIPY Library
from scipy.stats import gaussian_kde
import scipy.stats as st


########################################################################
# Keras Library
from keras.models import Sequential
from keras.layers import Dense

########################################################################
# Init random seed
#seed = 13
#np.random.seed(seed)

# %%
# Utility functions
########################################################################
# Print system information
def print_system_info():
    mem_bytes = os.sysconf('SC_PAGE_SIZE') * os.sysconf('SC_PHYS_PAGES')  # e.g. 4015976448
    mem_gib = mem_bytes/(1024.**3)  # e.g. 3.74
    print("{:<23}{:f} GB".format('RAM:', mem_gib))
    print("{:<23}{:d}".format('CORES:', multiprocessing.cpu_count()))
    # !lscpu

########################################################################
# Walk through input files
def print_input_files():
    # Input data files are available in the "../input/" directory.
    for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            print(os.path.join(dirname, filename))

########################################################################
# Dump text files
def dump_text_file(fname):
    with open(fname, 'r') as f:
        print(f.read())

########################################################################
# Dump CSV files
def dump_csv_file(fname, count=5):
    # count: 0 - column names only, -1 - all rows, default = 5 rows max
    df = pd.read_csv(fname)
    if count < 0:
        count = df.shape[0]
    return df.head(count)

########################################################################
# Dataset related functions
ds_nbaiot = '/kaggle/input/nbaiot-dataset'
dn_nbaiot = ['Danmini_Doorbell', 'Ecobee_Thermostat', 'Ennio_Doorbell', 'Philips_B120N10_Baby_Monitor', 'Provision_PT_737E_Security_Camera', 'Provision_PT_838_Security_Camera', 'Samsung_SNH_1011_N_Webcam', 'SimpleHome_XCS7_1002_WHT_Security_Camera', 'SimpleHome_XCS7_1003_WHT_Security_Camera']

def fname(ds, f):
    if '.csv' not in f:
        f = f'{f}.csv'
    return os.path.join(ds, f)

def fname_nbaiot(f):
    return fname(ds_nbaiot, f)

def get_nbaiot_device_files():
    nbaiot_all_files = dump_csv_file(fname_nbaiot('data_summary'), -1)
    nbaiot_all_files = nbaiot_all_files.iloc[:,0:1].values
    device_id = 1
    indices = []
    for j in range(len(nbaiot_all_files)):
        if str(device_id) not in str(nbaiot_all_files[j]):
            indices.append(j)
            device_id += 1
    nbaiot_device_files = np.split(nbaiot_all_files, indices)
    return nbaiot_device_files

def get_nbaiot_device_data(device_id, count_norm=-1, count_anom=-1):
    if device_id < 1 or device_id > 9:
        assert False, "Please provide a valid device ID 1-9, both inclusive"
    if count_anom == -1:
        count_anom = count_norm
    device_index = device_id -1
    device_files = get_nbaiot_device_files()
    device_file = device_files[device_index]
    df = pd.DataFrame()
    y = []
    for i in range(len(device_file)):
        fname = str(device_file[i][0])
        df_c = pd.read_csv(fname_nbaiot(fname))
        count = count_anom
        if 'benign' in fname:
            count = count_norm
        count = min(count, df_c.shape[0]) if count >=0 else df_c.shape[0]
        rows = count
        print("processing", fname, "rows =", rows)
        y_np = np.ones(rows) if 'benign' in fname else np.zeros(rows)
        y.extend(y_np.tolist())
        df = pd.concat([df.iloc[:,:].reset_index(drop=True),
                      df_c.iloc[:rows,:].reset_index(drop=True)], axis=0)
    X = df.iloc[:,:].values
    y = np.array(y)
    Xdf = df
    return (X, y, Xdf)

def get_nbaiot_devices_data():
    devices_data = []
    for i in range(9):
        device_id = i + 1
        (X, y) = get_nbaiot_device_data(device_id)
        devices_data.append((X, y))
    return devices_data
#print_input_files()
print_system_info()
# Out:
# RAM:                   18.571419 GB
# CORES:                 4
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              4
# On-line CPU(s) list: 0-3
# Thread(s) per core:  2
# Core(s) per socket:  2
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               85
# Model name:          Intel(R) Xeon(R) CPU @ 2.00GHz
# Stepping:            3
# CPU MHz:             2000.170
# BogoMIPS:            4000.34
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            1024K
# L3 cache:            39424K
# NUMA node0 CPU(s):   0-3
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities

# %%
def remove_correlated_features(df, threshold):
    df = df.copy()
    # Create correlation matrix
    corr_matrix = df.corr().abs()

    # Select upper triangle of correlation matrix
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

    # Find features with correlation greater than a threshold
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

    # Drop features 
    df.drop(to_drop, axis=1, inplace=True)
    return df.iloc[:,:].values

def mark_important_features(vector, pc_keep): # pc_keep is the percentage (0-100) of labels to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    important_bool = (vector >= th)
    important_int = important_bool.astype(int)
    return important_int

def select_features(X, X_norm, X_anom, threshold):
    rows_n = X_norm.shape[0]
    rows_a = X_anom.shape[0]
    if rows_n == 0 or rows_a == 0:
        return X

    y_norm = np.ones(rows_n)
    y_anom = -1 * np.ones(rows_a)

    reg_n = LinearRegression(fit_intercept=False)
    reg_n.fit(X_norm, y_norm)
    coef_n = abs(reg_n.coef_)
    n = mark_important_features(coef_n, threshold)

    reg_a = LinearRegression(fit_intercept=False)
    reg_a.fit(X_anom, y_anom)
    coef_a = abs(reg_a.coef_)
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel

# %%
def create_binary_classifier(hidden_layers, input_dim):
    layers = []
    for hl in hidden_layers:
        if hl > 0:
            layers.append(hl)

    layer_count = len(layers)
    assert layer_count >= 1, 'at least 1 non-zero hidden layer is needed'
    model = Sequential()
    model.add(Dense(layers[0],input_dim=input_dim,activation='relu'))
    for i in range(1, layer_count):
        model.add(Dense(layers[i],activation='relu'))

    model.add(Dense(1,activation='sigmoid'))
    #model.summary()
    model.compile(loss = 'binary_crossentropy',
             optimizer ='adam',metrics=['accuracy'])
    return model

# %%
def compute_time_complexity_single_pass(neurons_input, structure, neurons_output):
    count_hidden_layers = len(structure)
    neurons = [neurons_input, *structure, neurons_output]
    complexity = 0
    for i in range(count_hidden_layers + 1):
        complexity += neurons[i] * neurons[i+1]
    return complexity

# %%
def keep_mask(vector, pc_keep): # pc_keep is the percentage (0-100) of items to keep
    th = np.percentile(vector,(100-pc_keep)) # threshold, calculate percentile (100 - percentage) from percentage
    mask_bool = (vector >= th)
    mask_int = mask_bool.astype(int)
    return (mask_bool, mask_int)

# %%
'''
    a = mark_important_features(coef_a, threshold)
   
    mask = np.bitwise_or(n,a)
    mask = mask == 1 # convert to Boolean
    X_sel = X[:, mask]
    return X_sel
'''
# Out:
# '\n    a = mark_important_features(coef_a, threshold)\n   \n    mask = np.bitwise_or(n,a)\n    mask = mask == 1 # convert to Boolean\n    X_sel = X[:, mask]\n    return X_sel\n'

# %%
def analyze_ranks(model, threshold):
    w_d = 0
    b_d = 0
    layer_count = len(model.layers)
    layer_ranks = []
    new_structure = []
    for i in range(layer_count-1):
        (w_c, b_c) = model.layers[i+1].get_weights() # current weigths and biases
        rows = w_c.shape[0]
        cols = w_c.shape[1]
        w_c_abs = np.absolute(w_c)
        rank_neurons = np.sum(w_c_abs, axis=1) / cols
        rank_layer = np.sum(rank_neurons) / rows
        layer_ranks.append(rank_layer)
        (mask_bool, mask_int) = keep_mask(rank_neurons, threshold)
        new_neuron_count = np.sum(mask_int)
        new_structure.append(new_neuron_count)
        #print(f'{i+1}: {rank_neurons.shape} {rank_layer} {mask_int} {new_neuron_count}')
    layer_ranks = np.array(layer_ranks)
    new_structure = np.array(new_structure)
    (mask_bool, mask_int) = keep_mask(layer_ranks, threshold)
    new_structure = new_structure[mask_bool]
    #new_structure_masked = new_structure
    #print(f'layer mask: {mask_int} {new_structure}')
    return new_structure

# %%
model = None
def compute_report(title, model, X, y):
    y_pred = model.predict(X)
    y_pred = (y_pred > 0.25)
    #print(y_pred)
    #y_pred[y_pred <= 0] = -1 # convert negative values as 0 for anomaly
    #y_pred[y_pred > 0] = 1 # convert positive values as 1 for normal
    acc = accuracy_score(y, y_pred)
    tn, fp, fn, tp = confusion_matrix(y, y_pred, labels=[0,1]).ravel()
    cr = classification_report(y, y_pred)
    print("title,acc,tn,fp,fn,tp")
    print(f'{title}-cm,{acc:.2f},{tn},{fp},{fn},{tp}')
    #print(f'{cr}')
    results = model.evaluate(X, y, verbose=0)
    print(f'{title}-eval,{results}')
    return results[1] # accuracy

def rank_computation(title, X, y, structure, fc):
    global model
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
    print (f"========{title}========")
    feature_count = X.shape[1]
    print(f'Features={feature_count}')
    print(f'NN Structure: layers={len(structure)}, neurons: {structure}')
    complexity = compute_time_complexity_single_pass(fc, structure, 1)
    print(f'complexity: {complexity}')
    model = create_binary_classifier(structure, feature_count)
    model.fit(X_train,y_train,epochs=150,batch_size=10,verbose=0)
    #analyze_ranks(model, 95)
    acc_t = compute_report('training', model, X_train, y_train)
    acc_v = compute_report('validation', model, X_test, y_test)
    return (complexity, acc_t, acc_v)

# %%
output_title = ''
output_cplx_all_devices = []  # time complexity
output_acc_t_all_devices = [] # training accuracy
output_acc_v_all_devices = [] # validation accuracy

# %%
debug_flag = True

# %%
if debug_flag:
    count_norm = 1000
    count_anom = 100
    device_indices = [0]
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]
else:
    count_norm = -1
    count_anom = -1
    device_indices = [0, 1, 2, 3, 4, 5, 6, 7, 8]

structures = {
    '0': [97, 48, 73, 58, 64, 53, 83],
    '1': [88, 52, 66, 58, 75],
    '2': [57, 31, 43, 38, 34, 49],
    '3': [101, 46, 67, 55, 60, 50, 75],
    '4': [87, 43, 58, 52, 47, 75],
    '5': [88, 44, 58, 52, 48, 75],
    '6': [59, 32, 44, 39, 35, 50],
    '7': [76, 48, 59, 53, 67],
    '8': [88, 48, 59, 53, 76]
}

fcs = [47, 47, 59, 51, 40, 42, 56, 56, 56]
for i in device_indices:
    global output_title
    device_index = i
    device_id = device_index + 1
    device_name = dn_nbaiot[device_index]
    (X, y, Xdf) = get_nbaiot_device_data(device_id, count_norm, count_anom)
    X = remove_correlated_features(Xdf, 0.98)
    X_std = StandardScaler().fit_transform(X)
    indices_norm = np.where(y >= 0.5)
    indices_anom = np.where(y <= 0.5)
    X_norm_all = X_std[indices_norm]
    X_anom_all = X_std[indices_anom]
    X_std = select_features(X_std, X_norm_all, X_anom_all,75)
    fc = fcs[i]
    print(f'############################[{i+1} - {device_name}]##########################')
    (complexity, acc_t, acc_v) = rank_computation(device_name, X_std, y, structures.get(f'{i}'), fc)
    thresholds = [100, 99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88, 87, 86, 85]
    output_title = 'device_name'
    output_cplx = f'{device_name}'
    output_acc_t = f'{device_name}'
    output_acc_v = f'{device_name}'
    main_model = [model]
    main_model = main_model[0]
    for th_i in range(16):
        threshold = 100 - th_i
        #main_model = model
        output_title = f'{output_title},{threshold}'
        new_structure = analyze_ranks(main_model, threshold)
        new_complexity = compute_time_complexity_single_pass(fc, new_structure, 1)
        print(f'Th={threshold}, Revised NN Structure: layers={len(new_structure)}, neurons: {new_structure}, complexity: {new_complexity}')
# Out:
# processing 1.benign.csv rows = 1000
# processing 1.gafgyt.combo.csv rows = 100
# processing 1.gafgyt.junk.csv rows = 100
# processing 1.gafgyt.scan.csv rows = 100
# processing 1.gafgyt.tcp.csv rows = 100
# processing 1.gafgyt.udp.csv rows = 100
# processing 1.mirai.ack.csv rows = 100
# processing 1.mirai.scan.csv rows = 100
# processing 1.mirai.syn.csv rows = 100
# processing 1.mirai.udp.csv rows = 100
# processing 1.mirai.udpplain.csv rows = 100
# ############################[1 - Danmini_Doorbell]##########################
# ========Danmini_Doorbell========
# Features=43
# NN Structure: layers=7, neurons: [97, 48, 73, 58, 64, 53, 83]
# complexity: 28539
# title,acc,tn,fp,fn,tp
# training-cm,0.99,670,8,3,659
# training-eval,[0.013391876593232155, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,320,2,5,333
# validation-eval,[0.029692387208342552, 0.9909090995788574]
# Th=100, Revised NN Structure: layers=7, neurons: [97 48 73 58 64 53 83], complexity: 28539
# Th=99, Revised NN Structure: layers=6, neurons: [96 47 72 57 63 52], complexity: 23431
# Th=98, Revised NN Structure: layers=6, neurons: [95 47 71 56 62 51], complexity: 22928
# Th=97, Revised NN Structure: layers=6, neurons: [94 46 70 56 62 51], complexity: 22567
# Th=96, Revised NN Structure: layers=6, neurons: [93 46 70 55 61 50], complexity: 22174
# Th=95, Revised NN Structure: layers=6, neurons: [92 45 69 55 60 50], complexity: 21714
# Th=94, Revised NN Structure: layers=6, neurons: [91 45 68 54 60 49], complexity: 21333
# Th=93, Revised NN Structure: layers=6, neurons: [90 44 67 54 59 49], complexity: 20882
# Th=92, Revised NN Structure: layers=6, neurons: [89 44 67 53 58 48], complexity: 20504
# Th=91, Revised NN Structure: layers=6, neurons: [88 43 66 52 58 48], complexity: 20038
# Th=90, Revised NN Structure: layers=6, neurons: [87 43 65 52 57 47], complexity: 19695
# Th=89, Revised NN Structure: layers=6, neurons: [86 42 65 51 57 47], complexity: 19332
# Th=88, Revised NN Structure: layers=6, neurons: [85 42 64 51 56 46], complexity: 18995
# Th=87, Revised NN Structure: layers=6, neurons: [84 41 63 50 55 46], complexity: 18451
# Th=86, Revised NN Structure: layers=6, neurons: [83 41 62 50 55 45], complexity: 18216
# Th=85, Revised NN Structure: layers=6, neurons: [82 40 62 49 54 45], complexity: 17773
# processing 2.benign.csv rows = 1000
# processing 2.gafgyt.combo.csv rows = 100
# processing 2.gafgyt.junk.csv rows = 100
# processing 2.gafgyt.scan.csv rows = 100
# processing 2.gafgyt.tcp.csv rows = 100
# processing 2.gafgyt.udp.csv rows = 100
# processing 2.mirai.ack.csv rows = 100
# processing 2.mirai.scan.csv rows = 100
# processing 2.mirai.syn.csv rows = 100
# processing 2.mirai.udp.csv rows = 100
# processing 2.mirai.udpplain.csv rows = 100
# ############################[2 - Ecobee_Thermostat]##########################
# ========Ecobee_Thermostat========
# Features=53
# NN Structure: layers=5, neurons: [88, 52, 66, 58, 75]
# complexity: 20397
# title,acc,tn,fp,fn,tp
# training-cm,0.99,669,0,7,664
# training-eval,[0.02157609723508358, 0.9947761297225952]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,331,0,3,326
# validation-eval,[0.028943097218871117, 0.9954545497894287]
# Th=100, Revised NN Structure: layers=5, neurons: [88 52 66 58 75], complexity: 20397
# Th=99, Revised NN Structure: layers=4, neurons: [87 51 65 57], complexity: 15603
# Th=98, Revised NN Structure: layers=4, neurons: [86 50 64 56], complexity: 15182
# Th=97, Revised NN Structure: layers=4, neurons: [85 50 64 56], complexity: 15085
# Th=96, Revised NN Structure: layers=4, neurons: [84 49 63 55], complexity: 14671
# Th=95, Revised NN Structure: layers=4, neurons: [83 49 62 55], complexity: 14471
# Th=94, Revised NN Structure: layers=4, neurons: [82 48 62 54], complexity: 14168
# Th=93, Revised NN Structure: layers=4, neurons: [81 48 61 54], complexity: 13971
# Th=92, Revised NN Structure: layers=4, neurons: [81 47 60 53], complexity: 13667
# Th=91, Revised NN Structure: layers=4, neurons: [80 47 60 52], complexity: 13512
# Th=90, Revised NN Structure: layers=4, neurons: [79 46 59 52], complexity: 13181
# Th=89, Revised NN Structure: layers=4, neurons: [78 46 58 51], complexity: 12931
# Th=88, Revised NN Structure: layers=4, neurons: [77 45 58 51], complexity: 12703
# Th=87, Revised NN Structure: layers=4, neurons: [76 45 57 50], complexity: 12457
# Th=86, Revised NN Structure: layers=4, neurons: [75 44 56 50], complexity: 12139
# Th=85, Revised NN Structure: layers=4, neurons: [74 44 56 49], complexity: 11991
# processing 3.benign.csv rows = 1000
# processing 3.gafgyt.combo.csv rows = 100
# processing 3.gafgyt.junk.csv rows = 100
# processing 3.gafgyt.scan.csv rows = 100
# processing 3.gafgyt.tcp.csv rows = 100
# processing 3.gafgyt.udp.csv rows = 100
# ############################[3 - Ennio_Doorbell]##########################
# ========Ennio_Doorbell========
# Features=53
# NN Structure: layers=6, neurons: [57, 31, 43, 38, 34, 49]
# complexity: 11104
# title,acc,tn,fp,fn,tp
# training-cm,1.00,348,0,0,657
# training-eval,[6.877988401043922e-09, 1.0]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,152,0,4,339
# validation-eval,[0.12058869749307632, 0.991919219493866]
# Th=100, Revised NN Structure: layers=6, neurons: [57 31 43 38 34 49], complexity: 11104
# Th=99, Revised NN Structure: layers=5, neurons: [30 42 37 33 48], complexity: 7437
# Th=98, Revised NN Structure: layers=5, neurons: [30 42 37 33 48], complexity: 7437
# Th=97, Revised NN Structure: layers=5, neurons: [30 41 36 33 47], complexity: 7262
# Th=96, Revised NN Structure: layers=5, neurons: [29 41 36 32 47], complexity: 7079
# Th=95, Revised NN Structure: layers=5, neurons: [29 40 36 32 46], complexity: 6981
# Th=94, Revised NN Structure: layers=5, neurons: [29 40 35 32 46], complexity: 6909
# Th=93, Revised NN Structure: layers=5, neurons: [28 40 35 31 45], complexity: 6697
# Th=92, Revised NN Structure: layers=5, neurons: [28 39 35 31 45], complexity: 6634
# Th=91, Revised NN Structure: layers=5, neurons: [28 39 34 31 44], complexity: 6532
# Th=90, Revised NN Structure: layers=5, neurons: [28 38 34 30 44], complexity: 6392
# Th=89, Revised NN Structure: layers=5, neurons: [27 38 33 30 43], complexity: 6196
# Th=88, Revised NN Structure: layers=5, neurons: [27 37 33 30 43], complexity: 6136
# Th=87, Revised NN Structure: layers=5, neurons: [27 37 33 29 42], complexity: 6030
# Th=86, Revised NN Structure: layers=5, neurons: [26 37 32 29 42], complexity: 5868
# Th=85, Revised NN Structure: layers=5, neurons: [26 36 32 29 41], complexity: 5780
# processing 4.benign.csv rows = 1000
# processing 4.gafgyt.combo.csv rows = 100
# processing 4.gafgyt.junk.csv rows = 100
# processing 4.gafgyt.scan.csv rows = 100
# processing 4.gafgyt.tcp.csv rows = 100
# processing 4.gafgyt.udp.csv rows = 100
# processing 4.mirai.ack.csv rows = 100
# processing 4.mirai.scan.csv rows = 100
# processing 4.mirai.syn.csv rows = 100
# processing 4.mirai.udp.csv rows = 100
# processing 4.mirai.udpplain.csv rows = 100
# ############################[4 - Philips_B120N10_Baby_Monitor]##########################
# ========Philips_B120N10_Baby_Monitor========
# Features=54
# NN Structure: layers=7, neurons: [101, 46, 67, 55, 60, 50, 75]
# complexity: 26689
# title,acc,tn,fp,fn,tp
# training-cm,1.00,675,1,4,660
# training-eval,[0.016151316463947296, 0.9955223798751831]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,320,4,2,334
# validation-eval,[0.020576387643814087, 0.9939393997192383]
# Th=100, Revised NN Structure: layers=7, neurons: [101  46  67  55  60  50  75], complexity: 26689
# Th=99, Revised NN Structure: layers=6, neurons: [100  45  66  54  59  49], complexity: 22260
# Th=98, Revised NN Structure: layers=6, neurons: [99 45 65 53 58 49], complexity: 21839
# Th=97, Revised NN Structure: layers=6, neurons: [98 44 65 53 58 48], complexity: 21521
# Th=96, Revised NN Structure: layers=6, neurons: [97 44 64 52 57 48], complexity: 21107
# Th=95, Revised NN Structure: layers=6, neurons: [96 43 63 52 57 47], complexity: 20699
# Th=94, Revised NN Structure: layers=6, neurons: [95 43 63 51 56 47], complexity: 20387
# Th=93, Revised NN Structure: layers=6, neurons: [94 42 62 51 55 46], complexity: 19889
# Th=92, Revised NN Structure: layers=6, neurons: [93 42 61 50 55 46], complexity: 19587
# Th=91, Revised NN Structure: layers=6, neurons: [92 41 61 50 54 45], complexity: 19190
# Th=90, Revised NN Structure: layers=6, neurons: [91 41 60 49 54 45], complexity: 18893
# Th=89, Revised NN Structure: layers=6, neurons: [90 41 59 49 53 44], complexity: 18563
# Th=88, Revised NN Structure: layers=6, neurons: [89 40 59 48 52 44], complexity: 18119
# Th=87, Revised NN Structure: layers=6, neurons: [88 40 58 47 52 43], complexity: 17777
# Th=86, Revised NN Structure: layers=6, neurons: [87 39 57 47 51 43], complexity: 17365
# Th=85, Revised NN Structure: layers=6, neurons: [86 39 57 46 51 42], complexity: 17115
# processing 5.benign.csv rows = 1000
# processing 5.gafgyt.combo.csv rows = 100
# processing 5.gafgyt.junk.csv rows = 100
# processing 5.gafgyt.scan.csv rows = 100
# processing 5.gafgyt.tcp.csv rows = 100
# processing 5.gafgyt.udp.csv rows = 100
# processing 5.mirai.ack.csv rows = 100
# processing 5.mirai.scan.csv rows = 100
# processing 5.mirai.syn.csv rows = 100
# processing 5.mirai.udp.csv rows = 100
# processing 5.mirai.udpplain.csv rows = 100
# ############################[5 - Provision_PT_737E_Security_Camera]##########################
# ========Provision_PT_737E_Security_Camera========
# Features=37
# NN Structure: layers=6, neurons: [87, 43, 58, 52, 47, 75]
# complexity: 18775
# title,acc,tn,fp,fn,tp
# training-cm,0.99,683,0,9,648
# training-eval,[0.025529948994517326, 0.9932835698127747]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,316,1,5,338
# validation-eval,[0.047368958592414856, 0.9909090995788574]
# Th=100, Revised NN Structure: layers=6, neurons: [87 43 58 52 47 75], complexity: 18775
# Th=99, Revised NN Structure: layers=5, neurons: [86 42 57 51 46], complexity: 14745
# Th=98, Revised NN Structure: layers=5, neurons: [85 42 56 50 46], complexity: 14468
# Th=97, Revised NN Structure: layers=5, neurons: [84 41 56 50 45], complexity: 14195
# Th=96, Revised NN Structure: layers=5, neurons: [83 41 55 49 45], complexity: 13923
# Th=95, Revised NN Structure: layers=5, neurons: [82 40 55 49 44], complexity: 13655
# Th=94, Revised NN Structure: layers=5, neurons: [81 40 54 48 44], complexity: 13388
# Th=93, Revised NN Structure: layers=5, neurons: [80 40 54 48 43], complexity: 13259
# Th=92, Revised NN Structure: layers=5, neurons: [80 39 53 47 43], complexity: 12942
# Th=91, Revised NN Structure: layers=5, neurons: [79 39 52 47 42], complexity: 12729
# Th=90, Revised NN Structure: layers=5, neurons: [78 38 52 46 42], complexity: 12426
# Th=89, Revised NN Structure: layers=5, neurons: [77 38 51 46 41], complexity: 12217
# Th=88, Revised NN Structure: layers=5, neurons: [76 37 51 45 41], complexity: 11920
# Th=87, Revised NN Structure: layers=5, neurons: [75 37 50 45 41], complexity: 11761
# Th=86, Revised NN Structure: layers=5, neurons: [74 37 50 44 40], complexity: 11548
# Th=85, Revised NN Structure: layers=5, neurons: [74 36 49 44 40], complexity: 11344
# processing 6.benign.csv rows = 1000
# processing 6.gafgyt.combo.csv rows = 100
# processing 6.gafgyt.junk.csv rows = 100
# processing 6.gafgyt.scan.csv rows = 100
# processing 6.gafgyt.tcp.csv rows = 100
# processing 6.gafgyt.udp.csv rows = 100
# processing 6.mirai.ack.csv rows = 100
# processing 6.mirai.scan.csv rows = 100
# processing 6.mirai.syn.csv rows = 100
# processing 6.mirai.udp.csv rows = 100
# processing 6.mirai.udpplain.csv rows = 100
# ############################[6 - Provision_PT_838_Security_Camera]##########################
# ========Provision_PT_838_Security_Camera========
# Features=42
# NN Structure: layers=6, neurons: [88, 44, 58, 52, 48, 75]
# complexity: 19307
# title,acc,tn,fp,fn,tp
# training-cm,1.00,668,0,3,669
# training-eval,[0.01236244197934866, 0.9977611899375916]
# title,acc,tn,fp,fn,tp
# validation-cm,0.98,328,4,7,321
# validation-eval,[0.15509836375713348, 0.9833333492279053]
# Th=100, Revised NN Structure: layers=6, neurons: [88 44 58 52 48 75], complexity: 19307
# Th=99, Revised NN Structure: layers=5, neurons: [87 43 57 51 47], complexity: 15197
# Th=98, Revised NN Structure: layers=5, neurons: [86 43 56 50 47], complexity: 14915
# Th=97, Revised NN Structure: layers=5, neurons: [85 42 56 50 46], complexity: 14638
# Th=96, Revised NN Structure: layers=5, neurons: [84 42 55 49 46], complexity: 14361
# Th=95, Revised NN Structure: layers=5, neurons: [83 41 55 49 45], complexity: 14089
# Th=94, Revised NN Structure: layers=5, neurons: [82 41 54 48 45], complexity: 13817
# Th=93, Revised NN Structure: layers=5, neurons: [81 40 54 48 44], complexity: 13550
# Th=92, Revised NN Structure: layers=5, neurons: [81 40 53 47 44], complexity: 13365
# Th=91, Revised NN Structure: layers=5, neurons: [80 40 52 47 43], complexity: 13148
# Th=90, Revised NN Structure: layers=5, neurons: [79 39 52 46 43], complexity: 12840
# Th=89, Revised NN Structure: layers=5, neurons: [78 39 51 46 42], complexity: 12627
# Th=88, Revised NN Structure: layers=5, neurons: [77 38 51 45 42], complexity: 12325
# Th=87, Revised NN Structure: layers=5, neurons: [76 38 50 45 41], complexity: 12116
# Th=86, Revised NN Structure: layers=5, neurons: [75 37 50 44 41], complexity: 11820
# Th=85, Revised NN Structure: layers=5, neurons: [74 37 49 44 40], complexity: 11615
# processing 7.benign.csv rows = 1000
# processing 7.gafgyt.combo.csv rows = 100
# processing 7.gafgyt.junk.csv rows = 100
# processing 7.gafgyt.scan.csv rows = 100
# processing 7.gafgyt.tcp.csv rows = 100
# processing 7.gafgyt.udp.csv rows = 100
# ############################[7 - Samsung_SNH_1011_N_Webcam]##########################
# ========Samsung_SNH_1011_N_Webcam========
# Features=49
# NN Structure: layers=6, neurons: [59, 32, 44, 39, 35, 50]
# complexity: 11481
# title,acc,tn,fp,fn,tp
# training-cm,1.00,328,0,2,675
# training-eval,[0.012930143624544144, 0.998009979724884]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,172,0,4,319
# validation-eval,[0.027959080412983894, 0.9898989796638489]
# Th=100, Revised NN Structure: layers=6, neurons: [59 32 44 39 35 50], complexity: 11481
# Th=99, Revised NN Structure: layers=5, neurons: [58 31 43 38 34], complexity: 9339
# Th=98, Revised NN Structure: layers=5, neurons: [57 31 43 38 34], complexity: 9252
# Th=97, Revised NN Structure: layers=5, neurons: [57 31 42 37 33], complexity: 9069
# Th=96, Revised NN Structure: layers=5, neurons: [56 30 42 37 33], complexity: 8884
# Th=95, Revised NN Structure: layers=5, neurons: [56 30 41 37 33], complexity: 8817
# Th=94, Revised NN Structure: layers=5, neurons: [55 30 41 36 32], complexity: 8620
# Th=93, Revised NN Structure: layers=5, neurons: [54 29 40 36 32], complexity: 8374
# Th=92, Revised NN Structure: layers=5, neurons: [54 29 40 35 32], complexity: 8302
# Th=91, Revised NN Structure: layers=5, neurons: [53 29 40 35 31], complexity: 8181
# Th=90, Revised NN Structure: layers=5, neurons: [53 28 39 35 31], complexity: 8025
# Th=89, Revised NN Structure: layers=5, neurons: [52 28 39 34 31], complexity: 7871
# Th=88, Revised NN Structure: layers=5, neurons: [52 28 38 34 30], complexity: 7774
# Th=87, Revised NN Structure: layers=5, neurons: [51 27 38 34 30], complexity: 7601
# Th=86, Revised NN Structure: layers=5, neurons: [50 27 37 33 30], complexity: 7390
# Th=85, Revised NN Structure: layers=5, neurons: [50 27 37 33 29], complexity: 7356
# processing 8.benign.csv rows = 1000
# processing 8.gafgyt.combo.csv rows = 100
# processing 8.gafgyt.junk.csv rows = 100
# processing 8.gafgyt.scan.csv rows = 100
# processing 8.gafgyt.tcp.csv rows = 100
# processing 8.gafgyt.udp.csv rows = 100
# processing 8.mirai.ack.csv rows = 100
# processing 8.mirai.scan.csv rows = 100
# processing 8.mirai.syn.csv rows = 100
# processing 8.mirai.udp.csv rows = 100
# processing 8.mirai.udpplain.csv rows = 100
# ############################[8 - SimpleHome_XCS7_1002_WHT_Security_Camera]##########################
# ========SimpleHome_XCS7_1002_WHT_Security_Camera========
# Features=51
# NN Structure: layers=5, neurons: [76, 48, 59, 53, 67]
# complexity: 17481
# title,acc,tn,fp,fn,tp
# training-cm,0.99,667,1,8,664
# training-eval,[0.01342098880559206, 0.9940298795700073]
# title,acc,tn,fp,fn,tp
# validation-cm,0.99,330,2,5,323
# validation-eval,[0.10990376025438309, 0.9924242496490479]
# Th=100, Revised NN Structure: layers=5, neurons: [76 48 59 53 67], complexity: 17481
# Th=99, Revised NN Structure: layers=4, neurons: [47 58 52 66], complexity: 11872
# Th=98, Revised NN Structure: layers=4, neurons: [47 57 51 65], complexity: 11598
# Th=97, Revised NN Structure: layers=4, neurons: [46 57 51 65], complexity: 11485
# Th=96, Revised NN Structure: layers=4, neurons: [46 56 50 64], complexity: 11216
# Th=95, Revised NN Structure: layers=4, neurons: [45 56 50 63], complexity: 11053
# Th=94, Revised NN Structure: layers=4, neurons: [45 55 49 63], complexity: 10840
# Th=93, Revised NN Structure: layers=4, neurons: [44 54 49 62], complexity: 10586
# Th=92, Revised NN Structure: layers=4, neurons: [44 54 48 61], complexity: 10421
# Th=91, Revised NN Structure: layers=4, neurons: [43 53 48 61], complexity: 10220
# Th=90, Revised NN Structure: layers=4, neurons: [43 53 47 60], complexity: 10058
# Th=89, Revised NN Structure: layers=4, neurons: [42 52 47 59], complexity: 9812
# Th=88, Revised NN Structure: layers=4, neurons: [42 52 46 59], complexity: 9701
# Th=87, Revised NN Structure: layers=4, neurons: [41 51 46 58], complexity: 9459
# Th=86, Revised NN Structure: layers=4, neurons: [41 50 45 57], complexity: 9218
# Th=85, Revised NN Structure: layers=4, neurons: [40 50 45 57], complexity: 9112
# processing 9.benign.csv rows = 1000
# processing 9.gafgyt.combo.csv rows = 100
# processing 9.gafgyt.junk.csv rows = 100
# processing 9.gafgyt.scan.csv rows = 100
# processing 9.gafgyt.tcp.csv rows = 100
# processing 9.gafgyt.udp.csv rows = 100
# processing 9.mirai.ack.csv rows = 100
# processing 9.mirai.scan.csv rows = 100
# processing 9.mirai.syn.csv rows = 100
# processing 9.mirai.udp.csv rows = 100
# processing 9.mirai.udpplain.csv rows = 100
# ############################[9 - SimpleHome_XCS7_1003_WHT_Security_Camera]##########################
# ========SimpleHome_XCS7_1003_WHT_Security_Camera========
# Features=44
# NN Structure: layers=5, neurons: [88, 48, 59, 53, 76]
# complexity: 19215
# title,acc,tn,fp,fn,tp
# training-cm,1.00,679,0,4,657
# training-eval,[0.014064565300941467, 0.9970149397850037]
# title,acc,tn,fp,fn,tp
# validation-cm,1.00,321,0,0,339
# validation-eval,[0.0042234924621880054, 1.0]
# Th=100, Revised NN Structure: layers=5, neurons: [88 48 59 53 76], complexity: 19215
# Th=99, Revised NN Structure: layers=4, neurons: [87 47 58 75], complexity: 16112
# Th=98, Revised NN Structure: layers=4, neurons: [86 47 57 74], complexity: 15829
# Th=97, Revised NN Structure: layers=4, neurons: [85 46 57 73], complexity: 15526
# Th=96, Revised NN Structure: layers=4, neurons: [84 46 56 73], complexity: 15305
# Th=95, Revised NN Structure: layers=4, neurons: [83 45 56 72], complexity: 15007
# Th=94, Revised NN Structure: layers=4, neurons: [82 45 55 71], complexity: 14733
# Th=93, Revised NN Structure: layers=4, neurons: [81 44 54 70], complexity: 14326
# Th=92, Revised NN Structure: layers=4, neurons: [81 44 54 70], complexity: 14326
# Th=91, Revised NN Structure: layers=4, neurons: [80 43 53 69], complexity: 13925
# Th=90, Revised NN Structure: layers=4, neurons: [79 43 53 68], complexity: 13772
# Th=89, Revised NN Structure: layers=4, neurons: [78 42 52 67], complexity: 13379
# Th=88, Revised NN Structure: layers=4, neurons: [77 42 52 67], complexity: 13281
# Th=87, Revised NN Structure: layers=4, neurons: [76 41 51 66], complexity: 12895
# Th=86, Revised NN Structure: layers=4, neurons: [75 41 50 65], complexity: 12640
# Th=85, Revised NN Structure: layers=4, neurons: [74 40 50 64], complexity: 12368
